# %% [markdown]
# # Compare Frequency (XUE3M) with Mini Batching
#
# This notebook compare results using alternate frequencys and mini batching implementation to objective what more efficiency energy and maintain acurracy values. The results compareds this work use follow variables.
#
# Frequencies in MHz:
#
#     - Minimum: 600Mhz, Maximum: 600Mhz
#     - Minimum: 1200Mhz, Maximum: 1200Mhz
#
# Size mini-batching uses are:
#
#     - 1 (Sequential without mini-batching)
#     - 1 (Sequential with mini-batching)
#     - 50 (Paralel 4 CPUs with mini batching)
#     - 500 (Paralel 4 CPUs with mini batching)
#     - 2000 (Paralel 4 CPUs with mini batching)
#
# All executions are used ensemble size 25.

# %% [markdown]
# # Main Question
#
# Is possible use low frequency clock to consumer minus energy and maintain the accuracy algorithms

# %% [markdown]
# # Acurracy Frequencies X Mini-Batchings
#
# - A low (minimum) frequency is had same or near accuracy with mini-batching and without mini-batching
# - A high (minimum) frequency is had same or near accuracy with mini-batching and without mini-batching

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
# %mkdir -p parsed_csvs figures
# %cd results
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %%
def parse(fname):
    global header_printed
    #index of wanted columns
    columns = []
    #column names to get the data from
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    ret_string = ''
    #remove the path and isolate the filename
    spname = fname.split('/')[-1].split('-')
    spline = []
    #control flag for knowing when the column names have already been discovered
    got = False
    #we ignore the first parameter of the filename and add all others to the csv string
    for s in spname[1:]:
        ret_string += s + ','
    #should probably use a safer way, but python handles the closing of the file
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                #sometimes the dump file has multiple results in it, so we get the index of wanted columns only once
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        #OzaBagASHT bugs out on GMSC, this reuses the data from the sequential execution
        if 'GMSC' in spname and 'ASHT' in spname[2]:
            for c in columns[:-2]:
                ret_string += str(spline[c]) + ','
            ret_string += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        #normal code, how everything should run
        #we process the data (add the content of wanted columns to the csv string) only after the for
        #ensuring we use only the last (most recent) data and not the intermediate results
        else:
            for c in columns:
                ret_string += str(spline[c]) + ','
            if len(columns) == 5:
                ret_string += '0,'
        #header is a global variable, it will only be printed on the first file 
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,instances,time,acc,prec,recall,change'
            ret_string = f"{head}\n{ret_string}"
            header_printed = True
        #remove the last comma ,
        return (ret_string[:-1])

# %%
#loads the csv as a dataframe and standardizes the algorithm names 
def load_df(filename):
    df = pd.read_csv(filename, index_col=False)
    return select_columns_and_rename_values(df)

# %%
#standardize algorithm names
def select_columns_and_rename_values(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    df.batch_size.unique()
    return df

# %%
#filters by substring (there are multiple OzaBag algorithms)
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %%
#plots precision and recall with markers of one parameter configuration
def gen_lines(df, ax, alg_order, markers):
    lwidth = 0.75
    if markers:
        colors=['go', 'bs', 'rP', 'md', 'y+' , 'k*']
    else:
        colors=['g', 'b', 'r', 'm', 'y' , 'k']

    labels = df.batch_size
    alg = df.algorithm.unique()[0]
    x = np.arange(len(labels))
    
    ax.plot(x, pd.to_numeric(df.prec), f'{colors[alg_order]}--', linewidth=lwidth, label=f'{alg}-prec')
    ax.plot(x, pd.to_numeric(df.recall), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')

    #ax.plot(x,pd.to_numeric(df.prec), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_ylim(50,95)

# %%
#iterates over the parameter configurations and creates the chart grid
def gen_chart(df, markers=True, tables=False, frequencies=[], dataset=''):
    #dictionary containing the correct name to be printed
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
   
    #creates a 2x2 grid for plotting the charts
    #sharey=row means that all charts in a row share the same Y-axis
    fig, axs = plt.subplots(1, 2, figsize=(8,4), sharey='row')
    filename = "batch-size-vs-prediction-mark" if markers else "batch-size-vs-prediction"

    for frequency in frequencies:
        my_id = frequencies.index(frequency)
        #selects the correct position in the grid
        ax = axs[my_id]
        ax.set_title(f'{dataset} - Frequency {frequency}Mhz x {frequency}Mhz')

        #for each algorithm
        for alg in algorithms:
            #filters the df to contain the wanted values
            df_aux = filter_by_substring_algorithm(df[frequency][df[frequency].dataset == dataset].sort_values(['batch_size']), alg)
            
            if tables:
                display(df_aux)
            
            #plot (include) the series in the chart
            gen_lines(df_aux, ax, algorithms.index(alg), markers)
            
            #if its the first column, print Y-axis label
            ax.set_ylabel('Percentage')
            ax.set_xlabel('Batch sizes')

    #retrieves the handles and labels to create a global legend
    handles, labels = axs[0].get_legend_handles_labels()
    lgd = fig.legend(handles, labels, loc = 'lower center', ncol = math.ceil(len(algorithms)), bbox_to_anchor=(0.5,-0.1))
    fig.tight_layout()
    plt.savefig(f'figures/{filename}.png')
    plt.savefig(f'figures/{filename}.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

frequencies = ['600', '1200']
df = { '600': [], '1200': []}
for frequency in frequencies:
    resultsFolder = f"results/31-01-2022/{frequency}/{frequency}/first"
    csvFile = f"parsed_csvs/data-batch-vs-acc-{frequency}-{frequency}.csv"
    directory = os.fsencode(resultsFolder)
    header_printed = False

    with open(f"{csvFile}", "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("dump-"): 
                output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

    df[frequency] = load_df(f'{csvFile}')
    df[frequency] = df[frequency].drop(['cores', 'time'], axis=1)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
#false makes the chart without markers
datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
for ds in datasets:
    gen_chart(df, True, frequencies=frequencies, dataset=ds)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Low frequency (minimum) in clock CPU 600MHz had precision and recall decreased when size mini-batching increased. For example, in dataset Airlines algoritmh Adaptative Random Forest (ARF) first interation has precision on 70% but has a mini-batching size 2000 precision is reduce to 60%. Others algorithms to same behavior. Has a number precision major when has sequential without mini-batching but when mini-batching increased is precision decreased.
#
# High frequency (maximum) in clock CPU 1200MHz same similar behavior, analisyng same algorithm we can see it start in precision on 65% but decreased when size batch major. In size batch is 200 precision that near 62%.
#
# Precision and recall is near in minimum or maximum frequency when compared a sequential algorithm. In examples before, the precision ARF in sequential algorithm without mini-batching stay in near 60% while same algorithm without mini-batching paralel had precision in 63% in minimum frequency. In maximum frequency the precision stay in 63% without mini-batching and 65% with paralel execution. The paralelization was use 4 cores.

# %% [markdown]
# # Frequencies results
#
# Analising all frequencies in four datasets is possible see not big changes in each frequency utilized. All results aparently same precision in recall in percentage.

# %% [markdown]
# # Consumer Energy
#
# Now I need analisy the consumer energy to each frequency. Energy consumer is analising by JPI and Joules consumeds a period time. To obtained this data are used a follow architeture. We analisy the results of consumer each frequency from now with data accuracy already analised.
#
# To this, us define some questions:
#
# - Consumer energy is major in frequecy maximum
# - Consumer energy is minor in frequency minimum
# - Consumer energy reflect in accuracy when minimum frequecy
# - Consumer energy reflect in accuracy when maximum frequecy
# - Tax rate implicate more consumer of energy

# %%
PATH_TO_RESULTS = '/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/socket/24-02-2022/'

# %%
def parse_MOA(fname):
    global header_printed
    columns = []
    wanted = ['learning evaluation instances', 'Wall Time (Actual Time)', 'Avg Delay (ms)', 'outRate (inst/s)', 'classifications correct (percent)']
    pstr = ''
    spname = fname.split('/')[-1].split('-')
    spline = []
    for s in spname[1:]:
        pstr += s + ','
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                spline = line.split(',')
                for s in spline:
                    if s in wanted:
                        columns.append(spline.index(s))
            else:
                spline = line.split(',')
        for c in columns:
            pstr += spline[c] + ','
        if len(columns) == 2:
            pstr += '1,'
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,inc_rate,instances,time,delay,out_rate,acc'
            pstr = f"{head}\n{pstr}"
            header_printed = True
        return (pstr[:-1])

# %%
def read_MOA(folder, out_file):
    directory = os.fsencode(folder)
    global header_printed

    with open(out_file, "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("term-"): 
                output.write(f"{parse_MOA(f'{os.fsdecode(directory)}/{filename}')}\n")
    fname = os.fsdecode(out_file)
    df = pd.read_csv(fname)
    df['inc_rate'].astype('int64')
    return df[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'instances', 'time', 'delay', 'out_rate', 'acc']]

# %% [markdown]
# # Read Energy Data

# %%
def load_Wmeas(filename):
    return pd.read_csv(filename, header=None, names=['date', 'time', 'measure'])

# %%
def exper_order_to_dict(filename, d):
    with open(filename) as forder:
        got_timestamp = False
        dataset = algorithm = Esize = cores = Bsize = ''
        dnow=None
        for line in forder:
            if not got_timestamp:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
                if dnow:
                    dnow['finish'] = date_time_obj - datetime.timedelta(seconds=1)
            elif ':' not in line:
                spline = line.split('/')[-1].strip().split('-')
                #print(spline)
                if len(spline) == 6:
                    dataset,algorithm,Esize,cores,Bsize,rate = spline
                else:
                    dataset,algorithm,Esize,cores,Bsize,rate = *spline,1
                if algorithm not in d:
                    d[algorithm] = {}
                if dataset not in d[algorithm]:
                    d[algorithm][dataset] = {}
                if Esize not in d[algorithm][dataset]:
                    d[algorithm][dataset][Esize] = {}
                if cores not in d[algorithm][dataset][Esize]:
                    d[algorithm][dataset][Esize][cores] = {}
                if Bsize not in d[algorithm][dataset][Esize][cores]:
                    d[algorithm][dataset][Esize][cores][Bsize] = {}
                if rate not in d[algorithm][dataset][Esize][cores][Bsize]:
                    d[algorithm][dataset][Esize][cores][Bsize][rate] = {'start': date_time_obj, 'finish': ''}
                    dnow = d[algorithm][dataset][Esize][cores][Bsize][rate]
                got_timestamp = False
            else:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
    return d

# %%
def populate_dict(d, df):
    df['datetime'] = df['date'] + ' ' + df['time']
    for k, v in d.items():
        for k1, v1 in v.items():
            for k2, v2 in v1.items():
                for k3, v3 in v2.items():
                    for k4, v4 in v3.items():
                        for k5, v5 in v4.items():
                            if 'seconds' not in v5:
                                st = v5['start']
                                ed = v5['finish']
                                v5['seconds'] = (ed - st).seconds
                                new_df = df[(df.datetime <= f'{ed.strftime("%d/%m/%y")} {ed.strftime("%X")}')
                                          & (df.datetime >= f'{st.strftime("%d/%m/%y")} {st.strftime("%X")}')]
                                v5['avg_measure'] = new_df['measure'].mean()
                                v5['sum_measure'] = new_df['measure'].sum()
                                v5['avg_times_seconds'] = v5['avg_measure'] * v5['seconds']
    return d

# %%
def append_dict_to_df(d, ensemble_size=False):
    dappend = {'algorithm': [], 'dataset': [], 'ensemble_size': [], 'cores': [], 
               'batch_size': [], 'duration': [], 'inc_rate': [], 'avg_measure': [], 'sum_measure': [], 'avg_times_seconds': []}
    for kalg,valg in d.items():
        for kds,vds in valg.items():
            for kens,vens in vds.items():
                for kcore,vcore in vens.items():
                    for kmbs,vmbs in vcore.items():
                        for krate,vrate in vmbs.items():
                            dappend['algorithm'].append(kalg)
                            dappend['dataset'].append(kds)
                            dappend['ensemble_size'].append(kens)
                            dappend['cores'].append(kcore)
                            dappend['batch_size'].append(kmbs)
                            dappend['duration'].append(vrate['seconds'])
                            dappend['inc_rate'].append(krate)
                            for key in ['avg_measure', 'sum_measure','avg_times_seconds']:
                                dappend[key].append(vrate[key])
    adf = pd.DataFrame(data=dappend)
    adf = adf.sort_values(['algorithm','dataset']).astype({'inc_rate': 'int64', 
                                                           'cores': 'int64',
                                                           'batch_size': 'int64'})
    if ensemble_size:
        return adf[['algorithm', 'dataset', 'ensemble_size', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]
    return adf[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]

# %% [markdown]
# # Parse SSH Logs

# %%
def parse_SSH(fname):
    fname = os.fsdecode(fname)
    read_ssh = False
    alg = ''
    dataset = ''
    rate = ''
    d = {'algorithm': [], 'dataset': [], 'batch_size': [], 'inc_rate': [], 'prod_rate': [], 'tt_inst_prod': []}
    with open (fname, "r") as file:
        for line in file:
            if not read_ssh:
                if 'ssh-' in line:
                    read_ssh = True
                    spline = line.split('-')
                    if "MAX" in line:
                        if len(spline[1:]) == 3:
                            dataset, alg, rate = spline[1:]
                            bsize = 500
                        else:
                            dataset, alg, bsize, rate = spline[1:]
                    else:
                        dataset, alg, rate = spline[1:]
                        bsize = 1
                    d['algorithm'].append(alg)
                    d['dataset'].append(dataset)
                    d['inc_rate'].append(rate.strip())
                    d['batch_size'].append(bsize)
            else:
                if 'Total instances Producer' in line:
                    tt_inst = float(line.split(': ')[1])
                    d['tt_inst_prod'].append(tt_inst)
                elif 'Producer Rate' in line:
                    prod_rate = float(line.split(': ')[1])
                    d['prod_rate'].append(prod_rate)
                    read_ssh = False
    return pd.DataFrame.from_dict(d).astype({'inc_rate': 'int64'})

# %% [markdown]
# # Showing and preparing for charts

# %%
def filter_fields(df):
    wanted = ['algorithm', 'dataset', 'batch_size', 'cores', 'out_rate', 'instances', 'delay', 'joules', 'JPI']
    return df[[
        l for l in df.columns if any([w in l for w in wanted])
    ]]

# %%
def rename_columns_by_rate(df):
    rate = df.PERC.iloc[0]
    return df.rename(columns={"out_rate": f"out_rate_{rate}", "instances": f"instances_{rate}", 
                                "delay": f"delay_{rate}", "joules": f"joules_{rate}", 
                                "JPI": f"JPI_{rate}", "tput": f"tput_{rate}"})

# %%
def show_graph_JPI_delay(df, ax, mJPI, mDel, legend=False, title=False, ylabels=False, ds='', bar=False, share_y=False, log_y=False, norm=False, hide=True):
    if norm:
        df = my_norm(df, x=norm)
    global rate
    global twin
    width = 0.15
    alg_order = ['B50', 'B500', 'B2000']
    labels = ['10%', '50%', '90%']
    line_format = ['-', '--', ':', '-.', (0, (3, 5, 1, 5, 1, 5))]
    linfo = '--'
    x = np.arange(len(labels))
    lns_l = []
    versions = 3
    for i in range(versions):
        adf = df.iloc[i]
        values_j = [adf.JPI_10, adf.JPI_50, adf.JPI_90]
        if bar:
            lns_l += ax.bar(x - ((1 - i) * width), values_j, width, label=f'JPI-{alg_order[i]}')            
        else:
            lns_l += ax.plot(x, values_j, label=f'JPI-{alg_order[i]}')

    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax_r = ax.twinx()
    twin = ax_r
    if log_y:
        ax.set_yscale('log')
        ax_r.set_yscale('log')
    if title:
        alg_title = re.sub('Sequential', '', df.algorithm.iloc[0])
        ax.set_title(f'{alg_title}')
    if ylabels:
        ax.set_ylabel(ds)
    if last:
        ax.set_ymargin(2)
    for i in range(versions): 
        adf = df.iloc[i]
        values_d = [ x/1000 for x in [adf.delay_10, adf.delay_50, adf.delay_90]]
        if bar:
            linfo = f'k{line_format[i]}'
            lns_l += ax_r.plot(x, values_d, color='black', linestyle=line_format[i], label=f'delay-{alg_order[i]}')
        else:
            lns_l += ax_r.plot(x, values_d, linfo, label=f'delay-{alg_order[i]}')
    labs = [l.get_label() for l in lns_l]
    if legend:
        ax.legend(lns_l, labs, loc=0)
    if hide:
        ax_r.set_yticklabels([])
    if share_y == 'row':
        ax.set_ylim(top=mJPI)
        ax_r.set_ylim(top=mDel/1000)

# %%
def aux_graphNx1(ds, axis, id_ds, df, bar=False, share_y='row', log_y=False, norm=False):
    rates = ['10', '50', '90']
    algs = ['Ada', 'L', 'Patches', 'Adwin', 'ASHT', 'OzaBag']
    global title
    global labels
    hide_axis = True
#     fig.suptitle(f'JPI and delay for {ds}', fontsize=18, y=1)
#     get max value from delay for all rates on all algorithms for this dataset
    mLstJPI = []
    mLstDel = []
    if share_y == 'row':
        for rt in rates:
            rtDF = df[df.PERC == rt]
            mLstJPI.append(rtDF.JPI.max())
            mLstDel.append(rtDF.delay.max())
        mJPI = max(mLstJPI)*1.05
        mDel = max(mLstDel)*1.05
    else:
        mJPI = mDel = 0
    for alg in algs:
        dsalgdf = filter_by_substring_algorithm(df, alg).sort_values(['algorithm','batch_size','cores'])
#         if alg == 'L' and ds == 'kyoto_binary':
#             display(dsalgdf)
        for rt in rates:
            if rt == '10':
                showdf = rename_columns_by_rate(dsalgdf[dsalgdf.PERC == rt])
            else:
                to_join = dsalgdf[dsalgdf.PERC == rt]
                showdf = showdf.merge(rename_columns_by_rate(to_join),
                                  on=['algorithm', 'dataset', 'batch_size', 'cores']).sort_values(['batch_size','cores'])
       
        # debug print, if it shows it is wrong
        # if len(showdf) != 5:
        #     display(showdf)

        if 'Ada' in alg:
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, ylabels=True, ds=ds, bar=bar, share_y=share_y, log_y=log_y, norm=norm)
        else:
            if algs[-1] == alg:
                hide_axis = False
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, bar=bar, share_y=share_y, log_y=log_y, norm=norm, hide=hide_axis)

# %%
def gen_graph(df, bars=False, share_y='row', log_y=False, norm=False, freq='600', tput=False):
    ps = f'{freq}\nbars: {bars}\nshare_y: {share_y}\nlog_y: {log_y} '
    datasets = ['airlines', 'GMSC','elecNormNew','covtypeNorm']

    fig, axis = plt.subplots(len(datasets), 6, figsize=(16,12), tight_layout=True, sharey=share_y)
    global title
    global labels
    global last
    global twin
    leg = False
    labls = True
    title = True
    last = False
    twin = axis[0][0]
    for ds in datasets:
        if datasets.index(ds) == (len(datasets) - 1):
            last = True
        dsdf = df[df.dataset == ds]
        aux_graphNx1(ds, axis, datasets.index(ds), dsdf, bar=bars, share_y=share_y, log_y=log_y, norm=norm)
        title = True
    lines_1, labels_1 = axis[0][0].get_legend_handles_labels()
    lines_2, labels_2 = twin.get_legend_handles_labels()
    lines = lines_1 + lines_2
    labels = labels_1 + labels_2
    lgd = fig.legend(lines, labels, loc=8, ncol=5, bbox_to_anchor=(0.5, -0.02))
    lgd.set_in_layout(True)
    fig.subplots_adjust(bottom=-0.5)
    filename = 'all-4x1-JPI-delay'
    if bars:
        filename = f'bars-{filename}'
    if share_y:
        filename = f'sharey-{filename}'
    if log_y:
        filename = f'logy-{filename}'
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.eps', pad_inches=0.2, bbox_inches='tight')
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.png', pad_inches=0.2, bbox_inches='tight')
    plt.show()

# %% [markdown]
# # Run methods to obtained visible results

# %%
def read_data_create_final_dataframe(freq, DEBUG=False, GraphBar=False):
    d = {}
    global header_printed
    header_printed = False
    moaDF = read_MOA(f"{PATH_TO_RESULTS}{freq}/{freq}", f"{PATH_TO_RESULTS}{freq}/{freq}/inst-and-delay.csv")
    moaDF = moaDF[["algorithm", "dataset", "cores", "batch_size", "inc_rate", "out_rate", "instances", "time", "delay", "acc"]]
    measureDF = load_Wmeas(f'{PATH_TO_RESULTS}{freq}/{freq}/Wm-{freq}.log')
    d = exper_order_to_dict(f'{PATH_TO_RESULTS}{freq}/{freq}/exper_order-freq-max-{freq}-freq-min-{freq}.log', d)
    d = populate_dict(d, measureDF)
    mdf = append_dict_to_df(d)
    sshDF = parse_SSH(f'{PATH_TO_RESULTS}{freq}/{freq}/ssh-log')
    sshDF['batch_size'] = sshDF['batch_size'].astype(int)
    if DEBUG:
        print(f'moaDF: {len(moaDF)}    mdf: {len(mdf)}     sshDF: {len(sshDF)}')
    
    #join dfs
    finaldf = moaDF.merge(mdf, on=['algorithm', 'dataset', 'cores', 'batch_size', 'inc_rate'])
    finaldf = finaldf.merge(sshDF, 'left', on=['algorithm', 'dataset', 'batch_size', 'inc_rate'])
    
    ### temporario pega todos os nans, a media entre os valores preenchidos e coloca nestes campos vazios
    finaldf['avg_measure'] = finaldf['avg_measure'].replace(np.nan, 0)
    finaldf = finaldf.reset_index()
    total = 0
    average = 0 
    for index, row in finaldf.iterrows():
        if int(row['avg_measure']) > 0:
            total += row['avg_measure']

    average = total / len(finaldf.index)
    finaldf['avg_measure'] = finaldf['avg_measure'].replace(0, average)
    ### final do código temporario

    finaldf['joules'] = finaldf['avg_measure'] * finaldf['time']
    finaldf['JPI'] = finaldf['joules'] / finaldf['instances']

    if GraphBar:
        return finaldf

    # Add PERC column to identify if it used 90, 50 or 10% max rate
    # Before merging rows with the same batch size, we need to differentiate the experiments with different work loads
    # We use the **PERC**entage column for that
    tdf = finaldf.sort_values(by=['dataset','algorithm','batch_size','inc_rate'], ascending=False)
    tdf['PERC'] = 0
    if DEBUG:
        tdf.to_csv(f"{PATH_TO_RESULTS}tdf-{freq}.csv")
    masks = {'90':[], '50': [], '10': []}
    for k, v in zip(masks.keys(), [0, 1, 2]):
        for i in range(len(tdf)):
            masks[k].append(i % 3 == v)
    
    tdf.loc[masks['90'], 'PERC'] = '90'
    tdf.loc[masks['50'], 'PERC'] = '50'
    tdf.loc[masks['10'], 'PERC'] = '10'
    
    tdf['tput'] = tdf['instances'] / tdf['time']
    
    return tdf

# %%
freqs = ['600', '1200']
dataframes = []
for f in freqs:
    dataframes.append(read_data_create_final_dataframe(f, True))
# Out:
# moaDF: 216    mdf: 216     sshDF: 325
#      index                               algorithm      dataset  cores  \
# 0        0  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 1        1                    LBagExecutorMAXChunk     airlines      4
# 2        2                    LBagExecutorMAXChunk     airlines      4
# 3        3  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 4        4                    LBagExecutorMAXChunk         GMSC      4
# ..     ...                                     ...          ...    ...
# 320    320                    LBagExecutorMAXChunk     airlines      4
# 321    321                    LBagExecutorMAXChunk     airlines      4
# 322    322                  OzaBagExecutorMAXChunk     airlines      4
# 323    323  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 324    324  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
#
#      batch_size  inc_rate  out_rate  instances   time     delay   acc  \
# 0          2000        77     32.18   4,000.00 124.29 55,474.00 64.95
# 1            50        57     48.14   5,800.00 120.47  1,017.00 64.83
# 2            50        57     48.14   5,800.00 120.47  1,017.00 64.83
# 3          2000        19     15.01   1,800.00 119.95 77,347.00 40.33
# 4            50        83     79.87   9,585.00 120.00    369.00 93.52
# ..          ...       ...       ...        ...    ...       ...   ...
# 320        2000        29     25.01   3,000.00 119.96 57,798.00 67.80
# 321         500        28     22.68   3,000.00 132.25 16,374.00 69.60
# 322        2000       189    148.69  18,000.00 121.05 12,829.00 60.58
# 323         500        20     20.01   2,400.00 119.96 15,789.00 76.26
# 324         500        20     20.01   2,400.00 119.96 15,789.00 76.26
#
#      duration  avg_measure  sum_measure  prod_rate  tt_inst_prod  joules  JPI
# 0         130         4.20       991.50      74.89      9,000.00  522.17 0.13
# 1         128         1.32         0.00      54.92      6,600.00  159.09 0.03
# 2         128         1.32         0.00      54.92      6,600.00  159.09 0.03
# 3         143         3.53       913.50      14.98      1,800.00  423.08 0.24
# 4         128         1.32         0.00      79.87      9,600.00  158.47 0.02
# ..        ...          ...          ...        ...           ...     ...  ...
# 320       151         3.84     1,047.00      24.97      3,000.00  460.06 0.15
# 321       140         3.84       974.70      24.97      3,000.00  507.50 0.17
# 322       129         4.41     1,030.80     184.69     22,163.00  533.26 0.03
# 323       127         1.32         0.00      19.98      2,400.00  158.43 0.07
# 324       127         1.32         0.00      19.97      2,400.00  158.43 0.07
#
# [325 rows x 18 columns]
# moaDF: 216    mdf: 216     sshDF: 219
#      index                               algorithm      dataset  cores  \
# 0        0             OzaBagAdwinExecutorMAXChunk     airlines      4
# 1        1                    LBagExecutorMAXChunk     airlines      4
# 2        2                    LBagExecutorMAXChunk     airlines      4
# 3        3                    LBagExecutorMAXChunk         GMSC      4
# 4        4             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 5        5                  OzaBagExecutorMAXChunk  elecNormNew      4
# 6        6  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 7        7    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 8        8  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 9        9              OzaBagASHTExecutorMAXChunk     airlines      4
# 10      10              OzaBagASHTExecutorMAXChunk         GMSC      4
# 11      11  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 12      12              OzaBagASHTExecutorMAXChunk     airlines      4
# 13      13                    LBagExecutorMAXChunk     airlines      4
# 14      14                    LBagExecutorMAXChunk     airlines      4
# 15      15              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 16      16                  OzaBagExecutorMAXChunk  elecNormNew      4
# 17      17                    LBagExecutorMAXChunk     airlines      4
# 18      18              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 19      19             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 20      20    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 21      21             OzaBagAdwinExecutorMAXChunk     airlines      4
# 22      22             OzaBagAdwinExecutorMAXChunk     airlines      4
# 23      23                  OzaBagExecutorMAXChunk  elecNormNew      4
# 24      24                    LBagExecutorMAXChunk         GMSC      4
# 25      25  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 26      26    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 27      27    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 28      28             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 29      29              OzaBagASHTExecutorMAXChunk     airlines      4
# 30      30    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 31      31                    LBagExecutorMAXChunk  covtypeNorm      4
# 32      32                  OzaBagExecutorMAXChunk         GMSC      4
# 33      33                    LBagExecutorMAXChunk  covtypeNorm      4
# 34      34             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 35      35  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 36      36    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 37      37  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 38      38    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 39      39             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 40      40                    LBagExecutorMAXChunk  elecNormNew      4
# 41      41  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 42      42              OzaBagASHTExecutorMAXChunk         GMSC      4
# 43      43             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 44      44  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 45      45    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 46      46             OzaBagAdwinExecutorMAXChunk     airlines      4
# 47      47  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 48      48              OzaBagASHTExecutorMAXChunk         GMSC      4
# 49      49  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 50      50             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 51      51                  OzaBagExecutorMAXChunk         GMSC      4
# 52      52    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 53      53              OzaBagASHTExecutorMAXChunk     airlines      4
# 54      54                    LBagExecutorMAXChunk  elecNormNew      4
# 55      55             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 56      56    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 57      57  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 58      58    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 59      59              OzaBagASHTExecutorMAXChunk     airlines      4
# 60      60                    LBagExecutorMAXChunk  covtypeNorm      4
# 61      61             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 62      62    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 63      63  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 64      64  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 65      65                  OzaBagExecutorMAXChunk         GMSC      4
# 66      66              OzaBagASHTExecutorMAXChunk         GMSC      4
# 67      67                  OzaBagExecutorMAXChunk     airlines      4
# 68      68             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 69      69    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 70      70    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 71      71                  OzaBagExecutorMAXChunk     airlines      4
# 72      72    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 73      73    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 74      74              OzaBagASHTExecutorMAXChunk         GMSC      4
# 75      75                  OzaBagExecutorMAXChunk     airlines      4
# 76      76             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 77      77              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 78      78                    LBagExecutorMAXChunk  covtypeNorm      4
# 79      79             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 80      80                    LBagExecutorMAXChunk         GMSC      4
# 81      81             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 82      82             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 83      83  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 84      84                  OzaBagExecutorMAXChunk         GMSC      4
# 85      85                  OzaBagExecutorMAXChunk     airlines      4
# 86      86  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 87      87                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 88      88              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 89      89                  OzaBagExecutorMAXChunk     airlines      4
# 90      90    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 91      91  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 92      92              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 93      93    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 94      94              OzaBagASHTExecutorMAXChunk     airlines      4
# 95      95                    LBagExecutorMAXChunk     airlines      4
# 96      96  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 97      97                  OzaBagExecutorMAXChunk     airlines      4
# 98      98                    LBagExecutorMAXChunk     airlines      4
# 99      99                    LBagExecutorMAXChunk     airlines      4
# 100    100                  OzaBagExecutorMAXChunk  elecNormNew      4
# 101    101  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 102    102                    LBagExecutorMAXChunk  elecNormNew      4
# 103    103                    LBagExecutorMAXChunk         GMSC      4
# 104    104              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 105    105    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 106    106                    LBagExecutorMAXChunk         GMSC      4
# 107    107                  OzaBagExecutorMAXChunk         GMSC      4
# 108    108                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 109    109                  OzaBagExecutorMAXChunk     airlines      4
# 110    110  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 111    111                  OzaBagExecutorMAXChunk         GMSC      4
# 112    112              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 113    113                  OzaBagExecutorMAXChunk     airlines      4
# 114    114                    LBagExecutorMAXChunk         GMSC      4
# 115    115    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 116    116             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 117    117  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 118    118             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 119    119                  OzaBagExecutorMAXChunk  elecNormNew      4
# 120    120                  OzaBagExecutorMAXChunk  elecNormNew      4
# 121    121                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 122    122                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 123    123                  OzaBagExecutorMAXChunk  elecNormNew      4
# 124    124              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 125    125  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 126    126    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 127    127                    LBagExecutorMAXChunk  elecNormNew      4
# 128    128             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 129    129             OzaBagAdwinExecutorMAXChunk     airlines      4
# 130    130              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 131    131              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 132    132                  OzaBagExecutorMAXChunk  elecNormNew      4
# 133    133              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 134    134              OzaBagASHTExecutorMAXChunk         GMSC      4
# 135    135  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 136    136                    LBagExecutorMAXChunk  covtypeNorm      4
# 137    137              OzaBagASHTExecutorMAXChunk         GMSC      4
# 138    138  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 139    139                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 140    140             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 141    141                    LBagExecutorMAXChunk  elecNormNew      4
# 142    142                    LBagExecutorMAXChunk  elecNormNew      4
# 143    143                    LBagExecutorMAXChunk  elecNormNew      4
# 144    144             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 145    145  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 146    146                  OzaBagExecutorMAXChunk         GMSC      4
# 147    147    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 148    148                    LBagExecutorMAXChunk         GMSC      4
# 149    149              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 150    150  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 151    151    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 152    152  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 153    153  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 154    154    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 155    155    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 156    156  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 157    157             OzaBagAdwinExecutorMAXChunk     airlines      4
# 158    158  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 159    159                  OzaBagExecutorMAXChunk     airlines      4
# 160    160    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 161    161                    LBagExecutorMAXChunk  covtypeNorm      4
# 162    162                    LBagExecutorMAXChunk         GMSC      4
# 163    163              OzaBagASHTExecutorMAXChunk     airlines      4
# 164    164             OzaBagAdwinExecutorMAXChunk     airlines      4
# 165    165    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 166    166    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 167    167    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 168    168    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 169    169              OzaBagASHTExecutorMAXChunk         GMSC      4
# 170    170    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 171    171    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 172    172              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 173    173    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 174    174             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 175    175             OzaBagAdwinExecutorMAXChunk     airlines      4
# 176    176              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 177    177    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 178    178             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 179    179    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 180    180                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 181    181                  OzaBagExecutorMAXChunk         GMSC      4
# 182    182    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 183    183              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 184    184  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 185    185                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 186    186                    LBagExecutorMAXChunk  covtypeNorm      4
# 187    187  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 188    188    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 189    189  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 190    190              OzaBagASHTExecutorMAXChunk     airlines      4
# 191    191  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 192    192             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 193    193                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 194    194             OzaBagAdwinExecutorMAXChunk     airlines      4
# 195    195  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 196    196                  OzaBagExecutorMAXChunk  elecNormNew      4
# 197    197                    LBagExecutorMAXChunk  elecNormNew      4
# 198    198              OzaBagASHTExecutorMAXChunk         GMSC      4
# 199    199             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 200    200                    LBagExecutorMAXChunk     airlines      4
# 201    201                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 202    202             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 203    203              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 204    204                    LBagExecutorMAXChunk  covtypeNorm      4
# 205    205  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 206    206             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 207    207                    LBagExecutorMAXChunk  covtypeNorm      4
# 208    208                    LBagExecutorMAXChunk  elecNormNew      4
# 209    209             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 210    210                    LBagExecutorMAXChunk     airlines      4
# 211    211                    LBagExecutorMAXChunk     airlines      4
# 212    212              OzaBagASHTExecutorMAXChunk  elecNormNew      4
#
# 204       126         5.11     1,170.20     393.93     47,321.00   613.21 0.01
# 205       125         3.77       859.50      54.92      6,600.00   452.32 0.07
# 206       125         4.49     1,018.80     304.28     36,539.00   538.38 0.01
# 207       127         3.76       865.20      49.93      6,000.00   457.15 0.08
# 208        85         4.69       726.70     567.61     45,312.00   373.57 0.01
# 209        79         4.52       650.90   2,048.59    150,000.00   330.51 0.00
# 210       143         3.80       985.30      14.98      1,800.00   456.31 0.25
# 211       143         3.80       985.30      14.98      1,800.00   456.31 0.25
# 212        26         4.91       240.70   2,326.79     45,312.00    99.98 0.00
# 213       126         5.65     1,293.50     807.49     97,038.00   678.16 0.02
# 214       126         3.87       886.20     159.73     19,168.00   463.66 0.02
# 215       125         4.63     1,050.10     628.30     75,474.00   554.83 0.01
# 216       126         3.79       863.20      14.98      1,800.00   454.13 0.25
# 217        48         4.95       440.30   3,530.74    150,000.00   210.41 0.00
# 218       124         4.67     1,051.20        NaN           NaN   560.27 0.03
# 219       126         3.75       820.80      74.88      9,000.00   454.58 0.05
# 220       126         3.77       858.80     254.46     30,549.00   452.20 0.01

# %%
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    gen_graph(df, bars=True, freq=f)
# Out:
# ----------------- 600 -----------------
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ----------------- 1200 -----------------
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Average Consumer By Frequency

# %%
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    df['joules'] = df['joules'].replace(np.nan, 0)
    df = df.reset_index()

    total = 0
    average = 0 
    for index, row in df.iterrows():
        if int(row['joules']) > 0:
            total += row['joules']

    average = total / len(df.index)
    print(average)
# Out:
# ----------------- 600 -----------------
# 241.5528637534315
#
#
#
# ----------------- 1200 -----------------
# 559.4935837710227

# %% [markdown]
# The average basic show a comportament where in minimum frequency presetation 50% minus consumer energy compared the others frequencies. A point of attention is values similars in frequency 800, 1000 and 1200. This can point change frequency is are changed only 600 and 1200 and no others configurations.

# %% [markdown]
# # Compare Accuracy and IPS
#
# - The IPS has some ligation when accuracy?
# - IPS is minor when is frequency is minimum?
# - IPS is major when is frequency is maximum?
# - IPS is major when utilized mini-batching?

# %%
def plot(ax, dsdf, my_id, x):
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}
    c1 = 'tab:red'
    c2 = 'tab:blue'
    c3 = 'tab:green'
    ds = list(dsdf.dataset)[0]
    ax.set_title(f'{dsformalname[ds]}')
    ax.plot(x, pd.to_numeric(dsdf.acc), color=c1, label='acc')
    ax.tick_params(axis='y', labelcolor=c1)
    ax.set_xticks(x)
    ax.set_xticklabels(dsdf.batch_size)
    ax.set_ylim(0,100)
    ax2 = ax.twinx()
    ax2.plot(x, pd.to_numeric(dsdf.IPS), color=c2, label='IPS')
    ax2.tick_params(axis='y', labelcolor=c2)
    if int(my_id/2) == 1:
        ax.set_xlabel('Batch size')
    ax.set_ylabel('Accuracy %', color=c1)
    ax2.set_ylabel('IPS', color=c2)

# %%
def gen_graph_initial_peralg(df, display_df=False, freq=''):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
    # datasets = ['covtypeNorm']

    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    # algorithms = ['OB']

    filename = f"pi-rates"
    for alg in algorithms:
        fig, axs = plt.subplots(2, 2, figsize=(15,10))
        dfalg = filter_by_substring_algorithm(df, alg)
        display(dfalg)
        fig.suptitle(f'{alg} - Frequency {freq}')
        for ds in datasets:
            dsdf = dfalg[(dfalg.dataset == ds)]

            display(dsdf)
            x = np.arange(len(dsdf.batch_size))
            my_id = datasets.index(ds)
            ax = axs[int(my_id/2)][my_id%2]
            plot(ax, dsdf, my_id, x)
        plt.savefig(f'{filename}.eps', bbox_inches='tight')

# %%
frequencies = ['600', '1200']
df = { '600': [], '1200': []}
for frequency in frequencies:
    resultsFolder = f"results/socket/24-02-2022/{frequency}/{frequency}"
    csvFile = f"{resultsFolder}/acc-batch.csv"
    directory = os.fsencode(resultsFolder)
    header_printed = False

    with open(f"{csvFile}", "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("dump-"): 
                output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

    df[frequency] = load_df(f'{csvFile}')
    df[frequency] = df[frequency].drop(['cores', 'time'], axis=1)
# Out:
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
# freqs = ['600', '1200']
# acc = {'600': [], '1200': []}
# for freq, df in zip(freqs, dataframes):
#     print(f'\n\n\n----------------- {f} -----------------')

#     acc[freq] = load_df(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/parsed_csvs/pi-{freq}x{freq}-get_rates.csv')
#     display(acc[freq])
#     acc[freq] = acc[freq].loc[:,['dataset','algorithm','batch_size','acc', 'instances', 'time']].sort_values(by=['batch_size'])

#     for index_acc, row_acc in acc[freq].iterrows():
#         for index, row in df.iterrows():
#             if (row_acc['algorithm'] == row['algorithm'] and 
#                 row_acc['batch_size'] == row['batch_size'] and
#                 row_acc['dataset'] == row['dataset']):
#                 acc[freq]['JPI'] = df['JPI']
#                 acc[freq]['instances'] = df['instances']
#                 acc[freq]['time'] = df['time']

#     for ds in acc[freq].dataset.unique():
#         for alg in acc[freq].algorithm.unique():
#             aux = acc[freq][(acc[freq].dataset == ds) & (acc[freq].algorithm == alg)]
#             l = list(zip(aux.batch_size, aux.acc))
#             print(f'{ds:12} {alg:17} {l[0][1] - l[-1][1]}')

# %%
# chart_ensem_size = {'600': [], '1200': []}

# for freq in freqs:
#     acc[freq]['IPS'] = acc[freq]['instances'] / acc[freq]['time']
#     acc[freq] = acc[freq].sort_values(by=['batch_size', 'IPS'])
#     chart_ensem_size[freq] = acc[freq]

freqs = ['600', '1200']
dataframes = []
for f in freqs:
    dataframes.append(read_data_create_final_dataframe(f, True, False))
# Out:
# moaDF: 216    mdf: 216     sshDF: 325
# moaDF: 216    mdf: 216     sshDF: 219

# %%
freqs = ['600', '1200']
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')  
    df = df[df.PERC == '10']
    # showdf = showdf.loc[:,['dataset','algorithm','batch_size','acc', 'instances', 'time']].sort_values(by=['batch_size'])
    # showdf = select_columns_and_rename_values(showdf)
    showdf['IPS'] = showdf['instances'] / showdf['time']
    display(df)
    gen_graph_initial_peralg(df, display_df=False, freq=freq)
# Out:
# ----------------- 600 -----------------
#      index                               algorithm      dataset  cores  \
# 3        3  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 24      24  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 324    324  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 29      29  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 307    307  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4
# 242    242                  OzaBagExecutorMAXChunk  elecNormNew      4
# 250    250                  OzaBagExecutorMAXChunk  elecNormNew      4
# 269    269                  OzaBagExecutorMAXChunk  elecNormNew      4
# 294    294                  OzaBagExecutorMAXChunk  elecNormNew      4
# 285    285                  OzaBagExecutorMAXChunk  elecNormNew      4
# 178    178             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 201    201             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 241    241             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 80      80             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 76      76             OzaBagAdwinExecutorMAXChunk  elecNormNew      4
# 228    228              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 225    225              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 144    144              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 52      52              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 129    129              OzaBagASHTExecutorMAXChunk  elecNormNew      4
# 245    245                    LBagExecutorMAXChunk  elecNormNew      4
# 118    118                    LBagExecutorMAXChunk  elecNormNew      4
# 32      32                    LBagExecutorMAXChunk  elecNormNew      4
# 193    193                    LBagExecutorMAXChunk  elecNormNew      4
# 182    182                    LBagExecutorMAXChunk  elecNormNew      4
# 164    164    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 141    141    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 281    281    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 151    151    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4
# 79      79  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 14      14  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 188    188  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 272    272  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 136    136  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4
# 124    124                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 49      49                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 253    253                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 217    217                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 171    171                  OzaBagExecutorMAXChunk  covtypeNorm      4
# 134    134             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 109    109             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 96      96             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 207    207             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 158    158             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4
# 44      44              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 102    102              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 316    316              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 184    184              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 8        8              OzaBagASHTExecutorMAXChunk  covtypeNorm      4
# 51      51                    LBagExecutorMAXChunk  covtypeNorm      4
# 189    189                    LBagExecutorMAXChunk  covtypeNorm      4
# 301    301                    LBagExecutorMAXChunk  covtypeNorm      4
# 165    165                    LBagExecutorMAXChunk  covtypeNorm      4
# 283    283                    LBagExecutorMAXChunk  covtypeNorm      4
# 106    106    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 197    197    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 266    266    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 209    209    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 114    114    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4
# 0        0  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 104    104  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 260    260  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 101    101  StreamingRandomPatchesExecutorMAXChunk     airlines      4
# 322    322                  OzaBagExecutorMAXChunk     airlines      4
# 115    115                  OzaBagExecutorMAXChunk     airlines      4
# 221    221                  OzaBagExecutorMAXChunk     airlines      4
# 163    163                  OzaBagExecutorMAXChunk     airlines      4
# 317    317             OzaBagAdwinExecutorMAXChunk     airlines      4
# 303    303             OzaBagAdwinExecutorMAXChunk     airlines      4
# 130    130             OzaBagAdwinExecutorMAXChunk     airlines      4
# 21      21             OzaBagAdwinExecutorMAXChunk     airlines      4
# 127    127              OzaBagASHTExecutorMAXChunk     airlines      4
# 296    296              OzaBagASHTExecutorMAXChunk     airlines      4
# 54      54              OzaBagASHTExecutorMAXChunk     airlines      4
# 257    257              OzaBagASHTExecutorMAXChunk     airlines      4
# 41      41                    LBagExecutorMAXChunk     airlines      4
# 37      37                    LBagExecutorMAXChunk     airlines      4
# 1        1                    LBagExecutorMAXChunk     airlines      4
# 12      12                    LBagExecutorMAXChunk     airlines      4
# 292    292    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 229    229    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 33      33    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 65      65    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 45      45    AdaptiveRandomForestExecutorMAXChunk     airlines      4
# 6        6  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 177    177  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 94      94  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 73      73  StreamingRandomPatchesExecutorMAXChunk         GMSC      4
# 291    291                  OzaBagExecutorMAXChunk         GMSC      4
# 88      88                  OzaBagExecutorMAXChunk         GMSC      4
# 23      23                  OzaBagExecutorMAXChunk         GMSC      4
# 195    195                  OzaBagExecutorMAXChunk         GMSC      4
# 120    120             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 191    191             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 72      72             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 83      83             OzaBagAdwinExecutorMAXChunk         GMSC      4
# 121    121              OzaBagASHTExecutorMAXChunk         GMSC      4
# 63      63              OzaBagASHTExecutorMAXChunk         GMSC      4
# 108    108              OzaBagASHTExecutorMAXChunk         GMSC      4
# 274    274              OzaBagASHTExecutorMAXChunk         GMSC      4
# 58      58                    LBagExecutorMAXChunk         GMSC      4
# 89      89                    LBagExecutorMAXChunk         GMSC      4
# 36      36                    LBagExecutorMAXChunk         GMSC      4
# 4        4                    LBagExecutorMAXChunk         GMSC      4
# 68      68    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 66      66    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 212    212    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
# 205    205    AdaptiveRandomForestExecutorMAXChunk         GMSC      4
#
#      batch_size  inc_rate  out_rate  instances   time     delay   acc  \
# 3          2000        19     15.01   1,800.00 119.95 77,347.00 40.33
# 24          500       103     99.99  11,980.00 119.82  4,163.00 81.75
# 324         500        20     20.01   2,400.00 119.96 15,789.00 76.26
# 29           50        98     94.99  11,381.00 119.82    417.00 83.17
# 307          50        19     14.98   1,800.00 120.20  1,963.00 80.40
# 242        2000       151    149.98  17,970.00 119.81  8,019.00 79.24
# 250         500       782    778.56  45,312.00  58.20    520.00 77.45
# 269         500       156    154.98  18,569.00 119.82  1,895.00 79.93
# 294          50       712    707.72  45,312.00  64.03     54.00 79.15
# 285          50       142    139.96  16,772.00 119.83    200.00 82.45
# 178        2000       128    124.98  14,975.00 119.82  9,273.00 79.69
# 201         500       674    665.00  45,129.00  67.86    610.00 78.43
# 241         500       134    129.97  15,574.00 119.83  2,271.00 80.37
# 80           50       589    583.48  45,312.00  77.66     65.00 79.88
# 76           50       117    114.98  13,777.00 119.82    255.00 84.22
# 228        2000       147    144.98  17,371.00 119.82  8,073.00 79.02
# 225         500       787    777.62  45,092.00  57.99    531.00 77.09
# 144         500       157    154.97  18,569.00 119.82  1,898.00 80.45
# 317        2000       185    149.73  18,000.00 120.21 12,731.00 60.61
# 303         500       196    172.88  21,000.00 121.47  2,859.00 63.95
# 130          50       218    180.75  21,700.00 120.06    276.00 67.27
# 21           50       121    119.54  14,350.00 120.04    377.00 64.54
# 127        2000       206    169.51  22,000.00 129.79 11,330.00 63.04
# 296         500       212    182.90  22,000.00 120.29  2,704.00 64.22
# 54           50       209    174.91  21,050.00 120.35    285.00 64.57
# 257          50       116    114.81  13,778.00 120.01    386.00 63.43
# 41         2000        53     31.07   4,000.00 128.72 53,746.00 63.80
# 37          500        52     41.27   5,000.00 121.14 11,372.00 65.04
# 1            50        57     48.14   5,800.00 120.47  1,017.00 64.83
# 12           50        32     29.80   3,600.00 120.82  1,384.00 68.90
# 292        2000        72     40.40   6,000.00 148.50 44,673.00 61.35
# 229         500        72     47.49   6,000.00 126.33 10,228.00 66.36
# 33          500         8       NaN        NaN    NaN       NaN   NaN
# 65           50        70     44.57   5,500.00 123.41  1,119.00 67.28
# 45           50         7      4.97     600.00 120.70  6,299.00 76.36
# 6          2000       181    179.97  21,564.00 119.82  9,294.00 93.52
# 177         500       182    178.45  21,500.00 120.48  2,274.00 93.60
# 94           50       314    309.53  37,138.00 119.98    155.00 93.52
# 73           50        34     29.98   3,600.00 120.07    994.00 94.37
# 291        2000      1202  1,194.04 143,153.00 119.89  1,369.00 93.47
# 88          500      1236  1,228.81 147,500.00 120.04    332.00 93.44
# 23           50      1852  1,845.72 150,000.00  81.27     25.00 93.49
# 195          50       205    204.91  24,559.00 119.86    139.00 93.61
# 120        2000       991    982.70 118,000.00 120.08  1,651.00 93.48
# 191         500      1003    996.94 119,600.00 119.97    381.00 93.49
# 72           50      1843  1,833.22 149,800.00  81.71     26.00 93.31
# 83           50       204    199.87  23,960.00 119.88    127.00 93.67
# 121        2000      1263     49.53   8,000.00 161.53 40,188.00 93.48
# 63          500      1301  1,294.86 150,000.00 115.84    307.00 93.39
# 108          50      1956  1,945.23 149,592.00  76.90     25.00 93.33
# 274          50       217    214.92  25,757.00 119.84    132.00 93.50
# 58         2000       416    413.98  49,633.00 119.89  4,025.00 93.34
# 89          500       454    449.63  53,910.00 119.90    934.00 93.35
# 36           50       753    744.81  89,400.00 120.03     63.00 93.37
# 4            50        83     79.87   9,585.00 120.00    369.00 93.52
# 68         2000       327    324.82  38,935.00 119.86  5,089.00 93.51
# 66          500       337    332.72  40,000.00 120.22  1,245.00 93.46
# 212          50       600    597.99  71,800.00 120.07     79.00 93.42
# 205          50        66     64.96   7,800.00 120.08    461.00 93.56
#
#      duration  avg_measure  sum_measure  prod_rate  tt_inst_prod  joules  JPI  \
# 3         143         3.53       913.50      14.98      1,800.00  423.08 0.24
# 24        127         1.32         0.00      99.83     11,980.00  158.23 0.01
# 324       127         1.32         0.00      19.97      2,400.00  158.43 0.07
# 29        125         1.32         0.00      94.84     11,400.00  158.23 0.01
# 307       126         1.32         0.00      14.98      1,800.00  158.73 0.09
# 242       129         3.58       837.20     149.74     17,970.00  428.67 0.02
# 250        66         1.32         0.00     776.04     45,312.00   76.86 0.00
# 269       128         1.32         0.00     154.72     18,569.00  158.23 0.01
# 68        126         3.94       897.30     324.32     38,935.00  471.73 0.01
# 66        125         3.87       879.10     334.29     40,133.00  465.58 0.01
# 212       125         1.32         0.00     598.35     71,880.00  158.56 0.00
# 205       125         1.32         0.00      64.90      7,800.00  158.58 0.02
#
#     PERC     tput
# 3     10    15.01
# 24    10    99.99
# 324   10    20.01
# 29    10    94.99
# 307   10    14.98
# 242   10   149.98
# 250   10   778.56
# 269   10   154.98
# 294   10   707.72
# 285   10   139.96
# 178   10   124.98
# 201   10   665.00
# 241   10   129.97
# 80    10   583.48
# 76    10   114.98
# 228   10   144.98
# 225   10   777.62
# 144   10   154.97
# 52    10   687.36
# 129   10   134.93
# 245   10    65.01
# 118   10   328.64
# 32    10    64.90
# 193   10   299.30
# 182   10    59.95
# 164   10    35.01
# 141   10   203.26
# 281   10    40.00
# 151   10   199.73
# 79    10    59.52
# 14    10    70.01
# 188   10    40.01
# 272   10    64.85
# 136   10    34.93
# 124   10   194.31
# 49    10   199.91
# 253   10   107.77
# 217   10   179.71
# 171   10    99.99
# 134   10   173.98
# 109   10   187.31
# 96    10   102.69
# 207   10   169.77
# 158   10    94.99
# 44    10   194.63
# 102   10   228.67
# 316   10   128.04
# 184   10   184.72
# 8     10    99.98
# 51    10   159.96
# 189   10   164.84
# 301   10    94.99
# 165   10   134.55
# 283   10    74.79
# 106   10   165.37
# 197   10   228.09
# 266   10   115.67
# 209   10   267.49
# 114   10   154.79
# 0     10    32.18
# 104   10    37.12
# 260   10    40.22
# 101   10    38.17
# 322   10   148.69
# 115   10   168.44
# 221   10   168.22
# 163   10    99.86
# 317   10   149.73
# 303   10   172.88
# 130   10   180.75
# 21    10   119.54
# 127   10   169.51
# 296   10   182.90
# 54    10   174.91
# 257   10   114.81
# 41    10    31.07
# 37    10    41.27
# 1     10    48.14
# 12    10    29.80
# 292   10    40.40
# 229   10    47.49
# 33    10      NaN
# 65    10    44.57
# 45    10     4.97
# 6     10   179.97
# 177   10   178.45
# 94    10   309.53
# 73    10    29.98
# 291   10 1,194.04
# 88    10 1,228.81
# 23    10 1,845.72
# 195   10   204.91
# 120   10   982.70
# 191   10   996.94
# 72    10 1,833.22
# 83    10   199.87
# 121   10    49.53
# 63    10 1,294.86
# 108   10 1,945.23
# 274   10   214.92
# 58    10   413.98
# 89    10   449.63
# 36    10   744.81
# 4     10    79.87
# 68    10   324.82
# 66    10   332.72
# 212   10   597.99
# 205   10    64.96
# Empty DataFrame
# Columns: [index, algorithm, dataset, cores, batch_size, inc_rate, out_rate, instances, time, delay, acc, duration, avg_measure, sum_measure, prod_rate, tt_inst_prod, joules, JPI, PERC, tput]
# Index: []
# Empty DataFrame
# Columns: [index, algorithm, dataset, cores, batch_size, inc_rate, out_rate, instances, time, delay, acc, duration, avg_measure, sum_measure, prod_rate, tt_inst_prod, joules, JPI, PERC, tput]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb Cell 46' in <module>
#       <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000046?line=4'>5</a> # showdf = showdf.loc[:,['dataset','algorithm','batch_size','acc', 'instances', 'time']].sort_values(by=['batch_size'])
#       <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000046?line=5'>6</a> # showdf = select_columns_and_rename_values(showdf)
#       <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000046?line=6'>7</a> # showdf['IPS'] = showdf['instances'] / showdf['time']
#       <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000046?line=7'>8</a> display(df)
# ----> <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000046?line=8'>9</a> gen_graph_initial_peralg(df, display_df=False, freq=freq)
#
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb Cell 42' in gen_graph_initial_peralg(df, display_df, freq)
#      <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000042?line=18'>19</a>     my_id = datasets.index(ds)
#      <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000042?line=19'>20</a>     ax = axs[int(my_id/2)][my_id%2]
# ---> <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000042?line=20'>21</a>     plot(ax, dsdf, my_id, x)
#      <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000042?line=21'>22</a> plt.savefig(f'{filename}.eps', bbox_inches='tight')
#
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb Cell 41' in plot(ax, dsdf, my_id, x)
#       <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000041?line=3'>4</a> c2 = 'tab:blue'
#       <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000041?line=4'>5</a> c3 = 'tab:green'
# ----> <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000041?line=5'>6</a> ds = list(dsdf.dataset)[0]
#       <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000041?line=6'>7</a> ax.set_title(f'{dsformalname[ds]}')
#       <a href='vscode-notebook-cell:/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/Compare-Frequency-MiniBatching.ipynb#ch0000041?line=7'>8</a> ax.plot(x, pd.to_numeric(dsdf.acc), color=c1, label='acc')
#
# IndexError: list index out of range

# %% [markdown]
# To analisy the accuracy is compared the IPS now fixed in algorithm ARF. First, we see the results to dataset airlines, this dataset to not see big diferences when used more or minus IPS to processe in accuracy. The accuracy is maintain same increased more IPS. But, this case can see a big diference in quantity IPS is sequential without mini-batching and sequential with mini-batching basically IPS tends to grow a lot all scenaries. The same happen in frequency 1200. But the number of IPS to maximum frequency is more than double.

# %% [markdown]
# # Consumer TPUT Data

# %%
def aux2_tput(df, ax, mTput, legend=False, title=False, ylabels=False, ds='', bar=False, share_y=False, log_y=False, norm=False, hide=True):
    if norm:
        df = my_norm(df, x=norm)
    global rate
    width = 0.15
    alg_order = ['B50', 'B500', 'B2000']
    labels = ['10%', '50%', '90%']
    line_format = ['-', '--', ':', '-.', (0, (3, 5, 1, 5, 1, 5))]
    linfo = '--'
    x = np.arange(len(labels))
    lns_l = []
    versions = len(alg_order)

    for i in range(versions):
        adf = df.iloc[i]
        values = [adf.tput_10, adf.tput_50, adf.tput_90]
        if bar:
            lns_l += ax.bar(x - ((1 - i) * width), values, width, label=f'Tput-{alg_order[i]}')
        else:
            lns_l += ax.plot(x, values, label=f'Tput-{alg_order[i]}')

    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    if log_y:
        ax.set_yscale('log')
    if title:
        alg_title = re.sub('Sequential', '', df.algorithm.iloc[0])
        ax.set_title(f'{alg_title}')
    if ylabels:
        ax.set_ylabel(ds)
    if last:
        ax.set_ymargin(2)
    labs = [l.get_label() for l in lns_l]
    if legend:
        ax.legend(lns_l, labs, loc=0)
    if share_y == 'row':
        ax.set_ylim(bottom=0, top=mTput)

# %%
def aux_tput(ds, axis, id_ds, df, bar=False, share_y='row', log_y=False, norm=False):
    rates = ['10', '50', '90']
    algs = ['Ada', 'L', 'Patches', 'Adwin', 'ASHT', 'OzaBag']
    global title
    global labels
    hide_axis = True
#     get max value from delay for all rates on all algorithms for this dataset
    mLstTput = []
    if share_y == 'row':
        for rt in rates:
            rtDF = df[df.PERC == rt]
            mLstTput.append(rtDF.tput.max())
        mTput = max(mLstTput)*1.05
    else:
        mTput = 0
    for alg in algs:
        dsalgdf = filter_by_substring_algorithm(df, alg).sort_values(['algorithm','batch_size','cores'])
        for rt in rates:
            if rt == '10':
                showdf = rename_columns_by_rate(dsalgdf[dsalgdf.PERC == rt])
            else:
                to_join = dsalgdf[dsalgdf.PERC == rt]
                showdf = showdf.merge(rename_columns_by_rate(to_join),
                                  on=['algorithm', 'dataset', 'batch_size', 'cores']).sort_values(['batch_size','cores'])

        if 'Ada' in alg:
            aux2_tput(showdf, axis[id_ds][algs.index(alg)], mTput, title=title, ylabels=True, ds=ds, bar=bar, share_y=share_y, log_y=log_y, norm=norm)
        else:
            if algs[-1] == alg:
                hide_axis = False
            aux2_tput(showdf, axis[id_ds][algs.index(alg)], mTput, title=title, bar=bar, share_y=share_y, log_y=log_y, norm=norm, hide=hide_axis)

# %%
def show_tput(df, share_y='row', bars=False, log_y=False, norm=False, freq=''):
    print(f'{freq}\nshare_y: {share_y}\nlog_y: {log_y}\nnorm: {norm}')
    datasets = ['airlines', 'GMSC','elecNormNew','covtypeNorm']
    fig, axis = plt.subplots(len(datasets), 6, figsize=(16,12), tight_layout=True, sharey=share_y)
    global title
    global labels
    global last
    global twin
    leg = False
    labls = True
    title = True
    last = False
    twin = axis[0][0]
    for ds in datasets:
        if datasets.index(ds) == (len(datasets) - 1):
            last = True

        dsdf = df[df.dataset == ds]               
        aux_tput(ds, axis, datasets.index(ds), dsdf, bar=bars, share_y=share_y, log_y=log_y, norm=norm)
        title = False
    lines, labels = axis[0][0].get_legend_handles_labels()
    lgd = fig.legend(lines, labels, loc=8, ncol=5, bbox_to_anchor=(0.5, -0.02))
    lgd.set_in_layout(True)
    fig.subplots_adjust(bottom=-0.5)
    filename = 'all-Tput'
    if bars:
        filename = f'bars-{filename}'
    if share_y:
        filename = f'sharey-{filename}'
    if log_y:
        filename = f'logy-{filename}'
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.eps', pad_inches=0.2, bbox_inches='tight')
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.png', pad_inches=0.2, bbox_inches='tight')
    plt.show()

# %%
for freq,df in zip(freqs,dataframes):
    print(f'\n\n\n----------------- {freq} -----------------')

    ### temporario pega todos os nans, a media entre os valores preenchidos e coloca nestes campos vazios
    df['tput'] = df['tput'].replace(np.nan, 0)
    df = df.reset_index()
    total = 0
    average = 0 
    for index, row in df.iterrows():
        if int(row['tput']) > 0:
            total += row['tput']

    average = total / len(df.index)
    df['tput'] = df['tput'].replace(0, average)
    ### final do código temporario

    show_tput(df, freq=freq.title())
# Out:
# ----------------- 600 -----------------
# 600
# share_y: row
# log_y: False
# norm: False
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ----------------- 1200 -----------------
# 1200
# share_y: row
# log_y: False
# norm: False
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
