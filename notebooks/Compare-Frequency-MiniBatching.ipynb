# %% [markdown]
# # Compare Frequency (XUE3M) with Mini Batching
#
# This notebook compare results using alternate frequencys and mini batching implementation to objective what more efficiency energy and maintain acurracy values. The results compareds this work use follow variables.
#
# Frequencies in MHz:
#
#     - Minimum: 600Mhz, Maximum: 600Mhz
#     - Minimum: 1200Mhz, Maximum: 1200Mhz
#
# Size mini-batching uses are:
#
#     - 1 (Sequential without mini-batching)
#     - 1 (Sequential with mini-batching)
#     - 50 (Paralel 4 CPUs with mini batching)
#     - 500 (Paralel 4 CPUs with mini batching)
#     - 2000 (Paralel 4 CPUs with mini batching)
#
# All executions are used ensemble size 25.

# %% [markdown]
# # Main Question
#
# Is possible use low frequency clock to consumer minus energy and maintain the accuracy algorithms

# %% [markdown]
# # Acurracy Frequencies X Mini-Batchings
#
# - A low (minimum) frequency is had same or near accuracy with mini-batching and without mini-batching
# - A high (minimum) frequency is had same or near accuracy with mini-batching and without mini-batching

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
# %mkdir -p parsed_csvs figures
# %cd results
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %%
def parse(fname):
    global header_printed
    #index of wanted columns
    columns = []
    #column names to get the data from
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    ret_string = ''
    #remove the path and isolate the filename
    spname = fname.split('/')[-1].split('-')
    spline = []
    #control flag for knowing when the column names have already been discovered
    got = False
    #we ignore the first parameter of the filename and add all others to the csv string
    for s in spname[1:]:
        ret_string += s + ','
    #should probably use a safer way, but python handles the closing of the file
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                #sometimes the dump file has multiple results in it, so we get the index of wanted columns only once
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        #OzaBagASHT bugs out on GMSC, this reuses the data from the sequential execution
        if 'GMSC' in spname and 'ASHT' in spname[2]:
            for c in columns[:-2]:
                ret_string += str(spline[c]) + ','
            ret_string += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        #normal code, how everything should run
        #we process the data (add the content of wanted columns to the csv string) only after the for
        #ensuring we use only the last (most recent) data and not the intermediate results
        else:
            for c in columns:
                ret_string += str(spline[c]) + ','
            if len(columns) == 5:
                ret_string += '0,'
        #header is a global variable, it will only be printed on the first file 
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,instances,time,acc,prec,recall,change'
            ret_string = f"{head}\n{ret_string}"
            header_printed = True
        #remove the last comma ,
        return (ret_string[:-1])

# %%
#loads the csv as a dataframe and standardizes the algorithm names 
def load_df(filename):
    df = pd.read_csv(filename, index_col=False)
    return select_columns_and_rename_values(df)

# %%
#standardize algorithm names
def select_columns_and_rename_values(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    df.batch_size.unique()
    return df

# %%
#filters by substring (there are multiple OzaBag algorithms)
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %%
#plots precision and recall with markers of one parameter configuration
def gen_lines(df, ax, alg_order, markers):
    lwidth = 0.75
    if markers:
        colors=['go', 'bs', 'rP', 'md', 'y+' , 'k*']
    else:
        colors=['g', 'b', 'r', 'm', 'y' , 'k']

    labels = df.batch_size
    alg = df.algorithm.unique()[0]
    x = np.arange(len(labels))
    
    ax.plot(x, pd.to_numeric(df.prec), f'{colors[alg_order]}--', linewidth=lwidth, label=f'{alg}-prec')
    ax.plot(x, pd.to_numeric(df.recall), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')

    #ax.plot(x,pd.to_numeric(df.prec), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_ylim(50,95)

# %%
#iterates over the parameter configurations and creates the chart grid
def gen_chart(df, markers=True, tables=False, frequencies=[], dataset=''):
    #dictionary containing the correct name to be printed
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
   
    #creates a 2x2 grid for plotting the charts
    #sharey=row means that all charts in a row share the same Y-axis
    fig, axs = plt.subplots(1, 2, figsize=(8,4), sharey='row')
    filename = "batch-size-vs-prediction-mark" if markers else "batch-size-vs-prediction"

    for frequency in frequencies:
        my_id = frequencies.index(frequency)
        #selects the correct position in the grid
        ax = axs[my_id]
        ax.set_title(f'{dataset} - Frequency {frequency}Mhz x {frequency}Mhz')

        #for each algorithm
        for alg in algorithms:
            #filters the df to contain the wanted values
            df_aux = filter_by_substring_algorithm(df[frequency][df[frequency].dataset == dataset].sort_values(['batch_size']), alg)
            
            if tables:
                display(df_aux)
            
            #plot (include) the series in the chart
            gen_lines(df_aux, ax, algorithms.index(alg), markers)
            
            #if its the first column, print Y-axis label
            ax.set_ylabel('Percentage')
            ax.set_xlabel('Batch sizes')

    #retrieves the handles and labels to create a global legend
    handles, labels = axs[0].get_legend_handles_labels()
    lgd = fig.legend(handles, labels, loc = 'lower center', ncol = math.ceil(len(algorithms)), bbox_to_anchor=(0.5,-0.1))
    fig.tight_layout()
    plt.savefig(f'figures/{filename}.png')
    plt.savefig(f'figures/{filename}.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

frequencies = ['600', '1200']
df = { '600': [], '1200': []}
for frequency in frequencies:
    resultsFolder = f"results/31-01-2022/{frequency}/{frequency}/first"
    csvFile = f"parsed_csvs/data-batch-vs-acc-{frequency}-{frequency}.csv"
    directory = os.fsencode(resultsFolder)
    header_printed = False

    with open(f"{csvFile}", "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("dump-"): 
                output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

    df[frequency] = load_df(f'{csvFile}')
    df[frequency] = df[frequency].drop(['cores', 'time'], axis=1)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
#false makes the chart without markers
datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
for ds in datasets:
    gen_chart(df, True, frequencies=frequencies, dataset=ds)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Low frequency (minimum) in clock CPU 600MHz had precision and recall decreased when size mini-batching increased. For example, in dataset Airlines algoritmh Adaptative Random Forest (ARF) first interation has precision on 70% but has a mini-batching size 2000 precision is reduce to 60%. Others algorithms to same behavior. Has a number precision major when has sequential without mini-batching but when mini-batching increased is precision decreased.
#
# High frequency (maximum) in clock CPU 1200MHz same similar behavior, analisyng same algorithm we can see it start in precision on 65% but decreased when size batch major. In size batch is 200 precision that near 62%.
#
# Precision and recall is near in minimum or maximum frequency when compared a sequential algorithm. In examples before, the precision ARF in sequential algorithm without mini-batching stay in near 60% while same algorithm without mini-batching paralel had precision in 63% in minimum frequency. In maximum frequency the precision stay in 63% without mini-batching and 65% with paralel execution. The paralelization was use 4 cores.

# %% [markdown]
# # Frequencies results
#
# Analising all frequencies in four datasets is possible see not big changes in each frequency utilized. All results aparently same precision in recall in percentage.

# %% [markdown]
# # Consumer Energy
#
# Now I need analisy the consumer energy to each frequency. Energy consumer is analising by JPI and Joules consumeds a period time. To obtained this data are used a follow architeture. We analisy the results of consumer each frequency from now with data accuracy already analised.
#
# To this, us define some questions:
#
# - Consumer energy is major in frequecy maximum
# - Consumer energy is minor in frequency minimum
# - Consumer energy reflect in accuracy when minimum frequecy
# - Consumer energy reflect in accuracy when maximum frequecy
# - Tax rate implicate more consumer of energy

# %%
PATH_TO_RESULTS = '/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/socket/01-03-2022/'

# %%
def parse_MOA(fname):
    global header_printed
    columns = []
    wanted = ['learning evaluation instances', 'Wall Time (Actual Time)', 'Avg Delay (ms)', 'outRate (inst/s)', 'classifications correct (percent)']
    pstr = ''
    spname = fname.split('/')[-1].split('-')
    spline = []
    for s in spname[1:]:
        pstr += s + ','
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                spline = line.split(',')
                for s in spline:
                    if s in wanted:
                        columns.append(spline.index(s))
            else:
                spline = line.split(',')
        for c in columns:
            pstr += spline[c] + ','
        if len(columns) == 2:
            pstr += '1,'
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,inc_rate,instances,time,delay,out_rate,acc'
            pstr = f"{head}\n{pstr}"
            header_printed = True
        return (pstr[:-1])

# %%
def read_MOA(folder, out_file):
    directory = os.fsencode(folder)
    global header_printed

    with open(out_file, "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("term-"): 
                output.write(f"{parse_MOA(f'{os.fsdecode(directory)}/{filename}')}\n")
    fname = os.fsdecode(out_file)
    df = pd.read_csv(fname)

    df['inc_rate'].astype('int64')
    return df[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'instances', 'time', 'delay', 'out_rate', 'acc']]

# %% [markdown]
# # Read Energy Data

# %%
def load_Wmeas(filename):
    return pd.read_csv(filename, header=None, names=['date', 'time', 'measure'])

# %%
def exper_order_to_dict(filename, d):
    with open(filename) as forder:
        got_timestamp = False
        dataset = algorithm = Esize = cores = Bsize = ''
        dnow=None
        for line in forder:
            if not got_timestamp:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
                if dnow:
                    dnow['finish'] = date_time_obj - datetime.timedelta(seconds=1)
            elif ':' not in line:
                spline = line.split('/')[-1].strip().split('-')
                #print(spline)
                if len(spline) == 6:
                    dataset,algorithm,Esize,cores,Bsize,rate = spline
                else:
                    dataset,algorithm,Esize,cores,Bsize,rate = *spline,1
                if algorithm not in d:
                    d[algorithm] = {}
                if dataset not in d[algorithm]:
                    d[algorithm][dataset] = {}
                if Esize not in d[algorithm][dataset]:
                    d[algorithm][dataset][Esize] = {}
                if cores not in d[algorithm][dataset][Esize]:
                    d[algorithm][dataset][Esize][cores] = {}
                if Bsize not in d[algorithm][dataset][Esize][cores]:
                    d[algorithm][dataset][Esize][cores][Bsize] = {}
                if rate not in d[algorithm][dataset][Esize][cores][Bsize]:
                    d[algorithm][dataset][Esize][cores][Bsize][rate] = {'start': date_time_obj, 'finish': ''}
                    dnow = d[algorithm][dataset][Esize][cores][Bsize][rate]
                got_timestamp = False
            else:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
    return d

# %%
def populate_dict(d, df):
    df['datetime'] = df['date'] + ' ' + df['time']
    for k, v in d.items():
        for k1, v1 in v.items():
            for k2, v2 in v1.items():
                for k3, v3 in v2.items():
                    for k4, v4 in v3.items():
                        for k5, v5 in v4.items():
                            if 'seconds' not in v5:
                                st = v5['start']
                                ed = v5['finish']
                                v5['seconds'] = (ed - st).seconds
                                new_df = df[(df.datetime <= f'{ed.strftime("%d/%m/%y")} {ed.strftime("%X")}')
                                          & (df.datetime >= f'{st.strftime("%d/%m/%y")} {st.strftime("%X")}')]
                                v5['avg_measure'] = new_df['measure'].mean()
                                v5['sum_measure'] = new_df['measure'].sum()
                                v5['avg_times_seconds'] = v5['avg_measure'] * v5['seconds']
    return d

# %%
def append_dict_to_df(d, ensemble_size=False):
    dappend = {'algorithm': [], 'dataset': [], 'ensemble_size': [], 'cores': [], 
               'batch_size': [], 'duration': [], 'inc_rate': [], 'avg_measure': [], 'sum_measure': [], 'avg_times_seconds': []}
    for kalg,valg in d.items():
        for kds,vds in valg.items():
            for kens,vens in vds.items():
                for kcore,vcore in vens.items():
                    for kmbs,vmbs in vcore.items():
                        for krate,vrate in vmbs.items():
                            dappend['algorithm'].append(kalg)
                            dappend['dataset'].append(kds)
                            dappend['ensemble_size'].append(kens)
                            dappend['cores'].append(kcore)
                            dappend['batch_size'].append(kmbs)
                            dappend['duration'].append(vrate['seconds'])
                            dappend['inc_rate'].append(krate)
                            for key in ['avg_measure', 'sum_measure','avg_times_seconds']:
                                dappend[key].append(vrate[key])
    adf = pd.DataFrame(data=dappend)
    adf = adf.sort_values(['algorithm','dataset']).astype({'inc_rate': 'int64', 
                                                           'cores': 'int64',
                                                           'batch_size': 'int64'})
    if ensemble_size:
        return adf[['algorithm', 'dataset', 'ensemble_size', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]
    return adf[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]

# %% [markdown]
# # Parse SSH Logs

# %%
def parse_SSH(fname):
    fname = os.fsdecode(fname)
    read_ssh = False
    alg = ''
    dataset = ''
    rate = ''
    d = {'algorithm': [], 'dataset': [], 'batch_size': [], 'inc_rate': [], 'prod_rate': [], 'tt_inst_prod': []}
    with open (fname, "r") as file:
        for line in file:
            if not read_ssh:
                if 'ssh-' in line:
                    read_ssh = True
                    spline = line.split('-')
                    if "MAX" in line:
                        if len(spline[1:]) == 3:
                            dataset, alg, rate = spline[1:]
                            bsize = 500
                        else:
                            dataset, alg, bsize, rate = spline[1:]
                    else:
                        dataset, alg, rate = spline[1:]
                        bsize = 1
                    d['algorithm'].append(alg)
                    d['dataset'].append(dataset)
                    d['inc_rate'].append(rate.strip())
                    d['batch_size'].append(bsize)
            else:
                if 'Total instances Producer' in line:
                    tt_inst = float(line.split(': ')[1])
                    d['tt_inst_prod'].append(tt_inst)
                elif 'Producer Rate' in line:
                    prod_rate = float(line.split(': ')[1])
                    d['prod_rate'].append(prod_rate)
                    read_ssh = False
    return pd.DataFrame.from_dict(d).astype({'inc_rate': 'int64'})

# %% [markdown]
# # Showing and preparing for charts

# %%
def filter_fields(df):
    wanted = ['algorithm', 'dataset', 'batch_size', 'cores', 'out_rate', 'instances', 'delay', 'joules', 'JPI']
    return df[[
        l for l in df.columns if any([w in l for w in wanted])
    ]]

# %%
def rename_columns_by_rate(df):
    rate = df.PERC.iloc[0]
    return df.rename(columns={"out_rate": f"out_rate_{rate}", "instances": f"instances_{rate}", 
                                "delay": f"delay_{rate}", "joules": f"joules_{rate}", 
                                "JPI": f"JPI_{rate}", "tput": f"tput_{rate}"})

# %%
def show_graph_JPI_delay(df, ax, mJPI, mDel, legend=False, title=False, ylabels=False, ds='', bar=False, share_y=False, log_y=False, norm=False, hide=True):
    if norm:
        df = my_norm(df, x=norm)
    global rate
    global twin
    width = 0.15
    alg_order = ['B50', 'B500', 'B2000']
    labels = ['10%', '50%', '90%']
    line_format = ['-', '--', ':', '-.', (0, (3, 5, 1, 5, 1, 5))]
    linfo = '--'
    x = np.arange(len(labels))
    lns_l = []
    versions = 3
    for i in range(versions):
        adf = df.iloc[i]
        values_j = [adf.JPI_10, adf.JPI_50, adf.JPI_90]
        if bar:
            lns_l += ax.bar(x - ((1 - i) * width), values_j, width, label=f'JPI-{alg_order[i]}')            
        else:
            lns_l += ax.plot(x, values_j, label=f'JPI-{alg_order[i]}')

    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax_r = ax.twinx()
    twin = ax_r
    if log_y:
        ax.set_yscale('log')
        ax_r.set_yscale('log')
    if title:
        alg_title = re.sub('Sequential', '', df.algorithm.iloc[0])
        ax.set_title(f'{alg_title}')
    if ylabels:
        ax.set_ylabel(ds)
    if last:
        ax.set_ymargin(2)
    for i in range(versions): 
        adf = df.iloc[i]
        values_d = [ x/1000 for x in [adf.delay_10, adf.delay_50, adf.delay_90]]
        if bar:
            linfo = f'k{line_format[i]}'
            lns_l += ax_r.plot(x, values_d, color='black', linestyle=line_format[i], label=f'delay-{alg_order[i]}')
        else:
            lns_l += ax_r.plot(x, values_d, linfo, label=f'delay-{alg_order[i]}')
    labs = [l.get_label() for l in lns_l]
    if legend:
        ax.legend(lns_l, labs, loc=0)
    if hide:
        ax_r.set_yticklabels([])
    if share_y == 'row':
        ax.set_ylim(top=mJPI)
        ax_r.set_ylim(top=mDel/1000)

# %%
def aux_graphNx1(ds, axis, id_ds, df, bar=False, share_y='row', log_y=False, norm=False):
    rates = ['10', '50', '90']
    algs = ['Ada', 'L', 'Patches', 'Adwin', 'ASHT', 'OzaBag']
    global title
    global labels
    hide_axis = True
#     fig.suptitle(f'JPI and delay for {ds}', fontsize=18, y=1)
#     get max value from delay for all rates on all algorithms for this dataset
    mLstJPI = []
    mLstDel = []
    if share_y == 'row':
        for rt in rates:
            rtDF = df[df.PERC == rt]
            mLstJPI.append(rtDF.JPI.max())
            mLstDel.append(rtDF.delay.max())
        mJPI = max(mLstJPI)*1.05
        mDel = max(mLstDel)*1.05
    else:
        mJPI = mDel = 0
    for alg in algs:
        dsalgdf = filter_by_substring_algorithm(df, alg).sort_values(['algorithm','batch_size','cores'])
#         if alg == 'L' and ds == 'kyoto_binary':
#             display(dsalgdf)
        for rt in rates:
            if rt == '10':
                showdf = rename_columns_by_rate(dsalgdf[dsalgdf.PERC == rt])
            else:
                to_join = dsalgdf[dsalgdf.PERC == rt]
                showdf = showdf.merge(rename_columns_by_rate(to_join),
                                  on=['algorithm', 'dataset', 'batch_size', 'cores']).sort_values(['batch_size','cores'])
       
        # debug print, if it shows it is wrong
        # if len(showdf) != 5:
        #     display(showdf)

        if 'Ada' in alg:
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, ylabels=True, ds=ds, bar=bar, share_y=share_y, log_y=log_y, norm=norm)
        else:
            if algs[-1] == alg:
                hide_axis = False
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, bar=bar, share_y=share_y, log_y=log_y, norm=norm, hide=hide_axis)

# %%
def gen_graph(df, bars=False, share_y='row', log_y=False, norm=False, freq='600', tput=False):
    ps = f'{freq}\nbars: {bars}\nshare_y: {share_y}\nlog_y: {log_y} '
    datasets = ['airlines', 'GMSC','elecNormNew','covtypeNorm']

    fig, axis = plt.subplots(len(datasets), 6, figsize=(16,12), tight_layout=True, sharey=share_y)
    global title
    global labels
    global last
    global twin
    leg = False
    labls = True
    title = True
    last = False
    twin = axis[0][0]
    for ds in datasets:
        if datasets.index(ds) == (len(datasets) - 1):
            last = True
        dsdf = df[df.dataset == ds]
        aux_graphNx1(ds, axis, datasets.index(ds), dsdf, bar=bars, share_y=share_y, log_y=log_y, norm=norm)
        title = True
    lines_1, labels_1 = axis[0][0].get_legend_handles_labels()
    lines_2, labels_2 = twin.get_legend_handles_labels()
    lines = lines_1 + lines_2
    labels = labels_1 + labels_2
    lgd = fig.legend(lines, labels, loc=8, ncol=5, bbox_to_anchor=(0.5, -0.02))
    lgd.set_in_layout(True)
    fig.subplots_adjust(bottom=-0.5)
    filename = 'all-4x1-JPI-delay'
    if bars:
        filename = f'bars-{filename}'
    if share_y:
        filename = f'sharey-{filename}'
    if log_y:
        filename = f'logy-{filename}'
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.eps', pad_inches=0.2, bbox_inches='tight')
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.png', pad_inches=0.2, bbox_inches='tight')
    plt.show()

# %%
def debug(df):
    df = select_columns_and_rename_values(df)
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    dfalg = filter_by_substring_algorithm(df, alg)
    for ds in datasets:
        dsdf = dfalg[(dfalg.dataset == ds)]
        display(dsdf)

# %%
file_name = f"{PATH_TO_RESULTS}600/600/inst-and-delay-bkp.csv"
file_name_output = f"{PATH_TO_RESULTS}600/600/inst-and-delay.csv"

df = pd.read_csv(file_name)
display(df)
# Notes:
# - the `subset=None` means that every column is used 
#    to determine if two rows are different; to change that specify
#    the columns as an array
# - the `inplace=True` means that the data structure is changed and
#   the duplicate rows are gone  
df.drop_duplicates(subset=None, inplace=True)

# Write the results to a different file
df.to_csv(file_name_output, index=False)
# Out:
#          dataset                               algorithm  ensemble_size  \
# 0       airlines  StreamingRandomPatchesExecutorMAXChunk             25
# 1       airlines                    LBagExecutorMAXChunk             25
# 2    elecNormNew  StreamingRandomPatchesExecutorMAXChunk             25
# 3           GMSC                    LBagExecutorMAXChunk             25
# 4           GMSC  StreamingRandomPatchesExecutorMAXChunk             25
# 5    covtypeNorm              OzaBagASHTExecutorMAXChunk             25
# 6    covtypeNorm             OzaBagAdwinExecutorMAXChunk             25
# 7       airlines                    LBagExecutorMAXChunk             25
# 8    covtypeNorm                    LBagExecutorMAXChunk             25
# 9    covtypeNorm  StreamingRandomPatchesExecutorMAXChunk             25
# 10   covtypeNorm                  OzaBagExecutorMAXChunk             25
# 11          GMSC              OzaBagASHTExecutorMAXChunk             25
# 12      airlines             OzaBagAdwinExecutorMAXChunk             25
# 13          GMSC                  OzaBagExecutorMAXChunk             25
# 14   elecNormNew  StreamingRandomPatchesExecutorMAXChunk             25
# 15   covtypeNorm             OzaBagAdwinExecutorMAXChunk             25
# 16      airlines             OzaBagAdwinExecutorMAXChunk             25
# 17   elecNormNew  StreamingRandomPatchesExecutorMAXChunk             25
# 18   elecNormNew                    LBagExecutorMAXChunk             25
# 19      airlines    AdaptiveRandomForestExecutorMAXChunk             25
# 20          GMSC                    LBagExecutorMAXChunk             25
# 21      airlines                    LBagExecutorMAXChunk             25
# 22      airlines                  OzaBagExecutorMAXChunk             25
# 23      airlines  StreamingRandomPatchesExecutorMAXChunk             25
# 24      airlines                    LBagExecutorMAXChunk             25
# 25   covtypeNorm  StreamingRandomPatchesExecutorMAXChunk             25
# 26   covtypeNorm              OzaBagASHTExecutorMAXChunk             25
# 27      airlines    AdaptiveRandomForestExecutorMAXChunk             25
# 28          GMSC             OzaBagAdwinExecutorMAXChunk             25
# 29      airlines             OzaBagAdwinExecutorMAXChunk             25
# 30   covtypeNorm                  OzaBagExecutorMAXChunk             25
# 31   covtypeNorm                    LBagExecutorMAXChunk             25
# 32   elecNormNew              OzaBagASHTExecutorMAXChunk             25
# 33      airlines              OzaBagASHTExecutorMAXChunk             25
# 34   covtypeNorm                  OzaBagExecutorMAXChunk             25
# 35          GMSC                    LBagExecutorMAXChunk             25
# 36   covtypeNorm    AdaptiveRandomForestExecutorMAXChunk             25
# 37          GMSC             OzaBagAdwinExecutorMAXChunk             25
# 38      airlines              OzaBagASHTExecutorMAXChunk             25
# 39      airlines                  OzaBagExecutorMAXChunk             25
# 40          GMSC              OzaBagASHTExecutorMAXChunk             25
# 41      airlines    AdaptiveRandomForestExecutorMAXChunk             25
# 42          GMSC    AdaptiveRandomForestExecutorMAXChunk             25
# 43      airlines              OzaBagASHTExecutorMAXChunk             25
# 44          GMSC    AdaptiveRandomForestExecutorMAXChunk             25
# 45          GMSC  StreamingRandomPatchesExecutorMAXChunk             25
# 46          GMSC             OzaBagAdwinExecutorMAXChunk             25
# 47          GMSC  StreamingRandomPatchesExecutorMAXChunk             25
# 48   elecNormNew             OzaBagAdwinExecutorMAXChunk             25
# 49      airlines    AdaptiveRandomForestExecutorMAXChunk             25
# 50   covtypeNorm  StreamingRandomPatchesExecutorMAXChunk             25
# 51   elecNormNew             OzaBagAdwinExecutorMAXChunk             25
# 52   elecNormNew             OzaBagAdwinExecutorMAXChunk             25
# 53          GMSC             OzaBagAdwinExecutorMAXChunk             25
# 54      airlines                  OzaBagExecutorMAXChunk             25
# 55   elecNormNew    AdaptiveRandomForestExecutorMAXChunk             25
# 56          GMSC                  OzaBagExecutorMAXChunk             25
# 57          GMSC                    LBagExecutorMAXChunk             25
# 58          GMSC             OzaBagAdwinExecutorMAXChunk             25
# 59   covtypeNorm              OzaBagASHTExecutorMAXChunk             25
# 60          GMSC  StreamingRandomPatchesExecutorMAXChunk             25
# 61   covtypeNorm             OzaBagAdwinExecutorMAXChunk             25
# 62          GMSC             OzaBagAdwinExecutorMAXChunk             25
# 63          GMSC              OzaBagASHTExecutorMAXChunk             25
# 64      airlines  StreamingRandomPatchesExecutorMAXChunk             25
# 65   covtypeNorm              OzaBagASHTExecutorMAXChunk             25
# 66      airlines  StreamingRandomPatchesExecutorMAXChunk             25
# 67   elecNormNew                  OzaBagExecutorMAXChunk             25
# 68   covtypeNorm    AdaptiveRandomForestExecutorMAXChunk             25
# 69          GMSC              OzaBagASHTExecutorMAXChunk             25
# 70   covtypeNorm             OzaBagAdwinExecutorMAXChunk             25
# 71          GMSC              OzaBagASHTExecutorMAXChunk             25
# 72   elecNormNew              OzaBagASHTExecutorMAXChunk             25
# 73   covtypeNorm    AdaptiveRandomForestExecutorMAXChunk             25
# 74      airlines                  OzaBagExecutorMAXChunk             25
# 75   covtypeNorm                  OzaBagExecutorMAXChunk             25
# 76          GMSC              OzaBagASHTExecutorMAXChunk             25
# 77   elecNormNew                    LBagExecutorMAXChunk             25
# 78          GMSC             OzaBagAdwinExecutorMAXChunk             25
# 79          GMSC              OzaBagASHTExecutorMAXChunk             25
# 80   elecNormNew                    LBagExecutorMAXChunk             25
# 81          GMSC                    LBagExecutorMAXChunk             25
# 82   covtypeNorm                  OzaBagExecutorMAXChunk             25
# 83          GMSC                  OzaBagExecutorMAXChunk             25
# 84          GMSC    AdaptiveRandomForestExecutorMAXChunk             25
# 85      airlines              OzaBagASHTExecutorMAXChunk             25
# 86   elecNormNew              OzaBagASHTExecutorMAXChunk             25
# 87      airlines             OzaBagAdwinExecutorMAXChunk             25
# 88      airlines    AdaptiveRandomForestExecutorMAXChunk             25
# 89   covtypeNorm             OzaBagAdwinExecutorMAXChunk             25
# 90   covtypeNorm  StreamingRandomPatchesExecutorMAXChunk             25
# 91      airlines  StreamingRandomPatchesExecutorMAXChunk             25
# 92   elecNormNew              OzaBagASHTExecutorMAXChunk             25
# 93      airlines    AdaptiveRandomForestExecutorMAXChunk             25
# 94   elecNormNew    AdaptiveRandomForestExecutorMAXChunk             25
# 95   elecNormNew              OzaBagASHTExecutorMAXChunk             25
# 96   elecNormNew                    LBagExecutorMAXChunk             25
# 97      airlines             OzaBagAdwinExecutorMAXChunk             25
# 98   covtypeNorm    AdaptiveRandomForestExecutorMAXChunk             25
# 99      airlines                    LBagExecutorMAXChunk             25
# 100     airlines             OzaBagAdwinExecutorMAXChunk             25
# 101  elecNormNew    AdaptiveRandomForestExecutorMAXChunk             25
# 102  elecNormNew  StreamingRandomPatchesExecutorMAXChunk             25
# 103         GMSC                  OzaBagExecutorMAXChunk             25
# 104  covtypeNorm             OzaBagAdwinExecutorMAXChunk             25
# 105  elecNormNew  StreamingRandomPatchesExecutorMAXChunk             25
# 106     airlines    AdaptiveRandomForestExecutorMAXChunk             25
# 107     airlines                  OzaBagExecutorMAXChunk             25
# 108  elecNormNew    AdaptiveRandomForestExecutorMAXChunk             25
# 109  covtypeNorm                    LBagExecutorMAXChunk             25
# 110  covtypeNorm              OzaBagASHTExecutorMAXChunk             25
# 111         GMSC  StreamingRandomPatchesExecutorMAXChunk             25
# 112  covtypeNorm                  OzaBagExecutorMAXChunk             25
# 113  covtypeNorm                  OzaBagExecutorMAXChunk             25
# 114  elecNormNew    AdaptiveRandomForestExecutorMAXChunk             25
# 115  elecNormNew    AdaptiveRandomForestExecutorMAXChunk             25
# 116     airlines              OzaBagASHTExecutorMAXChunk             25
# 117         GMSC  StreamingRandomPatchesExecutorMAXChunk             25
# 118  elecNormNew             OzaBagAdwinExecutorMAXChunk             25
# 119  elecNormNew                    LBagExecutorMAXChunk             25
# 120  elecNormNew                    LBagExecutorMAXChunk             25
# 121         GMSC  StreamingRandomPatchesExecutorMAXChunk             25
# 122  covtypeNorm              OzaBagASHTExecutorMAXChunk             25
# 123  elecNormNew    AdaptiveRandomForestExecutorMAXChunk             25
# 124  covtypeNorm  StreamingRandomPatchesExecutorMAXChunk             25
# 125  covtypeNorm                    LBagExecutorMAXChunk             25
# 126         GMSC             OzaBagAdwinExecutorMAXChunk             25
# 127         GMSC                    LBagExecutorMAXChunk             25
# 128  elecNormNew                    LBagExecutorMAXChunk             25
# 129         GMSC                  OzaBagExecutorMAXChunk             25
# 130  covtypeNorm    AdaptiveRandomForestExecutorMAXChunk             25
# 131     airlines                  OzaBagExecutorMAXChunk             25
# 132         GMSC  StreamingRandomPatchesExecutorMAXChunk             25
# 133  elecNormNew             OzaBagAdwinExecutorMAXChunk             25
# 134     airlines                    LBagExecutorMAXChunk             25
# 135         GMSC    AdaptiveRandomForestExecutorMAXChunk             25
# 136     airlines             OzaBagAdwinExecutorMAXChunk             25
# 137  covtypeNorm             OzaBagAdwinExecutorMAXChunk             25
# 138  covtypeNorm    AdaptiveRandomForestExecutorMAXChunk             25
# 139         GMSC    AdaptiveRandomForestExecutorMAXChunk             25
# 140  elecNormNew                  OzaBagExecutorMAXChunk             25
# 141  elecNormNew    AdaptiveRandomForestExecutorMAXChunk             25
# 142  covtypeNorm                    LBagExecutorMAXChunk             25
# 143  covtypeNorm                  OzaBagExecutorMAXChunk             25
# 144     airlines  StreamingRandomPatchesExecutorMAXChunk             25
# 145     airlines                  OzaBagExecutorMAXChunk             25
# 146     airlines                  OzaBagExecutorMAXChunk             25
# 147  elecNormNew                    LBagExecutorMAXChunk             25
# 148  elecNormNew              OzaBagASHTExecutorMAXChunk             25
# 149  covtypeNorm  StreamingRandomPatchesExecutorMAXChunk             25
# 150  elecNormNew              OzaBagASHTExecutorMAXChunk             25
# 151     airlines    AdaptiveRandomForestExecutorMAXChunk             25
# 152  elecNormNew              OzaBagASHTExecutorMAXChunk             25
# 153  covtypeNorm    AdaptiveRandomForestExecutorMAXChunk             25
# 154         GMSC                  OzaBagExecutorMAXChunk             25
# 155  elecNormNew             OzaBagAdwinExecutorMAXChunk             25
# 156         GMSC    AdaptiveRandomForestExecutorMAXChunk             25
# 157  covtypeNorm  StreamingRandomPatchesExecutorMAXChunk             25
# 158  elecNormNew             OzaBagAdwinExecutorMAXChunk             25
# 159  covtypeNorm    AdaptiveRandomForestExecutorMAXChunk             25
# 160  elecNormNew                  OzaBagExecutorMAXChunk             25
# 161     airlines              OzaBagASHTExecutorMAXChunk             25
# 162  elecNormNew                    LBagExecutorMAXChunk             25
# 163  elecNormNew                  OzaBagExecutorMAXChunk             25
# 164         GMSC                    LBagExecutorMAXChunk             25
# 165  elecNormNew                  OzaBagExecutorMAXChunk             25
# 166  covtypeNorm                  OzaBagExecutorMAXChunk             25
# 167         GMSC                  OzaBagExecutorMAXChunk             25
# 168     airlines  StreamingRandomPatchesExecutorMAXChunk             25
# 169     airlines              OzaBagASHTExecutorMAXChunk             25
# 170  elecNormNew             OzaBagAdwinExecutorMAXChunk             25
# 171     airlines  StreamingRandomPatchesExecutorMAXChunk             25
# 172     airlines                    LBagExecutorMAXChunk             25
# 173  covtypeNorm             OzaBagAdwinExecutorMAXChunk             25
# 174  covtypeNorm              OzaBagASHTExecutorMAXChunk             25
# 175     airlines    AdaptiveRandomForestExecutorMAXChunk             25
# 176  covtypeNorm    AdaptiveRandomForestExecutorMAXChunk             25
# 177         GMSC                    LBagExecutorMAXChunk             25
# 178  elecNormNew                  OzaBagExecutorMAXChunk             25
# 179  covtypeNorm                    LBagExecutorMAXChunk             25
# 180  covtypeNorm  StreamingRandomPatchesExecutorMAXChunk             25
# 181         GMSC              OzaBagASHTExecutorMAXChunk             25
# 182         GMSC             OzaBagAdwinExecutorMAXChunk             25
# 183  covtypeNorm    AdaptiveRandomForestExecutorMAXChunk             25
# 184  elecNormNew  StreamingRandomPatchesExecutorMAXChunk             25
# 185  elecNormNew    AdaptiveRandomForestExecutorMAXChunk             25
# 186  covtypeNorm                    LBagExecutorMAXChunk             25
# 187  elecNormNew                  OzaBagExecutorMAXChunk             25
# 188  covtypeNorm  StreamingRandomPatchesExecutorMAXChunk             25
# 189  covtypeNorm             OzaBagAdwinExecutorMAXChunk             25
# 190         GMSC    AdaptiveRandomForestExecutorMAXChunk             25
# 191     airlines                  OzaBagExecutorMAXChunk             25
# 192  elecNormNew             OzaBagAdwinExecutorMAXChunk             25
# 193         GMSC                  OzaBagExecutorMAXChunk             25
# 194     airlines    AdaptiveRandomForestExecutorMAXChunk             25
# 195         GMSC    AdaptiveRandomForestExecutorMAXChunk             25
# 196  elecNormNew                  OzaBagExecutorMAXChunk             25
# 197     airlines              OzaBagASHTExecutorMAXChunk             25
# 198         GMSC  StreamingRandomPatchesExecutorMAXChunk             25
# 199  elecNormNew              OzaBagASHTExecutorMAXChunk             25
# 200  covtypeNorm                    LBagExecutorMAXChunk             25
# 201         GMSC              OzaBagASHTExecutorMAXChunk             25
# 202     airlines             OzaBagAdwinExecutorMAXChunk             25
# 203         GMSC                  OzaBagExecutorMAXChunk             25
# 204         GMSC    AdaptiveRandomForestExecutorMAXChunk             25
# 205  elecNormNew  StreamingRandomPatchesExecutorMAXChunk             25
# 206     airlines             OzaBagAdwinExecutorMAXChunk             25
# 207     airlines  StreamingRandomPatchesExecutorMAXChunk             25
# 208         GMSC                    LBagExecutorMAXChunk             25
# 209  elecNormNew  StreamingRandomPatchesExecutorMAXChunk             25
# 210     airlines              OzaBagASHTExecutorMAXChunk             25
# 211  covtypeNorm                    LBagExecutorMAXChunk             25
# 212  covtypeNorm              OzaBagASHTExecutorMAXChunk             25
# 213  covtypeNorm              OzaBagASHTExecutorMAXChunk             25
# 214     airlines             OzaBagAdwinExecutorMAXChunk             25
# 215  elecNormNew                  OzaBagExecutorMAXChunk             25
# 216     airlines                    LBagExecutorMAXChunk             25
# 217     airlines                    LBagExecutorMAXChunk             25
# 218     airlines                  OzaBagExecutorMAXChunk             25
# 219  elecNormNew  StreamingRandomPatchesExecutorMAXChunk             25
#
#      cores  batch_size  inc_rate  instances   time     delay  out_rate    acc
# 0        4        2000        77   6,000.00 168.43 51,674.00     35.62  61.27
# 1        4          50        57   6,000.00 120.44    983.00     49.82  64.27
# 2        4        2000        19   1,800.00 119.96 79,340.00     15.01  40.33
# 3        4          50        83   9,586.00 120.00    371.00     79.88  93.50
# 4        4        2000       181  21,564.00 119.82  9,170.00    179.97  93.56
# 5        4          50       103  11,980.00 119.91    400.00     99.91  62.26
# 6        4         500        21   2,400.00 119.95 14,397.00     20.01  50.89
# 7        4          50        32   3,600.00 121.00  1,372.00     29.75  69.07
# 8        4        2000        90  10,783.00 120.00 18,657.00     89.86  47.75
# 9        4         500        72   8,400.00 120.00  6,685.00     70.00  58.58
# 10       4         500        22   2,400.00 119.95 14,026.00     20.01  50.68
# 155      4          50      1060  44,191.00  42.90     47.00  1,030.17  79.60
# 156      4        2000       588  66,000.00 120.71  3,479.00    546.76  93.45
# 157      4          50         7     600.00 120.25  5,696.00      4.99  71.27
# 158      4         500       134  15,574.00 119.82  2,262.00    129.98  80.91
# 159      4        2000        32   3,600.00 119.96 45,742.00     30.01  37.25
# 160      4        2000       151  17,970.00 119.82  7,952.00    149.97  79.81
# 161      4          50        23   2,400.00 120.00  1,489.00     20.00  72.68
# 162      4        2000        66   7,800.00 120.00 19,438.00     65.00  74.69
# 163      4          50      1283  42,510.00  35.45     40.00  1,199.09  78.39
# 164      4          50       418  49,717.00 119.97     94.00    414.41  93.35
# 165      4         500       782  45,312.00  58.19    524.00    778.72  77.86
# 166      4         500       111  13,000.00 120.52  3,907.00    107.87  55.70
# 167      4         500       247  29,351.00 119.84  1,219.00    244.92  93.66
# 168      4         500        41   4,500.00 123.30 12,893.00     36.50  68.27
# 169      4          50       116  13,600.00 120.31    391.00    113.04  63.57
# 170      4         500      1213  41,075.00  37.62    444.00  1,091.87  77.35
# 171      4          50        72   4,850.00 120.31  1,237.00     40.31  68.21
# 172      4        2000         5     600.00 119.93 79,889.00      5.00  78.00
# 173      4        2000        21   2,400.00 119.95 51,400.00     20.01  61.25
# 174      4        2000       113  12,571.00 120.00 15,649.00    104.76  50.26
# 175      4         500        18   1,800.00 119.94 23,764.00     15.01  73.46
# 176      4         500       128  14,500.00 120.74  3,562.00    120.09  52.23
# 177      4        2000       749  85,819.00 119.97  2,694.00    715.35  93.50
# 178      4         500       156  18,569.00 119.81  1,884.00    154.98  80.31
# 179      4          50        15   1,800.00 120.21  1,975.00     14.97  63.26
# 180      4          50        68   7,791.00 120.00    710.00     64.92  76.68
# 181      4          50       217  25,757.00 119.85    133.00    214.92  93.50
# 182      4        2000       198  23,361.00 119.82  6,213.00    194.96  93.60
# 183      4         500        25   3,000.00 121.45 12,906.00     24.70  49.84
# 184      4        2000       178  19,897.00 119.83 11,491.00    166.04  78.30
# 185      4         500        41   4,800.00 119.98  7,840.00     40.01  78.40
# 186      4          50        77   9,000.00 120.32    556.00     74.80  70.79
# 187      4          50       142  16,772.00 119.85    201.00    139.94  82.54
# 188      4        2000         8     600.00 119.93 77,260.00      5.00   0.00
# 189      4        2000       107  12,000.00 126.01 17,662.00     95.23  51.11
# 190      4          50       333  39,534.00 119.91    114.00    329.69  93.45
# 191      4        2000        31   3,600.00 119.97 41,264.00     30.01  66.81
# 192      4        2000      1160  38,852.00  39.32  1,920.00    988.17  76.00
# 193      4        2000      1202 143,520.00 119.87  1,349.00  1,197.26  93.52
# 194      4        2000        72   6,000.00 152.78 46,133.00     39.27  62.38
# 195      4        2000        65   7,800.00 119.99 19,580.00     65.01  93.41
# 196      4          50       712  45,312.00  64.02     54.00    707.76  78.53
# 197      4         500       212  22,500.00 121.04  2,659.00    185.88  63.80
# 198      4         500        36   4,200.00 119.97  8,699.00     35.01  93.89
# 199      4         500      1418  39,968.00  32.10    396.00  1,245.30  76.98
# 200      4         500        95  11,381.00 119.81  4,587.00     94.99  56.31
# 201      4        2000       252  29,950.00 119.84  4,805.00    249.92  93.54
# 202      4         500       196  21,000.00 120.46  2,836.00    174.33  64.14
# 203      4        2000      2165 144,797.00  69.67    923.00  2,078.21  93.45
# 204      4         500       607  71,898.00 119.93    808.00    599.50  93.47
# 205      4          50        19   1,800.00 120.18  1,980.00     14.98  81.09
# 206      4         500       109  12,500.00 121.62  4,223.00    102.78  62.58
# 207      4        2000         8     600.00 119.94 84,131.00      5.00  78.00
# 208      4        2000        83   9,600.00 120.00 15,425.00     80.00  93.34
# 209      4        2000        99  11,382.00 120.01 16,134.00     94.84  80.67
# 210      4        2000        22   2,400.00 119.95 58,198.00     20.01  68.50
# 211      4        2000        18   1,800.00 119.95 75,164.00     15.01   0.00
# 212      4        2000        22   2,400.00 119.94 49,718.00     20.01  62.00
# 213      4         500       130  15,500.00 121.14  3,661.00    127.95  55.91
# 214      4        2000       185  18,000.00 120.68 12,790.00    149.16  60.52
# 215      4         500      1408  39,987.00  32.30    396.00  1,237.87  76.66
# 216      4        2000        29   3,000.00 119.96 55,554.00     25.01  67.20
# 217      4         500        28   3,000.00 132.14 16,449.00     22.70  69.36
# 218      4        2000       189  18,000.00 120.61 12,772.00    149.24  60.57
# 219      4         500        20   2,400.00 119.96 15,757.00     20.01  77.26

# %% [markdown]
# # Run methods to obtained visible results

# %%
def read_data_create_final_dataframe(freq, DEBUG=False):
    d = {}
    global header_printed
    header_printed = False
    moaDF = read_MOA(f"{PATH_TO_RESULTS}{freq}/{freq}", f"{PATH_TO_RESULTS}{freq}/{freq}/inst-and-delay.csv")
    moaDF = moaDF[["algorithm", "dataset", "cores", "batch_size", "inc_rate", "out_rate", "instances", "time", "delay", "acc"]]
    measureDF = load_Wmeas(f'{PATH_TO_RESULTS}{freq}/{freq}/Wm-{freq}.log')
    d = exper_order_to_dict(f'{PATH_TO_RESULTS}{freq}/{freq}/exper_order-freq-max-{freq}-freq-min-{freq}.log', d)
    d = populate_dict(d, measureDF)
    mdf = append_dict_to_df(d)
    sshDF = parse_SSH(f'{PATH_TO_RESULTS}{freq}/{freq}/ssh-log')
    sshDF['batch_size'] = sshDF['batch_size'].astype(int)
    if DEBUG:
        print(f'moaDF: {len(moaDF)}    mdf: {len(mdf)}     sshDF: {len(sshDF)}')
    
    #join dfs
    finaldf = moaDF.merge(mdf, on=['algorithm', 'dataset', 'cores', 'batch_size', 'inc_rate'])
    finaldf = finaldf.merge(sshDF, 'left', on=['algorithm', 'dataset', 'batch_size', 'inc_rate'])

    finaldf['joules'] = finaldf['avg_measure'] * finaldf['time']
    finaldf['JPI'] = finaldf['joules'] / finaldf['instances']

    # Add PERC column to identify if it used 90, 50 or 10% max rate
    # Before merging rows with the same batch size, we need to differentiate the experiments with different work loads
    # We use the **PERC**entage column for that
    tdf = finaldf.sort_values(by=['dataset','algorithm','batch_size','inc_rate'], ascending=False)
    tdf['PERC'] = 0
    if DEBUG:
        tdf.to_csv(f"{PATH_TO_RESULTS}tdf-{freq}.csv")
    masks = {'90':[], '50': [], '10': []}
    for k, v in zip(masks.keys(), [0, 1, 2]):
        for i in range(len(tdf)):
            masks[k].append(i % 3 == v)
    
    tdf.loc[masks['90'], 'PERC'] = '90'
    tdf.loc[masks['50'], 'PERC'] = '50'
    tdf.loc[masks['10'], 'PERC'] = '10'
    
    tdf['tput'] = tdf['instances'] / tdf['time']
    
    return tdf

# %%
freqs = ['600', '1200']
dataframes = []
for f in freqs:
    dataframes.append(read_data_create_final_dataframe(f, True))
# Out:
# moaDF: 220    mdf: 220     sshDF: 289
# moaDF: 216    mdf: 216     sshDF: 219

# %%
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    gen_graph(df, bars=True, freq=f)
# Out:
# ----------------- 600 -----------------
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ----------------- 1200 -----------------
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Average Consumer By Frequency

# %%
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    df['joules'] = df['joules'].replace(np.nan, 0)
    df = df.reset_index()

    total = 0
    average = 0 
    for index, row in df.iterrows():
        if int(row['joules']) > 0:
            total += row['joules']

    average = total / len(df.index)
    print(average)
# Out:
# ----------------- 600 -----------------
# 389.9513771586145
#
#
#
# ----------------- 1200 -----------------
# 559.4935837710227

# %% [markdown]
# The average basic show a comportament where in minimum frequency presetation 50% minus consumer energy compared the others frequencies. A point of attention is values similars in frequency 800, 1000 and 1200. This can point change frequency is are changed only 600 and 1200 and no others configurations.

# %% [markdown]
# # Compare Accuracy and IPS
#
# - The IPS has some ligation when accuracy?
# - IPS is minor when is frequency is minimum?
# - IPS is major when is frequency is maximum?
# - IPS is major when utilized mini-batching?

# %%
def plot(ax, dsdf, my_id, x):
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}
    c1 = 'tab:red'
    c2 = 'tab:blue'
    c3 = 'tab:green'
    ds = list(dsdf.dataset)[0]
    ax.set_title(f'{dsformalname[ds]}')
    ax.plot(x, pd.to_numeric(dsdf.acc), color=c1, label='acc')
    ax.tick_params(axis='y', labelcolor=c1)
    ax.set_xticks(x)
    ax.set_xticklabels(dsdf.batch_size)
    ax.set_ylim(0,100)
    ax2 = ax.twinx()
    ax2.plot(x, pd.to_numeric(dsdf.IPS), color=c2, label='IPS')
    ax2.tick_params(axis='y', labelcolor=c2)
    ax3 = ax.twinx()
    ax3.plot(x, pd.to_numeric(dsdf.JPI), color=c3, label='JPI')
    ax3.tick_params(axis='y', labelcolor=c3)
    if int(my_id/2) == 1:
        ax.set_xlabel('Batch size')

# %%
def gen_graph_initial_peralg(df, display_df=False, freq=''):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']

    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']

    filename = f"pi-rates"
    for alg in algorithms:
        fig, axs = plt.subplots(2, 2, figsize=(15,10))
        dfalg = filter_by_substring_algorithm(df, alg)
        fig.suptitle(f'{alg} - Frequency {freq}')
        for ds in datasets:
            dsdf = dfalg[(dfalg.dataset == ds)]
            x = np.arange(len(dsdf.batch_size))
            my_id = datasets.index(ds)
            ax = axs[int(my_id/2)][my_id%2]
            plot(ax, dsdf, my_id, x)
        plt.savefig(f'{filename}.eps', bbox_inches='tight')

# %%
freqs = ['600', '1200']
dataframes = []
for f in freqs:
    dataframes.append(read_data_create_final_dataframe(f, True))
# Out:
# moaDF: 220    mdf: 220     sshDF: 289
# moaDF: 216    mdf: 216     sshDF: 219

# %%
freqs = ['600', '1200']
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    df = df[df.PERC == '10']
    df = df.loc[:,['dataset','algorithm','batch_size','acc', 'instances', 'time', 'JPI']].sort_values(by=['batch_size'])
    df = select_columns_and_rename_values(df)
    df['IPS'] = df['instances'] / df['time']
    gen_graph_initial_peralg(df, display_df=False, freq=f)
# Out:
# ----------------- 600 -----------------
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# ----------------- 1200 -----------------
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_47799/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %% [markdown]
# To analisy the accuracy is compared the IPS now fixed in algorithm ARF. First, we see the results to dataset airlines, this dataset to not see big diferences when used more or minus IPS to processe in accuracy. The accuracy is maintain same increased more IPS. But, this case can see a big diference in quantity IPS is sequential without mini-batching and sequential with mini-batching basically IPS tends to grow a lot all scenaries. The same happen in frequency 1200. But the number of IPS to maximum frequency is more than double.

# %% [markdown]
# # What energy consumption profile for each frequency
