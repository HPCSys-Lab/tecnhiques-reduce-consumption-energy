# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregando os dados do CSV para um DataFrame
url = '/Users/reginaldo.junior/Documents/Ufscar/tecnhiques-reduce-consumption-energy/results/mb_socket_dynamic.csv'  # Substitua pelo caminho do seu arquivo CSV
df = pd.read_csv(url)
df = df[df.dataset == 'airlines']
display(df)

# Criando o gráfico de caixa com Seaborn
plt.figure(figsize=(8, 10))

# Box plot para a coluna "delay"
plt.subplot(3, 1, 1)
sns.boxplot(x='algorithm', y='JPI', data=df)
plt.title('JPI')

# Box plot para a coluna "delay"
plt.subplot(3, 1, 2)
sns.boxplot(x='algorithm', y='delay_s', data=df)
plt.title('Delay')

# Box plot para a coluna "IPS"
plt.subplot(3, 1, 3)
sns.boxplot(x='algorithm', y='IPS', data=df)
plt.title('IPS')

# Ajustando o layout
plt.tight_layout()

# Exibindo o gráfico
plt.show()
# Out:
#      Unnamed: 0   dataset  algorithm  batch_size        acc  instances  \
# 12           75  airlines      SRPMB          50  65.054271     8526.0
# 13            0  airlines       OBMB          50  63.676439    23415.0
# 14           55  airlines  OBAdwinMB          50  67.454253    25571.0
# 15           19  airlines   OBASHTMB          50  64.660350    23692.0
# 16           88  airlines     LBagMB          50  63.169489     7313.0
# ..          ...       ...        ...         ...        ...        ...
# 718          39  airlines       OBMB        2000  60.089686    17164.0
# 719          85  airlines  OBAdwinMB        2000  60.656671    17807.0
# 720          36  airlines   OBASHTMB        2000  63.187865    22898.0
# 721          42  airlines     LBagMB        2000  61.555076     4778.0
# 722          57  airlines      ARFMB        2000  62.221069     5854.0
#
#            time       JPI       joules  cores   label     delay        IPS  \
# 12   599.281982  0.219734  1858.819725      4  MB-500    2211.0  14.227025
# 13   599.286987  0.081007  1866.522440      4  MB-500     746.0  39.071431
# 14   599.453003  0.080971  2044.770357      4  MB-500     684.0  42.657222
# 15   599.534973  0.078268  1834.533136      4  MB-500     740.0  39.517294
# 16   599.551025  0.279628  2023.155287      4  MB-500    2451.0  12.197461
# ..          ...       ...          ...    ...     ...       ...        ...
# 718  599.288025  0.110043  1855.611665      4  MB-500   41437.0  28.640652
# 719  599.255981  0.106421  1855.574686      4  MB-500   44859.0  29.715181
# 720  599.265015  0.083501  1884.543708      4  MB-500   29822.0  38.210140
# 721  599.244019  0.397667  1848.370875      4  MB-500  158325.0   7.973380
# 722  599.263000  0.335030  1871.520036      4  MB-500   94064.0   9.768666
#
#      delay_s
# 12     2.211
# 13     0.746
# 14     0.684
# 15     0.740
# 16     2.451
# ..       ...
# 718   41.437
# 719   44.859
# 720   29.822
# 721  158.325
# 722   94.064
#
# [180 rows x 14 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregando os dados do CSV para um DataFrame
url = '/Users/reginaldo.junior/Documents/Ufscar/tecnhiques-reduce-consumption-energy/results/mblf_mb_and_socket_dynamic.csv'  # Substitua pelo caminho do seu arquivo CSV
df = pd.read_csv(url)
df = df[df.dataset == 'airlines']
display(df)

# Criando o gráfico de caixa com Seaborn
plt.figure(figsize=(8, 10))

# Box plot para a coluna "delay"
plt.subplot(3, 1, 1)
sns.boxplot(x='algorithm', y='JPI', data=df)
plt.title('JPI')

# Box plot para a coluna "delay"
plt.subplot(3, 1, 2)
sns.boxplot(x='algorithm', y='delay_s', data=df)
plt.title('Delay')

# Box plot para a coluna "IPS"
plt.subplot(3, 1, 3)
sns.boxplot(x='algorithm', y='IPS', data=df)
plt.title('IPS')

# Ajustando o layout
plt.tight_layout()

# Exibindo o gráfico
plt.show()
# Out:
#      Unnamed: 0   dataset  algorithm batch_size        acc  instances  \
# 12            8  airlines      SRPMB        NaN  66.310850     9689.0
# 13           21  airlines       OBMB        NaN  62.983230   219517.0
# 14            4  airlines  OBAdwinMB        NaN  64.869792    19931.0
# 15            3  airlines   OBASHTMB        NaN  64.246816    88904.0
# 16            7  airlines     LBagMB        NaN  61.080675    14096.0
# 17           11  airlines      ARFMB        NaN  66.089286     6373.0
# 36            8  airlines      SRPMB        NaN  66.541353     7257.0
# 37           21  airlines       OBMB        NaN  63.236192   224531.0
# 38            4  airlines  OBAdwinMB        NaN  66.739130    31707.0
# 39            3  airlines   OBASHTMB        NaN  67.172171   142987.0
# 40            7  airlines     LBagMB        NaN  61.103448    16217.0
# 41           11  airlines      ARFMB        NaN  65.617486    10784.0
# 60            8  airlines      SRPMB        NaN  66.491979     9871.0
# 61           21  airlines       OBMB        NaN  64.685358   178196.0
# 62            4  airlines  OBAdwinMB        NaN  67.470860    28799.0
# 63            3  airlines   OBASHTMB        NaN  63.318235   172835.0
# 64            7  airlines     LBagMB        NaN  61.980392    10424.0
# 65           11  airlines      ARFMB        NaN  65.861386     9069.0
# 84            8  airlines      SRPMB        NaN  65.140893     8665.0
# 85           21  airlines       OBMB        NaN  65.317160   127987.0
# 86            4  airlines  OBAdwinMB        NaN  65.397454    18397.0
# 87            3  airlines   OBASHTMB        NaN  65.432207   114706.0
# 88            7  airlines     LBagMB        NaN  61.139159    15902.0
# 89           11  airlines      ARFMB        NaN  66.017699     8597.0
# 108           8  airlines      SRPMB       MB-D  65.804878     7298.0
# 109          21  airlines       OBMB       MB-D  61.020442   269429.0
# 110           4  airlines  OBAdwinMB       MB-D  67.092105    32268.0
# 111           3  airlines   OBASHTMB       MB-D  66.701585   145494.0
# 112           7  airlines     LBagMB       MB-D  61.407767    10914.0
# 113          11  airlines      ARFMB       MB-D  66.677165     7457.0
#
#            time       JPI       joules  cores label   delay         IPS  \
# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregando os dados do CSV para um DataFrame
url = '/Users/reginaldo.junior/Documents/Ufscar/tecnhiques-reduce-consumption-energy/results/mblf_socket_dynamic.csv'  # Substitua pelo caminho do seu arquivo CSV
df = pd.read_csv(url)
df = df[df.dataset == 'airlines']
display(df)

# Criando o gráfico de caixa com Seaborn
plt.figure(figsize=(8, 10))

# Box plot para a coluna "delay"
plt.subplot(3, 1, 1)
sns.boxplot(x='algorithm', y='JPI', data=df)
plt.title('JPI')

# Box plot para a coluna "delay"
plt.subplot(3, 1, 2)
sns.boxplot(x='algorithm', y='delay_s', data=df)
plt.title('Delay')

# Box plot para a coluna "IPS"
plt.subplot(3, 1, 3)
sns.boxplot(x='algorithm', y='IPS', data=df)
plt.title('IPS')

# Ajustando o layout
plt.tight_layout()

# Exibindo o gráfico
plt.show()
# Out:
#      Unnamed: 0   dataset  algorithm  batch_size                 acc  \
# 12           52  airlines      SRPMB          50   67.69868995633188
# 13           21  airlines       OBMB          50   61.32032854209446
# 14           67  airlines  OBAdwinMB          50   68.32261116367077
# 15           32  airlines   OBASHTMB          50   62.33881673881674
# 16            8  airlines     LBagMB          50   64.09442060085837
# ..          ...       ...        ...         ...                 ...
# 711          91  airlines       OBMB        2000  61.746788990825685
# 712          34  airlines  OBAdwinMB        2000   63.60833333333333
# 713           2  airlines   OBASHTMB        2000   62.27692307692308
# 714          60  airlines     LBagMB        2000              59.575
# 715          45  airlines      ARFMB        2000                65.0
#
#      instances        time       JPI       joules  cores      label     delay  \
# 12     22950.0  599.263977  0.115751  2635.661932      4  MB-LF-500    1059.0
# 13    389650.0  600.552002  0.008361  3223.328378      4  MB-LF-500      77.0
# 14    105750.0  599.484009  0.025371  2654.089184      4  MB-LF-500     205.0
# 15    519800.0  556.913025  0.004620  2379.622350      4  MB-LF-500      49.0
# 16     23350.0  599.752014  4.032089  1711.771922      4  MB-LF-500    1026.0
# ..         ...         ...       ...          ...    ...        ...       ...
# 711   220000.0  599.344971  0.008794  1916.585457      4  MB-LF-500    3358.0
# 712    26000.0  599.265015  0.073525  1890.398759      4  MB-LF-500   24481.0
# 713   132000.0  599.338989  0.014061  1835.612866      4  MB-LF-500    5425.0
# 714     8000.0  741.203003  0.394624  3132.491294      4  MB-LF-500  145240.0
# 715     4000.0  599.203979  0.444614  1761.418041      4  MB-LF-500  123183.0
#
#             IPS  delay_s
# 12    38.296979    1.059
# 13   648.819750    0.077
# 14   176.401703    0.205
# 15   933.359388    0.049
# 16    38.932758    1.026
# ..          ...      ...
# 711  367.067400    3.358
# 712   43.386481   24.481
# 713  220.242638    5.425
# 714   10.793264  145.240
# 715    6.675523  123.183
#
# [182 rows x 14 columns]
