# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregando os dados do CSV para um DataFrame
url = '/Users/reginaldo.junior/Documents/Ufscar/tecnhiques-reduce-consumption-energy/results/mb_socket_dynamic.csv'  # Substitua pelo caminho do seu arquivo CSV
df = pd.read_csv(url)
df = df[df.dataset == 'airlines']
display(df)

# Criando o gráfico de caixa com Seaborn
plt.figure(figsize=(8, 10))

# Box plot para a coluna "delay"
plt.subplot(3, 1, 1)
sns.boxplot(x='algorithm', y='JPI', data=df)
plt.title('JPI')

# Box plot para a coluna "delay"
plt.subplot(3, 1, 2)
sns.boxplot(x='algorithm', y='delay_s', data=df)
plt.title('Delay')

# Box plot para a coluna "IPS"
plt.subplot(3, 1, 3)
sns.boxplot(x='algorithm', y='IPS', data=df)
plt.title('IPS')

# Ajustando o layout
plt.tight_layout()

# Exibindo o gráfico
plt.show()
# Out:
#      Unnamed: 0   dataset  algorithm  batch_size        acc  instances  \
# 15           25  airlines      SRPMB         500  65.113030     8374.0
# 16           84  airlines       OBMB         500  63.551852    27500.0
# 17           48  airlines  OBAdwinMB         500  64.421067    30633.0
# 18           54  airlines   OBASHTMB         500  64.710955    28333.0
# 19           36  airlines     LBagMB         500  62.520325     6650.0
# 20           81  airlines      ARFMB         500  64.584353    10713.0
# 43           26  airlines      SRPMB         500  65.002319     6969.0
# 44           85  airlines       OBMB         500  63.813793    29500.0
# 45           49  airlines  OBAdwinMB         500  62.167545    17570.0
# 46           55  airlines   OBASHTMB         500  64.971014    35000.0
# 47           37  airlines     LBagMB         500  68.926123     3126.0
# 48           82  airlines      ARFMB         500  64.974666    11355.0
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregando os dados do CSV para um DataFrame
url = '/Users/reginaldo.junior/Documents/Ufscar/tecnhiques-reduce-consumption-energy/results/mblf_mb_and_socket_dynamic.csv'  # Substitua pelo caminho do seu arquivo CSV
df = pd.read_csv(url)
df = df[df.dataset == 'airlines']
display(df)

# Criando o gráfico de caixa com Seaborn
plt.figure(figsize=(8, 10))

# Box plot para a coluna "delay"
plt.subplot(3, 1, 1)
sns.boxplot(x='algorithm', y='JPI', data=df)
plt.title('JPI')

# Box plot para a coluna "delay"
plt.subplot(3, 1, 2)
sns.boxplot(x='algorithm', y='delay_s', data=df)
plt.title('Delay')

# Box plot para a coluna "IPS"
plt.subplot(3, 1, 3)
sns.boxplot(x='algorithm', y='IPS', data=df)
plt.title('IPS')

# Ajustando o layout
plt.tight_layout()

# Exibindo o gráfico
plt.show()
# Out:
#      Unnamed: 0   dataset  algorithm batch_size        acc  instances  \
# 12            8  airlines      SRPMB        NaN  66.800000     6324.0
# 13           21  airlines       OBMB        NaN  65.733873   185556.0
# 14            4  airlines  OBAdwinMB        NaN  65.494737    28501.0
# 15            3  airlines   OBASHTMB        NaN  66.082065   184010.0
# 16            7  airlines     LBagMB        NaN  59.020408    11209.0
# 17           11  airlines      ARFMB        NaN  65.800000    11258.0
# 36            8  airlines      SRPMB        NaN  66.068027     7883.0
# 37           21  airlines       OBMB        NaN  63.908993   141466.0
# 38            4  airlines  OBAdwinMB        NaN  67.110048    32448.0
# 39            3  airlines   OBASHTMB        NaN  66.013295   120949.0
# 40            7  airlines     LBagMB        NaN  61.463063    14109.0
# 41           11  airlines      ARFMB        NaN  64.714286     8195.0
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregando os dados do CSV para um DataFrame
url = '/Users/reginaldo.junior/Documents/Ufscar/tecnhiques-reduce-consumption-energy/results/mblf_socket_dynamic.csv'  # Substitua pelo caminho do seu arquivo CSV
df = pd.read_csv(url)
df = df[df.dataset == 'airlines']
display(df)

# Criando o gráfico de caixa com Seaborn
plt.figure(figsize=(8, 10))

# Box plot para a coluna "delay"
plt.subplot(3, 1, 1)
sns.boxplot(x='algorithm', y='JPI', data=df)
plt.title('JPI')

# Box plot para a coluna "delay"
plt.subplot(3, 1, 2)
sns.boxplot(x='algorithm', y='delay_s', data=df)
plt.title('Delay')

# Box plot para a coluna "IPS"
plt.subplot(3, 1, 3)
sns.boxplot(x='algorithm', y='IPS', data=df)
plt.title('IPS')

# Ajustando o layout
plt.tight_layout()

# Exibindo o gráfico
plt.show()
# Out:
#      Unnamed: 0   dataset  algorithm  batch_size        acc  instances  \
# 12           64  airlines      SRPMB         500  68.854054    37500.0
# 13           46  airlines       OBMB         500  61.660000   410500.0
# 14           38  airlines  OBAdwinMB         500  67.610417    48500.0
# 15           96  airlines   OBASHTMB         500  61.967814   538000.0
# 16           76  airlines     LBagMB         500  62.092308     7000.0
# 17           39  airlines      ARFMB         500  66.075410    31000.0
# 36           62  airlines      SRPMB         500  67.120000     5500.0
# 37           44  airlines       OBMB         500  66.724397   187000.0
# 38           36  airlines  OBAdwinMB         500  64.813043    23500.0
# 39           94  airlines   OBASHTMB         500  66.294424   135000.0
# 40           74  airlines     LBagMB         500  61.012500     8500.0
# 41           37  airlines      ARFMB         500  65.636364     6500.0
# ...
