# %% [markdown]
# # Analisy Loop Fusion - Time, speedup, perf and energy aware
#
# This notebook analisy results time, speedup, perf and energy aware with implementation loop fusion when compared sequential MOA. Variables to this experiments are:
#
# - Mini-batching: 50
# - Ensemble: 25
# - Parallel: 4 cores

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %%
#loads the csv as a dataframe and standardizes the algorithm names 
def load_df(filename):
    df = pd.read_csv(filename, index_col=False)
    return select_columns_and_rename_values(df)

# %%
#filters by substring (there are multiple OzaBag algorithms)
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %%
#standardize algorithm names
def select_columns_and_rename_values(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    df.batch_size.unique()
    return df

# %%
#Folder inside results directory that contains all the MOA dump files for these experiments
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
folderMOADumps = "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/analisy-speedup"
wantedCSVfilename = "speedup-pi-loop-fusion"
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching

# %%
def parse_speedup(fname):
    global header_printed
    #index of wanted columns
    columns = []
    #column names to get the data from
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    ret_string = ''
    #remove the path and isolate the filename
    spname = fname.split('/')[-1].split('-')
    spline = []
    #control flag for knowing when the column names have already been discovered
    got = False
    #we ignore the first parameter of the filename and add all others to the csv string
    for s in spname[1:]:
        ret_string += s + ','
    #should probably use a safer way, but python handles the closing of the file
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                #sometimes the dump file has multiple results in it, so we get the index of wanted columns only once
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        #OzaBagASHT bugs out on GMSC, this reuses the data from the sequential execution
        if 'GMSC' in spname and 'ASHT' in spname[2]:
            for c in columns[:-2]:
                ret_string += str(spline[c]) + ','
            ret_string += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        #normal code, how everything should run
        #we process the data (add the content of wanted columns to the csv string) only after the for
        #ensuring we use only the last (most recent) data and not the intermediate results
        else:
            for c in columns:
                ret_string += str(spline[c]) + ','
            if len(columns) == 5:
                ret_string += '0,'
        #header is a global variable, it will only be printed on the first file 
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,inc_rate,instances,time,acc,prec,recall'
            ret_string = f"{head}\n{ret_string}"
            header_printed = True
        #remove the last comma ,
        return (ret_string[:-1])

# %%
def find_sequential_value_by_index(df, algorithm):
    for data in df:
        if (data['algorithm'] == algorithm):
            return data

# %%
def find_list_value_by_index(df, algorithm):
    response = []

    for data in df:
        if (data['algorithm'] == algorithm):
            response.append(data)

    return response

# %%
df_speedup = {
    '15092022': {
        'airlines': {
            'mini-batching': [],
            'sequential': [],
            'loop_fusion': []
        },
        'GMSC': {
            'mini-batching': [],
            'sequential': [],
            'loop_fusion': []
        },
        'covtypeNorm': {
            'mini-batching': [],
            'sequential': [],
            'loop_fusion': []
        },
        'elecNormNew': {
            'mini-batching': [],
            'sequential': [],
            'loop_fusion': []
        }
    }
}

from_to = {
    'LBagMB': 'LBagSequential',
    'ARFMB': 'ARFSequential',
    'OBAdwinMB': 'OBAdwinSequential',
    'OBMB': 'OBSequential',
    'OBASHTMB': 'OBASHTSequential',
    'SRPMB': 'SRPSequential',
    'LBagSequential': 'LBagMB',
    'ARFSequential': 'ARFMB',
    'OBAdwinSequential': 'OBAdwinMB',
    'OBSequential': 'OBMB',
    'OBASHTSequential': 'OBASHTMB',
    'SRPSequential': 'SRPMB'
}

algorithms = ['LBagMB', 'ARFMB', 'OBAdwinMB', 'OBMB', 'OBASHTMB', 'SRPMB']
dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}

df = {"15092022": []}
for execution in list(["15092022"]):
    for cpu in list([1, "mini-batching", 4]):
        resultsFolder = f"{folderMOADumps}/{str(cpu)}/{execution}"
        csvFile = f"parsed_csvs/{wantedCSVfilename}-{str(cpu)}.csv"
        directory = os.fsencode(resultsFolder)
        header_printed = False

        with open(f"{csvFile}", "w+") as output:
            for file in os.listdir(directory):
                filename = os.fsdecode(file)
                if filename.startswith("dump-"): 
                    output.write(f"{parse_speedup(f'{os.fsdecode(directory)}/{filename}')}\n")

        df[execution] = load_df(f'{csvFile}')
        for index, row in df[execution][['dataset', 'algorithm', 'cores', 'acc', 'time', 'instances']].iterrows():
            if (cpu == "mini-batching"):
                data_sequential = find_sequential_value_by_index(df_speedup[execution][row['dataset']]['sequential'], from_to[row['algorithm']])
                speedup = data_sequential['time'] / row['time']
                eficiency = speedup / row['cores']

                df_speedup[execution][row['dataset']]['mini-batching'].append({
                    'dataset': row['dataset'],
                    'algorithm': row['algorithm'],
                    'cores': 'MB-4',
                    'time': row['time'],
                    'instances': row['instances'],
                    'speedup': speedup,
                    'eficiency': eficiency,
                    'acc': row['acc']
                })
            elif row['cores'] == 1 and cpu != "mini-batching":
                speedup = 1
                eficiency = 1

                df_speedup[execution][row['dataset']]['sequential'].append({
                    'dataset': row['dataset'],
                    'algorithm': row['algorithm'],
                    'cores': row['cores'],
                    'time': row['time'],
                    'instances': row['instances'],
                    'speedup': speedup,
                    'eficiency': eficiency,
                    'acc': row['acc']
                })
            else:
                data_sequential = find_sequential_value_by_index(df_speedup[execution][row['dataset']]['sequential'], from_to[row['algorithm']])

                speedup = data_sequential['time'] / row['time']
                eficiency = speedup / row['cores']

                df_speedup[execution][row['dataset']]['loop_fusion'].append({
                    'dataset': row['dataset'],
                    'algorithm': row['algorithm'],
                    'cores': 'MB-4+LF',
                    'time': row['time'],
                    'instances': row['instances'],
                    'speedup': speedup,
                    'eficiency': eficiency,
                    'acc': row['acc']
                })
# Out:
# /Users/reginaldoluisdeluna/Library/Python/3.8/lib/python/site-packages/pandas/util/_decorators.py:311: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   return func(*args, **kwargs)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
def gen_graph_speedup(execution='first', only_eficiency=False):
    filename = f"pi-rates"
    fig, axs = plt.subplots(2, 2, figsize=(14,9))
    datasets = ['airlines', 'GMSC', 'covtypeNorm', 'elecNormNew']
    
    for ds in datasets:
        current_df = df_speedup[execution][ds]
        my_id = datasets.index(ds)

        #selects the correct position in the grid
        ax = axs[int(my_id/2)][my_id%2]
        ax.set_title(f'{dsformalname[ds]}')

        for alg in algorithms:
            #data_sequential = [find_sequential_value_by_index(current_df['sequential'], from_to[alg])]
            data_parallel = find_list_value_by_index(current_df['loop_fusion'], alg)
            data_mini_batching = [find_sequential_value_by_index(current_df['mini-batching'], alg)]
            df = pd.DataFrame(data_mini_batching + data_parallel)

            colors=['go', 'bs', 'rP', 'md', 'y+' , 'k*']
            labels = df.cores
            x = np.arange(len(labels))
            alg_order = algorithms.index(alg)

            if only_eficiency == False:
                ax.plot(x, pd.to_numeric(df.speedup), f'{colors[alg_order]}--', linewidth=0.75, label=f'{alg}-speedup')
            else:
                ax.plot(x, pd.to_numeric(df.eficiency), f'{colors[alg_order]}--', linewidth=0.75, label=f'{alg}-eficiency')

            #if its the first column, print Y-axis label
            if my_id%2 == 0:
                if only_eficiency == False:
                    ax.set_ylabel('Speedup')
                else:
                    ax.set_ylabel('Eficiency', color = "r")

            #if its the last row, print the X-axis label
            if int(my_id/2) == 1:
                ax.set_xlabel('Cores')

            ax.set_xticks(x)
            ax.set_xticklabels(labels)

    #retrieves the handles and labels to create a global legend
    handles, labels = axs[0][0].get_legend_handles_labels()
    lgd = fig.legend(handles, labels, loc = 'lower center', ncol = math.ceil(len(algorithms)/2), bbox_to_anchor=(0.5,-0.1))
    fig.tight_layout()
    plt.savefig(f'figures/{filename}.png')
    plt.savefig(f'figures/{filename}.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
def gen_graph_time(execution='first', only_eficiency=False):
    filename = f"pi-rates"
    fig, axs = plt.subplots(2, 2, figsize=(14,9))
    datasets = ['airlines', 'GMSC', 'covtypeNorm', 'elecNormNew']
    
    for ds in datasets:
        current_df = df_speedup[execution][ds]
        my_id = datasets.index(ds)

        #selects the correct position in the grid
        ax = axs[int(my_id/2)][my_id%2]
        ax.set_title(f'{dsformalname[ds]}')

        for alg in algorithms:
            data_sequential = [find_sequential_value_by_index(current_df['sequential'], from_to[alg])]
            data_parallel = find_list_value_by_index(current_df['loop_fusion'], alg)
            data_mini_batching = [find_sequential_value_by_index(current_df['mini-batching'], alg)]
            df = pd.DataFrame(data_sequential + data_mini_batching + data_parallel)

            colors=['go', 'bs', 'rP', 'md', 'y+' , 'k*']
            labels = df.cores
            x = np.arange(len(labels))
            alg_order = algorithms.index(alg)
            
            ax.plot(x, pd.to_numeric(df.time), f'{colors[alg_order]}--', linewidth=0.75, label=f'{alg}-time')

            #if its the first column, print Y-axis label
            if my_id%2 == 0:
                ax.set_ylabel('Time in Seconds')

            #if its the last row, print the X-axis label
            if int(my_id/2) == 1:
                ax.set_xlabel('Cores')

            ax.set_xticks(x)
            ax.set_xticklabels(labels)

    #retrieves the handles and labels to create a global legend
    handles, labels = axs[0][0].get_legend_handles_labels()
    lgd = fig.legend(handles, labels, loc = 'lower center', ncol = math.ceil(len(algorithms)/2), bbox_to_anchor=(0.5,-0.1))
    fig.tight_layout()
    plt.savefig(f'figures/{filename}.png')
    plt.savefig(f'figures/{filename}.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %% [markdown]
# # Time
#
# Here we will analisy time execution for sequetial, mini-batching 4 cores with 50 batch size and mini-batching with loop fusion with 50 batch size.

# %%
for execution in ['15092022']:
    gen_graph_time(execution=execution)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Speedup
#
# First, we will see results to speedup in all algorithms and datasets. In graph, can be see the increase in all CPUs. For example in dataset airlines, the major sppedup is 5 while minor is 2. The gain in speedup is considerable very good in all scenaries.

# %%
for execution in ['15092022']:
    gen_graph_speedup(execution=execution)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Eficiency
#
# The efficiency normally doubles the value when the core increases, but from more core increased efficiency lose and no gain more data. This happens because from 2 cores the sppedup double but when increase more core the speedup not double more, but increase a bit sppedup in relation the before.

# %%
for execution in ['15092022']:
    gen_graph_speedup(execution, True) # eficiency
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Perf tools analysis
#
# This next data is possible see results for cache misses and cache references. Remember cache misses and cache references are better when decrease.

# %%
# %run "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/loop-fusion/Perftools-Analisys.ipynb"
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
#         dataset                               algorithm ensemble methodology  \
# 16         GMSC    AdaptiveRandomForestExecutorMAXChunk       25          MB
# 5          GMSC                    LBagExecutorMAXChunk       25          MB
# 1          GMSC              OzaBagASHTExecutorMAXChunk       25          MB
# 10         GMSC             OzaBagAdwinExecutorMAXChunk       25          MB
# 19         GMSC                  OzaBagExecutorMAXChunk       25          MB
# 15         GMSC  StreamingRandomPatchesExecutorMAXChunk       25          MB
# 18     airlines    AdaptiveRandomForestExecutorMAXChunk       25          MB
# 2      airlines                    LBagExecutorMAXChunk       25          MB
# 17     airlines              OzaBagASHTExecutorMAXChunk       25          MB
# 9      airlines             OzaBagAdwinExecutorMAXChunk       25          MB
# 22     airlines                  OzaBagExecutorMAXChunk       25          MB
# 23     airlines  StreamingRandomPatchesExecutorMAXChunk       25          MB
# 6   covtypeNorm    AdaptiveRandomForestExecutorMAXChunk       25          MB
# 0   covtypeNorm                    LBagExecutorMAXChunk       25          MB
# 20  covtypeNorm              OzaBagASHTExecutorMAXChunk       25          MB
# 14  covtypeNorm             OzaBagAdwinExecutorMAXChunk       25          MB
# 8   covtypeNorm                  OzaBagExecutorMAXChunk       25          MB
# 12  covtypeNorm  StreamingRandomPatchesExecutorMAXChunk       25          MB
# 4   elecNormNew    AdaptiveRandomForestExecutorMAXChunk       25          MB
# 7   elecNormNew                    LBagExecutorMAXChunk       25          MB
# 13  elecNormNew              OzaBagASHTExecutorMAXChunk       25          MB
# 3   elecNormNew             OzaBagAdwinExecutorMAXChunk       25          MB
# 21  elecNormNew                  OzaBagExecutorMAXChunk       25          MB
# 11  elecNormNew  StreamingRandomPatchesExecutorMAXChunk       25          MB
#
#     cores batch_size rate  cache_misses  cache_references
# 16      4         50    1      2,075.97         75,642.13
# 5       4         50    1      1,522.23         54,793.94
# 1       4         50    1        617.31         18,834.79
# 10      4         50    1        576.19         23,075.28
# 19      4         50    1        635.44         18,139.24
# 15      4         50    1      3,960.52        149,179.73
# 18      4         50    1     44,678.76      2,016,438.27
# 2       4         50    1     65,830.57      2,566,721.42
# 17      4         50    1      3,823.63        271,889.00
# 9       4         50    1     18,649.15        819,639.60
# 22      4         50    1      3,591.50        168,261.22
# 23      4         50    1     44,443.96      2,296,918.00
# 6       4         50    1     13,122.18        669,897.43
# 0       4         50    1     18,196.36        730,019.51
# 20      4         50    1      7,489.50        267,154.51
# 14      4         50    1     11,331.64        406,924.55
# 8       4         50    1      7,006.85        277,561.49
# 12      4         50    1     53,497.03      2,294,267.12
# 4       4         50    1      1,245.79         43,548.64
# 7       4         50    1        834.34         29,240.90
# 13      4         50    1        340.77         10,333.30
# 3       4         50    1        405.77         13,221.17
# 21      4         50    1        336.35         10,434.30
# 11      4         50    1      2,374.25         87,718.16
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
#         dataset                               algorithm ensemble methodology  \
# 16         GMSC    AdaptiveRandomForestExecutorMAXChunk       25       MB-LF
# 5          GMSC                    LBagExecutorMAXChunk       25       MB-LF
# 1          GMSC              OzaBagASHTExecutorMAXChunk       25       MB-LF
# 10         GMSC             OzaBagAdwinExecutorMAXChunk       25       MB-LF
# 19         GMSC                  OzaBagExecutorMAXChunk       25       MB-LF
# 15         GMSC  StreamingRandomPatchesExecutorMAXChunk       25       MB-LF
# 18     airlines    AdaptiveRandomForestExecutorMAXChunk       25       MB-LF
# 2      airlines                    LBagExecutorMAXChunk       25       MB-LF
# 17     airlines              OzaBagASHTExecutorMAXChunk       25       MB-LF
# 9      airlines             OzaBagAdwinExecutorMAXChunk       25       MB-LF
# 22     airlines                  OzaBagExecutorMAXChunk       25       MB-LF
# 23     airlines  StreamingRandomPatchesExecutorMAXChunk       25       MB-LF
# 6   covtypeNorm    AdaptiveRandomForestExecutorMAXChunk       25       MB-LF
# 0   covtypeNorm                    LBagExecutorMAXChunk       25       MB-LF
# 20  covtypeNorm              OzaBagASHTExecutorMAXChunk       25       MB-LF
# 14  covtypeNorm             OzaBagAdwinExecutorMAXChunk       25       MB-LF
# 8   covtypeNorm                  OzaBagExecutorMAXChunk       25       MB-LF
# 12  covtypeNorm  StreamingRandomPatchesExecutorMAXChunk       25       MB-LF
# 4   elecNormNew    AdaptiveRandomForestExecutorMAXChunk       25       MB-LF
# 7   elecNormNew                    LBagExecutorMAXChunk       25       MB-LF
# 13  elecNormNew              OzaBagASHTExecutorMAXChunk       25       MB-LF
# 3   elecNormNew             OzaBagAdwinExecutorMAXChunk       25       MB-LF
# 21  elecNormNew                  OzaBagExecutorMAXChunk       25       MB-LF
# 11  elecNormNew  StreamingRandomPatchesExecutorMAXChunk       25       MB-LF
#
#     cores batch_size rate  cache_misses  cache_references
# 16      4         50    1      1,902.50         73,531.47
# 5       4         50    1      1,352.17         56,966.56
# 1       4         50    1        380.75         12,590.18
# 10      4         50    1        545.89         23,928.45
# 19      4         50    1        380.20         12,144.87
# 15      4         50    1      3,622.52        137,774.34
# 18      4         50    1     44,689.77      1,995,375.61
# 2       4         50    1     63,027.52      2,546,019.01
# 17      4         50    1      1,773.63        141,218.82
# 9       4         50    1     17,911.76        819,785.49
# 22      4         50    1      1,887.12         74,773.40
# 23      4         50    1     44,096.07      2,035,722.04
# 6       4         50    1     11,918.31        640,677.10
# 0       4         50    1     15,375.02        699,858.36
# 20      4         50    1      2,382.40        119,360.25
# 14      4         50    1      9,109.78        411,874.17
# 8       4         50    1      2,202.00        112,270.43
# 12      4         50    1     49,457.15      2,185,666.34
# 4       4         50    1      1,204.60         43,516.22
# 7       4         50    1        830.75         29,775.44
# 13      4         50    1        266.67          8,134.80
# 3       4         50    1        359.21         13,367.87
# 21      4         50    1        251.86          8,041.57
# 11      4         50    1      2,384.87         88,316.97
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
#         dataset                       algorithm ensemble methodology  cores  \
# 20         GMSC  AdaptiveRandomForestSequential       25  Sequential      1
# 6          GMSC                   LeveragingBag       25  Sequential      1
# 7          GMSC                          OzaBag       25  Sequential      1
# 13         GMSC                      OzaBagASHT       25  Sequential      1
# 18         GMSC                     OzaBagAdwin       25  Sequential      1
# 14         GMSC          StreamingRandomPatches       25  Sequential      1
# 10     airlines  AdaptiveRandomForestSequential       25  Sequential      1
# 17     airlines                   LeveragingBag       25  Sequential      1
# 0      airlines                          OzaBag       25  Sequential      1
# 2      airlines                      OzaBagASHT       25  Sequential      1
# 22     airlines                     OzaBagAdwin       25  Sequential      1
# 16     airlines          StreamingRandomPatches       25  Sequential      1
# 19  covtypeNorm  AdaptiveRandomForestSequential       25  Sequential      1
# 21  covtypeNorm                   LeveragingBag       25  Sequential      1
# 4   covtypeNorm                          OzaBag       25  Sequential      1
# 5   covtypeNorm                      OzaBagASHT       25  Sequential      1
# 12  covtypeNorm                     OzaBagAdwin       25  Sequential      1
# 3   covtypeNorm          StreamingRandomPatches       25  Sequential      1
# 23  elecNormNew  AdaptiveRandomForestSequential       25  Sequential      1
# 1   elecNormNew                   LeveragingBag       25  Sequential      1
# 9   elecNormNew                          OzaBag       25  Sequential      1
# 11  elecNormNew                      OzaBagASHT       25  Sequential      1
# 15  elecNormNew                     OzaBagAdwin       25  Sequential      1
# 8   elecNormNew          StreamingRandomPatches       25  Sequential      1
#
#    batch_size rate  cache_misses  cache_references
# 20          1    1      2,167.05         75,418.06
# 6           1    1      1,640.41         51,172.66
# 7           1    1        714.28         16,963.88
# 13          1    1        698.71         17,737.31
# 18          1    1        818.42         21,513.40
# 14          1    1      4,389.36        159,603.15
# 10          1    1     45,007.84      2,003,195.36
# 17          1    1     59,569.68      2,355,699.52
# 0           1    1      3,357.03        159,963.11
# 2           1    1      3,797.86        270,280.61
# 22          1    1     16,121.14        685,528.03
# 16          1    1     43,837.99      2,285,472.61
# 19          1    1     13,682.86        678,070.13
# 21          1    1     18,929.39        679,802.79
# 4           1    1      8,157.59        248,980.87
# 5           1    1      9,680.78        331,368.78
# 12          1    1     12,116.11        374,971.02
# 3           1    1     52,481.53      2,047,501.26
# 23          1    1      1,265.64         42,192.10
# 1           1    1        810.74         26,746.16
# 9           1    1        346.53          9,804.87
# 11          1    1        364.62         11,036.41
# 15          1    1        415.05         12,543.59
# 8           1    1      2,221.08         80,552.49
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/4142396040.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/4142396040.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/4142396040.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/4142396040.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
#         dataset          algorithm ensemble methodology  cores  batch_size  \
# 40         GMSC                ARF       25          MB      4       50.00
# 64         GMSC                ARF       25       MB-LF      4       50.00
# 20         GMSC      ARFSequential       25  Sequential      1        1.00
# 29         GMSC               LBag       25          MB      4       50.00
# 53         GMSC               LBag       25       MB-LF      4       50.00
# 6          GMSC     LBagSequential       25  Sequential      1        1.00
# 43         GMSC                 OB       25          MB      4       50.00
# 67         GMSC                 OB       25       MB-LF      4       50.00
# 13         GMSC   OBASHTSequential       25  Sequential      1        1.00
# 25         GMSC   OBASHTSequential       25          MB      4       50.00
# 49         GMSC   OBASHTSequential       25       MB-LF      4       50.00
# 34         GMSC            OBAdwin       25          MB      4       50.00
# 58         GMSC            OBAdwin       25       MB-LF      4       50.00
# 18         GMSC  OBAdwinSequential       25  Sequential      1        1.00
# 7          GMSC       OBSequential       25  Sequential      1        1.00
# 14         GMSC      SRPSequential       25  Sequential      1        1.00
# 39         GMSC      SRPSequential       25          MB      4       50.00
# 63         GMSC      SRPSequential       25       MB-LF      4       50.00
# 42     airlines                ARF       25          MB      4       50.00
# 66     airlines                ARF       25       MB-LF      4       50.00
# 10     airlines      ARFSequential       25  Sequential      1        1.00
# 26     airlines               LBag       25          MB      4       50.00
# 50     airlines               LBag       25       MB-LF      4       50.00
# 17     airlines     LBagSequential       25  Sequential      1        1.00
# 46     airlines                 OB       25          MB      4       50.00
# 70     airlines                 OB       25       MB-LF      4       50.00
# 2      airlines   OBASHTSequential       25  Sequential      1        1.00
# 41     airlines   OBASHTSequential       25          MB      4       50.00
# 65     airlines   OBASHTSequential       25       MB-LF      4       50.00
# 33     airlines            OBAdwin       25          MB      4       50.00
# 57     airlines            OBAdwin       25       MB-LF      4       50.00
# 22     airlines  OBAdwinSequential       25  Sequential      1        1.00
# 0      airlines       OBSequential       25  Sequential      1        1.00
# 16     airlines      SRPSequential       25  Sequential      1        1.00
# 47     airlines      SRPSequential       25          MB      4       50.00
# 71     airlines      SRPSequential       25       MB-LF      4       50.00
# 30  covtypeNorm                ARF       25          MB      4       50.00
# 54  covtypeNorm                ARF       25       MB-LF      4       50.00
# 19  covtypeNorm      ARFSequential       25  Sequential      1        1.00
# 24  covtypeNorm               LBag       25          MB      4       50.00
# 48  covtypeNorm               LBag       25       MB-LF      4       50.00
# 21  covtypeNorm     LBagSequential       25  Sequential      1        1.00
# 32  covtypeNorm                 OB       25          MB      4       50.00
# 56  covtypeNorm                 OB       25       MB-LF      4       50.00
# 5   covtypeNorm   OBASHTSequential       25  Sequential      1        1.00
# 44  covtypeNorm   OBASHTSequential       25          MB      4       50.00
# 68  covtypeNorm   OBASHTSequential       25       MB-LF      4       50.00
# 38  covtypeNorm            OBAdwin       25          MB      4       50.00
# 62  covtypeNorm            OBAdwin       25       MB-LF      4       50.00
# 12  covtypeNorm  OBAdwinSequential       25  Sequential      1        1.00
# 4   covtypeNorm       OBSequential       25  Sequential      1        1.00
# 3   covtypeNorm      SRPSequential       25  Sequential      1        1.00
# 36  covtypeNorm      SRPSequential       25          MB      4       50.00
# 60  covtypeNorm      SRPSequential       25       MB-LF      4       50.00
# 28  elecNormNew                ARF       25          MB      4       50.00
# 52  elecNormNew                ARF       25       MB-LF      4       50.00
# 23  elecNormNew      ARFSequential       25  Sequential      1        1.00
# 31  elecNormNew               LBag       25          MB      4       50.00
# 55  elecNormNew               LBag       25       MB-LF      4       50.00
# 1   elecNormNew     LBagSequential       25  Sequential      1        1.00
# 45  elecNormNew                 OB       25          MB      4       50.00
# 69  elecNormNew                 OB       25       MB-LF      4       50.00
# 11  elecNormNew   OBASHTSequential       25  Sequential      1        1.00
# 37  elecNormNew   OBASHTSequential       25          MB      4       50.00
# 61  elecNormNew   OBASHTSequential       25       MB-LF      4       50.00
# 27  elecNormNew            OBAdwin       25          MB      4       50.00
# 51  elecNormNew            OBAdwin       25       MB-LF      4       50.00
# 15  elecNormNew  OBAdwinSequential       25  Sequential      1        1.00
# 9   elecNormNew       OBSequential       25  Sequential      1        1.00
# 8   elecNormNew      SRPSequential       25  Sequential      1        1.00
# 35  elecNormNew      SRPSequential       25          MB      4       50.00
# 59  elecNormNew      SRPSequential       25       MB-LF      4       50.00
#
#     rate  cache_misses  cache_references
# 40  1.00      2,075.97         75,642.13
# 64  1.00      1,902.50         73,531.47
# 20  1.00      2,167.05         75,418.06
# 29  1.00      1,522.23         54,793.94
# 53  1.00      1,352.17         56,966.56
# 6   1.00      1,640.41         51,172.66
# 43  1.00        635.44         18,139.24
# 67  1.00        380.20         12,144.87
# 13  1.00        698.71         17,737.31
# 25  1.00        617.31         18,834.79
# 49  1.00        380.75         12,590.18
# 34  1.00        576.19         23,075.28
# 58  1.00        545.89         23,928.45
# 18  1.00        818.42         21,513.40
# 7   1.00        714.28         16,963.88
# 14  1.00      4,389.36        159,603.15
# 39  1.00      3,960.52        149,179.73
# 63  1.00      3,622.52        137,774.34
# 42  1.00     44,678.76      2,016,438.27
# 66  1.00     44,689.77      1,995,375.61
# 10  1.00     45,007.84      2,003,195.36
# 26  1.00     65,830.57      2,566,721.42
# 50  1.00     63,027.52      2,546,019.01
# 17  1.00     59,569.68      2,355,699.52
# 46  1.00      3,591.50        168,261.22
# 70  1.00      1,887.12         74,773.40
# 2   1.00      3,797.86        270,280.61
# 41  1.00      3,823.63        271,889.00
# 65  1.00      1,773.63        141,218.82
# 33  1.00     18,649.15        819,639.60
# 57  1.00     17,911.76        819,785.49
# 22  1.00     16,121.14        685,528.03
# 0   1.00      3,357.03        159,963.11
# 16  1.00     43,837.99      2,285,472.61
# 47  1.00     44,443.96      2,296,918.00
# 71  1.00     44,096.07      2,035,722.04
# 30  1.00     13,122.18        669,897.43
# 54  1.00     11,918.31        640,677.10
# 19  1.00     13,682.86        678,070.13
# 24  1.00     18,196.36        730,019.51
# 48  1.00     15,375.02        699,858.36
# 21  1.00     18,929.39        679,802.79
# 32  1.00      7,006.85        277,561.49
# 56  1.00      2,202.00        112,270.43
# 5   1.00      9,680.78        331,368.78
# 44  1.00      7,489.50        267,154.51
# 68  1.00      2,382.40        119,360.25
# 38  1.00     11,331.64        406,924.55
# 62  1.00      9,109.78        411,874.17
# 12  1.00     12,116.11        374,971.02
# 4   1.00      8,157.59        248,980.87
# 3   1.00     52,481.53      2,047,501.26
# 36  1.00     53,497.03      2,294,267.12
# 60  1.00     49,457.15      2,185,666.34
# 28  1.00      1,245.79         43,548.64
# 52  1.00      1,204.60         43,516.22
# 23  1.00      1,265.64         42,192.10
# 31  1.00        834.34         29,240.90
# 55  1.00        830.75         29,775.44
# 1   1.00        810.74         26,746.16
# 45  1.00        336.35         10,434.30
# 69  1.00        251.86          8,041.57
# 11  1.00        364.62         11,036.41
# 37  1.00        340.77         10,333.30
# 61  1.00        266.67          8,134.80
# 27  1.00        405.77         13,221.17
# 51  1.00        359.21         13,367.87
# 15  1.00        415.05         12,543.59
# 9   1.00        346.53          9,804.87
# 8   1.00      2,221.08         80,552.49
# 35  1.00      2,374.25         87,718.16
# 59  1.00      2,384.87         88,316.97
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Accuracy and Energy Consume
#
# From here results is precision and recall when compared sequential, mb and mb with loop fusion. After consumer energy in JPI, Delay and IPS.

# %%
# %run "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/loop-fusion/Moa-MiniBatchingLoopFusion.ipynb"
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Library/Python/3.8/lib/python/site-packages/pandas/util/_decorators.py:311: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   return func(*args, **kwargs)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/788530580.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.batch_size[df.batch_size == 1] = 'Sequential'
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/788530580.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.batch_size[df.batch_size == 0] = 'MB'
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/788530580.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.batch_size[df.batch_size == 50] = 'MB-LF'
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# moaDF: 216    mdf: 216     sshDF: 216
#
#
#
# ----------------- Energy Consume -----------------
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# moaDF: 216    mdf: 216     sshDF: 216
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/852888933.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.methodology_x[df.methodology_x == 1] = 'Sequential'
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/852888933.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.methodology_x[df.methodology_x == 2] = 'MB+50-4'
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66040/852888933.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.methodology_x[df.methodology_x == 3] = 'MBLF+50-4'
#       dataset      algorithm  batch_size  instances   time  JPI   acc  \
# 136  airlines  ARFSequential           1   3,576.00 120.01 0.14 70.02
# 28   airlines          ARFMB          50   8,400.00 120.26 0.07 65.84
# 209  airlines          ARFMB          50   9,600.00 122.18 0.07 64.93
#
#     methodology_x   IPS ensemble_size
# 136    Sequential 29.80            25
# 28        MB+50-4 69.85            25
# 209     MBLF+50-4 78.57            25
#     dataset      algorithm  batch_size  instances   time  JPI   acc  \
# 111    GMSC  ARFSequential           1  48,257.00 120.00 0.01 93.44
# 107    GMSC          ARFMB          50  69,484.00 119.98 0.01 93.50
# 29     GMSC          ARFMB          50 150,000.00  98.70 0.00 93.53
#
#     methodology_x      IPS ensemble_size
# 111    Sequential   402.14            25
# 107       MB+50-4   579.13            25
# 29      MBLF+50-4 1,519.80            25
#          dataset      algorithm  batch_size  instances   time  JPI   acc  \
# 31   elecNormNew  ARFSequential           1  28,168.00 120.00 0.02 89.13
# 200  elecNormNew          ARFMB          50  45,312.00 114.93 0.01 80.23
# 78   elecNormNew          ARFMB          50  43,000.00  55.10 0.01 88.92
#
#     methodology_x    IPS ensemble_size
# 31     Sequential 234.73            25
# 200       MB+50-4 394.25            25
# 78      MBLF+50-4 780.43            25
#          dataset      algorithm  batch_size  instances   time  JPI   acc  \
# 100  covtypeNorm  ARFSequential           1  19,328.00 120.00 0.03 77.11
# 66   covtypeNorm          ARFMB          50  18,569.00 119.89 0.03 71.86
# 167  covtypeNorm          ARFMB          50 103,550.00 119.97 0.01 90.64
#
#     methodology_x    IPS ensemble_size
# 100    Sequential 161.06            25
# 66        MB+50-4 154.88            25
# 167     MBLF+50-4 863.13            25
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#       dataset       algorithm  batch_size  instances   time  JPI   acc  \
# 138  airlines  LBagSequential           1   3,793.00 120.00 0.13 68.55
# 41   airlines          LBagMB          50   7,800.00 120.42 0.08 62.85
# 142  airlines          LBagMB          50   9,800.00 121.69 0.07 61.77
#
#     methodology_x   IPS ensemble_size
# 138    Sequential 31.61            25
# 41        MB+50-4 64.77            25
# 142     MBLF+50-4 80.54            25
#     dataset       algorithm  batch_size  instances   time  JPI   acc  \
# 22     GMSC  LBagSequential           1   6,602.00 120.02 0.08 93.56
# 183    GMSC          LBagMB          50  97,550.00 120.02 0.01 93.34
# 210    GMSC          LBagMB          50 145,900.00  82.16 0.00 93.37
#
#     methodology_x      IPS ensemble_size
# 22     Sequential    55.01            25
# 183       MB+50-4   812.76            25
# 210     MBLF+50-4 1,775.74            25
#          dataset       algorithm  batch_size  instances   time  JPI   acc  \
# 152  elecNormNew  LBagSequential           1  42,498.00 100.33 0.01 89.55
# 215  elecNormNew          LBagMB          50  45,312.00  75.70 0.01 81.41
# 178  elecNormNew          LBagMB          50  42,050.00  38.45 0.01 90.51
#
#     methodology_x      IPS ensemble_size
# 152    Sequential   423.57            25
# 215       MB+50-4   598.60            25
# 178     MBLF+50-4 1,093.74            25
#          dataset       algorithm  batch_size  instances   time  JPI   acc  \
# 16   covtypeNorm  LBagSequential           1  12,909.00 120.00 0.04 74.31
# 91   covtypeNorm          LBagMB          50  15,574.00 119.98 0.03 70.26
# 130  covtypeNorm          LBagMB          50  71,050.00 120.01 0.01 90.37
#
#     methodology_x    IPS ensemble_size
# 16     Sequential 107.57            25
# 91        MB+50-4 129.81            25
# 130     MBLF+50-4 592.03            25
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#       dataset      algorithm  batch_size  instances   time  JPI   acc  \
# 51   airlines  SRPSequential           1   2,729.00 120.04 0.18 73.29
# 134  airlines          SRPMB          50   7,700.00 120.18 0.09 66.08
# 207  airlines          SRPMB          50   8,600.00 120.23 0.08 65.51
#
#     methodology_x   IPS ensemble_size
# 51     Sequential 22.73            25
# 134       MB+50-4 64.07            25
# 207     MBLF+50-4 71.53            25
#     dataset      algorithm  batch_size  instances   time  JPI   acc  \
# 154    GMSC  SRPSequential           1  28,092.00 120.00 0.02 93.55
# 19     GMSC          SRPMB          50  37,737.00 119.93 0.01 93.55
# 193    GMSC          SRPMB          50 101,450.00 120.08 0.01 93.46
#
#     methodology_x    IPS ensemble_size
# 154    Sequential 234.10            25
# 19        MB+50-4 314.65            25
# 193     MBLF+50-4 844.84            25
#          dataset      algorithm  batch_size  instances   time  JPI   acc  \
# 150  elecNormNew  SRPSequential           1  16,550.00 120.01 0.03 91.38
# 170  elecNormNew          SRPMB          50  23,361.00 119.92 0.02 82.76
# 1    elecNormNew          SRPMB          50  45,100.00 115.29 0.01 89.56
#
#     methodology_x    IPS ensemble_size
# 150    Sequential 137.90            25
# 170       MB+50-4 194.81            25
# 1       MBLF+50-4 391.19            25
#          dataset      algorithm  batch_size  instances   time  JPI   acc  \
# 109  covtypeNorm  SRPSequential           1   7,161.00 120.01 0.07 82.15
# 4    covtypeNorm          SRPMB          50   8,986.00 120.00 0.05 77.10
# 172  covtypeNorm          SRPMB          50  27,550.00 119.99 0.02 87.65
#
#     methodology_x    IPS ensemble_size
# 109    Sequential  59.67            25
# 4         MB+50-4  74.88            25
# 172     MBLF+50-4 229.59            25
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#      dataset          algorithm  batch_size  instances   time  JPI   acc  \
# 95  airlines  OBAdwinSequential           1  12,182.00 120.01 0.04 63.80
# 5   airlines          OBAdwinMB          50  26,356.00 119.98 0.02 67.32
# 20  airlines          OBAdwinMB          50  42,000.00 120.23 0.02 86.54
#
#    methodology_x    IPS ensemble_size
# 95    Sequential 101.50            25
# 5        MB+50-4 219.67            25
# 20     MBLF+50-4 349.34            25
#     dataset          algorithm  batch_size  instances   time  JPI   acc  \
# 7      GMSC  OBAdwinSequential           1 145,472.00 102.23 0.00 93.45
# 45     GMSC          OBAdwinMB          50 150,000.00  85.11 0.00 93.35
# 157    GMSC          OBAdwinMB          50 148,900.00  41.45 0.00 93.45
#
#     methodology_x      IPS ensemble_size
# 7      Sequential 1,422.95            25
# 45        MB+50-4 1,762.51            25
# 157     MBLF+50-4 3,591.93            25
#          dataset          algorithm  batch_size  instances  time  JPI   acc  \
# 171  elecNormNew  OBAdwinSequential           1  39,257.00 49.89 0.01 84.15
# 94   elecNormNew          OBAdwinMB          50  45,312.00 42.23 0.00 79.97
# 169  elecNormNew          OBAdwinMB          50  42,950.00 20.11 0.00 85.64
#
#     methodology_x      IPS ensemble_size
# 171    Sequential   786.89            25
# 94        MB+50-4 1,072.88            25
# 169     MBLF+50-4 2,135.43            25
#          dataset          algorithm  batch_size  instances   time  JPI   acc  \
# 52   covtypeNorm  OBAdwinSequential           1  19,872.00 120.00 0.02 74.92
# 48   covtypeNorm          OBAdwinMB          50  18,569.00 119.93 0.03 70.50
# 156  covtypeNorm          OBAdwinMB          50 105,350.00 120.00 0.01 87.63
#
#     methodology_x    IPS ensemble_size
# 52     Sequential 165.60            25
# 48        MB+50-4 154.83            25
# 156     MBLF+50-4 877.91            25
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#       dataset         algorithm  batch_size  instances   time  JPI   acc  \
# 164  airlines  OBASHTSequential           1  12,420.00 120.71 0.04 63.80
# 205  airlines          OBASHTMB          50  33,950.00 121.17 0.02 65.03
# 63   airlines          OBASHTMB          50  25,000.00 120.77 0.02 56.25
#
#     methodology_x    IPS ensemble_size
# 164    Sequential 102.89            25
# 205       MB+50-4 280.18            25
# 63      MBLF+50-4 207.01            25
#     dataset         algorithm  batch_size  instances  time  JPI   acc  \
# 113    GMSC  OBASHTSequential           1 144,090.00 80.93 0.00 93.33
# 6      GMSC          OBASHTMB          50 150,000.00 81.70 0.00 93.39
# 92     GMSC          OBASHTMB          50 142,850.00 24.63 0.00 93.40
#
#     methodology_x      IPS ensemble_size
# 113    Sequential 1,780.54            25
# 6         MB+50-4 1,835.94            25
# 92      MBLF+50-4 5,800.31            25
#          dataset         algorithm  batch_size  instances  time  JPI   acc  \
# 129  elecNormNew  OBASHTSequential           1  38,362.00 43.31 0.01 82.90
# 128  elecNormNew          OBASHTMB          50  45,312.00 34.79 0.00 79.57
# 140  elecNormNew          OBASHTMB          50  43,500.00 12.19 0.00 77.77
#
#     methodology_x      IPS ensemble_size
# 129    Sequential   885.77            25
# 128       MB+50-4 1,302.56            25
# 140     MBLF+50-4 3,568.21            25
#          dataset         algorithm  batch_size  instances   time  JPI   acc  \
# 10   covtypeNorm  OBASHTSequential           1  23,830.00 120.00 0.02 71.69
# 195  covtypeNorm          OBASHTMB          50 286,750.00 120.00 0.00 78.43
# 165  covtypeNorm          OBASHTMB          50  32,300.00 119.91 0.01 69.80
#
#     methodology_x      IPS ensemble_size
# 10     Sequential   198.58            25
# 195     MBLF+50-4 2,389.56            25
# 165     MBLF+50-4   269.37            25
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#       dataset     algorithm  batch_size  instances   time  JPI   acc  \
# 187  airlines  OBSequential           1  12,357.00 120.01 0.04 63.65
# 125  airlines          OBMB          50  25,450.00 121.52 0.03 63.90
# 155  airlines          OBMB          50 190,000.00 120.01 0.00 62.62
#
#     methodology_x      IPS ensemble_size
# 187    Sequential   102.97            25
# 125       MB+50-4   209.43            25
# 155     MBLF+50-4 1,583.18            25
#     dataset     algorithm  batch_size  instances  time  JPI   acc  \
# 141    GMSC  OBSequential           1 143,472.00 79.36 0.00 93.46
# 15     GMSC          OBMB          50 150,000.00 81.68 0.00 93.48
# 116    GMSC          OBMB          50 142,800.00 23.93 0.00 93.47
#
#     methodology_x      IPS ensemble_size
# 141    Sequential 1,807.93            25
# 15        MB+50-4 1,836.52            25
# 116     MBLF+50-4 5,968.40            25
#          dataset     algorithm  batch_size  instances  time  JPI   acc  \
# 214  elecNormNew  OBSequential           1  37,864.00 39.36 0.00 82.36
# 204  elecNormNew          OBMB          50  45,312.00 35.63 0.00 78.68
# 146  elecNormNew          OBMB          50  43,150.00 12.18 0.00 77.36
#
#     methodology_x      IPS ensemble_size
# 214    Sequential   962.09            25
# 204       MB+50-4 1,271.70            25
# 146     MBLF+50-4 3,542.11            25
#          dataset     algorithm  batch_size  instances   time  JPI   acc  \
# 108  covtypeNorm  OBSequential           1  27,907.00 120.00 0.02 71.97
# 143  covtypeNorm          OBMB          50 283,750.00 120.00 0.00 80.47
# 9    covtypeNorm          OBMB          50  31,700.00 119.89 0.01 68.23
#
#     methodology_x      IPS ensemble_size
# 108    Sequential   232.56            25
# 143     MBLF+50-4 2,364.56            25
# 9       MBLF+50-4   264.40            25
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
