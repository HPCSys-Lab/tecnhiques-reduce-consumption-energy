# %% [markdown]
# # Analisy results MOA mini-batching
#
# The results compareds this work use follow variables.
#
# Frequencies in MHz:
#
#     - Minimum: 600Mhz, Maximum: 1200Mhz
#
# Size mini-batching uses are:
#
#     - 1 (Sequential without mini-batching)
#     - 1 (Sequential with mini-batching)
#     - 25 (Paralel 4 CPUs with mini batching)
#     - 75 (Paralel 4 CPUs with mini batching)
#     - 50 (Paralel 4 CPUs with mini batching)
#     - 100 (Paralel 4 CPUs with mini batching)
#
# All executions are used ensemble size 25.

# %% [markdown]
# # Main Question
#
# Qual é o consumo energético e a acuracia para os batch-size de 25 à 100.

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
# %mkdir -p parsed_csvs figures
# %cd results
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %%
def parse(fname):
    global header_printed
    #index of wanted columns
    columns = []
    #column names to get the data from
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    ret_string = ''
    #remove the path and isolate the filename
    spname = fname.split('/')[-1].split('-')
    spline = []
    #control flag for knowing when the column names have already been discovered
    got = False
    #we ignore the first parameter of the filename and add all others to the csv string
    for s in spname[1:]:
        ret_string += s + ','
    #should probably use a safer way, but python handles the closing of the file
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                #sometimes the dump file has multiple results in it, so we get the index of wanted columns only once
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        #OzaBagASHT bugs out on GMSC, this reuses the data from the sequential execution
        if 'GMSC' in spname and 'ASHT' in spname[2]:
            for c in columns[:-2]:
                ret_string += str(spline[c]) + ','
            ret_string += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        #normal code, how everything should run
        #we process the data (add the content of wanted columns to the csv string) only after the for
        #ensuring we use only the last (most recent) data and not the intermediate results
        else:
            for c in columns:
                ret_string += str(spline[c]) + ','
            if len(columns) == 5:
                ret_string += '0,'
        #header is a global variable, it will only be printed on the first file 
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,instances,time,acc,prec,recall,change'
            ret_string = f"{head}\n{ret_string}"
            header_printed = True
        #remove the last comma ,
        return (ret_string[:-1])

# %%
def add_label_column_df(df):
    for index, row in df.iterrows():
        _str = row["algorithm"]

        if "RUNPER" in _str and row["batch_size"] == 1:
            df.at[index, 'label'] = "Parallel"
        elif row["batch_size"] == 1:
            df.at[index, 'label'] = "Seq"
        else:
            df.at[index, 'label'] = row["batch_size"]
            
    return df

# %%
#loads the csv as a dataframe and standardizes the algorithm names 
def load_df(filename):
    df = pd.read_csv(filename, index_col=False)
    return select_columns_and_rename_values(df)

# %%
#standardize algorithm names
def select_columns_and_rename_values(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    df.batch_size.unique()
    return df

# %%
#filters by substring (there are multiple OzaBag algorithms)
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %%
#plots precision and recall with markers of one parameter configuration
def gen_lines(df, ax, alg_order, markers):
    lwidth = 0.75
    if markers:
        colors=['go', 'bs', 'rP', 'md', 'y+' , 'k*']
    else:
        colors=['g', 'b', 'r', 'm', 'y' , 'k']

    labels = df.label
    alg = df.algorithm.unique()[0]
    x = np.arange(len(labels))
    
    ax.plot(x, pd.to_numeric(df.prec), f'{colors[alg_order]}--', linewidth=lwidth, label=f'{alg}-prec')
    ax.plot(x, pd.to_numeric(df.recall), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')

    #ax.plot(x,pd.to_numeric(df.prec), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_ylim(50,95)

# %%
#iterates over the parameter configurations and creates the chart grid
def gen_chart(df, markers=True, tables=False):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
    #dictionary containing the correct name to be printed
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    #creates a 2x2 grid for plotting the charts
    #sharey=row means that all charts in a row share the same Y-axis
    fig, axs = plt.subplots(2, 2, figsize=(8,8), sharey='row')
    filename = "batch-size-vs-prediction-mark" if markers else "batch-size-vs-prediction"
    #each chart presents the results for a given dataset and contains the series for all algorithms
    for ds in datasets:
        title = ''
        my_id = datasets.index(ds)
        #selects the correct position in the grid
        ax = axs[int(my_id/2)][my_id%2]
        ax.set_title(f'{dsformalname[ds]}')
        #for each algorithm
        for alg in algorithms:
            #filters the df to contain the wanted values
            df_aux = filter_by_substring_algorithm(df[df.dataset == ds].sort_values(by=['label', 'batch_size'], ascending=False), alg)
            if tables:
                display(df_aux)
            #plot (include) the series in the chart
            gen_lines(df_aux, ax, algorithms.index(alg), markers)
            #if its the first column, print Y-axis label
            if my_id%2 == 0:
                ax.set_ylabel('Percentage')
            #if its the last row, print the X-axis label
            if int(my_id/2) == 1:
                ax.set_xlabel('Algorithm Methodology')
    #retrieves the handles and labels to create a global legend
    handles, labels = axs[0][0].get_legend_handles_labels()
    lgd = fig.legend(handles, labels, loc = 'lower center', ncol = math.ceil(len(algorithms)/2), bbox_to_anchor=(0.5,-0.1))
    fig.tight_layout()
    plt.savefig(f'figures/{filename}.png')
    plt.savefig(f'figures/{filename}.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/06-03-2022/600/1200/first"
wantedCSVfilename = "data-batch-vs-acc-600-1200.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

df = load_df(f'{csvFile}')
df = add_label_column_df(df)
df = df.drop(['cores', 'time'], axis=1)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_35050/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_35050/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_35050/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_35050/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_35050/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
#false makes the chart without markers
gen_chart(df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [82], in <module>
#       1 #false makes the chart without markers
# ----> 2 gen_chart(df)
#
# Input In [80], in gen_chart(df, markers, tables)
#      23     display(df_aux)
#      24 #plot (include) the series in the chart
# ---> 25 gen_lines(df_aux, ax, algorithms.index(alg), markers)
#      26 #if its the first column, print Y-axis label
#      27 if my_id%2 == 0:
#
# Input In [79], in gen_lines(df, ax, alg_order, markers)
#      15 else:
#      16     colors=['g', 'b', 'r', 'm', 'y' , 'k']
# ---> 19 idx = [idx for idx, _ in sorted(enumerate(df['label']), key=sort_key)]
#      21 df = df.iloc[idx, :]
#      23 labels = df.label
#
# Input In [79], in sort_key(x)
#       7     return np.inf
#       8 else:
# ----> 9     return int(x[1].split()[2])
#
# IndexError: list index out of range

# %% [markdown]
# Pegando o dataset Electricity e sua precisão e recall podemos observar que ao utilizar o os batch-sizes de tamanho entre 25 à 100 eles pedem um pouco em relação ao MOA comum e ao MOA paralelo. No dataset GMSC para o algoritmo OzaBag temos uma linha estável de precisão e recall para todos os cenários. O algoritmo OzaBag também em outros datasets é o que mais tem estabilidade ao utilizar o mini-batching ou sem ele. Já no dataset covertype podemos observar uma linha um pouco mais de instabilidade ao adicionamos a paralelização no algoritmos, alguns casos descem como o Ozabag e outros como o LBag melhoram a precisão porém com os mini-batchs esses dados são estabilizados.

# %% [markdown]
# # Consumer Energy

# %%
PATH_TO_RESULTS = '/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/socket/07-04-2022/'

# %%
def parse_MOA(fname):
    global header_printed
    columns = []
    wanted = ['learning evaluation instances', 'Wall Time (Actual Time)', 'Avg Delay (ms)', 'outRate (inst/s)', 'classifications correct (percent)']
    pstr = ''
    spname = fname.split('/')[-1].split('-')
    spline = []
    for s in spname[1:]:
        pstr += s + ','
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                spline = line.split(',')
                for s in spline:
                    if s in wanted:
                        columns.append(spline.index(s))
            else:
                spline = line.split(',')
        for c in columns:
            pstr += spline[c] + ','
        if len(columns) == 2:
            pstr += '1,'
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,inc_rate,instances,time,delay,out_rate,acc'
            pstr = f"{head}\n{pstr}"
            header_printed = True
        return (pstr[:-1])

# %%
def read_MOA(folder, out_file):
    directory = os.fsencode(folder)
    global header_printed

    with open(out_file, "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("term-"): 
                output.write(f"{parse_MOA(f'{os.fsdecode(directory)}/{filename}')}\n")
    fname = os.fsdecode(out_file)
    df = pd.read_csv(fname)

    df['inc_rate'].astype('int64')
    return df[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'instances', 'time', 'delay', 'out_rate', 'acc']]

# %% [markdown]
# # Read Energy Data

# %%
def load_Wmeas(filename):
    return pd.read_csv(filename, header=None, names=['date', 'time', 'measure'])

# %%
def exper_order_to_dict(filename, d):
    with open(filename) as forder:
        got_timestamp = False
        dataset = algorithm = Esize = cores = Bsize = ''
        dnow=None
        for line in forder:
            if not got_timestamp:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
                if dnow:
                    dnow['finish'] = date_time_obj - datetime.timedelta(seconds=1)
            elif ':' not in line:
                spline = line.split('/')[-1].strip().split('-')
                #print(spline)
                if len(spline) == 6:
                    dataset,algorithm,Esize,cores,Bsize,rate = spline
                else:
                    dataset,algorithm,Esize,cores,Bsize,rate = *spline,1
                if algorithm not in d:
                    d[algorithm] = {}
                if dataset not in d[algorithm]:
                    d[algorithm][dataset] = {}
                if Esize not in d[algorithm][dataset]:
                    d[algorithm][dataset][Esize] = {}
                if cores not in d[algorithm][dataset][Esize]:
                    d[algorithm][dataset][Esize][cores] = {}
                if Bsize not in d[algorithm][dataset][Esize][cores]:
                    d[algorithm][dataset][Esize][cores][Bsize] = {}
                if rate not in d[algorithm][dataset][Esize][cores][Bsize]:
                    d[algorithm][dataset][Esize][cores][Bsize][rate] = {'start': date_time_obj, 'finish': ''}
                    dnow = d[algorithm][dataset][Esize][cores][Bsize][rate]
                got_timestamp = False
            else:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
    return d

# %%
def populate_dict(d, df):
    df['datetime'] = df['date'] + ' ' + df['time']
    for k, v in d.items():
        for k1, v1 in v.items():
            for k2, v2 in v1.items():
                for k3, v3 in v2.items():
                    for k4, v4 in v3.items():
                        for k5, v5 in v4.items():
                            if 'seconds' not in v5:
                                st = v5['start']
                                ed = v5['finish']
                                v5['seconds'] = (ed - st).seconds
                                new_df = df[(df.datetime <= f'{ed.strftime("%d/%m/%y")} {ed.strftime("%X")}')
                                          & (df.datetime >= f'{st.strftime("%d/%m/%y")} {st.strftime("%X")}')]
                                v5['avg_measure'] = new_df['measure'].mean()
                                v5['sum_measure'] = new_df['measure'].sum()
                                v5['avg_times_seconds'] = v5['avg_measure'] * v5['seconds']
    return d

# %%
def append_dict_to_df(d, ensemble_size=False):
    dappend = {'algorithm': [], 'dataset': [], 'ensemble_size': [], 'cores': [], 
               'batch_size': [], 'duration': [], 'inc_rate': [], 'avg_measure': [], 'sum_measure': [], 'avg_times_seconds': []}
    for kalg,valg in d.items():
        for kds,vds in valg.items():
            for kens,vens in vds.items():
                for kcore,vcore in vens.items():
                    for kmbs,vmbs in vcore.items():
                        for krate,vrate in vmbs.items():
                            dappend['algorithm'].append(kalg)
                            dappend['dataset'].append(kds)
                            dappend['ensemble_size'].append(kens)
                            dappend['cores'].append(kcore)
                            dappend['batch_size'].append(kmbs)
                            dappend['duration'].append(vrate['seconds'])
                            dappend['inc_rate'].append(krate)
                            for key in ['avg_measure', 'sum_measure','avg_times_seconds']:
                                dappend[key].append(vrate[key])
    adf = pd.DataFrame(data=dappend)
    adf = adf.sort_values(['algorithm','dataset']).astype({'inc_rate': 'int64', 
                                                           'cores': 'int64',
                                                           'batch_size': 'int64'})
    if ensemble_size:
        return adf[['algorithm', 'dataset', 'ensemble_size', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]
    return adf[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]

# %% [markdown]
# # Parse SSH Logs

# %%
def parse_SSH(fname):
    fname = os.fsdecode(fname)
    read_ssh = False
    alg = ''
    dataset = ''
    rate = ''
    d = {'algorithm': [], 'dataset': [], 'batch_size': [], 'inc_rate': [], 'prod_rate': [], 'tt_inst_prod': []}
    with open (fname, "r") as file:
        for line in file:
            if not read_ssh:
                if 'ssh-' in line:
                    read_ssh = True
                    spline = line.split('-')
                    if "MAX" in line:
                        if len(spline[1:]) == 3:
                            dataset, alg, rate = spline[1:]
                            bsize = 500
                        else:
                            dataset, alg, bsize, rate = spline[1:]
                    else:
                        if len(spline[1:]) == 3:
                            dataset, alg, rate = spline[1:]
                            bsize = 1
                        else:
                            dataset, alg, bsize, rate = spline[1:]
                    d['algorithm'].append(alg)
                    d['dataset'].append(dataset)
                    d['inc_rate'].append(rate.strip())
                    d['batch_size'].append(bsize)
            else:
                if 'Total instances Producer' in line:
                    tt_inst = float(line.split(': ')[1])
                    d['tt_inst_prod'].append(tt_inst)
                elif 'Producer Rate' in line:
                    prod_rate = float(line.split(': ')[1])
                    d['prod_rate'].append(prod_rate)
                    read_ssh = False
    return pd.DataFrame.from_dict(d).astype({'inc_rate': 'int64'})

# %% [markdown]
# # Showing and preparing for charts

# %%
def filter_fields(df):
    wanted = ['algorithm', 'dataset', 'batch_size', 'cores', 'out_rate', 'instances', 'delay', 'joules', 'JPI']
    return df[[
        l for l in df.columns if any([w in l for w in wanted])
    ]]

# %%
def rename_columns_by_rate(df):
    rate = df.PERC.iloc[0]
    return df.rename(columns={"out_rate": f"out_rate_{rate}", "instances": f"instances_{rate}", 
                                "delay": f"delay_{rate}", "joules": f"joules_{rate}", 
                                "JPI": f"JPI_{rate}", "tput": f"tput_{rate}"})

# %%
def show_graph_JPI_delay(df, ax, mJPI, mDel, legend=False, title=False, ylabels=False, ds='', bar=False, share_y=False, log_y=False, norm=False, hide=True):
    if norm:
        df = my_norm(df, x=norm)
    global rate
    global twin
    width = 0.15
    alg_order = ['B1', 'B25', 'B50', 'B75', 'B100']
    labels = ['10%', '50%', '90%']
    line_format = ['*', '-', '--', ':', '-.', (0, (3, 5, 1, 5, 1, 5))]
    linfo = '--'
    x = np.arange(len(labels))
    lns_l = []
    versions = 5
    for i in range(versions):
        adf = df.iloc[i]
        values_j = [adf.JPI_10, adf.JPI_50, adf.JPI_90]
        if bar:
            lns_l += ax.bar(x - ((1 - i) * width), values_j, width, label=f'JPI-{alg_order[i]}')            
        else:
            lns_l += ax.plot(x, values_j, label=f'JPI-{alg_order[i]}')

    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax_r = ax.twinx()
    twin = ax_r
    if log_y:
        ax.set_yscale('log')
        ax_r.set_yscale('log')
    if title:
        alg_title = re.sub('Sequential', '', df.algorithm.iloc[0])
        ax.set_title(f'{alg_title}')
    if ylabels:
        ax.set_ylabel(ds)
    if last:
        ax.set_ymargin(2)
    for i in range(versions): 
        adf = df.iloc[i]
        values_d = [ x/1000 for x in [adf.delay_10, adf.delay_50, adf.delay_90]]
        if bar:
            linfo = f'k{line_format[i]}'
            lns_l += ax_r.plot(x, values_d, color='black', linestyle=line_format[i], label=f'delay-{alg_order[i]}')
        else:
            lns_l += ax_r.plot(x, values_d, linfo, label=f'delay-{alg_order[i]}')
    labs = [l.get_label() for l in lns_l]
    if legend:
        ax.legend(lns_l, labs, loc=0)
    if hide:
        ax_r.set_yticklabels([])
    if share_y == 'row':
        ax.set_ylim(top=mJPI)
        ax_r.set_ylim(top=mDel/1000)

# %%
def aux_graphNx1(ds, axis, id_ds, df, bar=False, share_y='row', log_y=False, norm=False):
    rates = ['10', '50', '90']
    algs = ['Ada', 'L', 'Patches', 'Adwin', 'ASHT', 'OzaBag']
    global title
    global labels
    hide_axis = True
#     fig.suptitle(f'JPI and delay for {ds}', fontsize=18, y=1)
#     get max value from delay for all rates on all algorithms for this dataset
    mLstJPI = []
    mLstDel = []
    if share_y == 'row':
        for rt in rates:
            rtDF = df[df.PERC == rt]
            mLstJPI.append(rtDF.JPI.max())
            mLstDel.append(rtDF.delay.max())
        mJPI = max(mLstJPI)*1.05
        mDel = max(mLstDel)*1.05
    else:
        mJPI = mDel = 0
    for alg in algs:
        dsalgdf = filter_by_substring_algorithm(df, alg).sort_values(['algorithm','batch_size','cores'])
#         if alg == 'L' and ds == 'kyoto_binary':
#             display(dsalgdf)
        for rt in rates:
            if rt == '10':
                showdf = rename_columns_by_rate(dsalgdf[dsalgdf.PERC == rt])
            else:
                to_join = dsalgdf[dsalgdf.PERC == rt]
                showdf = showdf.merge(rename_columns_by_rate(to_join),
                                  on=['algorithm', 'dataset', 'batch_size', 'cores']).sort_values(['batch_size','cores'])
       
        # debug print, if it shows it is wrong
        # if len(showdf) != 5:
        #     display(showdf)

        display(showdf)
        if 'Ada' in alg:
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, ylabels=True, ds=ds, bar=bar, share_y=share_y, log_y=log_y, norm=norm)
        else:
            if algs[-1] == alg:
                hide_axis = False
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, bar=bar, share_y=share_y, log_y=log_y, norm=norm, hide=hide_axis)

# %%
def gen_graph(df, bars=False, share_y='row', log_y=False, norm=False, freq='600', tput=False):
    ps = f'{freq}\nbars: {bars}\nshare_y: {share_y}\nlog_y: {log_y} '
    datasets = ['airlines', 'GMSC','elecNormNew','covtypeNorm']

    fig, axis = plt.subplots(len(datasets), 6, figsize=(16,12), tight_layout=True, sharey=share_y)
    global title
    global labels
    global last
    global twin
    leg = False
    labls = True
    title = True
    last = False
    twin = axis[0][0]
    for ds in datasets:
        if datasets.index(ds) == (len(datasets) - 1):
            last = True
        dsdf = df[df.dataset == ds]
        aux_graphNx1(ds, axis, datasets.index(ds), dsdf, bar=bars, share_y=share_y, log_y=log_y, norm=norm)
        title = True
    lines_1, labels_1 = axis[0][0].get_legend_handles_labels()
    lines_2, labels_2 = twin.get_legend_handles_labels()
    lines = lines_1 + lines_2
    labels = labels_1 + labels_2
    lgd = fig.legend(lines, labels, loc=8, ncol=5, bbox_to_anchor=(0.5, -0.02))
    lgd.set_in_layout(True)
    fig.subplots_adjust(bottom=-0.5)
    filename = 'all-4x1-JPI-delay'
    if bars:
        filename = f'bars-{filename}'
    if share_y:
        filename = f'sharey-{filename}'
    if log_y:
        filename = f'logy-{filename}'
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.eps', pad_inches=0.2, bbox_inches='tight')
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.png', pad_inches=0.2, bbox_inches='tight')
    plt.show()

# %%
def debug(df):
    df = select_columns_and_rename_values(df)
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    dfalg = filter_by_substring_algorithm(df, alg)
    for ds in datasets:
        dsdf = dfalg[(dfalg.dataset == ds)]
        display(dsdf)

# %% [markdown]
# # Run methods to obtained visible results

# %%
def read_data_create_final_dataframe(freq, DEBUG=False):
    d = {}
    global header_printed
    header_printed = False
    folder_path = f"{PATH_TO_RESULTS}{freq['minimum']}/{freq['maximum']}"
    min = freq['minimum']
    max = freq['maximum']
    moaDF = read_MOA(f"{folder_path}", f"{folder_path}/inst-and-delay.csv")
    moaDF = moaDF[["algorithm", "dataset", "cores", "batch_size", "inc_rate", "out_rate", "instances", "time", "delay", "acc"]]
    measureDF = load_Wmeas(f'{folder_path}/Wm-log.log')
    d = exper_order_to_dict(f'{folder_path}/exper_order-freq-max-{max}-freq-min-{min}.log', d)
    d = populate_dict(d, measureDF)
    d = populate_dict(d, measureDF)
    mdf = append_dict_to_df(d, True)
    sshDF = parse_SSH(f'{folder_path}/ssh-log')
    sshDF['batch_size'] = sshDF['batch_size'].astype(int)
    if DEBUG:
        print(f'moaDF: {len(moaDF)}    mdf: {len(mdf)}     sshDF: {len(sshDF)}')
    
    #join dfs
    finaldf = moaDF.merge(mdf, on=['algorithm', 'dataset', 'cores', 'batch_size', 'inc_rate'])
    finaldf = finaldf.merge(sshDF, 'left', on=['algorithm', 'dataset', 'batch_size', 'inc_rate'])
    
    finaldf['avg_times_duration'] = finaldf['avg_measure'] * finaldf['duration']
    finaldf['joules'] = finaldf['avg_measure'] * finaldf['time']
    finaldf['JPIold'] = finaldf['avg_measure'] / finaldf['instances']
    finaldf['JPI'] = finaldf['avg_times_duration'] / finaldf['instances']
    
    # Add PERC column to identify if it used 90, 50 or 10% max rate
    # Before merging rows with the same batch size, we need to differentiate the experiments with different work loads
    # We use the **PERC**entage column for that
    tdf = finaldf.sort_values(by=['dataset','algorithm','batch_size','inc_rate'], ascending=False)

    tdf['PERC'] = 0

    masks = {'90':[], '50': [], '10': []}
    for k, v in zip(masks.keys(), [0, 1, 2]):
        for i in range(len(tdf)):
            masks[k].append(i % 3 == v)
    
    tdf.loc[masks['90'], 'PERC'] = '90'
    tdf.loc[masks['50'], 'PERC'] = '50'
    tdf.loc[masks['10'], 'PERC'] = '10'
    
    tdf['tput'] = tdf['instances'] / tdf['time']
    if DEBUG:
        tdf.to_csv(f"{PATH_TO_RESULTS}tdf-{min}x{max}.csv")    
    return tdf

# %%
freqs = [{'minimum': '600', 'maximum': '1200'}]
dataframes = []
for f in freqs:
    dataframes.append(read_data_create_final_dataframe(f, True))
# Out:
# moaDF: 432    mdf: 432     sshDF: 1510

# %%
#standardize algorithm names
def select_columns_and_rename_values_basic(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "")
    df.batch_size.unique()
    return df

# %%
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    df = select_columns_and_rename_values_basic(df)
    gen_graph(df, bars=True, freq=f"{f['minimum']}x{f['maximum']}")
# Out:
# ----------------- {'minimum': '600', 'maximum': '1200'} -----------------
#                          algorithm   dataset  cores  batch_size  inc_rate_x  \
# 0   AdaptiveRandomForestSequential  airlines      1           1          60
# 1       AdaptiveRandomForestRUNPER  airlines      4           1         143
# 2             AdaptiveRandomForest  airlines      4          25         170
# 3             AdaptiveRandomForest  airlines      4          50         174
# 4             AdaptiveRandomForest  airlines      4          50         174
# 5             AdaptiveRandomForest  airlines      4          50         174
# 6             AdaptiveRandomForest  airlines      4          50         174
# 7             AdaptiveRandomForest  airlines      4          50          97
# 8             AdaptiveRandomForest  airlines      4          50          97
# 9             AdaptiveRandomForest  airlines      4          50          97
# 10            AdaptiveRandomForest  airlines      4          50          97
# 11            AdaptiveRandomForest  airlines      4          75         178
# 12            AdaptiveRandomForest  airlines      4          75         178
# 13            AdaptiveRandomForest  airlines      4          75         178
# 14            AdaptiveRandomForest  airlines      4          75         178
# 15            AdaptiveRandomForest  airlines      4          75          99
# 16            AdaptiveRandomForest  airlines      4          75          99
# 17            AdaptiveRandomForest  airlines      4          75          99
# 18            AdaptiveRandomForest  airlines      4          75          99
# 19            AdaptiveRandomForest  airlines      4         100         179
# 20            AdaptiveRandomForest  airlines      4         100         179
# 21            AdaptiveRandomForest  airlines      4         100         179
# 22            AdaptiveRandomForest  airlines      4         100         179
# 23            AdaptiveRandomForest  airlines      4         100          99
# 24            AdaptiveRandomForest  airlines      4         100          99
# 25            AdaptiveRandomForest  airlines      4         100          99
# 26            AdaptiveRandomForest  airlines      4         100          99
#
#     out_rate_10  instances_10  time_x  delay_10  acc_x  ... avg_measure  \
# 0         36.92      4,431.00  120.00 12,684.00  68.47  ...        4.15
# 1         59.84      7,181.00  120.01 18,057.00  65.77  ...        4.79
# 2         73.20      8,800.00  120.21    341.00  66.19  ...        5.44
# 3         76.14      9,250.00  121.48    656.00  65.47  ...        4.17
# 4         76.14      9,250.00  121.48    656.00  65.47  ...        4.28
# 5         76.14      9,250.00  121.48    656.00  65.47  ...        4.17
# 6         76.14      9,250.00  121.48    656.00  65.47  ...        4.28
# 7         66.92      8,050.00  120.29    745.00  65.90  ...        4.17
# 8         66.92      8,050.00  120.29    745.00  65.90  ...        4.28
# 9         66.92      8,050.00  120.29    745.00  65.90  ...        4.17
# 10        66.92      8,050.00  120.29    745.00  65.90  ...        4.28
# 11        78.66      9,450.00  120.13    951.00  65.58  ...        4.21
# 12        78.66      9,450.00  120.13    951.00  65.58  ...        4.15
# 13        78.66      9,450.00  120.13    951.00  65.58  ...        4.21
# 14        78.66      9,450.00  120.13    951.00  65.58  ...        4.15
# 15        84.85     10,200.00  120.21    876.00  65.83  ...        4.21
# 16        84.85     10,200.00  120.21    876.00  65.83  ...        4.15
# 17        84.85     10,200.00  120.21    876.00  65.83  ...        4.21
# 18        84.85     10,200.00  120.21    876.00  65.83  ...        4.15
# 19        98.04     11,800.00  120.36  1,017.00  65.60  ...        4.23
# 20        98.04     11,800.00  120.36  1,017.00  65.60  ...        4.23
# 21        98.04     11,800.00  120.36  1,017.00  65.60  ...        4.23
# 22        98.04     11,800.00  120.36  1,017.00  65.60  ...        4.23
# 23        84.55     10,200.00  120.64  1,168.00  65.41  ...        4.23
# 24        84.55     10,200.00  120.64  1,168.00  65.41  ...        4.23
# 25        84.55     10,200.00  120.64  1,168.00  65.41  ...        4.23
# 26        84.55     10,200.00  120.64  1,168.00  65.41  ...        4.23
#
#     sum_measure  prod_rate  tt_inst_prod  avg_times_duration  jo
en_graph(df, bars=True, freq=f"{f['minimum']}x{f['maximum']}")
#
# Input In [51], in gen_graph(df, bars, share_y, log_y, norm, freq, tput)
#      17         last = True
#      18     dsdf = df[df.dataset == ds]
# ---> 19     aux_graphNx1(ds, axis, datasets.index(ds), dsdf, bar=bars, share_y=share_y, log_y=log_y, norm=norm)
#      20     title = True
#      21 lines_1, labels_1 = axis[0][0].get_legend_handles_labels()
#
# Input In [50], in aux_graphNx1(ds, axis, id_ds, df, bar, share_y, log_y, norm)
#      36 display(showdf)
#      37 if 'Ada' in alg:
# ---> 38     show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, ylabels=True, ds=ds, bar=bar, share_y=share_y, log_y=log_y, norm=norm)
#      39 else:
#      40     if algs[-1] == alg:
#
# Input In [42], in show_graph_JPI_delay(df, ax, mJPI, mDel, legend, title, ylabels, ds, bar, share_y, log_y, norm, hide)
#      39 if bar:
#      40     linfo = f'k{line_format[i]}'
# ---> 41     lns_l += ax_r.plot(x, values_d, color='black', linestyle=line_format[i], label=f'delay-{alg_order[i]}')
#      42 else:
#      43     lns_l += ax_r.plot(x, values_d, linfo, label=f'delay-{alg_order[i]}')
#
# File /opt/homebrew/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File /opt/homebrew/lib/python3.9/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/matplotlib/axes/_base.py:538, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File /opt/homebrew/lib/python3.9/site-packages/matplotlib/axes/_base.py:538, in <listcomp>(.0)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File /opt/homebrew/lib/python3.9/site-packages/matplotlib/axes/_base.py:531, in <genexpr>(.0)
#     528 else:
#     529     labels = [label] * n_datasets
# --> 531 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                       {**kwargs, 'label': label})
#     533           for j, label in enumerate(labels))
#     535 if return_kwargs:
#     536     return list(result)
#
# File /opt/homebrew/lib/python3.9/site-packages/matplotlib/axes/_base.py:351, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     349 default_dict = self._getdefaults(set(), kw)
#     350 self._setdefaults(default_dict, kw)
# --> 351 seg = mlines.Line2D(x, y, **kw)
#     352 return seg, kw
#
# File /opt/homebrew/lib/python3.9/site-packages/matplotlib/lines.py:366, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     363 self._us_dashOffset = 0
#     365 self.set_linewidth(linewidth)
# --> 366 self.set_linestyle(linestyle)
#     367 self.set_drawstyle(drawstyle)
#     369 self._color = None
#
# File /opt/homebrew/lib/python3.9/site-packages/matplotlib/lines.py:1122, in Line2D.set_linestyle(self, ls)
#    1119 if ls in [' ', '', 'none']:
#    1120     ls = 'None'
# -> 1122 _api.check_in_list([*self._lineStyles, *ls_mapper_r], ls=ls)
#    1123 if ls not in self._lineStyles:
#    1124     ls = ls_mapper_r[ls]
#
# File /opt/homebrew/lib/python3.9/site-packages/matplotlib/_api/__init__.py:129, in check_in_list(_values, _print_supported_values, **kwargs)
#     127 if _print_supported_values:
#     128     msg += f"; supported values are {', '.join(map(repr, values))}"
# --> 129 raise ValueError(msg)
#
# ValueError: '*' is not a valid value for ls; supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

# %% [markdown]
# Neste gráfico podemos analisar a quantidade de Joules por instancia (JPI) para cada taxa de saída 10%, 50%, 90%. A taxa de saída representa a quantidade de instancias que serão enviadas ao socket para serem processadas para obtenção do tamanho necessário do mini-batch a ser processado. Pois bem, podemos ver que em todos os algoritmos quanto maior a taxa de saída menor é o JPI e também seu delay, o delay é o tempo necessário que o algoritmo vai ficar em standby para fazer um novo processamento. Analisando todos os casos podemos ver que os algorimos OzaBag obtém um melhor desempenho energético em relação aos outros algoritmos. Segundo o trabalho do Cassales, isso se dever pela limitação do tamanho da estrutura de dados que ele carrega para processar em relação aos outros algoritmos processados.

# %% [markdown]
# # Average Consumer By Frequency

# %%
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    df['joules'] = df['joules'].replace(np.nan, 0)
    df = df.reset_index()

    total = 0
    average = 0 
    for index, row in df.iterrows():
        if int(row['joules']) > 0:
            total += row['joules']

    average = total / len(df.index)
    print(average)
# Out:
# ----------------- {'minimum': '600', 'maximum': '1200'} -----------------
# 498.6450141081419

# %% [markdown]
# Este é o consumo médio em Joules gasto pela aplicação durante toda sua execução

# %% [markdown]
# # Compare Accuracy and IPS
#
# - The IPS has some ligation when accuracy?
# - IPS is minor when is frequency is minimum?
# - IPS is major when is frequency is maximum?
# - IPS is major when utilized mini-batching?

# %%
def plot(ax, dsdf, my_id, x):
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}
    c1 = 'tab:red'
    c2 = 'tab:blue'
    c3 = 'tab:green'
    ds = list(dsdf.dataset)[0]
    ax.set_title(f'{dsformalname[ds]}')
    ax.plot(x, pd.to_numeric(dsdf.acc), color=c1, label='Acuraccy')
    ax.tick_params(axis='y', labelcolor=c1)
    ax.set_xticks(x)
    ax.set_xticklabels(dsdf.batch_size)
    ax.set_ylim(0,100)
    ax2 = ax.twinx()
    ax2.plot(x, pd.to_numeric(dsdf.IPS), color=c2, label='IPS')
    ax2.tick_params(axis='y', labelcolor=c2)
    ax3 = ax.twinx()
    ax3.plot(x, pd.to_numeric(dsdf.JPI), color=c3, label='JPI')
    ax3.tick_params(axis='y', labelcolor=c3)
    ax3.spines["right"].set_position(("axes", 1.14))
    ax3.set_label('JPI')
    if int(my_id/2) == 1:
        ax.set_xlabel('Batch size')
        ax.legend(loc='upper center', bbox_to_anchor=(0, -0.20), fancybox=True, shadow=True, ncol=5)
        ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.20), fancybox=True, shadow=True, ncol=5)
        ax3.legend(loc='upper center', bbox_to_anchor=(1, -0.20), fancybox=True, shadow=True, ncol=5)

# %%
def new_plot(ax, dsdf, my_id, x, fig):
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype', 'kyoto_binary': 'Kyoto'}
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm', 'kyoto_binary']
    global twin1
    global twin2
    c1 = 'tab:red'
    c2 = 'tab:blue'
    c3 = 'tab:green'
    ds = list(dsdf.dataset)[0]
    ax.set_title(f'{dsformalname[ds]}')
    ax.plot(x, pd.to_numeric(dsdf.acc), color=c1, label='Acuraccy')
    ax.tick_params(axis='y', labelcolor=c1)
    ax.set_xticks(x)
    ax.set_xticklabels(dsdf.batch_size)
    ax.set_ylim(0,100)
    ax2 = ax.twinx()
    ax2.plot(x, pd.to_numeric(dsdf.IPS), color=c2, label='IPS')
    ax2.tick_params(axis='y', labelcolor=c2)
    ax3 = ax.twinx()
    ax3.plot(x, pd.to_numeric(dsdf.JPI), color=c3, label='JPI')
    ax3.tick_params(axis='y', labelcolor=c3)
    ax3.spines["right"].set_position(("axes", 1.14))
    ax3.set_label('JPI')
    if int(my_id/2) == 1:
        ax.set_xlabel('Batch size')
        ax.legend(loc='upper center', bbox_to_anchor=(0, -0.20), fancybox=True, shadow=True, ncol=5)
        ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.20), fancybox=True, shadow=True, ncol=5)
        ax3.legend(loc='upper center', bbox_to_anchor=(1, -0.20), fancybox=True, shadow=True, ncol=5)

# %%
def gen_graph_initial_peralg_joules(df, display_df=False):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
#     algorithms = ['LBag']
    alg_formal_name = {'ARF': 'AdaptiveRandomForest', 'LBag': 'LeveragingBag', 'SRP':'StreamingRandomPatches', 
                                                'OBAdwin':'OzaBagAdwin', 'OBASHT':'OzaBagASHT', 'OB':'OzaBag'}
    global twin1
    global twin2
    if display_df:
        display(df)
    df = select_columns_and_rename_values(df)
    if display_df:
        display(df)
    for alg in algorithms:
        filename = f"{alg}-sizeVS3"
        fig, axs = plt.subplots(3, 2, figsize=(10,8))
        twin1 = twin2 = axs[0][0]
        axs[2][1].set_visible(False)
        dfalg = filter_by_substring_algorithm(df, alg)
        if display_df:
            display(dfalg)
#         fig.suptitle(f'{alg_formal_name[alg]}')
        for ds in datasets:
#             display(dfalg)
            dsdf = dfalg[(dfalg.dataset == ds)]
            x = np.arange(len(dsdf.ensemble_size))
            if display_df:
                if alg == 'SRP':
                    display(dsdf)
            my_id = datasets.index(ds)
            if my_id == 4:
                pass
            ax = axs[int(my_id/2)][my_id%2]
            new_plot(ax, dsdf, my_id, x, fig)

        fig.tight_layout(pad=0.5)
#         print('pos:', axs[2][0].get_position(), '\nanchor:',axs[2][0].get_anchor())
        x0=0.05081018518518519
        y0=0.03703703703703709
        x1=0.4019981060606061
        y1=0.28742283950617287
        axs[2][0].set_position([x0+0.25, y0, x1-x0, y1-y0])
#         plt.savefig(f'{filename}.eps', bbox_inches='tight')
        
        
        lines_1, labels_1 = axs[0][0].get_legend_handles_labels()
        lines_2, labels_2 = twin1.get_legend_handles_labels()
        lines_3, labels_3 = twin2.get_legend_handles_labels()
        lines = lines_1 + lines_2 + lines_3
        labels = labels_1 + labels_2 + labels_3
        lgd = fig.legend(lines, labels, loc=3, ncol=1, bbox_to_anchor=(0.05, 0.1), prop={'size': 14})
#         lgd.set_in_layout(True)
#         fig.subplots_adjust(bottom=0.2)
        
        plt.savefig(f'Pi-{filename}.eps', pad_inches=1.5)
        print(filename)
        plt.savefig(f'Pi-{filename}.png', pad_inches=1.5)

# %%
def gen_graph_initial_peralg(df, display_df=False, freq=''):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']

    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    #algorithms = ['OB']
    filename = f"pi-rates"
    for alg in algorithms:
        fig, axs = plt.subplots(2, 2, figsize=(14,9))
        # set the spacing between subplots
        plt.subplots_adjust(left=0.1,
                            bottom=0.1, 
                            right=0.9, 
                            top=0.9, 
                            wspace=0.4, 
                            hspace=0.4)
        dfalg = filter_by_substring_algorithm(df, alg)
        fig.suptitle(f'{alg} - Frequency {freq}')
        for ds in datasets:
            dsdf = dfalg[(dfalg.dataset == ds)]
            x = np.arange(len(dsdf.batch_size))
            my_id = datasets.index(ds)
            ax = axs[int(my_id/2)][my_id%2]
            plot(ax, dsdf, my_id, x)
        plt.savefig(f'{filename}.eps', bbox_inches='tight')

# %%
freqs = [{'minimum': '600', 'maximum': '1200'}]
dataframes = []
for f in freqs:
    dataframes.append(read_data_create_final_dataframe(f, True))
# Out:
# moaDF: 288    mdf: 288     sshDF: 288
#                                   algorithm      dataset  cores  batch_size  \
# 42   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4         100
# 106  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4         100
# 277  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4         100
# 117  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          75
# 138  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          75
# 56   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          75
# 31   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          50
# 141  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          50
# 8    StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          50
# 98   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          25
# 60   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          25
# 23   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          25
# 91                   OzaBagExecutorMAXChunk  elecNormNew      4         100
# 236                  OzaBagExecutorMAXChunk  elecNormNew      4         100
# 69                   OzaBagExecutorMAXChunk  elecNormNew      4         100
# 253                  OzaBagExecutorMAXChunk  elecNormNew      4          75
# 273                  OzaBagExecutorMAXChunk  elecNormNew      4          75
# 120                  OzaBagExecutorMAXChunk  elecNormNew      4          75
# 14                   OzaBagExecutorMAXChunk  elecNormNew      4          50
# 47                   OzaBagExecutorMAXChunk  elecNormNew      4          50
# 272                  OzaBagExecutorMAXChunk  elecNormNew      4          50
# 242                  OzaBagExecutorMAXChunk  elecNormNew      4          25
# 164                  OzaBagExecutorMAXChunk  elecNormNew      4          25
# 189                  OzaBagExecutorMAXChunk  elecNormNew      4          25
# 233             OzaBagAdwinExecutorMAXChunk  elecNormNew      4         100
# 284             OzaBagAdwinExecutorMAXChunk  elecNormNew      4         100
# 234             OzaBagAdwinExecutorMAXChunk  elecNormNew      4         100
# 210             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          75
# 59              OzaBagAdwinExecutorMAXChunk  elecNormNew      4          75
# 278             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          75
# 132             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          50
# 230             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          50
# 268             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          50
# 112             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          25
# 285             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          25
# 259             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          25
# 188              OzaBagASHTExecutorMAXChunk  elecNormNew      4         100
# 151              OzaBagASHTExecutorMAXChunk  elecNormNew      4         100
# 257              OzaBagASHTExecutorMAXChunk  elecNormNew      4         100
# 1                OzaBagASHTExecutorMAXChunk  elecNormNew      4          75
# 87               OzaBagASHTExecutorMAXChunk  elecNormNew      4          75
# 142              OzaBagASHTExecutorMAXChunk  elecNormNew      4          75
# 66               OzaBagASHTExecutorMAXChunk  elecNormNew      4          50
# 146              OzaBagASHTExecutorMAXChunk  elecNormNew      4          50
# 114              OzaBagASHTExecutorMAXChunk  elecNormNew      4          50
# 43               OzaBagASHTExecutorMAXChunk  elecNormNew      4          25
# 266              OzaBagASHTExecutorMAXChunk  elecNormNew      4          25
# 100              OzaBagASHTExecutorMAXChunk  elecNormNew      4          25
# 21                     LBagExecutorMAXChunk  elecNormNew      4         100
# 186                    LBagExecutorMAXChunk  elecNormNew      4         100
# 173                    LBagExecutorMAXChunk  elecNormNew      4         100
# 9                      LBagExecutorMAXChunk  elecNormNew      4          75
# 29                     LBagExecutorMAXChunk  elecNormNew      4          75
# 10                     LBagExecutorMAXChunk  elecNormNew      4          75
# 219                    LBagExecutorMAXChunk  elecNormNew      4          50
# 156                    LBagExecutorMAXChunk  elecNormNew      4          50
# 261                    LBagExecutorMAXChunk  elecNormNew      4          50
# 67                     LBagExecutorMAXChunk  elecNormNew      4          25
# 51                     LBagExecutorMAXChunk  elecNormNew      4          25
# 244                    LBagExecutorMAXChunk  elecNormNew      4          25
# 12     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4         100
# 99     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4         100
# 240    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4         100
# 181    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          75
# 238    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          75
# 95     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          75
# 128    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          50
# 224    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          50
# 107    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          50
# 77     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          25
# 176    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          25
# 161    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          25
# 286  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4         100
# 281  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4         100
# 17   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4         100
# 172  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          75
# 144  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          75
# 15   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          75
# 32   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          50
# 44   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          50
# 62   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          50
# 237  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          25
# 86   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          25
# 39   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          25
# 214                  OzaBagExecutorMAXChunk  covtypeNorm      4         100
# 167                  OzaBagExecutorMAXChunk  covtypeNorm      4         100
# 0                    OzaBagExecutorMAXChunk  covtypeNorm      4         100
# 229                  OzaBagExecutorMAXChunk  covtypeNorm      4          75
# 145                  OzaBagExecutorMAXChunk  covtypeNorm      4          75
# 74                   OzaBagExecutorMAXChunk  covtypeNorm      4          75
# 37                   OzaBagExecutorMAXChunk  covtypeNorm      4          50
# 270                  OzaBagExecutorMAXChunk  covtypeNorm      4          50
# 7                    OzaBagExecutorMAXChunk  covtypeNorm      4          50
# 197                  OzaBagExecutorMAXChunk  covtypeNorm      4          25
# 200                  OzaBagExecutorMAXChunk  covtypeNorm      4          25
# 126                  OzaBagExecutorMAXChunk  covtypeNorm      4          25
# 226             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4         100
# 171             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4         100
# 4               OzaBagAdwinExecutorMAXChunk  covtypeNorm      4         100
# 97              OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          75
# 165             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          75
# 79              OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          75
# 121             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          50
# 116             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          50
# 110             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          50
# 177             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          25
# 287             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          25
# 275             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          25
# 27               OzaBagASHTExecutorMAXChunk  covtypeNorm      4         100
# 241              OzaBagASHTExecutorMAXChunk  covtypeNorm      4         100
# 283              OzaBagASHTExecutorMAXChunk  covtypeNorm      4         100
# 57               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          75
# 103              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          75
# 3                OzaBagASHTExecutorMAXChunk  covtypeNorm      4          75
# 33               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          50
# 133              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          50
# 72               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          50
# 65               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          25
# 182              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          25
# 225              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          25
# 137                    LBagExecutorMAXChunk  covtypeNorm      4         100
# 30                     LBagExecutorMAXChunk  covtypeNorm      4         100
# 153                    LBagExecutorMAXChunk  covtypeNorm      4         100
# 193                    LBagExecutorMAXChunk  covtypeNorm      4          75
# 76                     LBagExecutorMAXChunk  covtypeNorm      4          75
# 279                    LBagExecutorMAXChunk  covtypeNorm      4          75
# 61                     LBagExecutorMAXChunk  covtypeNorm      4          50
# 102                    LBagExecutorMAXChunk  covtypeNorm      4          50
# 89                     LBagExecutorMAXChunk  covtypeNorm      4          50
# 250                    LBagExecutorMAXChunk  covtypeNorm      4          25
# 235                    LBagExecutorMAXChunk  covtypeNorm      4          25
# 213                    LBagExecutorMAXChunk  covtypeNorm      4          25
# 78     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4         100
# 175    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4         100
# 217    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4         100
# 48     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          75
# 83     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          75
# 11     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          75
# 185    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          50
# 129    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          50
# 55     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          50
# 58     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          25
# 251    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          25
# 212    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          25
# 49   StreamingRandomPatchesExecutorMAXChunk     airlines      4         100
# 70   StreamingRandomPatchesExecutorMAXChunk     airlines      4         100
# 195  StreamingRandomPatchesExecutorMAXChunk     airlines      4         100
# 187  StreamingRandomPatchesExecutorMAXChunk     airlines      4          75
# 143  StreamingRandomPatchesExecutorMAXChunk     airlines      4          75
# 163  StreamingRandomPatchesExecutorMAXChunk     airlines      4          75
# 94   StreamingRandomPatchesExecutorMAXChunk     airlines      4          50
# 203  StreamingRandomPatchesExecutorMAXChunk     airlines      4          50
# 207  StreamingRandomPatchesExecutorMAXChunk     airlines      4          50
# 170  StreamingRandomPatchesExecutorMAXChunk     airlines      4          25
# 68   StreamingRandomPatchesExecutorMAXChunk     airlines      4          25
# 221  StreamingRandomPatchesExecutorMAXChunk     airlines      4          25
# 252                  OzaBagExecutorMAXChunk     airlines      4         100
# 274                  OzaBagExecutorMAXChunk     airlines      4         100
# 276                  OzaBagExecutorMAXChunk     airlines      4         100
# 162                  OzaBagExecutorMAXChunk     airlines      4          75
# 159                  OzaBagExecutorMAXChunk     airlines      4          75
# 105                  OzaBagExecutorMAXChunk     airlines      4          75
# 223                  OzaBagExecutorMAXChunk     airlines      4          50
# 108                  OzaBagExecutorMAXChunk     airlines      4          50
# 155                  OzaBagExecutorMAXChunk     airlines      4          50
# 50                   OzaBagExecutorMAXChunk     airlines      4          25
# 139                  OzaBagExecutorMAXChunk     airlines      4          25
# 247                  OzaBagExecutorMAXChunk     airlines      4          25
# 119             OzaBagAdwinExecutorMAXChunk     airlines      4         100
# 169             OzaBagAdwinExecutorMAXChunk     airlines      4         100
# 130             OzaBagAdwinExecutorMAXChunk     airlines      4         100
# 201             OzaBagAdwinExecutorMAXChunk     airlines      4          75
# 82              OzaBagAdwinExecutorMAXChunk     airlines      4          75
# 16              OzaBagAdwinExecutorMAXChunk     airlines      4          75
# 73              OzaBagAdwinExecutorMAXChunk     airlines      4          50
# 52              OzaBagAdwinExecutorMAXChunk     airlines      4          50
# 63              OzaBagAdwinExecutorMAXChunk     airlines      4          50
# 220             OzaBagAdwinExecutorMAXChunk     airlines      4          25
# 154             OzaBagAdwinExecutorMAXChunk     airlines      4          25
# 194             OzaBagAdwinExecutorMAXChunk     airlines      4          25
# 149              OzaBagASHTExecutorMAXChunk     airlines      4         100
# 243              OzaBagASHTExecutorMAXChunk     airlines      4         100
# 232              OzaBagASHTExecutorMAXChunk     airlines      4         100
# 267              OzaBagASHTExecutorMAXChunk     airlines      4          75
# 80               OzaBagASHTExecutorMAXChunk     airlines      4          75
# 180              OzaBagASHTExecutorMAXChunk     airlines      4          75
# 46               OzaBagASHTExecutorMAXChunk     airlines      4          50
# 239              OzaBagASHTExecutorMAXChunk     airlines      4          50
# 245              OzaBagASHTExecutorMAXChunk     airlines      4          50
# 38               OzaBagASHTExecutorMAXChunk     airlines      4          25
# 255              OzaBagASHTExecutorMAXChunk     airlines      4          25
# 168              OzaBagASHTExecutorMAXChunk     airlines      4          25
# 88                     LBagExecutorMAXChunk     airlines      4         100
# 158                    LBagExecutorMAXChunk     airlines      4         100
# 124                    LBagExecutorMAXChunk     airlines      4         100
# 263                    LBagExecutorMAXChunk     airlines      4          75
# 184                    LBagExecutorMAXChunk     airlines      4          75
# 93                     LBagExecutorMAXChunk     airlines      4          75
# 166                    LBagExecutorMAXChunk     airlines      4          50
# 123                    LBagExecutorMAXChunk     airlines      4          50
# 131                    LBagExecutorMAXChunk     airlines      4          50
# 254                    LBagExecutorMAXChunk     airlines      4          25
# 111                    LBagExecutorMAXChunk     airlines      4          25
# 135                    LBagExecutorMAXChunk     airlines      4          25
# 24     AdaptiveRandomForestExecutorMAXChunk     airlines      4         100
# 249    AdaptiveRandomForestExecutorMAXChunk     airlines      4         100
# 53     AdaptiveRandomForestExecutorMAXChunk     airlines      4         100
# 231    AdaptiveRandomForestExecutorMAXChunk     airlines      4          75
# 104    AdaptiveRandomForestExecutorMAXChunk     airlines      4          75
# 157    AdaptiveRandomForestExecutorMAXChunk     airlines      4          75
# 199    AdaptiveRandomForestExecutorMAXChunk     airlines      4          50
# 92     AdaptiveRandomForestExecutorMAXChunk     airlines      4          50
# 206    AdaptiveRandomForestExecutorMAXChunk     airlines      4          50
# 134    AdaptiveRandomForestExecutorMAXChunk     airlines      4          25
# 258    AdaptiveRandomForestExecutorMAXChunk     airlines      4          25
# 196    AdaptiveRandomForestExecutorMAXChunk     airlines      4          25
# 5    StreamingRandomPatchesExecutorMAXChunk         GMSC      4         100
# 96   StreamingRandomPatchesExecutorMAXChunk         GMSC      4         100
# 222  StreamingRandomPatchesExecutorMAXChunk         GMSC      4         100
# 190  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          75
# 85   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          75
# 147  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          75
# 36   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          50
# 215  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          50
# 198  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          50
# 84   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          25
# 20   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          25
# 45   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          25
# 191                  OzaBagExecutorMAXChunk         GMSC      4         100
# 264                  OzaBagExecutorMAXChunk         GMSC      4         100
# 152                  OzaBagExecutorMAXChunk         GMSC      4         100
# 202                  OzaBagExecutorMAXChunk         GMSC      4          75
# 81                   OzaBagExecutorMAXChunk         GMSC      4          75
# 178                  OzaBagExecutorMAXChunk         GMSC      4          75
# 113                  OzaBagExecutorMAXChunk         GMSC      4          50
# 246                  OzaBagExecutorMAXChunk         GMSC      4          50
# 248                  OzaBagExecutorMAXChunk         GMSC      4          50
# 179                  OzaBagExecutorMAXChunk         GMSC      4          25
# 280                  OzaBagExecutorMAXChunk         GMSC      4          25
# 109                  OzaBagExecutorMAXChunk         GMSC      4          25
# 2               OzaBagAdwinExecutorMAXChunk         GMSC      4         100
# 192             OzaBagAdwinExecutorMAXChunk         GMSC      4         100
# 269             OzaBagAdwinExecutorMAXChunk         GMSC      4         100
# 26              OzaBagAdwinExecutorMAXChunk         GMSC      4          75
# 148             OzaBagAdwinExecutorMAXChunk         GMSC      4          75
# 205             OzaBagAdwinExecutorMAXChunk         GMSC      4          75
# 127             OzaBagAdwinExecutorMAXChunk         GMSC      4          50
# 35              OzaBagAdwinExecutorMAXChunk         GMSC      4          50
# 136             OzaBagAdwinExecutorMAXChunk         GMSC      4          50
# 140             OzaBagAdwinExecutorMAXChunk         GMSC      4          25
# 211             OzaBagAdwinExecutorMAXChunk         GMSC      4          25
# 118             OzaBagAdwinExecutorMAXChunk         GMSC      4          25
# 75               OzaBagASHTExecutorMAXChunk         GMSC      4         100
# 90               OzaBagASHTExecutorMAXChunk         GMSC      4         100
# 282              OzaBagASHTExecutorMAXChunk         GMSC      4         100
# 18               OzaBagASHTExecutorMAXChunk         GMSC      4          75
# 260              OzaBagASHTExecutorMAXChunk         GMSC      4          75
# 204              OzaBagASHTExecutorMAXChunk         GMSC      4          75
# 54               OzaBagASHTExecutorMAXChunk         GMSC      4          50
# 174              OzaBagASHTExecutorMAXChunk         GMSC      4          50
# 208              OzaBagASHTExecutorMAXChunk         GMSC      4          50
# 216              OzaBagASHTExecutorMAXChunk         GMSC      4          25
# 218              OzaBagASHTExecutorMAXChunk         GMSC      4          25
# 64               OzaBagASHTExecutorMAXChunk         GMSC      4          25
# 271                    LBagExecutorMAXChunk         GMSC      4         100
# 13                     LBagExecutorMAXChunk         GMSC      4         100
# 101                    LBagExecutorMAXChunk         GMSC      4         100
# 28                     LBagExecutorMAXChunk         GMSC      4          75
# 41                     LBagExecutorMAXChunk         GMSC      4          75
# 160                    LBagExecutorMAXChunk         GMSC      4          75
# 262                    LBagExecutorMAXChunk         GMSC      4          50
# 115                    LBagExecutorMAXChunk         GMSC      4          50
# 25                     LBagExecutorMAXChunk         GMSC      4          50
# 150                    LBagExecutorMAXChunk         GMSC      4          25
# 40                     LBagExecutorMAXChunk         GMSC      4          25
# 183                    LBagExecutorMAXChunk         GMSC      4          25
# 265    AdaptiveRandomForestExecutorMAXChunk         GMSC      4         100
# 227    AdaptiveRandomForestExecutorMAXChunk         GMSC      4         100
# 125    AdaptiveRandomForestExecutorMAXChunk         GMSC      4         100
# 19     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          75
# 71     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          75
# 256    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          75
# 209    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          50
# 228    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          50
# 34     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          50
# 22     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          25
# 6      AdaptiveRandomForestExecutorMAXChunk         GMSC      4          25
# 122    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          25
#
#      inc_rate  out_rate  instances   time    delay   acc ensemble_size  \
# 42        365    363.90  43,700.00 120.09   262.00 79.90            25
# 106       203    199.92  23,960.00 119.85   380.00 80.97            25
# 277        40     39.95   4,800.00 120.14 1,445.00 80.66            25
# 117       352    349.37  41,925.00 120.00   194.00 79.98            25
# 138       195    194.36  23,325.00 120.01   310.00 81.93            25
# 56         39     34.97   4,200.00 120.10 1,231.00 80.97            25
# 31        351    349.55  41,930.00 119.95   131.00 80.95            25
# 141       195    194.80  23,361.00 119.92   196.00 82.61            25
# 8          39     34.99   4,200.00 120.04   820.00 82.48            25
# 98        332    329.31  39,525.00 120.02    68.00 82.23            25
# 60        184    179.88  21,564.00 119.88   101.00 84.83            25
# 23         36     35.00   4,200.00 120.02   402.00 83.86            25
# 91       2519  2,333.75  42,934.00  18.40    42.00 78.85            25
# 236      1399  1,392.16  45,312.00  32.55    56.00 78.36            25
# 69        279    274.77  32,945.00 119.90   199.00 77.56            25
# 253      2531  2,418.59  43,496.00  17.98    31.00 78.51            25
# 273      1406  1,401.63  45,312.00  32.33    41.00 78.57            25
# 120       281    279.78  33,544.00 119.90   147.00 79.28            25
# 14       2318  2,222.73  43,510.00  19.58    21.00 78.67            25
# 47       1288  1,281.34  45,312.00  35.36    29.00 78.73            25
# 272       257    254.85  30,549.00 119.87   107.00 79.64            25
# 242      2328  2,265.48  44,272.00  19.54    11.00 79.49            25
# 164      1293  1,289.51  45,312.00  35.14    14.00 79.67            25
# 189       258    254.83  30,549.00 119.88    52.00 79.29            25
# 233      2096  2,023.07  43,927.00  21.71    48.00 79.10            25
# 284      1164  1,157.01  45,312.00  39.16    64.00 79.09            25
# 234       232    229.89  27,554.00 119.86   245.00 80.69            25
# 210      2108  2,020.99  43,609.00  21.58    36.00 78.66            25
# 59       1171  1,168.53  45,312.00  38.78    50.00 79.15            25
# 278       234    229.81  27,554.00 119.90   184.00 80.71            25
# 132      1931  1,806.45  42,484.00  23.52    26.00 79.48            25
# 230      1072  1,067.87  45,312.00  42.43    35.00 79.56            25
# 268       214    209.89  25,158.00 119.86   130.00 81.64            25
# 112      1652  1,606.72  44,204.00  27.51    15.00 80.86            25
# 204              484.76  461.32    0.00 0.01
# 54               237.08  207.30    0.00 0.00
# 174              351.06  329.05    0.00 0.00
# 208              485.29  461.84    0.00 0.01
# 216              247.23  224.79    0.00 0.00
# 218              386.92  360.08    0.00 0.00
# 64               479.79  460.21    0.00 0.01
# 271              590.97  565.45    0.00 0.00
# 13               574.78  551.99    0.00 0.01
# 101              485.51  465.36    0.00 0.03
# 28               558.01  524.31    0.00 0.00
# 41               586.03  567.20    0.00 0.01
# 160              502.57  477.89    0.00 0.02
# 262              592.18  561.66    0.00 0.00
# 115              575.34  548.03    0.00 0.01
# 25               491.20  470.95    0.00 0.03
# 150              625.21  600.61    0.00 0.00
# 40               588.28  560.29    0.00 0.01
# 183              492.92  472.52    0.00 0.03
# 265              679.93  652.72    0.00 0.01
# 227              571.62  553.03    0.00 0.01
# 125              488.10  471.61    0.00 0.03
# 19               658.85  637.45    0.00 0.01
# 71               564.89  546.68    0.00 0.01
# 256              490.98  475.17    0.00 0.04
# 209              645.52  624.51    0.00 0.01
# 228              569.14  550.65    0.00 0.01
# 34               488.14  472.43    0.00 0.04
# 22               663.21  641.84    0.00 0.01
# 6                574.64  556.15    0.00 0.01
# 122              490.87  474.38    0.00 0.04

# %%
freqs = [{'minimum': '600', 'maximum': '1200'}]
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    df = df[df.PERC == '90']
    df = df.loc[:,['dataset','algorithm','batch_size', 'instances', 'time', 'JPI', 'acc']].sort_values(by=['batch_size'])
    df = select_columns_and_rename_values(df)
    #display(df)
    df['IPS'] = df['instances'] / df['time']
    df['ensemble_size'] = '25'

    gen_graph_initial_peralg(df, display_df=False)
# Out:
# ----------------- {'minimum': '600', 'maximum': '1200'} -----------------
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_15341/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_15341/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_15341/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_15341/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
#          dataset  algorithm  batch_size  instances   time  JPI   acc      IPS  \
# 58   covtypeNorm      ARFMB          25  57,850.00 120.03 0.01 86.78   481.97
# 237  covtypeNorm      SRPMB          25  13,175.00 120.05 0.05 77.98   109.74
# 197  covtypeNorm       OBMB          25  70,400.00 120.01 0.01 81.63   586.62
# 177  covtypeNorm  OBAdwinMB          25  49,000.00 120.02 0.01 81.82   408.28
# 65   covtypeNorm   OBASHTMB          25  68,500.00 120.00 0.01 81.30   570.82
# 250  covtypeNorm     LBagMB          25  40,725.00 120.01 0.02 81.71   339.36
# 170     airlines      SRPMB          25   8,425.00 120.40 0.09 65.64    69.97
# 50      airlines       OBMB          25  21,200.00 122.21 0.04 65.25   173.48
# 77   elecNormNew      ARFMB          25  44,711.00  73.86 0.01 81.60   605.32
# 220     airlines  OBAdwinMB          25  40,775.00 120.04 0.02 68.58   339.66
# 254     airlines     LBagMB          25  14,375.00 120.05 0.06 60.86   119.74
# 134     airlines      ARFMB          25  10,075.00 120.21 0.07 65.35    83.81
# 84          GMSC      SRPMB          25  72,400.00 120.01 0.01 93.40   603.29
# 179         GMSC       OBMB          25 150,000.00  48.40 0.00 93.49 3,098.98
# 140         GMSC  OBAdwinMB          25 150,000.00  62.02 0.00 93.38 2,418.54
# 216         GMSC   OBASHTMB          25 150,000.00  45.46 0.00 93.44 3,299.46
# 150         GMSC     LBagMB          25 150,000.00 112.40 0.00 93.40 1,334.57
# 38      airlines   OBASHTMB          25  20,225.00 120.28 0.03 65.19   168.15
# 67   elecNormNew     LBagMB          25  43,040.00  46.63 0.01 83.02   923.03
# 22          GMSC      ARFMB          25 127,950.00 120.00 0.01 93.54 1,066.21
# 98   elecNormNew      SRPMB          25  39,525.00 120.02 0.02 82.23   329.31
# 112  elecNormNew  OBAdwinMB          25  44,204.00  27.51 0.00 80.86 1,606.72
# 242  elecNormNew       OBMB          25  44,272.00  19.54 0.00 79.49 2,265.48
# 43   elecNormNew   OBASHTMB          25  43,187.00  19.74 0.00 80.07 2,188.12
# 223     airlines       OBMB          50  24,700.00 120.98 0.03 66.19   204.16
# 73      airlines  OBAdwinMB          50  46,150.00 120.06 0.02 68.65   384.40
# 54          GMSC   OBASHTMB          50 150,000.00  41.10 0.00 93.36 3,649.90
# 31   elecNormNew      SRPMB          50  41,930.00 119.95 0.02 80.95   349.55
# 61   covtypeNorm     LBagMB          50  47,900.00 120.02 0.01 85.43   399.11
# 127         GMSC  OBAdwinMB          50 149,259.00  45.95 0.00 93.33 3,248.01
# 219  elecNormNew     LBagMB          50  42,962.00  44.80 0.01 81.39   958.91
# 46      airlines   OBASHTMB          50  34,300.00 121.91 0.02 67.76   281.36
# 33   covtypeNorm   OBASHTMB          50  74,350.00 120.01 0.01 81.67   619.54
# 132  elecNormNew  OBAdwinMB          50  42,484.00  23.52 0.00 79.48 1,806.45
# 94      airlines      SRPMB          50   8,250.00 120.27 0.09 65.52    68.60
# 166     airlines     LBagMB          50   9,300.00 120.34 0.09 61.81    77.28
# 121  covtypeNorm  OBAdwinMB          50  66,150.00 120.01 0.01 83.41   551.19
# 185  covtypeNorm      ARFMB          50  62,100.00 120.05 0.01 86.23   517.28
# 262         GMSC     LBagMB          50 150,000.00 107.18 0.00 93.34 1,399.55
# 37   covtypeNorm       OBMB          50  77,200.00 120.03 0.01 81.89   643.20
# 199     airlines      ARFMB          50  11,250.00 120.20 0.07 65.95    93.59
# 32   covtypeNorm      SRPMB          50  14,975.00 119.94 0.04 75.44   124.85
# 14   elecNormNew       OBMB          50  43,510.00  19.58 0.00 78.67 2,222.73
# 113         GMSC       OBMB          50 149,625.00  49.43 0.00 93.39 3,027.19
# 128  elecNormNew      ARFMB          50  43,654.00  65.86 0.01 80.72   662.88
# 36          GMSC      SRPMB          50  68,250.00 120.03 0.01 93.43   568.60
# 66   elecNormNew   OBASHTMB          50  43,758.00  19.06 0.00 79.37 2,295.92
# 209         GMSC      ARFMB          50 119,600.00 119.96 0.01 93.53   996.97
# 201     airlines  OBAdwinMB          75  44,025.00 120.01 0.02 68.90   366.86
# 267     airlines   OBASHTMB          75  22,500.00 120.49 0.03 65.79   186.74
# 263     airlines     LBagMB          75   9,375.00 120.21 0.09 61.72    77.99
# 231     airlines      ARFMB          75  10,650.00 121.38 0.07 65.11    87.74
# 190         GMSC      SRPMB          75  70,575.00 120.01 0.01 93.43   588.08
# 210  elecNormNew  OBAdwinMB          75  43,609.00  21.58 0.00 78.66 2,020.99
# 26          GMSC  OBAdwinMB          75 149,068.00  40.40 0.00 93.34 3,689.71
# 18          GMSC   OBASHTMB          75 150,000.00  39.21 0.00 93.36 3,825.16
# 97   covtypeNorm  OBAdwinMB          75  71,250.00 120.10 0.01 84.16   593.25
# 181  elecNormNew      ARFMB          75  43,042.00  64.01 0.01 79.52   672.42
# 9    elecNormNew     LBagMB          75  42,694.00  43.67 0.01 80.47   977.65
# 19          GMSC      ARFMB          75 125,580.00 119.97 0.01 93.54 1,046.75
# 172  covtypeNorm      SRPMB          75  16,173.00 119.87 0.04 73.79   134.92
# 117  elecNormNew      SRPMB          75  41,925.00 120.00 0.02 79.98   349.37
# 229  covtypeNorm       OBMB          75  71,475.00 120.00 0.01 81.03   595.60
# 162     airlines       OBMB          75  25,125.00 120.15 0.03 64.68   209.12
# 28          GMSC     LBagMB          75 148,771.00  96.78 0.00 93.39 1,537.21
# 202         GMSC       OBMB          75 150,000.00  40.63 0.00 93.50 3,691.49
# 57   covtypeNorm   OBASHTMB          75  78,525.00 120.02 0.01 81.55   654.29
# 1    elecNormNew   OBASHTMB          75  44,158.00  19.88 0.00 79.30 2,220.78
# 193  covtypeNorm     LBagMB          75  49,650.00 120.01 0.01 85.46   413.70
# 48   covtypeNorm      ARFMB          75  63,375.00 120.08 0.01 85.67   527.78
# 253  elecNormNew       OBMB          75  43,496.00  17.98 0.00 78.51 2,418.59
# 187     airlines      SRPMB          75   8,325.00 120.76 0.09 65.94    68.94
# 91   elecNormNew       OBMB         100  42,934.00  18.40 0.00 78.85 2,333.75
# 271         GMSC     LBagMB         100 150,000.00 104.29 0.00 93.37 1,438.26
# 265         GMSC      ARFMB         100 130,962.00 120.00 0.01 93.56 1,091.38
# 2           GMSC  OBAdwinMB         100 149,922.00  42.73 0.00 93.39 3,508.42
# 75          GMSC   OBASHTMB         100 150,000.00  39.06 0.00 93.35 3,840.25
# 12   elecNormNew      ARFMB         100  43,424.00  67.29 0.01 79.29   645.37
# 5           GMSC      SRPMB         100  73,600.00 120.03 0.01 93.49   613.20
# 286  covtypeNorm      SRPMB         100  14,975.00 119.82 0.04 71.77   124.97
# 21   elecNormNew     LBagMB         100  42,105.00  41.86 0.01 79.77 1,005.88
# 214  covtypeNorm       OBMB         100  78,900.00 120.04 0.01 81.41   657.30
# 226  covtypeNorm  OBAdwinMB         100  75,300.00 120.00 0.01 83.73   627.49
# 27   covtypeNorm   OBASHTMB         100  77,200.00 120.03 0.01 81.30   643.17
# 137  covtypeNorm     LBagMB         100  50,800.00 120.02 0.01 85.63   423.26
# 188  elecNormNew   OBASHTMB         100  42,780.00  17.69 0.00 78.40 2,417.63
# 78   covtypeNorm      ARFMB         100  71,700.00 120.07 0.01 86.12   597.16
# 49      airlines      SRPMB         100   8,600.00 120.58 0.09 65.31    71.32
# 252     airlines       OBMB         100  23,700.00 122.86 0.03 64.44   192.90
# 119     airlines  OBAdwinMB         100  45,200.00 120.35 0.02 68.58   375.58
# 149     airlines   OBASHTMB         100  33,100.00 122.03 0.02 67.40   271.25
# 233  elecNormNew  OBAdwinMB         100  43,927.00  21.71 0.00 79.10 2,023.07
# 88      airlines     LBagMB         100   8,400.00 123.20 0.10 61.98    68.18
# 24      airlines      ARFMB         100  10,600.00 120.19 0.07 65.76    88.19
# 191         GMSC       OBMB         100 149,607.00  39.81 0.00 93.40 3,758.21
# 42   elecNormNew      SRPMB         100  43,700.00 120.09 0.02 79.90   363.90
#
#     ensemble_size
# 58             25
# 237            25
# 197            25
# 177            25
# 65             25
# 250            25
# 170            25
# 50             25
# 77             25
# 220            25
# 254            25
# 134            25
# 84             25
# 179            25
# 140            25
# 216            25
# 150            25
# 38             25
# 67             25
# 22             25
# 98             25
# 112            25
# 242            25
# 43             25
# 223            25
# 73             25
# 54             25
# 31             25
# 61             25
# 127            25
# 219            25
# 46             25
# 33             25
# 132            25
# 94             25
# 166            25
# 121            25
# 185            25
# 262            25
# 37             25
# 199            25
# 32             25
# 14             25
# 113            25
# 128            25
# 36             25
# 66             25
# 209            25
# 201            25
# 267            25
# 263            25
# 231            25
# 190            25
# 210            25
# 26             25
# 18             25
# 97             25
# 181            25
# 9              25
# 19             25
# 172            25
# 117            25
# 229            25
# 162            25
# 28             25
# 202            25
# 57             25
# 1              25
# 193            25
# 48             25
# 253            25
# 187            25
# 91             25
# 271            25
# 265            25
# 2              25
# 75             25
# 12             25
# 5              25
# 286            25
# 21             25
# 214            25
# 226            25
# 27             25
# 137            25
# 188            25
# 78             25
# 49             25
# 252            25
# 119            25
# 149            25
# 233            25
# 88             25
# 24             25
# 191            25
# 42             25
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Agora iremos analisar a relação entre o número de instancias processadas por segundo (IPS) o JPI e a acurácia entre esses valores. Primeiro vamos analisar a linha azul que representa o IPS, individualmente irei analisar primeiro o dataset Airlines nos algoritmos Adaptive Random Forest (ARF), OzaBag (OB), LBag (LB). Para o ARF o IPS inicia com um processamento de 84 instancias e evolui para 94 no batch-size de tamanho 50 e cai para 88 no batch-size 75 e 100. A linha verde representa o JPI neste primeiro algoritmo observamos o comportamento de queda no maior numero de IPS mas no batch-size de 75 e 100 um novo aumento. No algoritmo OB temos um aumento no número de IPS em relação ao tamnho do batch-size somente caindo no 100. Já o número do JPI diminui em relação ao aumento do IPS exceto na quanto o IPS cai no batch-size 100. Por último vamos analisar o LB, para este algoritmo a tendência do batch-size aumenta o IPS diminui e o JPI tende a crescer. Vendo esses casos podemos dizer que para os algoritmos ARF e OB a têndencia é quanto maior o IPS menor será o JPI já no LBAG o oposto aconteceu pelo menos no dataset airlines, quanto menor o IPS maior o JPI. Já em outros dasets ocorreu de o IPS maior trazer um menor JPI.

# %% [markdown]
# # Conclusoes
#
# Neste cenário podemos observar que o tamanho do mini-batch não traz grande diferença no consumo energético quando seu tamanho é menor ou maior, mas sim em relação ao seu padrão de comportamento sequencial já comprovado no artigo do Cassales. Nesta analise constatamos alguns comportamentos tais como quando a quantidade de IPS aumenta em determinados algoritmos temos uma tendencia que o JPI diminua e que existem algoritmos que são mais eficiente energéticamente e mantem a mesma linha de precisão e acurácia como o OzaBag.
