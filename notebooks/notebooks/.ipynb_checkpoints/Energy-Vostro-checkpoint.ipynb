# %% [markdown]
# ## Code used for cleaning up and organizing the log results from MOA Multithread Ensembles
#
# - Run ./chunk_pre.sh <Folder with chunk logs\> > file.csv
# - Import and show
# - Functions format_table_excel_* will either print (show) or (copy to) clipboard a df in the suggested format for annalysis

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ***
# ## Parsing preliminary results to find maximum rate and acc comparison

# %%
def parse_folder_to_file(folder, outfilename):
    # %cd ../results/
    directory = os.fsencode(folder)
    header_printed = False

    with open(f"{outfilename}.csv", "w+") as output:
        output.write('dataset,algorithm,ensemble_size,cores,batch_size,rate,instances,time,acc,prec,recall,change\n')
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("dump-"): 
                s = parse(f'{os.fsdecode(directory)}/{filename}')
                output.write(f"{s}\n")

# %%
def parse(fname):
    columns = []
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    pstr = ''
    spname = fname.split('/')[-1].split('-')
    spline = []
    got = False
    for s in spname[1:]:
        pstr += s + ','
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        if 'GMSC' in spname and 'ASHT' in spname[2]:
            for c in columns[:-2]:
                pstr += str(spline[c]) + ','
            pstr += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        else:
            for c in columns:
                pstr += str(spline[c]) + ','
            if len(columns) == 5:
                pstr += '0,'
#         if not header_printed:
#             head = 'dataset,algorithm,ensemble_size,cores,batch_size,instances,time,acc,prec,recall,change'
#             pstr = f"{head}\n{pstr}"
#             header_printed = True
        return (pstr[:-1])

# %%
parse_folder_to_file('energy_vostro/get_rate', '../parsed_csvs/get_rate-vostro')
# parse_folder_to_file('acc-small', '../scripts/data-acc')
# Out:
# /home/cassales/Documents/newpar/Parallel-Classifier-MOA/results

# %%
def load_df(filename):
    df = pd.read_csv(filename)
    return select_columns_and_rename_values(df)

# %%
def select_columns_and_rename_values(df):
    df = df.loc[:,['dataset', 'algorithm', 'ensemble_size', 'cores', 'batch_size', 'instances', 'time', 'acc']]
    df['algorithm'] = df["algorithm"].str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df["algorithm"].str.replace("ARF$", "ARFSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB+")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    return df

# %%
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %% [markdown]
# ## Finding rate for Socket experiments

# %%
def calculate_rate(desired_esize):
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    file_algs = {'ARF': 'ARF', 'LBag': 'LBag', 'SRP': 'SRP', 'OBAdwin': 'OBagAd', 'OBASHT':'OBagASHT', 'OB': 'OBag'}
    for ds in df.dataset.unique():
        dsdf = df[df.dataset == ds]
        for alg in algorithms:
            s = f'X $1{ds}.arff {file_algs[alg]}'
            adf = filter_by_substring_algorithm(dsdf, alg)
#             if alg == 'LBag' and ds == 'airlines':
#                 display(adf)
            dfres = adf[adf.ensemble_size == desired_esize]
#             display(dfres)
            # get sequential
            seq_rate = list((dfres[(dfres.batch_size == 1) & (dfres.cores == 1)].IPS))[0]
#             print(list((dfres[(dfres.batch_size == 1) & (dfres.cores == 1)].IPS)))
            # get runper
            runper_rate = list(dfres[(dfres.batch_size == 1) & (dfres.cores != 1)].IPS)[0]
            # get MB
            mb_rate = list(dfres[(dfres.batch_size != 1) & (dfres.cores != 1)].IPS)[0]
            #we have max rates, now we need 10, 50 and 90
            if mb_rate != 'NaN':
                #10
                print(f'{s} {int(0.9*seq_rate)} {int(0.9*runper_rate)} {int(0.9*mb_rate)}')
                #50
                print(f'{s} {int(0.5*seq_rate)} {int(0.5*runper_rate)} {int(0.5*mb_rate)}')
                #90
                print(f'{s} {int(0.1*seq_rate)} {int(0.1*runper_rate)} {int(0.1*mb_rate)}')

# %%
df = load_df('../parsed_csvs/get_rate-vostro.csv')
df['IPS'] = df['instances'] / df['time']

# %%
print("Copy the following lines to the end of the script used to run the experimets\n")
# calculate_rate(100)
# Out:
# Copy the following lines to the end of the script used to run the experimets

# %% [markdown]
# ***
# #
#
# #
#
# #
#
# #
#
# ## Energy processing

# %% [markdown]
# # MOA logs

# %%
def parse_MOA(fname):
    global header_printed
    columns = []
    wanted = ['learning evaluation instances', 'Wall Time (Actual Time)', 'Avg Delay (ms)', 'outRate (inst/s)']
    pstr = ''
    spname = fname.split('/')[-1].split('-')
    spline = []
    for s in spname[1:]:
        pstr += s + ','
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                spline = line.split(',')
                for s in spline:
                    if s in wanted:
                        columns.append(spline.index(s))
            else:
                spline = line.split(',')
        for c in columns:
            pstr += spline[c] + ','
        if len(columns) == 2:
            pstr += '1,'
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,inc_rate,instances,time,delay,out_rate'
            pstr = f"{head}\n{pstr}"
            header_printed = True
        return (pstr[:-1])

# %%
def read_MOA(folder, out_file):
    directory = os.fsencode(folder)
    global header_printed

    with open(out_file, "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("term-"): 
                output.write(f"{parse_MOA(f'{os.fsdecode(directory)}/{filename}')}\n")
    fname = os.fsdecode(out_file)
    df = pd.read_csv(fname)
    df['inc_rate'].astype('int64')
    return df[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'instances', 'time', 'delay', 'out_rate']]

# %% [markdown]
# ## Energy Data

# %%
def load_Wmeas(filename):
    return pd.read_csv(filename, header=None, names=['date', 'time', 'measure'])

# %%
def exper_order_to_dict(filename, d):
    with open(filename) as forder:
        got_timestamp = False
        dataset = algorithm = Esize = cores = Bsize = ''
        dnow=None
        for line in forder:
            if not got_timestamp:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
                if dnow:
                    dnow['finish'] = date_time_obj - datetime.timedelta(seconds=1)
            elif ':' not in line:
                spline = line.split('/')[-1].strip().split('-')
#                 print(spline)
                if len(spline) == 6:
                    dataset,algorithm,Esize,cores,Bsize,rate = spline
                else:
                    dataset,algorithm,Esize,cores,Bsize,rate = *spline,1
                if algorithm not in d:
                    d[algorithm] = {}
#                 if method not in d[algorithm]:
#                     d[algorithm][method] = {}
                if dataset not in d[algorithm]:
                    d[algorithm][dataset] = {}
                if Esize not in d[algorithm][dataset]:
                    d[algorithm][dataset][Esize] = {}
                if cores not in d[algorithm][dataset][Esize]:
                    d[algorithm][dataset][Esize][cores] = {}
                if Bsize not in d[algorithm][dataset][Esize][cores]:
                    d[algorithm][dataset][Esize][cores][Bsize] = {}
                if rate not in d[algorithm][dataset][Esize][cores][Bsize]:
                    d[algorithm][dataset][Esize][cores][Bsize][rate] = {'start': date_time_obj, 'finish': ''}
                    dnow = d[algorithm][dataset][Esize][cores][Bsize][rate]
                got_timestamp = False
            else:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
    return d

# %%
def populate_dict(d, df):
    df['datetime'] = df['date'] + ' ' + df['time']
    for k, v in d.items():
        for k1, v1 in v.items():
            for k2, v2 in v1.items():
                for k3, v3 in v2.items():
                    for k4, v4 in v3.items():
                        for k5, v5 in v4.items():
#                             for k6, v6 in v5.items():
                            if 'seconds' not in v5:
                                st = v5['start']
                                ed = v5['finish']
                                v5['seconds'] = (ed - st).seconds
                                new_df = df[(df.datetime <= f'{ed.strftime("%d/%m/%y")} {ed.strftime("%X")}')
                                          & (df.datetime >= f'{st.strftime("%d/%m/%y")} {st.strftime("%X")}')]
                                v5['avg_measure'] = new_df['measure'].mean()
                                v5['sum_measure'] = new_df['measure'].sum()
                                v5['avg_times_seconds'] = v5['avg_measure'] * v5['seconds']
    return d

# %%
def append_dict_to_df(d, ensemble_size=False):
    dappend = {'algorithm': [], 'dataset': [], 'ensemble_size': [], 'cores': [], 
               'batch_size': [], 'duration': [], 'inc_rate': [], 'avg_measure': [], 'sum_measure': [], 'avg_times_seconds': []}
    for kalg,valg in d.items():
        for kds,vds in valg.items():
            for kens,vens in vds.items():
                for kcore,vcore in vens.items():
                    for kmbs,vmbs in vcore.items():
                        for krate,vrate in vmbs.items():
                            dappend['algorithm'].append(kalg)
                            dappend['dataset'].append(kds)
                            dappend['ensemble_size'].append(kens)
                            dappend['cores'].append(kcore)
                            dappend['batch_size'].append(kmbs)
                            dappend['duration'].append(vrate['seconds'])
                            dappend['inc_rate'].append(krate)
                            for key in ['avg_measure', 'sum_measure','avg_times_seconds']:
                                dappend[key].append(vrate[key])
    adf = pd.DataFrame(data=dappend)
    adf = adf.sort_values(['algorithm','dataset']).astype({'inc_rate': 'int64', 
                                                           'cores': 'int64',
                                                           'batch_size': 'int64'})
    if ensemble_size:
        return adf[['algorithm', 'dataset', 'ensemble_size', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]
    return adf[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]

# %% [markdown]
# # Parse SSH logs

# %%
def parse_SSH(fname):
    fname = os.fsdecode(fname)
    read_ssh = False
    alg = ''
    dataset = ''
    rate = ''
    d = {'algorithm': [], 'dataset': [], 'batch_size': [], 'inc_rate': [], 'prod_rate': [], 'tt_inst_prod': []}
    with open (fname, "r") as file:
        for line in file:
            if not read_ssh:
                if 'ssh-' in line:
                    read_ssh = True
#                     print(line)
                    spline = line.split('-')
                    if "MAX" in line:
                        if len(spline[1:]) == 3:
                            dataset, alg, rate = spline[1:]
                            bsize = 500
                        else:
                            dataset, alg, bsize, rate = spline[1:]
                    else:
                        dataset, alg, rate = spline[1:]
                        bsize = 1
                    d['algorithm'].append(alg)
                    d['dataset'].append(dataset)
                    d['inc_rate'].append(rate.strip())
                    d['batch_size'].append(bsize)
            else:
                if 'Total instances Producer' in line:
                    tt_inst = float(line.split(': ')[1])
                    d['tt_inst_prod'].append(tt_inst)
                elif 'Producer Rate' in line:
                    prod_rate = float(line.split(': ')[1])
                    d['prod_rate'].append(prod_rate)
                    read_ssh = False
    return pd.DataFrame.from_dict(d).astype({'inc_rate': 'int64'})

# %% [markdown]
# # RUN MOTHERFUCKER

# %% [markdown]
# %cd pi
# d = {}
# df = load_Wmeas(f'energy/Wmeasure.log')
# exper_order_to_dict(f'energy/exper_order.log')
# d = populate_dict(d)
# adf = append_dict_to_df(d, df)

# %%
# %pwd
# Out:
# '/home/cassales/Documents/newpar/Parallel-Classifier-MOA/results'

# %% [markdown]
# d = {}
# header_printed = False
# moaDF = read_MOA("energy_vostro/energy/energy-vostro", "energy_vostro/energy/inst-and-delay.csv")
# measureDF = load_Wmeas(f'energy_vostro/energy/Wmeasure_vostro.log')
# d = exper_order_to_dict(f'energy_vostro/energy/exper_order_vostro.log', d)
# d = populate_dict(d, measureDF)
# mdf = append_dict_to_df(d)
# sshDF = parse_SSH(f'energy_vostro/energy/energy-vostro/ssh-log')

# %%
d = {}
header_printed = False
moaDF = read_MOA("Energy/vostro/socket", "Energy/vostro/inst-and-delay.csv")
moaDF = moaDF[["algorithm", "dataset", "cores", "batch_size", "inc_rate", "out_rate", "instances", "time", "delay"]]
measureDF = load_Wmeas(f'Energy/vostro/Wm-vostro.log')
d = exper_order_to_dict(f'Energy/vostro/exper_order-vostro.log', d)
d = populate_dict(d, measureDF)
mdf = append_dict_to_df(d)
sshDF = parse_SSH(f'Energy/vostro/ssh-log-vostro')
sshDF['batch_size'] = sshDF['batch_size'].astype(int)
print(f"moaDF {len(moaDF)}     mdf {len(mdf)}      sshDF {len(sshDF)}")
# Out:
# moaDF 450     mdf 450      sshDF 450

# %%
#join dfs
finaldf = moaDF.merge(mdf, on=['algorithm', 'dataset', 'cores', 'batch_size', 'inc_rate'])
# display(finaldf[(finaldf.algorithm == 'LBagExecutorMAXChunk') & (finaldf.dataset == 'kyoto_binary')])
# display(sshDF[(sshDF.algorithm == 'LBagExecutorMAXChunk') & (sshDF.dataset == 'kyoto_binary')])
# print(finaldf.dtypes)
# print(f'\n\n{sshDF.dtypes}')
finaldf = finaldf.merge(sshDF, 'left', on=['algorithm', 'dataset', 'batch_size', 'inc_rate'])
# display(finaldf[(finaldf.algorithm == 'LBagExecutorMAXChunk') & (finaldf.dataset == 'kyoto_binary')])
# display(finaldf[(finaldf.algorithm == 'AdaptiveRandomForestExecutorMAXChunk') & (finaldf.dataset == 'kyoto_binary')])
finaldf['joules'] = finaldf['avg_measure'] * finaldf['time']
finaldf['JPI'] = finaldf['joules'] / finaldf['instances']
# finaldf['JP1kI'] = finaldf['joules'] / (finaldf['instances']/1000)
# finaldf['JPIoriginal'] = finaldf['JPI']
# finaldf['JPI'] = finaldf['JP1kI']
# finaldf.dataset.unique()

# %% [markdown]
# ### Add PERC column to identify if it used 90, 50 or 10% max rate

# %%
tdf = finaldf.sort_values(by=['dataset','algorithm','batch_size','inc_rate'], ascending=False)
# display(tdf[(tdf.algorithm == 'StreamingRandomPatchesExecutorMAXChunk') & (tdf.dataset == 'kyoto_binary') & (tdf.batch_size == 250)])
tdf.to_csv('tdf.csv')
print(f'tdf entries: {len(tdf)}')
tdf['PERC'] = 0
masks = {'90':[], '50': [], '10': []}
for k, v in zip(masks.keys(), [0, 1, 2]):
#         x = 1 if i % 3 == v else 0
    for i in range(len(tdf)):
        masks[k].append(i % 3 == v)
tdf.loc[masks['90'],'PERC'] = '90'
tdf.loc[masks['50'],'PERC'] = '50'
tdf.loc[masks['10'],'PERC'] = '10'
# tdf
# Out:
# tdf entries: 450

# %% [markdown]
# ### Show DFs for each algorithm and dataset, divided by rate

# %%
algs = ['Ada', 'L', 'Patch', 'Adwin', 'ASHT', 'OzaBag']
datasets = ['airlines', 'GMSC','elecNormNew','covtypeNorm']
for k in ['90', '50', '10']:
#     print(f"\n\n\n\n{k}")
    energy = tdf[tdf.PERC == k]
    for ds in energy.dataset.unique():
        for alg in algs:
#             auxdf = energy[(energy.dataset == ds) & (energy.algorithm.str.contains(alg))]
            auxdf = filter_by_substring_algorithm(energy[energy.dataset == ds], alg)
#             display(auxdf)
#             if alg == 'Patch' or alg == 'Ada':
#                 display(auxdf[['algorithm','dataset','cores','batch_size','prod_rate','out_rate','instances','time','joules','JPI', 'JP1kI']].sort_values(['cores','batch_size']))
#         auxdf = energy[(energy.dataset == ds) & (~energy.algorithm.str.contains('|'.join(algs)))]
#         display(auxdf[['algorithm','dataset','cores','batch_size','prod_rate','out_rate','instances','time','joules','JPI', 'JP1kI']].sort_values(['cores','batch_size']))

# %% [markdown]
# # Showing and preparing for graphs

# %%
def filter_fields(df):
    wanted = ['algorithm', 'dataset', 'batch_size', 'cores', 'out_rate', 'instances', 'delay', 'joules', 'JPI']
    return df[[
        l for l in df.columns if any([w in l for w in wanted])
    ]]

# %%
def rename_columns_by_rate(df):
#     display(df)
    rate = df.PERC.iloc[0]
    return df.rename(columns={"out_rate": f"out_rate_{rate}", "instances": f"instances_{rate}",
                              "delay": f"delay_{rate}", "joules": f"joules_{rate}", "JPI": f"JPI_{rate}"})

# %%
def my_norm(df, x='90MB'):
    mdf = df.iloc[:,[0,1,15,30,45]]
    if x == '90MB':
        thisisone = mdf.iloc[2,4]
#     else:
    elif x == '10S':
        thisisone = mdf.iloc[0,2]
    else:
#         10P
        thisisone = mdf.iloc[1,2]
    for i in ['JPI_10','JPI_50','JPI_90']:
           df[i] = df[i]/thisisone
#     display(df.iloc[:,[0,1,15,30,45]])
    return df.iloc[:,[0,1,15,30,45,7,22,37]]

# %% [markdown]
# linhas pretas (solida, tracejada, pontilhada)
#
# JPI em barras (3 barras por rate)

# %%
def show_graph_JPI_delay(df, ax, mJPI, mDel, legend=False, title=False, ylabels=False, ds='', bar=False, share_y=False, log_y=False, norm=False, hide=True):
    if norm:
        df = my_norm(df, x=norm)
    global rate
    global twin
    width = 0.15
    alg_order = ['Sequential', 'B1', 'B50', 'B250', 'B500']
    labels = ['10%', '50%', '90%']
    line_format = ['-', '--', ':', '-.', ' ']
    linfo = '--'
    x = np.arange(len(labels))
    lns_l = []
    versions = 5
    for i in range(versions):
        adf = df.iloc[[i]]
        values_j = [adf.JPI_10.iloc[0], adf.JPI_50.iloc[0], adf.JPI_90.iloc[0]]
        if bar:
            lns_l += ax.bar(x - ((1 - i) * width), values_j, width, label=f'JPI-{alg_order[i]}')            
        else:
            lns_l += ax.plot(x, values_j, label=f'JPI-{alg_order[i]}')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax_r = ax.twinx()
    twin = ax_r
    if log_y:
        ax.set_yscale('log')
        ax_r.set_yscale('log')
    if title:
        alg_title = re.sub('Sequential', '', df.algorithm.iloc[0])
        ax.set_title(f'{alg_title}')
#         ax.set_xlabel('Rate')
    if ylabels:
        ax.set_ylabel(ds)
#         ax.set_ylabel('JPI')
#         ax_r.set_ylabel('delay')
    if last:
        ax.set_ymargin(2)
    for i in range(versions):
        adf = df.iloc[[i]]
        values_d = [ x/1000 for x in [adf.delay_10.iloc[0], adf.delay_50.iloc[0], adf.delay_90.iloc[0]]]
        if bar:
            linfo = f'k{line_format[i]}'
        lns_l += ax_r.plot(x, values_d, linfo, label=f'delay-{alg_order[i]}')
    labs = [l.get_label() for l in lns_l]
    if legend:
        ax.legend(lns_l, labs, loc=0)
    if hide:
        ax_r.set_yticklabels([])
    if share_y == 'row':
        ax.set_ylim(top=mJPI)
        ax_r.set_ylim(top=mDel/1000)

# %%
def aux_graphNx1(ds, axis, id_ds, df, bar=False, share_y='row', log_y=False, norm=False):
#     print(f'aux {bar}')
    rates = ['10', '50', '90']
    algs = ['Ada', 'L', 'Patches', 'Adwin', 'ASHT', 'OzaBag']
    global title
    global labels
    hide_axis = True
#     fig.suptitle(f'JPI and delay for {ds}', fontsize=18, y=1)
#     get max value from delay for all rates on all algorithms for this dataset
    mLstJPI = []
    mLstDel = []
    if share_y == 'row':
        for rt in rates:
            rtDF = df[df.PERC == rt]
            mLstJPI.append(rtDF.JPI.max())
            mLstDel.append(rtDF.delay.max())
        mJPI = max(mLstJPI)*1.05
        mDel = max(mLstDel)*1.05
    else:
        mJPI = mDel = 0
    for alg in algs:
        dsalgdf = filter_by_substring_algorithm(df, alg).sort_values(['algorithm','batch_size','cores'])
#         if alg == 'L' and ds == 'kyoto_binary':
#             display(dsalgdf)
        for rt in rates:
            if rt == '10':
#                 display(dsalgdf)
                showdf = rename_columns_by_rate(dsalgdf[dsalgdf.PERC == rt])
            else:
                to_join = dsalgdf[dsalgdf.PERC == rt]
                showdf = showdf.merge(rename_columns_by_rate(to_join),
                                  on=['algorithm', 'dataset', 'batch_size', 'cores']).sort_values(['batch_size','cores'])
        # debug print, if it shows it is wrong
        if len(showdf) != 5:
            display(showdf)
        if 'Ada' in alg:
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, ylabels=True, ds=ds, bar=bar, share_y=share_y, log_y=log_y, norm=norm)
        else:
            if algs[-1] == alg:
                hide_axis = False
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, bar=bar, share_y=share_y, log_y=log_y, norm=norm, hide=hide_axis)

# %%
def gen_graph(bars=False, share_y='row', log_y=False, norm=False):
#     print(f'gen {bars}')
    datasets = ['airlines', 'GMSC','elecNormNew','covtypeNorm', 'kyoto_binary']
    print(share_y)
    fig, axis = plt.subplots(len(datasets), 6, figsize=(16,12), tight_layout=True, sharey=share_y)
    global title
    global labels
    global last
    global twin
    leg = False
    labls = True
    title = True
    last = False
    twin = axis[0][0]
    for ds in datasets:
        if datasets.index(ds) == (len(datasets) - 1):
            last = True
        dsdf = tdf[tdf.dataset == ds]
#         display(dsdf)
        aux_graphNx1(ds, axis, datasets.index(ds), dsdf, bar=bars, share_y=share_y, log_y=log_y, norm=norm)
        title = False
    lines_1, labels_1 = axis[0][0].get_legend_handles_labels()
    lines_2, labels_2 = twin.get_legend_handles_labels()
    lines = lines_1 + lines_2
    labels = labels_1 + labels_2
    lgd = fig.legend(lines, labels, loc=8, ncol=5, bbox_to_anchor=(0.5, -0.02))
    lgd.set_in_layout(True)
    fig.subplots_adjust(bottom=0.2)
    filename = 'bars-all-4x1-JPI-delay.eps' if bars else 'all-4x1-JPI-delay.eps'
    plt.savefig(f'Vostro-{filename}', pad_inches=0.2, bbox_inches='tight')

# %% [markdown]
# rates = ['10', '50', '90']
# algs = ['Ada', 'L', 'Patches', 'Adwin', 'ASHT', 'OzaBag']
# datasets = ['airlines', 'GMSC','elecNormNew','covtypeNorm','kyoto_binary']
# all_values = []
# # filtra algoritmo
# for alg in algs:
# #         line = alg + ' & $\Delta$ '
#     line = alg + '  '
#     algdf = filter_by_substring_algorithm(tdf, alg).sort_values(['algorithm','batch_size','cores'])
#     # filtra dataset
#     for ds in datasets:
#         dsalgdf = algdf[algdf.dataset == ds]
# #         display(dsalgdf.head())
#         # "junta"
#         for rt in rates:
#             if rt == '10':
#                 showdf = rename_columns_by_rate(dsalgdf[dsalgdf.PERC == rt])
#             else:
#                 to_join = dsalgdf[dsalgdf.PERC == rt]
#                 showdf = showdf.merge(rename_columns_by_rate(to_join),on=['algorithm', 'dataset', 'batch_size', 'cores']).sort_values(['batch_size','cores'])
# #         showdf = showdf[['algorithm','dataset','cores','batch_size','JPI_10','JPI_50','JPI_90']]
# #         display(showdf)
#         for i in rates:
#             minoutro = min(showdf[showdf.batch_size == 1][f'JPI_{i}'])
# #             print(f"JPI_{i} minoutro {minoutro}")
# #             display(showdf[showdf.batch_size != 1])
#             val = ((showdf[showdf.batch_size != 1][f'JPI_{i}'].iloc[0] - minoutro) / minoutro ) * 100
#             all_values.append(val)
#             sval = f"{val:.2f} " if val < 0 else "\\textbf{ " + f"{val:.2f}" + "} "
#             line += f"& {sval}"
#     print(f"{line} \\\\")
# print(f'\n\nAverage reduction: {sum(all_values)/len(all_values)}')

# %%
def table_delta_rates_vert(ratio=False):
    rates = ['10', '50', '90']
    algs = ['Ada', 'L', 'Patches', 'Adwin', 'ASHT', 'OzaBag']
    datasets = ['airlines', 'GMSC','elecNormNew','covtypeNorm','kyoto_binary']
    all_values = []
    # filtra algoritmo
    for alg in algs:
        line = '\hline\n\\multirow{3}{*}{' + alg + '} '
        algdf = filter_by_substring_algorithm(tdf, alg).sort_values(['algorithm','batch_size','cores'])
#         display(algdf)
        # filtra rate
        for rt in rates:
            if rt != '10':
                line += '\\\\\n'
            line += f' & {rt} '
            rtalgdf = rename_columns_by_rate(algdf[algdf.PERC == rt])
            # filtra dataset
            for ds in datasets:
#                 print(ds)
                dsrtalgdf = rtalgdf[rtalgdf.dataset == ds]
#                 display(dsrtalgdf)
                minoutro = min(dsrtalgdf[dsrtalgdf.batch_size == 1][f'JPI_{rt}'])
#                 print(f"JPI_{rt} minoutro {minoutro}")
                val = ((dsrtalgdf[dsrtalgdf.batch_size != 1][f'JPI_{rt}'].iloc[0] - minoutro)/minoutro)*100 if ratio else dsrtalgdf[dsrtalgdf.batch_size != 1][f'JPI_{rt}'].iloc[0] - minoutro 
                all_values.append(val)
                sval = f"{val:.2f} " if val < 0 else "\\textbf{ " + f"{val:.2f}" + "} "
                line += f"& {sval} "
        print(f"{line} \\\\")
    print(f'\n\nAverage reduction: {sum(all_values)/len(all_values)}')

# %%
table_delta_rates_vert()
# Out:
# \hline
# \multirow{3}{*}{Ada}  & 10 & -0.13  & -0.16  & -0.16  & -0.26  & -0.10  \\
#  & 50 & -0.06  & -0.03  & -0.04  & -0.06  & -0.02  \\
#  & 90 & -0.18  & -0.02  & -0.02  & -0.04  & -0.02   \\
# \hline
# \multirow{3}{*}{L}  & 10 & \textbf{ 0.01}  & -0.17  & -0.16  & -0.39  & -0.11  \\
#  & 50 & \textbf{ 0.22}  & -0.04  & -0.04  & -0.08  & -0.02  \\
#  & 90 & \textbf{ 0.28}  & -0.02  & -0.02  & -0.05  & -0.02   \\
# \hline
# \multirow{3}{*}{Patches}  & 10 & -0.01  & -0.28  & -0.25  & -0.79  & -0.11  \\
#  & 50 & -0.15  & -0.06  & -0.05  & -0.18  & -0.03  \\
#  & 90 & -0.01  & -0.03  & -0.02  & -0.11  & -0.00   \\
# \hline
# \multirow{3}{*}{Adwin}  & 10 & -0.21  & -0.06  & -0.07  & -0.17  & -0.05  \\
#  & 50 & -0.15  & -0.02  & -0.02  & -0.04  & -0.01  \\
#  & 90 & -0.14  & -0.01  & -0.01  & -0.02  & -0.01   \\
# \hline
# \multirow{3}{*}{ASHT}  & 10 & -0.16  & -0.04  & -0.06  & -0.16  & -0.04  \\
#  & 50 & -0.08  & -0.01  & -0.01  & -0.04  & -0.01  \\
#  & 90 & -0.09  & -0.01  & -0.01  & -0.02  & -0.01   \\
# \hline
# \multirow{3}{*}{OzaBag}  & 10 & -0.08  & -0.04  & -0.05  & -0.13  & -0.03  \\
#  & 50 & \textbf{ 0.06}  & -0.01  & -0.01  & -0.03  & -0.01  \\
#  & 90 & -0.02  & -0.00  & -0.01  & -0.02  & -0.00   \\
#
#
# Average reduction: -0.06751103126803246

# %% [markdown]
# Sharey = row
#
# Linear scale

# %%
gen_graph(bars=True)
# Out:
# row
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# sharey = False
#
# linear scale

# %%
gen_graph(bars=True, share_y=False)
# Out:
# False
#                               algorithm   dataset  cores batch_size  \
# 0        AdaptiveRandomForestSequential  airlines      1          1
# 1    AdaptiveRandomForestExecutorRUNPER  airlines      4          1
# 2  AdaptiveRandomForestExecutorMAXChunk  airlines      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          14         9.99      1,198.00  119.96     16.00         130  ...
# 1          37        34.98      4,198.00  120.00     15.00         124  ...
# 2          53        48.97      6,000.00  122.53  6,786.00         127  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 122.39 11,829.00       127        54.02     6,212.80     124.80
# 1 164.18  8,973.00       174        58.01     9,165.70     329.27
# 2 232.68  7,255.00       257        48.92    11,349.40     478.73
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    15,000.00   6,612.20    0.70    90
# 1    39,534.00   9,523.92    0.56    90
# 2    57,504.00  11,382.42    0.71    90
#
# [3 rows x 43 columns]
#               algorithm   dataset  cores batch_size  inc_rate_x  out_rate_10  \
# 0         LeveragingBag  airlines      1          1          11         9.99
# 1    LBagExecutorRUNPER  airlines      4          1          35        34.96
# 2  LBagExecutorMAXChunk  airlines      4        500          22        20.01
#
#    instances_10  time_x  delay_10  duration_x  ...   time  delay_90  duration  \
# 0      1,198.00  119.94     12.00         130  ... 120.97  6,787.00       130
# 1      4,196.00  120.01     15.00         124  ... 120.55  4,425.00       156
# 2      2,400.00  119.95 13,507.00         125  ... 370.21 30,446.00       403
#
#    avg_measure  sum_measure  prod_rate tt_inst_prod  joules_90  JPI_90  PERC
# 0        49.64     5,858.10     104.83    12,600.00   6,005.60    1.07    90
# 1        47.93     6,758.50     319.37    38,336.00   5,778.42    0.90    90
# 2        38.46    13,998.60     199.66    23,960.00  14,237.35    2.37    90
#
# [3 rows x 43 columns]
#                                 algorithm   dataset  cores batch_size  \
# 0                  StreamingRandomPatches  airlines      1          1
# 1    StreamingRandomPatchesExecutorRUNPER  airlines      4          1
# 2  StreamingRandomPatchesExecutorMAXChunk  airlines      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          14         9.99      1,198.00  119.96     15.00         124  ...
# 1          36        34.97      4,196.00  120.00     17.00         124  ...
# 2          49        45.01      5,400.00  119.98  7,435.00         125  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00 13,711.00       124        54.22     6,072.10     129.79
# 1 120.00 18,116.00       124        84.01     9,409.10     329.29
# 2 121.26  2,322.00       125        95.74    10,913.80     443.87
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    15,600.00   6,506.09    0.80    90
# 1    39,534.00  10,081.60    0.49    90
# 2    53,311.00  11,608.55    0.45    90
#
# [3 rows x 43 columns]
#                      algorithm   dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagAdwin  airlines      1          1          45
# 1    OzaBagAdwinExecutorRUNPER  airlines      4          1          57
# 2  OzaBagAdwinExecutorMAXChunk  airlines      4        500         162
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0        44.99      5,398.00  119.99     20.00         129  ... 128.76
# 1        54.92      6,590.00  120.00     13.00         125  ... 126.72
# 2       144.57     18,000.00  124.51  2,521.00         145  ... 142.06
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0 14,266.00       186        45.32     7,613.20     409.02    49,118.00
# 1  4,173.00       164        46.27     6,847.70     508.79    61,098.00
# 2  3,639.00       166        48.92     7,484.20   1,459.42   175,214.00
#
#    joules_90  JPI_90  PERC
# 0   5,835.16    0.26    90
# 1   5,863.34    0.38    90
# 2   6,948.96    0.36    90
#
# [3 rows x 43 columns]
#                     algorithm   dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagASHT  airlines      1          1         131
# 1    OzaBagASHTExecutorRUNPER  airlines      4          1          78
# 2  OzaBagASHTExecutorMAXChunk  airlines      4        500         353
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       129.76     15,573.00  120.01     77.00         125  ... 120.07
# 1        74.87      8,985.00  120.00     23.00         124  ... 120.00
# 2       349.71     41,930.00  119.90  1,035.00         125  ... 120.02
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0 30,688.00       128        52.70     6,113.50   1,175.87   141,128.00
# 1 20,865.00       124        52.24     5,850.80     702.96    84,459.00
# 2    334.00       124        82.62     9,253.20   3,171.53   380,964.00
#
#    joules_90  JPI_90  PERC
# 0   6,327.79    0.50    90
# 1   6,268.87    0.17    90
# 2   9,915.96    0.06    90
#
# [3 rows x 43 columns]
#                 algorithm   dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBag  airlines      1          1         131
# 1    OzaBagExecutorRUNPER  airlines      4          1         124
# 2  OzaBagExecutorMAXChunk  airlines      4        500         325
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       129.76     15,573.00  120.01    165.00         128  ... 176.07
# 1        70.41     13,349.00  189.59     55.00         202  ... 123.02
# 2       146.50     19,000.00  129.69  3,139.00         149  ... 141.77
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0 14,213.00       192        44.12     7,677.30   1,180.43   141,726.00
# 1  6,473.00       155        46.68     6,675.60   1,115.84   133,952.00
# 2  3,374.00       158        46.91     6,754.50   2,918.74   350,415.00
#
#    joules_90  JPI_90  PERC
# 0   7,768.63    0.37    90
# 1   5,742.84    0.37    90
# 2   6,649.99    0.32    90
#
# [3 rows x 43 columns]
#                               algorithm dataset  cores batch_size  inc_rate_x  \
# 0        AdaptiveRandomForestSequential    GMSC      1          1          93
# 1    AdaptiveRandomForestExecutorRUNPER    GMSC      4          1         105
# 2  AdaptiveRandomForestExecutorMAXChunk    GMSC      4        500         244
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0        89.85     10,783.00  120.01     15.00         123  ... 120.18
# 1       104.82     12,580.00  120.01     11.00         123  ... 120.00
# 2       239.90     28,752.00  119.85  1,206.00         125  ...  68.45
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    698.00       124        50.23     5,625.70     832.26   100,033.00
# 1    100.00       124        52.43     5,924.90     946.61   113,620.00
# 2    223.00        73        73.36     4,914.90   2,194.46   150,000.00
#
#    joules_90  JPI_90  PERC
# 0   6,036.58    0.06    90
# 1   6,291.98    0.06    90
# 2   5,021.05    0.03    90
#
# [3 rows x 43 columns]
#               algorithm dataset  cores batch_size  inc_rate_x  out_rate_10  \
# 0         LeveragingBag    GMSC      1          1         123       119.80
# 1    LBagExecutorRUNPER    GMSC      4          1         114       109.81
# 2  LBagExecutorMAXChunk    GMSC      4        500         335       334.76
#
#    instances_10  time_x  delay_10  duration_x  ...   time  delay_90  duration  \
# 0     14,377.00  120.01     14.00         124  ... 120.00    347.00       124
# 1     13,179.00  120.01     10.00         125  ... 120.00     80.00       124
# 2     40,133.00  119.89    878.00         124  ...  49.99    162.00        54
#
#    avg_measure  sum_measure  prod_rate tt_inst_prod  joules_90  JPI_90  PERC
# 0        50.83     5,693.40   1,110.65   133,354.00   6,100.12    0.05    90
# 1        50.71     5,730.00   1,021.22   122,590.00   6,085.06    0.05    90
# 2        70.50     3,454.50   3,000.42   150,000.00   3,524.58    0.02    90
#
# [3 rows x 43 columns]
#                                 algorithm dataset  cores batch_size  \
# 0                  StreamingRandomPatches    GMSC      1          1
# 1    StreamingRandomPatchesExecutorRUNPER    GMSC      4          1
# 2  StreamingRandomPatchesExecutorMAXChunk    GMSC      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          52        49.96      5,995.00  120.00     14.00         123  ...
# 1          63        59.93      7,192.00  120.00     10.00         123  ...
# 2         141       139.98     16,772.00  119.82  2,068.00         125  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00    408.00       124        50.62     5,669.70     463.82
# 1 120.00     94.00       123        52.49     5,878.60     568.51
# 2 119.07    386.00       123        76.43     8,560.40   1,268.10
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    55,707.00   6,074.73    0.11    90
# 1    68,286.00   6,298.55    0.09    90
# 2   150,000.00   9,100.85    0.06    90
#
# [3 rows x 43 columns]
#                      algorithm dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagAdwin    GMSC      1          1         296
# 1    OzaBagAdwinExecutorRUNPER    GMSC      4          1         193
# 2  OzaBagAdwinExecutorMAXChunk    GMSC      4        500         869
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0       294.82     35,341.00  119.87     12.00         124  ... 56.35
# 1       189.93     22,762.00  119.84     10.00         125  ... 86.67
# 2       863.43    103,454.00  119.82    340.00         124  ... 19.25
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    254.00        60        49.03     2,647.50   2,659.90   150,000.00
# 1     63.00        91        53.04     4,402.00   1,728.17   150,000.00
# 2     63.00        23        63.40     1,394.90   7,785.74   150,000.00
#
#    joules_90  JPI_90  PERC
# 0   2,762.96    0.02    90
# 1   4,596.38    0.03    90
# 2   1,220.60    0.01    90
#
# [3 rows x 43 columns]
#                     algorithm dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagASHT    GMSC      1          1         453
# 1    OzaBagASHTExecutorRUNPER    GMSC      4          1         226
# 2  OzaBagASHTExecutorMAXChunk    GMSC      4        500        1290
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0       449.54     53,910.00  119.92     10.00         124  ... 36.83
# 1       224.86     26,955.00  119.88     11.00         125  ... 73.90
# 2     1,284.81    150,000.00  116.75    225.00         121  ... 12.97
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    797.00        41        50.24     1,909.00   4,064.82   150,000.00
# 1     73.00        79        53.05     3,819.40   2,027.38   150,000.00
# 2     43.00        17        68.33     1,093.20  11,509.25   150,000.00
#
#    joules_90  JPI_90  PERC
# 0   1,850.02    0.01    90
# 1   3,920.14    0.03    90
# 2     885.97    0.01    90
#
# [3 rows x 43 columns]
#                 algorithm dataset  cores batch_size  inc_rate_x  out_rate_10  \
# 0                  OzaBag    GMSC      1          1         382       379.59
# 1    OzaBagExecutorRUNPER    GMSC      4          1         188       184.93
# 2  OzaBagExecutorMAXChunk    GMSC      4        500         930       928.15
#
#    instances_10  time_x  delay_10  duration_x  ...  time  delay_90  duration  \
# 0     45,524.00  119.93     10.00         125  ... 43.87    334.00        48
# 1     22,163.00  119.85      9.00         124  ... 88.82     64.00        94
# 2    111,228.00  119.84    315.00         124  ... 17.98     58.00        22
#
#    avg_measure  sum_measure  prod_rate tt_inst_prod  joules_90  JPI_90  PERC
# 0        49.03     2,157.40   3,414.13   150,000.00   2,150.88    0.01    90
# 1        50.26     4,322.00   1,689.11   150,000.00   4,463.67    0.03    90
# 2        63.58     1,271.60   8,309.79   150,000.00   1,143.36    0.01    90
#
# [3 rows x 43 columns]
#                               algorithm      dataset  cores batch_size  \
# 0        AdaptiveRandomForestSequential  elecNormNew      1          1
# 1    AdaptiveRandomForestExecutorRUNPER  elecNormNew      4          1
# 2  AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          55        54.93      6,592.00  120.00     15.00         123  ...
# 1          97        94.97     11,381.00  119.84     12.00         123  ...
# 2         194       189.94     22,762.00  119.84  1,561.00         125  ...
#
#    time  delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0 91.76  1,692.00        96        51.89     4,618.40     493.29    45,312.00
# 1 51.94    336.00        56        61.89     3,342.30     871.62    45,312.00
# 2 25.87    284.00        30        81.86     2,373.80   1,738.56    45,312.00
#
#    joules_90  JPI_90  PERC
# 0   4,761.78    0.11    90
# 1   3,214.74    0.07    90
# 2   2,117.76    0.05    90
#
# [3 rows x 43 columns]
#               algorithm      dataset  cores batch_size  inc_rate_x  \
# 0         LeveragingBag  elecNormNew      1          1          97
# 1    LBagExecutorRUNPER  elecNormNew      4          1         113
# 2  LBagExecutorMAXChunk  elecNormNew      4        500         289
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0        94.85     11,382.00  120.00     14.00         124  ... 51.89
# 1       109.96     13,178.00  119.84     11.00         125  ... 44.61
# 2       284.79     34,143.00  119.89  1,028.00         124  ... 17.40
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    889.00        56        50.44     2,673.40     871.65    45,312.00
# 1    136.00        50        54.06     2,540.60   1,011.93    45,312.00
# 2    184.00        21        70.12     1,472.50   2,595.78    45,312.00
#
#    joules_90  JPI_90  PERC
# 0   2,617.56    0.06    90
# 1   2,411.25    0.05    90
# 2   1,220.21    0.03    90
#
# [3 rows x 43 columns]
#                                 algorithm      dataset  cores batch_size  \
# 0                  StreamingRandomPatches  elecNormNew      1          1
# 1    StreamingRandomPatchesExecutorRUNPER  elecNormNew      4          1
# 2  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          26        25.01      3,000.00  119.97     10.00         124  ...
# 1          54        49.95      5,994.00  120.00      9.00         124  ...
# 2          88        84.86     10,184.00  120.01  3,389.00         124  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 119.98    289.00       124        49.87     5,584.90     239.50
# 1  93.69    111.00        97        64.90     5,971.10     482.78
# 2  57.49    620.00        62        82.99     4,730.40     786.72
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    28,752.00   5,982.62    0.21    90
# 1    45,312.00   6,080.92    0.13    90
# 2    45,312.00   4,770.82    0.11    90
#
# [3 rows x 43 columns]
#                      algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagAdwin  elecNormNew      1          1         216
# 1    OzaBagAdwinExecutorRUNPER  elecNormNew      4          1         159
# 2  OzaBagAdwinExecutorMAXChunk  elecNormNew      4        500         543
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0       214.87     25,757.00  119.87     12.00         124  ... 23.40
# 1       154.93     18,569.00  119.85     11.00         125  ... 31.64
# 2       539.10     45,312.00   84.05    533.00          88  ...  9.32
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    994.00        29        48.62     1,361.30   1,930.63    45,312.00
# 1    148.00        35        51.58     1,702.10   1,429.49    45,312.00
# 2     99.00        13        57.66       749.60   4,806.62    45,312.00
#
#    joules_90  JPI_90  PERC
# 0   1,137.51    0.03    90
# 1   1,632.06    0.04    90
# 2     537.69    0.01    90
#
# [3 rows x 43 columns]
#                     algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagASHT  elecNormNew      1          1         237
# 1    OzaBagASHTExecutorRUNPER  elecNormNew      4          1         150
# 2  OzaBagASHTExecutorMAXChunk  elecNormNew      4        500         525
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0       234.85     28,153.00  119.87     12.00         124  ... 21.31
# 1       149.94     17,970.00  119.85     12.00         125  ... 33.63
# 2       524.07     45,312.00   86.46    553.00          90  ...  9.60
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    931.00        26        46.73     1,121.40   2,109.50    45,312.00
# 1    383.00        38        48.74     1,754.50   1,344.33    45,312.00
# 2    102.00        13        57.26       744.40   4,706.76    45,312.00
#
#    joules_90  JPI_90  PERC
# 0     995.76    0.02    90
# 1   1,638.85    0.04    90
# 2     549.42    0.01    90
#
# [3 rows x 43 columns]
#                 algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBag  elecNormNew      1          1         272
# 1    OzaBagExecutorRUNPER  elecNormNew      4          1         180
# 2  OzaBagExecutorMAXChunk  elecNormNew      4        500         611
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0       269.77     32,346.00  119.90     11.00         124  ... 18.55
# 1       179.91     21,564.00  119.86     10.00         125  ... 27.94
# 2       608.70     45,312.00   74.44    471.00          78  ...  8.30
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    809.00        23        46.00     1,057.90   2,426.35    45,312.00
# 1    121.00        33        50.14     1,504.30   1,615.06    45,312.00
# 2     89.00        12        55.89       726.60   5,379.56    45,312.00
#
#    joules_90  JPI_90  PERC
# 0     853.27    0.02    90
# 1   1,401.16    0.03    90
# 2     464.07    0.01    90
#
# [3 rows x 43 columns]
#                               algorithm      dataset  cores batch_size  \
# 0        AdaptiveRandomForestSequential  covtypeNorm      1          1
# 1    AdaptiveRandomForestExecutorRUNPER  covtypeNorm      4          1
# 2  AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          50        49.96      5,995.00  120.00     26.00         124  ...
# 1          72        69.89      8,387.00  120.00     15.00         123  ...
# 2         163       159.96     19,168.00  119.83  1,919.00         124  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00  1,885.00       126        50.13     5,814.80     448.78
# 1 120.00  1,096.00       124        55.47     6,489.60     652.91
# 2 120.08    323.00       125        71.52     8,224.50   1,470.24
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    53,910.00   6,015.36    0.11    90
# 1    78,469.00   6,656.06    0.08    90
# 2   176,705.00   8,587.59    0.05    90
#
# [3 rows x 43 columns]
#               algorithm      dataset  cores batch_size  inc_rate_x  \
# 0         LeveragingBag  covtypeNorm      1          1          41
# 1    LBagExecutorRUNPER  covtypeNorm      4          1          47
# 2  LBagExecutorMAXChunk  covtypeNorm      4        500         109
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0        40.00      4,800.00  119.99     23.00         124  ... 120.00
# 1        44.99      5,399.00  120.00     10.00         124  ... 120.00
# 2       104.95     12,579.00  119.86  2,955.00         125  ... 120.05
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  1,384.00       125        47.57     5,423.20     374.00    44,925.00
# 1    275.00       124        49.29     5,718.00     423.86    50,915.00
# 2    471.00       125        63.65     7,510.20     976.12   117,208.00
#
#    joules_90  JPI_90  PERC
# 0   5,708.77    0.13    90
# 1   5,915.37    0.12    90
# 2   7,640.42    0.07    90
#
# [3 rows x 43 columns]
#                                 algorithm      dataset  cores batch_size  \
# 0                  StreamingRandomPatches  covtypeNorm      1          1
# 1    StreamingRandomPatchesExecutorRUNPER  covtypeNorm      4          1
# 2  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          12        10.00      1,200.00  119.96     12.00         124  ...
# 1          21        20.00      2,400.00  119.98      9.00         124  ...
# 2          46        45.01      5,400.00  119.97  6,596.00         125  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00    449.00       123        51.90     5,968.50     104.82
# 1 119.97     92.00       125        56.88     6,655.50     189.61
# 2 119.93  1,146.00       124        79.77     9,253.30     418.87
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    12,579.00   6,228.16    0.50    90
# 1    22,762.00   6,824.67    0.30    90
# 2    50,316.00   9,566.95    0.19    90
#
# [3 rows x 43 columns]
#                      algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagAdwin  covtypeNorm      1          1          89
# 1    OzaBagAdwinExecutorRUNPER  covtypeNorm      4          1          74
# 2  OzaBagAdwinExecutorMAXChunk  covtypeNorm      4        500         160
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0        84.89     10,187.00  120.00     37.00         124  ... 119.94
# 1        69.89      8,387.00  120.00     17.00         125  ... 120.00
# 2       159.96     19,168.00  119.83  2,141.00         124  ... 120.22
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  2,047.00       124        50.42     5,848.70     802.15    96,278.00
# 1  2,207.00       125        53.86     6,302.10     662.84    79,667.00
# 2    330.00       124        61.07     7,023.10   1,435.79   172,512.00
#
#    joules_90  JPI_90  PERC
# 0   6,047.61    0.06    90
# 1   6,463.75    0.08    90
# 2   7,342.07    0.04    90
#
# [3 rows x 43 columns]
#                     algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagASHT  covtypeNorm      1          1          90
# 1    OzaBagASHTExecutorRUNPER  covtypeNorm      4          1          73
# 2  OzaBagASHTExecutorMAXChunk  covtypeNorm      4        500         146
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0        89.85     10,783.00  120.01     35.00         125  ... 119.97
# 1        69.89      8,387.00  120.00     15.00         124  ... 120.00
# 2       144.97     17,371.00  119.83  2,202.00         124  ... 119.92
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  2,150.00       124        51.24     5,944.20     812.04    97,474.00
# 1  1,157.00       125        52.08     6,093.10     662.85    79,667.00
# 2    347.00       124        54.43     6,150.40   1,314.66   157,872.00
#
#    joules_90  JPI_90  PERC
# 0   6,147.89    0.06    90
# 1   6,249.39    0.08    90
# 2   6,527.10    0.04    90
#
# [3 rows x 43 columns]
#                 algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBag  covtypeNorm      1          1         108
# 1    OzaBagExecutorRUNPER  covtypeNorm      4          1          73
# 2  OzaBagExecutorMAXChunk  covtypeNorm      4        500         193
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       104.96     12,579.00  119.84     32.00         125  ... 119.98
# 1        69.89      8,387.00  120.00     16.00         124  ... 120.00
# 2       189.91     22,762.00  119.86  1,792.00         124  ... 119.99
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  1,430.00       125        49.43     5,684.00     971.18   116,610.00
# 1  2,003.00       124        52.17     5,999.20     658.00    79,068.00
# 2    274.00       124        60.09     6,970.30   1,734.61   208,452.00
#
#    joules_90  JPI_90  PERC
# 0   5,930.24    0.05    90
# 1   6,260.09    0.08    90
# 2   7,209.93    0.03    90
#
# [3 rows x 43 columns]
#                               algorithm       dataset  cores batch_size  \
# 0        AdaptiveRandomForestSequential  kyoto_binary      1          1
# 1    AdaptiveRandomForestExecutorRUNPER  kyoto_binary      4          1
# 2  AdaptiveRandomForestExecutorMAXChunk  kyoto_binary      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          98        94.83     11,382.00  120.02      4.00         125  ...
# 1         160       159.93     19,168.00  119.85      5.00         124  ...
# 2         335       334.67     40,133.00  119.92    800.00         125  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00  1,515.00       123        39.21     4,391.50     881.75
# 1 120.00  2,250.00       124        57.10     6,395.60   1,441.01
# 2 120.05    160.00       123        77.39     8,589.80   3,006.97
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0   105,846.00   4,705.22    0.05    90
# 1   173,111.00   6,852.49    0.04    90
# 2   361,197.00   9,289.91    0.03    90
#
# [3 rows x 43 columns]
#                 algorithm       dataset  cores batch_size  inc_rate  out_rate  \
# 130  LBagExecutorMAXChunk  kyoto_binary      4        500      3069  3,039.48
# 32   LBagExecutorMAXChunk  kyoto_binary      4        500      1705  1,698.49
# 56   LBagExecutorMAXChunk  kyoto_binary      4        500       341    339.67
# 192    LBagExecutorRUNPER  kyoto_binary      4          1      1392  1,256.70
# 122    LBagExecutorRUNPER  kyoto_binary      4          1       773    767.28
# 77     LBagExecutorRUNPER  kyoto_binary      4          1       154    149.94
# 150         LeveragingBag  kyoto_binary      1          1      1142  1,022.02
# 204         LeveragingBag  kyoto_binary      1          1       634    613.27
# 197         LeveragingBag  kyoto_binary      1          1       126    124.95
#
#      instances   time    delay  duration  avg_measure  sum_measure  prod_rate  \
# 130 365,500.00 120.25   151.00       124        72.34     8,174.70   3,055.26
# 32  204,000.00 120.11   231.00       124        56.11     6,284.50   1,699.72
# 56   40,732.00 119.92   798.00       124        31.90     3,604.30     339.18
# 192 150,806.00 120.00 1,702.00       125        53.30     6,022.60   1,385.81
# 122  92,093.00 120.03    33.00       124        41.29     4,665.60     767.44
# 77   17,970.00 119.85     6.00       124        31.59     3,506.30     149.74
# 150 122,644.00 120.00 1,911.00       124        44.27     4,869.60   1,135.19
# 204  73,593.00 120.00    46.00       125        34.52     3,900.80     628.20
# 197  14,975.00 119.85     6.00       125        30.60     3,488.20     124.78
#
#      tt_inst_prod   joules  JPI PERC
# 130    367,187.00 8,699.26 0.02   90
# 32     204,259.00 6,739.40 0.03   50
# 56      40,732.00 3,824.86 0.09   10
# 192    166,522.00 6,395.79 0.04   90
# 122     92,246.00 4,955.65 0.05   50
# 77      17,970.00 3,785.82 0.21   10
# 150    136,344.00 5,312.38 0.04   90
# 204     75,474.00 4,142.48 0.06   50
# 197     14,975.00 3,667.08 0.24   10
#               algorithm       dataset  cores batch_size  inc_rate_x  \
# 0         LeveragingBag  kyoto_binary      1          1         126
# 1    LBagExecutorRUNPER  kyoto_binary      4          1         154
# 2  LBagExecutorMAXChunk  kyoto_binary      4        500         341
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       124.95     14,975.00  119.85      6.00         125  ... 120.00
# 1       149.94     17,970.00  119.85      6.00         124  ... 120.00
# 2       339.67     40,732.00  119.92    798.00         124  ... 120.25
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  1,911.00       124        44.27     4,869.60   1,135.19   136,344.00
# 1  1,702.00       125        53.30     6,022.60   1,385.81   166,522.00
# 2    151.00       124        72.34     8,174.70   3,055.26   367,187.00
#
#    joules_90  JPI_90  PERC
# 0   5,312.38    0.04    90
# 1   6,395.79    0.04    90
# 2   8,699.26    0.02    90
#
# [3 rows x 43 columns]
#                                 algorithm       dataset  cores batch_size  \
# 0                  StreamingRandomPatches  kyoto_binary      1          1
# 1    StreamingRandomPatchesExecutorRUNPER  kyoto_binary      4          1
# 2  StreamingRandomPatchesExecutorMAXChunk  kyoto_binary      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          59        54.92      6,590.00  120.00      4.00         123  ...
# 1          83        79.86      9,585.00  120.02      5.00         124  ...
# 2         119       114.79     13,778.00  120.02  2,271.00         124  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00     30.00       125        34.57     3,906.20     533.55
# 1 120.00    372.00       123        45.84     5,134.60     742.64
# 2 120.61    418.00       125        61.07     6,901.30   1,065.67
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    64,093.00   4,148.04    0.06    90
# 1    89,251.00   5,501.40    0.07    90
# 2   127,972.00   7,365.95    0.06    90
#
# [3 rows x 43 columns]
#                      algorithm       dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagAdwin  kyoto_binary      1          1         313
# 1    OzaBagAdwinExecutorRUNPER  kyoto_binary      4          1         233
# 2  OzaBagAdwinExecutorMAXChunk  kyoto_binary      4        500         674
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       309.70     37,138.00  119.92     10.00         125  ... 120.00
# 1       229.83     27,554.00  119.89      9.00         124  ... 120.00
# 2       667.66     80,133.00  120.02    436.00         124  ... 120.10
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  1,210.00       124        50.60     5,717.80   2,811.48   337,836.00
# 1  2,114.00       125        54.48     6,156.00   2,092.91   251,160.00
# 2     81.00       124        65.35     7,319.10   6,044.52   725,457.00
#
#    joules_90  JPI_90  PERC
# 0   6,072.05    0.02    90
# 1   6,537.45    0.03    90
# 2   7,848.56    0.01    90
#
# [3 rows x 43 columns]
#                     algorithm       dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagASHT  kyoto_binary      1          1         345
# 1    OzaBagASHTExecutorRUNPER  kyoto_binary      4          1         226
# 2  OzaBagASHTExecutorMAXChunk  kyoto_binary      4        500         738
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       344.62     41,331.00  119.93      8.00         124  ... 120.02
# 1       224.84     26,955.00  119.88      8.00         124  ... 120.00
# 2       732.53     87,907.00  120.00    394.00         125  ... 114.73
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    579.00       125        49.20     5,609.10   3,094.82   371,979.00
# 1    809.00       124        54.84     6,142.40   2,024.05   243,194.00
# 2     74.00       118        64.27     6,748.60   6,626.99   725,457.00
#
#    joules_90  JPI_90  PERC
# 0   5,905.35    0.02    90
# 1   6,581.20    0.03    90
# 2   7,374.03    0.01    90
#
# [3 rows x 43 columns]
#                 algorithm       dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBag  kyoto_binary      1          1         363
# 1    OzaBagExecutorRUNPER  kyoto_binary      4          1         218
# 2  OzaBagExecutorMAXChunk  kyoto_binary      4        500         721
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       359.61     43,128.00  119.93      7.00         125  ... 120.01
# 1       214.87     25,757.00  119.87      8.00         124  ... 120.00
# 2       717.58     86,113.00  120.00    395.00         124  ... 119.23
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    586.00       124        48.73     5,409.10   3,254.46   391,147.00
# 1  1,352.00       125        53.44     6,092.20   1,954.19   234,808.00
# 2     77.00       123        63.71     7,071.70   6,474.46   725,457.00
#
#    joules_90  JPI_90  PERC
# 0   5,848.36    0.01    90
# 1   6,412.90    0.03    90
# 2   7,596.03    0.01    90
#
# [3 rows x 43 columns]
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# sharey = false
#
# log scale y

# %%
gen_graph(bars=True, share_y=False, log_y=True)
# Out:
# False
#                               algorithm   dataset  cores batch_size  \
# 0        AdaptiveRandomForestSequential  airlines      1          1
# 1    AdaptiveRandomForestExecutorRUNPER  airlines      4          1
# 2  AdaptiveRandomForestExecutorMAXChunk  airlines      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          14         9.99      1,198.00  119.96     16.00         130  ...
# 1          37        34.98      4,198.00  120.00     15.00         124  ...
# 2          53        48.97      6,000.00  122.53  6,786.00         127  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 122.39 11,829.00       127        54.02     6,212.80     124.80
# 1 164.18  8,973.00       174        58.01     9,165.70     329.27
# 2 232.68  7,255.00       257        48.92    11,349.40     478.73
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    15,000.00   6,612.20    0.70    90
# 1    39,534.00   9,523.92    0.56    90
# 2    57,504.00  11,382.42    0.71    90
#
# [3 rows x 43 columns]
#               algorithm   dataset  cores batch_size  inc_rate_x  out_rate_10  \
# 0         LeveragingBag  airlines      1          1          11         9.99
# 1    LBagExecutorRUNPER  airlines      4          1          35        34.96
# 2  LBagExecutorMAXChunk  airlines      4        500          22        20.01
#
#    instances_10  time_x  delay_10  duration_x  ...   time  delay_90  duration  \
# 0      1,198.00  119.94     12.00         130  ... 120.97  6,787.00       130
# 1      4,196.00  120.01     15.00         124  ... 120.55  4,425.00       156
# 2      2,400.00  119.95 13,507.00         125  ... 370.21 30,446.00       403
#
#    avg_measure  sum_measure  prod_rate tt_inst_prod  joules_90  JPI_90  PERC
# 0        49.64     5,858.10     104.83    12,600.00   6,005.60    1.07    90
# 1        47.93     6,758.50     319.37    38,336.00   5,778.42    0.90    90
# 2        38.46    13,998.60     199.66    23,960.00  14,237.35    2.37    90
#
# [3 rows x 43 columns]
#                                 algorithm   dataset  cores batch_size  \
# 0                  StreamingRandomPatches  airlines      1          1
# 1    StreamingRandomPatchesExecutorRUNPER  airlines      4          1
# 2  StreamingRandomPatchesExecutorMAXChunk  airlines      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          14         9.99      1,198.00  119.96     15.00         124  ...
# 1          36        34.97      4,196.00  120.00     17.00         124  ...
# 2          49        45.01      5,400.00  119.98  7,435.00         125  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00 13,711.00       124        54.22     6,072.10     129.79
# 1 120.00 18,116.00       124        84.01     9,409.10     329.29
# 2 121.26  2,322.00       125        95.74    10,913.80     443.87
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    15,600.00   6,506.09    0.80    90
# 1    39,534.00  10,081.60    0.49    90
# 2    53,311.00  11,608.55    0.45    90
#
# [3 rows x 43 columns]
#                      algorithm   dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagAdwin  airlines      1          1          45
# 1    OzaBagAdwinExecutorRUNPER  airlines      4          1          57
# 2  OzaBagAdwinExecutorMAXChunk  airlines      4        500         162
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0        44.99      5,398.00  119.99     20.00         129  ... 128.76
# 1        54.92      6,590.00  120.00     13.00         125  ... 126.72
# 2       144.57     18,000.00  124.51  2,521.00         145  ... 142.06
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0 14,266.00       186        45.32     7,613.20     409.02    49,118.00
# 1  4,173.00       164        46.27     6,847.70     508.79    61,098.00
# 2  3,639.00       166        48.92     7,484.20   1,459.42   175,214.00
#
#    joules_90  JPI_90  PERC
# 0   5,835.16    0.26    90
# 1   5,863.34    0.38    90
# 2   6,948.96    0.36    90
#
# [3 rows x 43 columns]
#                     algorithm   dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagASHT  airlines      1          1         131
# 1    OzaBagASHTExecutorRUNPER  airlines      4          1          78
# 2  OzaBagASHTExecutorMAXChunk  airlines      4        500         353
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       129.76     15,573.00  120.01     77.00         125  ... 120.07
# 1        74.87      8,985.00  120.00     23.00         124  ... 120.00
# 2       349.71     41,930.00  119.90  1,035.00         125  ... 120.02
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0 30,688.00       128        52.70     6,113.50   1,175.87   141,128.00
# 1 20,865.00       124        52.24     5,850.80     702.96    84,459.00
# 2    334.00       124        82.62     9,253.20   3,171.53   380,964.00
#
#    joules_90  JPI_90  PERC
# 0   6,327.79    0.50    90
# 1   6,268.87    0.17    90
# 2   9,915.96    0.06    90
#
# [3 rows x 43 columns]
#                 algorithm   dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBag  airlines      1          1         131
# 1    OzaBagExecutorRUNPER  airlines      4          1         124
# 2  OzaBagExecutorMAXChunk  airlines      4        500         325
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       129.76     15,573.00  120.01    165.00         128  ... 176.07
# 1        70.41     13,349.00  189.59     55.00         202  ... 123.02
# 2       146.50     19,000.00  129.69  3,139.00         149  ... 141.77
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0 14,213.00       192        44.12     7,677.30   1,180.43   141,726.00
# 1  6,473.00       155        46.68     6,675.60   1,115.84   133,952.00
# 2  3,374.00       158        46.91     6,754.50   2,918.74   350,415.00
#
#    joules_90  JPI_90  PERC
# 0   7,768.63    0.37    90
# 1   5,742.84    0.37    90
# 2   6,649.99    0.32    90
#
# [3 rows x 43 columns]
#                               algorithm dataset  cores batch_size  inc_rate_x  \
# 0        AdaptiveRandomForestSequential    GMSC      1          1          93
# 1    AdaptiveRandomForestExecutorRUNPER    GMSC      4          1         105
# 2  AdaptiveRandomForestExecutorMAXChunk    GMSC      4        500         244
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0        89.85     10,783.00  120.01     15.00         123  ... 120.18
# 1       104.82     12,580.00  120.01     11.00         123  ... 120.00
# 2       239.90     28,752.00  119.85  1,206.00         125  ...  68.45
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    698.00       124        50.23     5,625.70     832.26   100,033.00
# 1    100.00       124        52.43     5,924.90     946.61   113,620.00
# 2    223.00        73        73.36     4,914.90   2,194.46   150,000.00
#
#    joules_90  JPI_90  PERC
# 0   6,036.58    0.06    90
# 1   6,291.98    0.06    90
# 2   5,021.05    0.03    90
#
# [3 rows x 43 columns]
#               algorithm dataset  cores batch_size  inc_rate_x  out_rate_10  \
# 0         LeveragingBag    GMSC      1          1         123       119.80
# 1    LBagExecutorRUNPER    GMSC      4          1         114       109.81
# 2  LBagExecutorMAXChunk    GMSC      4        500         335       334.76
#
#    instances_10  time_x  delay_10  duration_x  ...   time  delay_90  duration  \
# 0     14,377.00  120.01     14.00         124  ... 120.00    347.00       124
# 1     13,179.00  120.01     10.00         125  ... 120.00     80.00       124
# 2     40,133.00  119.89    878.00         124  ...  49.99    162.00        54
#
#    avg_measure  sum_measure  prod_rate tt_inst_prod  joules_90  JPI_90  PERC
# 0        50.83     5,693.40   1,110.65   133,354.00   6,100.12    0.05    90
# 1        50.71     5,730.00   1,021.22   122,590.00   6,085.06    0.05    90
# 2        70.50     3,454.50   3,000.42   150,000.00   3,524.58    0.02    90
#
# [3 rows x 43 columns]
#                                 algorithm dataset  cores batch_size  \
# 0                  StreamingRandomPatches    GMSC      1          1
# 1    StreamingRandomPatchesExecutorRUNPER    GMSC      4          1
# 2  StreamingRandomPatchesExecutorMAXChunk    GMSC      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          52        49.96      5,995.00  120.00     14.00         123  ...
# 1          63        59.93      7,192.00  120.00     10.00         123  ...
# 2         141       139.98     16,772.00  119.82  2,068.00         125  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00    408.00       124        50.62     5,669.70     463.82
# 1 120.00     94.00       123        52.49     5,878.60     568.51
# 2 119.07    386.00       123        76.43     8,560.40   1,268.10
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    55,707.00   6,074.73    0.11    90
# 1    68,286.00   6,298.55    0.09    90
# 2   150,000.00   9,100.85    0.06    90
#
# [3 rows x 43 columns]
#                      algorithm dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagAdwin    GMSC      1          1         296
# 1    OzaBagAdwinExecutorRUNPER    GMSC      4          1         193
# 2  OzaBagAdwinExecutorMAXChunk    GMSC      4        500         869
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0       294.82     35,341.00  119.87     12.00         124  ... 56.35
# 1       189.93     22,762.00  119.84     10.00         125  ... 86.67
# 2       863.43    103,454.00  119.82    340.00         124  ... 19.25
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    254.00        60        49.03     2,647.50   2,659.90   150,000.00
# 1     63.00        91        53.04     4,402.00   1,728.17   150,000.00
# 2     63.00        23        63.40     1,394.90   7,785.74   150,000.00
#
#    joules_90  JPI_90  PERC
# 0   2,762.96    0.02    90
# 1   4,596.38    0.03    90
# 2   1,220.60    0.01    90
#
# [3 rows x 43 columns]
#                     algorithm dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagASHT    GMSC      1          1         453
# 1    OzaBagASHTExecutorRUNPER    GMSC      4          1         226
# 2  OzaBagASHTExecutorMAXChunk    GMSC      4        500        1290
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0       449.54     53,910.00  119.92     10.00         124  ... 36.83
# 1       224.86     26,955.00  119.88     11.00         125  ... 73.90
# 2     1,284.81    150,000.00  116.75    225.00         121  ... 12.97
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    797.00        41        50.24     1,909.00   4,064.82   150,000.00
# 1     73.00        79        53.05     3,819.40   2,027.38   150,000.00
# 2     43.00        17        68.33     1,093.20  11,509.25   150,000.00
#
#    joules_90  JPI_90  PERC
# 0   1,850.02    0.01    90
# 1   3,920.14    0.03    90
# 2     885.97    0.01    90
#
# [3 rows x 43 columns]
#                 algorithm dataset  cores batch_size  inc_rate_x  out_rate_10  \
# 0                  OzaBag    GMSC      1          1         382       379.59
# 1    OzaBagExecutorRUNPER    GMSC      4          1         188       184.93
# 2  OzaBagExecutorMAXChunk    GMSC      4        500         930       928.15
#
#    instances_10  time_x  delay_10  duration_x  ...  time  delay_90  duration  \
# 0     45,524.00  119.93     10.00         125  ... 43.87    334.00        48
# 1     22,163.00  119.85      9.00         124  ... 88.82     64.00        94
# 2    111,228.00  119.84    315.00         124  ... 17.98     58.00        22
#
#    avg_measure  sum_measure  prod_rate tt_inst_prod  joules_90  JPI_90  PERC
# 0        49.03     2,157.40   3,414.13   150,000.00   2,150.88    0.01    90
# 1        50.26     4,322.00   1,689.11   150,000.00   4,463.67    0.03    90
# 2        63.58     1,271.60   8,309.79   150,000.00   1,143.36    0.01    90
#
# [3 rows x 43 columns]
#                               algorithm      dataset  cores batch_size  \
# 0        AdaptiveRandomForestSequential  elecNormNew      1          1
# 1    AdaptiveRandomForestExecutorRUNPER  elecNormNew      4          1
# 2  AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          55        54.93      6,592.00  120.00     15.00         123  ...
# 1          97        94.97     11,381.00  119.84     12.00         123  ...
# 2         194       189.94     22,762.00  119.84  1,561.00         125  ...
#
#    time  delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0 91.76  1,692.00        96        51.89     4,618.40     493.29    45,312.00
# 1 51.94    336.00        56        61.89     3,342.30     871.62    45,312.00
# 2 25.87    284.00        30        81.86     2,373.80   1,738.56    45,312.00
#
#    joules_90  JPI_90  PERC
# 0   4,761.78    0.11    90
# 1   3,214.74    0.07    90
# 2   2,117.76    0.05    90
#
# [3 rows x 43 columns]
#               algorithm      dataset  cores batch_size  inc_rate_x  \
# 0         LeveragingBag  elecNormNew      1          1          97
# 1    LBagExecutorRUNPER  elecNormNew      4          1         113
# 2  LBagExecutorMAXChunk  elecNormNew      4        500         289
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0        94.85     11,382.00  120.00     14.00         124  ... 51.89
# 1       109.96     13,178.00  119.84     11.00         125  ... 44.61
# 2       284.79     34,143.00  119.89  1,028.00         124  ... 17.40
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    889.00        56        50.44     2,673.40     871.65    45,312.00
# 1    136.00        50        54.06     2,540.60   1,011.93    45,312.00
# 2    184.00        21        70.12     1,472.50   2,595.78    45,312.00
#
#    joules_90  JPI_90  PERC
# 0   2,617.56    0.06    90
# 1   2,411.25    0.05    90
# 2   1,220.21    0.03    90
#
# [3 rows x 43 columns]
#                                 algorithm      dataset  cores batch_size  \
# 0                  StreamingRandomPatches  elecNormNew      1          1
# 1    StreamingRandomPatchesExecutorRUNPER  elecNormNew      4          1
# 2  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          26        25.01      3,000.00  119.97     10.00         124  ...
# 1          54        49.95      5,994.00  120.00      9.00         124  ...
# 2          88        84.86     10,184.00  120.01  3,389.00         124  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 119.98    289.00       124        49.87     5,584.90     239.50
# 1  93.69    111.00        97        64.90     5,971.10     482.78
# 2  57.49    620.00        62        82.99     4,730.40     786.72
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    28,752.00   5,982.62    0.21    90
# 1    45,312.00   6,080.92    0.13    90
# 2    45,312.00   4,770.82    0.11    90
#
# [3 rows x 43 columns]
#                      algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagAdwin  elecNormNew      1          1         216
# 1    OzaBagAdwinExecutorRUNPER  elecNormNew      4          1         159
# 2  OzaBagAdwinExecutorMAXChunk  elecNormNew      4        500         543
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0       214.87     25,757.00  119.87     12.00         124  ... 23.40
# 1       154.93     18,569.00  119.85     11.00         125  ... 31.64
# 2       539.10     45,312.00   84.05    533.00          88  ...  9.32
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    994.00        29        48.62     1,361.30   1,930.63    45,312.00
# 1    148.00        35        51.58     1,702.10   1,429.49    45,312.00
# 2     99.00        13        57.66       749.60   4,806.62    45,312.00
#
#    joules_90  JPI_90  PERC
# 0   1,137.51    0.03    90
# 1   1,632.06    0.04    90
# 2     537.69    0.01    90
#
# [3 rows x 43 columns]
#                     algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagASHT  elecNormNew      1          1         237
# 1    OzaBagASHTExecutorRUNPER  elecNormNew      4          1         150
# 2  OzaBagASHTExecutorMAXChunk  elecNormNew      4        500         525
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0       234.85     28,153.00  119.87     12.00         124  ... 21.31
# 1       149.94     17,970.00  119.85     12.00         125  ... 33.63
# 2       524.07     45,312.00   86.46    553.00          90  ...  9.60
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    931.00        26        46.73     1,121.40   2,109.50    45,312.00
# 1    383.00        38        48.74     1,754.50   1,344.33    45,312.00
# 2    102.00        13        57.26       744.40   4,706.76    45,312.00
#
#    joules_90  JPI_90  PERC
# 0     995.76    0.02    90
# 1   1,638.85    0.04    90
# 2     549.42    0.01    90
#
# [3 rows x 43 columns]
#                 algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBag  elecNormNew      1          1         272
# 1    OzaBagExecutorRUNPER  elecNormNew      4          1         180
# 2  OzaBagExecutorMAXChunk  elecNormNew      4        500         611
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...  time  \
# 0       269.77     32,346.00  119.90     11.00         124  ... 18.55
# 1       179.91     21,564.00  119.86     10.00         125  ... 27.94
# 2       608.70     45,312.00   74.44    471.00          78  ...  8.30
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    809.00        23        46.00     1,057.90   2,426.35    45,312.00
# 1    121.00        33        50.14     1,504.30   1,615.06    45,312.00
# 2     89.00        12        55.89       726.60   5,379.56    45,312.00
#
#    joules_90  JPI_90  PERC
# 0     853.27    0.02    90
# 1   1,401.16    0.03    90
# 2     464.07    0.01    90
#
# [3 rows x 43 columns]
#                               algorithm      dataset  cores batch_size  \
# 0        AdaptiveRandomForestSequential  covtypeNorm      1          1
# 1    AdaptiveRandomForestExecutorRUNPER  covtypeNorm      4          1
# 2  AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          50        49.96      5,995.00  120.00     26.00         124  ...
# 1          72        69.89      8,387.00  120.00     15.00         123  ...
# 2         163       159.96     19,168.00  119.83  1,919.00         124  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00  1,885.00       126        50.13     5,814.80     448.78
# 1 120.00  1,096.00       124        55.47     6,489.60     652.91
# 2 120.08    323.00       125        71.52     8,224.50   1,470.24
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    53,910.00   6,015.36    0.11    90
# 1    78,469.00   6,656.06    0.08    90
# 2   176,705.00   8,587.59    0.05    90
#
# [3 rows x 43 columns]
#               algorithm      dataset  cores batch_size  inc_rate_x  \
# 0         LeveragingBag  covtypeNorm      1          1          41
# 1    LBagExecutorRUNPER  covtypeNorm      4          1          47
# 2  LBagExecutorMAXChunk  covtypeNorm      4        500         109
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0        40.00      4,800.00  119.99     23.00         124  ... 120.00
# 1        44.99      5,399.00  120.00     10.00         124  ... 120.00
# 2       104.95     12,579.00  119.86  2,955.00         125  ... 120.05
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  1,384.00       125        47.57     5,423.20     374.00    44,925.00
# 1    275.00       124        49.29     5,718.00     423.86    50,915.00
# 2    471.00       125        63.65     7,510.20     976.12   117,208.00
#
#    joules_90  JPI_90  PERC
# 0   5,708.77    0.13    90
# 1   5,915.37    0.12    90
# 2   7,640.42    0.07    90
#
# [3 rows x 43 columns]
#                                 algorithm      dataset  cores batch_size  \
# 0                  StreamingRandomPatches  covtypeNorm      1          1
# 1    StreamingRandomPatchesExecutorRUNPER  covtypeNorm      4          1
# 2  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          12        10.00      1,200.00  119.96     12.00         124  ...
# 1          21        20.00      2,400.00  119.98      9.00         124  ...
# 2          46        45.01      5,400.00  119.97  6,596.00         125  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00    449.00       123        51.90     5,968.50     104.82
# 1 119.97     92.00       125        56.88     6,655.50     189.61
# 2 119.93  1,146.00       124        79.77     9,253.30     418.87
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    12,579.00   6,228.16    0.50    90
# 1    22,762.00   6,824.67    0.30    90
# 2    50,316.00   9,566.95    0.19    90
#
# [3 rows x 43 columns]
#                      algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagAdwin  covtypeNorm      1          1          89
# 1    OzaBagAdwinExecutorRUNPER  covtypeNorm      4          1          74
# 2  OzaBagAdwinExecutorMAXChunk  covtypeNorm      4        500         160
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0        84.89     10,187.00  120.00     37.00         124  ... 119.94
# 1        69.89      8,387.00  120.00     17.00         125  ... 120.00
# 2       159.96     19,168.00  119.83  2,141.00         124  ... 120.22
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  2,047.00       124        50.42     5,848.70     802.15    96,278.00
# 1  2,207.00       125        53.86     6,302.10     662.84    79,667.00
# 2    330.00       124        61.07     7,023.10   1,435.79   172,512.00
#
#    joules_90  JPI_90  PERC
# 0   6,047.61    0.06    90
# 1   6,463.75    0.08    90
# 2   7,342.07    0.04    90
#
# [3 rows x 43 columns]
#                     algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagASHT  covtypeNorm      1          1          90
# 1    OzaBagASHTExecutorRUNPER  covtypeNorm      4          1          73
# 2  OzaBagASHTExecutorMAXChunk  covtypeNorm      4        500         146
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0        89.85     10,783.00  120.01     35.00         125  ... 119.97
# 1        69.89      8,387.00  120.00     15.00         124  ... 120.00
# 2       144.97     17,371.00  119.83  2,202.00         124  ... 119.92
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  2,150.00       124        51.24     5,944.20     812.04    97,474.00
# 1  1,157.00       125        52.08     6,093.10     662.85    79,667.00
# 2    347.00       124        54.43     6,150.40   1,314.66   157,872.00
#
#    joules_90  JPI_90  PERC
# 0   6,147.89    0.06    90
# 1   6,249.39    0.08    90
# 2   6,527.10    0.04    90
#
# [3 rows x 43 columns]
#                 algorithm      dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBag  covtypeNorm      1          1         108
# 1    OzaBagExecutorRUNPER  covtypeNorm      4          1          73
# 2  OzaBagExecutorMAXChunk  covtypeNorm      4        500         193
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       104.96     12,579.00  119.84     32.00         125  ... 119.98
# 1        69.89      8,387.00  120.00     16.00         124  ... 120.00
# 2       189.91     22,762.00  119.86  1,792.00         124  ... 119.99
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  1,430.00       125        49.43     5,684.00     971.18   116,610.00
# 1  2,003.00       124        52.17     5,999.20     658.00    79,068.00
# 2    274.00       124        60.09     6,970.30   1,734.61   208,452.00
#
#    joules_90  JPI_90  PERC
# 0   5,930.24    0.05    90
# 1   6,260.09    0.08    90
# 2   7,209.93    0.03    90
#
# [3 rows x 43 columns]
#                               algorithm       dataset  cores batch_size  \
# 0        AdaptiveRandomForestSequential  kyoto_binary      1          1
# 1    AdaptiveRandomForestExecutorRUNPER  kyoto_binary      4          1
# 2  AdaptiveRandomForestExecutorMAXChunk  kyoto_binary      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          98        94.83     11,382.00  120.02      4.00         125  ...
# 1         160       159.93     19,168.00  119.85      5.00         124  ...
# 2         335       334.67     40,133.00  119.92    800.00         125  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00  1,515.00       123        39.21     4,391.50     881.75
# 1 120.00  2,250.00       124        57.10     6,395.60   1,441.01
# 2 120.05    160.00       123        77.39     8,589.80   3,006.97
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0   105,846.00   4,705.22    0.05    90
# 1   173,111.00   6,852.49    0.04    90
# 2   361,197.00   9,289.91    0.03    90
#
# [3 rows x 43 columns]
#                 algorithm       dataset  cores batch_size  inc_rate  out_rate  \
# 130  LBagExecutorMAXChunk  kyoto_binary      4        500      3069  3,039.48
# 32   LBagExecutorMAXChunk  kyoto_binary      4        500      1705  1,698.49
# 56   LBagExecutorMAXChunk  kyoto_binary      4        500       341    339.67
# 192    LBagExecutorRUNPER  kyoto_binary      4          1      1392  1,256.70
# 122    LBagExecutorRUNPER  kyoto_binary      4          1       773    767.28
# 77     LBagExecutorRUNPER  kyoto_binary      4          1       154    149.94
# 150         LeveragingBag  kyoto_binary      1          1      1142  1,022.02
# 204         LeveragingBag  kyoto_binary      1          1       634    613.27
# 197         LeveragingBag  kyoto_binary      1          1       126    124.95
#
#      instances   time    delay  duration  avg_measure  sum_measure  prod_rate  \
# 130 365,500.00 120.25   151.00       124        72.34     8,174.70   3,055.26
# 32  204,000.00 120.11   231.00       124        56.11     6,284.50   1,699.72
# 56   40,732.00 119.92   798.00       124        31.90     3,604.30     339.18
# 192 150,806.00 120.00 1,702.00       125        53.30     6,022.60   1,385.81
# 122  92,093.00 120.03    33.00       124        41.29     4,665.60     767.44
# 77   17,970.00 119.85     6.00       124        31.59     3,506.30     149.74
# 150 122,644.00 120.00 1,911.00       124        44.27     4,869.60   1,135.19
# 204  73,593.00 120.00    46.00       125        34.52     3,900.80     628.20
# 197  14,975.00 119.85     6.00       125        30.60     3,488.20     124.78
#
#      tt_inst_prod   joules  JPI PERC
# 130    367,187.00 8,699.26 0.02   90
# 32     204,259.00 6,739.40 0.03   50
# 56      40,732.00 3,824.86 0.09   10
# 192    166,522.00 6,395.79 0.04   90
# 122     92,246.00 4,955.65 0.05   50
# 77      17,970.00 3,785.82 0.21   10
# 150    136,344.00 5,312.38 0.04   90
# 204     75,474.00 4,142.48 0.06   50
# 197     14,975.00 3,667.08 0.24   10
#               algorithm       dataset  cores batch_size  inc_rate_x  \
# 0         LeveragingBag  kyoto_binary      1          1         126
# 1    LBagExecutorRUNPER  kyoto_binary      4          1         154
# 2  LBagExecutorMAXChunk  kyoto_binary      4        500         341
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       124.95     14,975.00  119.85      6.00         125  ... 120.00
# 1       149.94     17,970.00  119.85      6.00         124  ... 120.00
# 2       339.67     40,732.00  119.92    798.00         124  ... 120.25
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  1,911.00       124        44.27     4,869.60   1,135.19   136,344.00
# 1  1,702.00       125        53.30     6,022.60   1,385.81   166,522.00
# 2    151.00       124        72.34     8,174.70   3,055.26   367,187.00
#
#    joules_90  JPI_90  PERC
# 0   5,312.38    0.04    90
# 1   6,395.79    0.04    90
# 2   8,699.26    0.02    90
#
# [3 rows x 43 columns]
#                                 algorithm       dataset  cores batch_size  \
# 0                  StreamingRandomPatches  kyoto_binary      1          1
# 1    StreamingRandomPatchesExecutorRUNPER  kyoto_binary      4          1
# 2  StreamingRandomPatchesExecutorMAXChunk  kyoto_binary      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          59        54.92      6,590.00  120.00      4.00         123  ...
# 1          83        79.86      9,585.00  120.02      5.00         124  ...
# 2         119       114.79     13,778.00  120.02  2,271.00         124  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 120.00     30.00       125        34.57     3,906.20     533.55
# 1 120.00    372.00       123        45.84     5,134.60     742.64
# 2 120.61    418.00       125        61.07     6,901.30   1,065.67
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    64,093.00   4,148.04    0.06    90
# 1    89,251.00   5,501.40    0.07    90
# 2   127,972.00   7,365.95    0.06    90
#
# [3 rows x 43 columns]
#                      algorithm       dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagAdwin  kyoto_binary      1          1         313
# 1    OzaBagAdwinExecutorRUNPER  kyoto_binary      4          1         233
# 2  OzaBagAdwinExecutorMAXChunk  kyoto_binary      4        500         674
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       309.70     37,138.00  119.92     10.00         125  ... 120.00
# 1       229.83     27,554.00  119.89      9.00         124  ... 120.00
# 2       667.66     80,133.00  120.02    436.00         124  ... 120.10
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0  1,210.00       124        50.60     5,717.80   2,811.48   337,836.00
# 1  2,114.00       125        54.48     6,156.00   2,092.91   251,160.00
# 2     81.00       124        65.35     7,319.10   6,044.52   725,457.00
#
#    joules_90  JPI_90  PERC
# 0   6,072.05    0.02    90
# 1   6,537.45    0.03    90
# 2   7,848.56    0.01    90
#
# [3 rows x 43 columns]
#                     algorithm       dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBagASHT  kyoto_binary      1          1         345
# 1    OzaBagASHTExecutorRUNPER  kyoto_binary      4          1         226
# 2  OzaBagASHTExecutorMAXChunk  kyoto_binary      4        500         738
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       344.62     41,331.00  119.93      8.00         124  ... 120.02
# 1       224.84     26,955.00  119.88      8.00         124  ... 120.00
# 2       732.53     87,907.00  120.00    394.00         125  ... 114.73
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    579.00       125        49.20     5,609.10   3,094.82   371,979.00
# 1    809.00       124        54.84     6,142.40   2,024.05   243,194.00
# 2     74.00       118        64.27     6,748.60   6,626.99   725,457.00
#
#    joules_90  JPI_90  PERC
# 0   5,905.35    0.02    90
# 1   6,581.20    0.03    90
# 2   7,374.03    0.01    90
#
# [3 rows x 43 columns]
#                 algorithm       dataset  cores batch_size  inc_rate_x  \
# 0                  OzaBag  kyoto_binary      1          1         363
# 1    OzaBagExecutorRUNPER  kyoto_binary      4          1         218
# 2  OzaBagExecutorMAXChunk  kyoto_binary      4        500         721
#
#    out_rate_10  instances_10  time_x  delay_10  duration_x  ...   time  \
# 0       359.61     43,128.00  119.93      7.00         125  ... 120.01
# 1       214.87     25,757.00  119.87      8.00         124  ... 120.00
# 2       717.58     86,113.00  120.00    395.00         124  ... 119.23
#
#    delay_90  duration  avg_measure  sum_measure  prod_rate tt_inst_prod  \
# 0    586.00       124        48.73     5,409.10   3,254.46   391,147.00
# 1  1,352.00       125        53.44     6,092.20   1,954.19   234,808.00
# 2     77.00       123        63.71     7,071.70   6,474.46   725,457.00
#
#    joules_90  JPI_90  PERC
# 0   5,848.36    0.01    90
# 1   6,412.90    0.03    90
# 2   7,596.03    0.01    90
#
# [3 rows x 43 columns]
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# sharey = false
#
# normalizado MB 90

# %%
gen_graph(bars=True, share_y=False, log_y=False, norm='90MB')
# Out:
# False
#                               algorithm   dataset  cores batch_size  \
# 0        AdaptiveRandomForestSequential  airlines      1          1
# 1    AdaptiveRandomForestExecutorRUNPER  airlines      4          1
# 2  AdaptiveRandomForestExecutorMAXChunk  airlines      4        500
#
#    inc_rate_x  out_rate_10  instances_10  time_x  delay_10  duration_x  ...  \
# 0          14         9.99      1,198.00  119.96     16.00         130  ...
# 1          37        34.98      4,198.00  120.00     15.00         124  ...
# 2          53        48.97      6,000.00  122.53  6,786.00         127  ...
#
#     time  delay_90  duration  avg_measure  sum_measure  prod_rate  \
# 0 122.39 11,829.00       127        54.02     6,212.80     124.80
# 1 164.18  8,973.00       174        58.01     9,165.70     329.27
# 2 232.68  7,255.00       257        48.92    11,349.40     478.73
#
#   tt_inst_prod  joules_90  JPI_90  PERC
# 0    15,000.00   6,612.20    0.70    90
# 1    39,534.00   9,523.92    0.56    90
# 2    57,504.00  11,382.42    0.71    90
#
# [3 rows x 43 columns]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-4f3a4eda6fb6> in <module>
# ----> 1 gen_graph(bars=True, share_y=False, log_y=False, norm='90MB')
#
# <ipython-input-28-a7b383098035> in gen_graph(bars, share_y, log_y, norm)
#      18         dsdf = tdf[tdf.dataset == ds]
#      19 #         display(dsdf)
# ---> 20         aux_graphNx1(ds, axis, datasets.index(ds), dsdf, bar=bars, share_y=share_y, log_y=log_y, norm=norm)
#      21         title = False
#      22     lines_1, labels_1 = axis[0][0].get_legend_handles_labels()
#
# <ipython-input-27-2f5c79e1be0c> in aux_graphNx1(ds, axis, id_ds, df, bar, share_y, log_y, norm)
#      35             display(showdf)
#      36         if 'Ada' in alg:
# ---> 37             show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, ylabels=True, ds=ds, bar=bar, share_y=share_y, log_y=log_y, norm=norm)
#      38         else:
#      39             if algs[-1] == alg:
#
# <ipython-input-26-bdb0d0a171cb> in show_graph_JPI_delay(df, ax, mJPI, mDel, legend, title, ylabels, ds, bar, share_y, log_y, norm, hide)
#       1 def show_graph_JPI_delay(df, ax, mJPI, mDel, legend=False, title=False, ylabels=False, ds='', bar=False, share_y=False, log_y=False, norm=False, hide=True):
#       2     if norm:
# ----> 3         df = my_norm(df, x=norm)
#       4     global rate
#       5     global twin
#
# <ipython-input-25-69728bfe1195> in my_norm(df, x)
#       1 def my_norm(df, x='90MB'):
# ----> 2     mdf = df.iloc[:,[0,1,15,30,45]]
#       3     if x == '90MB':
#       4         thisisone = mdf.iloc[2,4]
#       5 #     else:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2064     def _getitem_tuple(self, tup: Tuple):
#    2065
# -> 2066         self._has_valid_tuple(tup)
#    2067         try:
#    2068             return self._getitem_lowerdim(tup)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     700                 raise IndexingError("Too many indexers")
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError:
#     704                 raise ValueError(
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    2006             # check that the key does not exceed the maximum size of the index
#    2007             if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
# -> 2008                 raise IndexError("positional indexers are out-of-bounds")
#    2009         else:
#    2010             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# IndexError: positional indexers are out-of-bounds

# %% [markdown]
# sharey = false
#
# normalizado Seq10

# %%
gen_graph(bars=True, share_y=False, log_y=False, norm='10S')

# %%
gen_graph(bars=True, share_y=False, log_y=False, norm='10P')
