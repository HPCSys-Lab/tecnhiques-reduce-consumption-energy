# %% [markdown]
# # To use this notebook, make sure you cd into the main folder of the cloned repository in the next cell

# %%
# %cd ..
# %mkdir -p parsed_csvs figures
# Out:
# /home/cassales/Documents/Parallel-Classifier-MOA

# %% [markdown]
# ## Folders inside results directory that contains all the MOA dump files for these experiments
#
# ### Ideally results should be in this hierarchy:
#
#
# ```bash
# ├─ results
# │   ├── Energy
#         ├── pi
#         │   ├── get_rates
#         │   └── socket
#         ├── vostro
#         │   ├── get_rates
#         │   └── socket
#         └── xeon
#             ├── get_rates
#             └── socket
#
# ```

# %% [markdown]
# ## folder variables

# %%
#should probably find automatically...
moaDumpFolders = ["vostro/get_rates/", "pi/get_rates/", "xeon/get_rates/"]
wantedCSVfilename = ["vostro-get_rates.csv", "pi-get_rates.csv", "xeon-get_rates.csv"]

# %% [markdown]
# ## Calibrating the workload generator based on maximum throughput

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ***
# ## Parsing preliminary results to find maximum rate

# %%
def parse_folder_to_file(folder, outfilename):
    directory = os.fsencode(folder)
    header_printed = False
    with open(f"{outfilename}", "w+") as output:
        output.write('dataset,algorithm,ensemble_size,cores,batch_size,rate,instances,time,acc,prec,recall,change\n')
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("dump-"): 
                s = parse(f'{os.fsdecode(directory)}/{filename}')
                output.write(f"{s}\n")

# %%
def parse(fname):
    columns = []
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    pstr = ''
    spname = fname.split('/')[-1].split('-')
    spline = []
    got = False
    for s in spname[1:]:
        pstr += s + ','
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        if 'GMSC' in spname and 'ASHT' in spname[2]:
            for c in columns[:-2]:
                pstr += str(spline[c]) + ','
            pstr += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        else:
            for c in columns:
                pstr += str(spline[c]) + ','
            if len(columns) == 5:
                pstr += '0,'
        return (pstr[:-1])

# %%
def load_df(filename):
    df = pd.read_csv(filename)
    return select_columns_and_rename_values(df)

# %%
def select_columns_and_rename_values(df):
    df = df.loc[:,['dataset', 'algorithm', 'ensemble_size', 'cores', 'batch_size', 'instances', 'time', 'acc']]
    df['algorithm'] = df["algorithm"].str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df["algorithm"].str.replace("ARF$", "ARFSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB+")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    return df

# %%
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %% [markdown]
# ## Finding rate for Socket experiments

# %%
def calculate_rate_bsize(df,desired_esize, desired_bsize, incremental_included=False, rates=[0.1, 0.5, 0.9]):
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    file_algs = {'ARF': 'ARF', 'LBag': 'LBag', 'SRP': 'SRP', 'OBAdwin': 'OBagAd', 'OBASHT':'OBagASHT', 'OB': 'OBag'}
    for ds in df.dataset.unique():
        dsdf = df[df.dataset == ds]
        for alg in algorithms:
            s = f'X $1{ds}.arff {file_algs[alg]}'
            adf = filter_by_substring_algorithm(dsdf, alg)
            dfres = adf[adf.ensemble_size == desired_esize]
            #if we are just testing with all versions (sequential, parallel and mini-batch parallel)
            if incremental_included:
                # get sequential
                dfseq = dfres[(dfres.batch_size == 1) & (dfres.cores == 1)]
                # sanity check
                seq_rate = list((dfseq.IPS))[0] if dfseq.size else 0
                # get runper
                dfrunp = dfres[(dfres.batch_size == 1) & (dfres.cores != 1)]
                runper_rate = list(dfrunp.IPS)[0] if dfrunp.size else 0
            # if we are testing only the mini-batch parallel version
            else:
                seq_rate = 0
                runper_rate = 0
            # get Mini-Batch
            dfmb = dfres[(dfres.batch_size == desired_bsize) & (dfres.cores != 1)]
            mb_rate = list(dfmb.IPS)[0] if dfmb.size else 0
            #we have max rates, now we need the parameter rates (default = 10, 50 and 90)
            if mb_rate != 'NaN':
                for load in rates:
                    print(f'{s} {desired_bsize} {int(load*seq_rate)} {int(load*runper_rate)} {int(load*mb_rate)}')

# %%
def calculate_rate_csv(csvFilename, arch, batch_sizes=[50, 250, 500], incre=True):
    df = load_df(csvFilename)
    df['IPS'] = df['instances'] / df['time']
    incre = True
    esize = df.ensemble_size.unique()[0]
    for bsize in batch_sizes:
        print(f"--------------------\n{arch}\nesize {esize}\nbsize {bsize}\nwith incremental: {incre}\n")
        calculate_rate_bsize(df,esize, bsize, incre)
        incre = False
        print("\n\n")

# %% [markdown]
# ### MAIN PORTION
#
# - This `for` iterates through all files on the lists defined in the beginning
# - Then, it parses the folders in the respective `moaDumpFolder` and creates the csv
# - Finally, it calculates and prints the correct workloads to paste on the scripts that will execute the energy experiments
# - Outputs are identified with architecture, ensemble size, batch size and a boolean indicating if only the mini-batch rate was printed or the incremental rates are printed too
# - You have to **copy all outputs from a given architecture and paste at the end of the script that runs the experiments**

# %%
for i in range(len(moaDumpFolders)):
    architecture=moaDumpFolders[i].split('/')[0]
    print(f"------------------------------ {architecture} ------------------------------ ")
    parse_folder_to_file(f"results/Energy/{moaDumpFolders[i]}", f"parsed_csvs/{wantedCSVfilename[i]}")
    calculate_rate_csv(f'parsed_csvs/{wantedCSVfilename[i]}', architecture)
# Out:
# ------------------------------ vostro ------------------------------
# --------------------
# vostro
# esize 100
# bsize 50
# with incremental: True
#
# X $1covtypeNorm.arff ARF 50 48 72 155
# X $1covtypeNorm.arff ARF 50 243 364 776
# X $1covtypeNorm.arff ARF 50 438 656 1397
# X $1covtypeNorm.arff LBag 50 41 47 107
# X $1covtypeNorm.arff LBag 50 207 237 537
# X $1covtypeNorm.arff LBag 50 373 427 967
# X $1covtypeNorm.arff SRP 50 11 21 42
# X $1covtypeNorm.arff SRP 50 59 107 214
# X $1covtypeNorm.arff SRP 50 106 194 386
# X $1covtypeNorm.arff OBagAd 50 88 74 145
# X $1covtypeNorm.arff OBagAd 50 444 370 729
# X $1covtypeNorm.arff OBagAd 50 800 666 1312
# X $1covtypeNorm.arff OBagASHT 50 91 73 158
# X $1covtypeNorm.arff OBagASHT 50 456 369 791
# X $1covtypeNorm.arff OBagASHT 50 821 665 1425
# X $1covtypeNorm.arff OBag 50 108 73 184
# X $1covtypeNorm.arff OBag 50 544 367 924
# X $1covtypeNorm.arff OBag 50 980 661 1664
# X $1kyoto_binary.arff ARF 50 98 160 322
# X $1kyoto_binary.arff ARF 50 493 804 1611
# X $1kyoto_binary.arff ARF 50 887 1447 2901
# X $1kyoto_binary.arff LBag 50 126 154 340
# X $1kyoto_binary.arff LBag 50 634 773 1704
# X $1kyoto_binary.arff LBag 50 1142 1392 3067
# X $1kyoto_binary.arff SRP 50 59 83 115
# X $1kyoto_binary.arff SRP 50 298 415 575
# X $1kyoto_binary.arff SRP 50 536 748 1035
# X $1kyoto_binary.arff OBagAd 50 313 233 622
# X $1kyoto_binary.arff OBagAd 50 1568 1169 3113
# X $1kyoto_binary.arff OBagAd 50 2822 2104 5603
# X $1kyoto_binary.arff OBagASHT 50 345 226 590
# X $1kyoto_binary.arff OBagASHT 50 1727 1130 2953
# X $1kyoto_binary.arff OBagASHT 50 3108 2034 5316
# X $1kyoto_binary.arff OBag 50 363 218 538
# X $1kyoto_binary.arff OBag 50 1816 1090 2694
# X $1kyoto_binary.arff OBag 50 3269 1963 4849
# X $1GMSC.arff ARF 50 92 105 225
# X $1GMSC.arff ARF 50 461 528 1129
# X $1GMSC.arff ARF 50 830 950 2032
# X $1GMSC.arff LBag 50 123 114 325
# X $1GMSC.arff LBag 50 618 570 1628
# X $1GMSC.arff LBag 50 1112 1026 2931
# X $1GMSC.arff SRP 50 53 63 133
# X $1GMSC.arff SRP 50 268 316 667
# X $1GMSC.arff SRP 50 483 570 1201
# X $1GMSC.arff OBagAd 50 305 193 780
# X $1GMSC.arff OBagAd 50 1526 965 3904
# X $1GMSC.arff OBagAd 50 2747 1738 7027
# X $1GMSC.arff OBagASHT 50 448 226 1019
# X $1GMSC.arff OBagASHT 50 2241 1131 5098
# X $1GMSC.arff OBagASHT 50 4035 2036 9177
# X $1GMSC.arff OBag 50 384 188 678
# X $1GMSC.arff OBag 50 1923 942 3390
# X $1GMSC.arff OBag 50 3461 1697 6102
# X $1airlines.arff ARF 50 12 37 46
# X $1airlines.arff ARF 50 64 185 233
# X $1airlines.arff ARF 50 116 334 421
# X $1airlines.arff LBag 50 11 35 39
# X $1airlines.arff LBag 50 58 179 196
# X $1airlines.arff LBag 50 104 323 353
# X $1airlines.arff SRP 50 14 36 44
# X $1airlines.arff SRP 50 72 184 221
# X $1airlines.arff SRP 50 131 331 398
# X $1airlines.arff OBagAd 50 47 57 104
# X $1airlines.arff OBagAd 50 235 285 524
# X $1airlines.arff OBagAd 50 424 513 944
# X $1airlines.arff OBagASHT 50 130 78 305
# X $1airlines.arff OBagASHT 50 654 391 1527
# X $1airlines.arff OBagASHT 50 1178 705 2749
# X $1airlines.arff OBag 50 117 124 283
# X $1airlines.arff OBag 50 586 623 1417
# X $1airlines.arff OBag 50 1055 1122 2551
# X $1elecNormNew.arff ARF 50 55 97 182
# X $1elecNormNew.arff ARF 50 278 486 911
# X $1elecNormNew.arff ARF 50 500 876 1640
# X $1elecNormNew.arff LBag 50 95 113 255
# X $1elecNormNew.arff LBag 50 478 568 1278
# X $1elecNormNew.arff LBag 50 860 1023 2301
# X $1elecNormNew.arff SRP 50 27 54 85
# X $1elecNormNew.arff SRP 50 137 270 427
# X $1elecNormNew.arff SRP 50 248 486 769
# X $1elecNormNew.arff OBagAd 50 213 159 444
# X $1elecNormNew.arff OBagAd 50 1068 797 2222
# X $1elecNormNew.arff OBagAd 50 1924 1435 4000
# X $1elecNormNew.arff OBagASHT 50 239 150 428
# X $1elecNormNew.arff OBagASHT 50 1198 751 2142
# X $1elecNormNew.arff OBagASHT 50 2156 1353 3855
# X $1elecNormNew.arff OBag 50 281 180 510
# X $1elecNormNew.arff OBag 50 1409 903 2554
# X $1elecNormNew.arff OBag 50 2537 1625 4598
#
#
#
# --------------------
# vostro
# esize 100
# bsize 250
# with incremental: False
#
# X $1covtypeNorm.arff ARF 250 0 0 162
# X $1covtypeNorm.arff ARF 250 0 0 813
# X $1covtypeNorm.arff ARF 250 0 0 1463
# X $1covtypeNorm.arff LBag 250 0 0 106
# X $1covtypeNorm.arff LBag 250 0 0 533
# X $1covtypeNorm.arff LBag 250 0 0 961
# X $1covtypeNorm.arff SRP 250 0 0 45
# X $1covtypeNorm.arff SRP 250 0 0 227
# X $1covtypeNorm.arff SRP 250 0 0 409
# X $1covtypeNorm.arff OBagAd 250 0 0 157
# X $1covtypeNorm.arff OBagAd 250 0 0 788
# X $1covtypeNorm.arff OBagAd 250 0 0 1419
# X $1covtypeNorm.arff OBagASHT 250 0 0 156
# X $1covtypeNorm.arff OBagASHT 250 0 0 780
# X $1covtypeNorm.arff OBagASHT 250 0 0 1405
# X $1covtypeNorm.arff OBag 250 0 0 185
# X $1covtypeNorm.arff OBag 250 0 0 927
# X $1covtypeNorm.arff OBag 250 0 0 1668
# X $1kyoto_binary.arff ARF 250 0 0 333
# X $1kyoto_binary.arff ARF 250 0 0 1666
# X $1kyoto_binary.arff ARF 250 0 0 3000
# X $1kyoto_binary.arff LBag 250 0 0 340
# X $1kyoto_binary.arff LBag 250 0 0 1704
# X $1kyoto_binary.arff LBag 250 0 0 3068
# X $1kyoto_binary.arff SRP 250 0 0 117
# X $1kyoto_binary.arff SRP 250 0 0 587
# X $1kyoto_binary.arff SRP 250 0 0 1056
# X $1kyoto_binary.arff OBagAd 250 0 0 671
# X $1kyoto_binary.arff OBagAd 250 0 0 3358
# X $1kyoto_binary.arff OBagAd 250 0 0 6045
# X $1kyoto_binary.arff OBagASHT 250 0 0 732
# X $1kyoto_binary.arff OBagASHT 250 0 0 3663
# X $1kyoto_binary.arff OBagASHT 250 0 0 6594
# X $1kyoto_binary.arff OBag 250 0 0 711
# X $1kyoto_binary.arff OBag 250 0 0 3557
# X $1kyoto_binary.arff OBag 250 0 0 6403
# X $1GMSC.arff ARF 250 0 0 247
# X $1GMSC.arff ARF 250 0 0 1235
# X $1GMSC.arff ARF 250 0 0 2224
# X $1GMSC.arff LBag 250 0 0 324
# X $1GMSC.arff LBag 250 0 0 1623
# X $1GMSC.arff LBag 250 0 0 2921
# X $1GMSC.arff SRP 250 0 0 140
# X $1GMSC.arff SRP 250 0 0 701
# X $1GMSC.arff SRP 250 0 0 1262
# X $1GMSC.arff OBagAd 250 0 0 848
# X $1GMSC.arff OBagAd 250 0 0 4244
# X $1GMSC.arff OBagAd 250 0 0 7639
# X $1GMSC.arff OBagASHT 250 0 0 1236
# X $1GMSC.arff OBagASHT 250 0 0 6182
# X $1GMSC.arff OBagASHT 250 0 0 11128
# X $1GMSC.arff OBag 250 0 0 908
# X $1GMSC.arff OBag 250 0 0 4543
# X $1GMSC.arff OBag 250 0 0 8178
# X $1airlines.arff ARF 250 0 0 50
# X $1airlines.arff ARF 250 0 0 253
# X $1airlines.arff ARF 250 0 0 455
# X $1airlines.arff LBag 250 0 0 54
# X $1airlines.arff LBag 250 0 0 272
# X $1airlines.arff LBag 250 0 0 490
# X $1airlines.arff SRP 250 0 0 47
# X $1airlines.arff SRP 250 0 0 236
# X $1airlines.arff SRP 250 0 0 426
# X $1airlines.arff OBagAd 250 0 0 130
# X $1airlines.arff OBagAd 250 0 0 652
# X $1airlines.arff OBagAd 250 0 0 1174
# X $1airlines.arff OBagASHT 250 0 0 349
# X $1airlines.arff OBagASHT 250 0 0 1745
# X $1airlines.arff OBagASHT 250 0 0 3142
# X $1airlines.arff OBag 250 0 0 312
# X $1airlines.arff OBag 250 0 0 1563
# X $1airlines.arff OBag 250 0 0 2814
# X $1elecNormNew.arff ARF 250 0 0 190
# X $1elecNormNew.arff ARF 250 0 0 951
# X $1elecNormNew.arff ARF 250 0 0 1712
# X $1elecNormNew.arff LBag 250 0 0 279
# X $1elecNormNew.arff LBag 250 0 0 1397
# X $1elecNormNew.arff LBag 250 0 0 2516
# X $1elecNormNew.arff SRP 250 0 0 92
# X $1elecNormNew.arff SRP 250 0 0 464
# X $1elecNormNew.arff SRP 250 0 0 835
# X $1elecNormNew.arff OBagAd 250 0 0 515
# X $1elecNormNew.arff OBagAd 250 0 0 2576
# X $1elecNormNew.arff OBagAd 250 0 0 4637
# X $1elecNormNew.arff OBagASHT 250 0 0 515
# X $1elecNormNew.arff OBagASHT 250 0 0 2578
# X $1elecNormNew.arff OBagASHT 250 0 0 4642
# X $1elecNormNew.arff OBag 250 0 0 590
# X $1elecNormNew.arff OBag 250 0 0 2951
# X $1elecNormNew.arff OBag 250 0 0 5313
#
#
#
# --------------------
# vostro
# esize 100
# bsize 500
# with incremental: False
#
# X $1covtypeNorm.arff ARF 500 0 0 163
# X $1covtypeNorm.arff ARF 500 0 0 819
# X $1covtypeNorm.arff ARF 500 0 0 1475
# X $1covtypeNorm.arff LBag 500 0 0 109
# X $1covtypeNorm.arff LBag 500 0 0 545
# X $1covtypeNorm.arff LBag 500 0 0 981
# X $1covtypeNorm.arff SRP 500 0 0 46
# X $1covtypeNorm.arff SRP 500 0 0 234
# X $1covtypeNorm.arff SRP 500 0 0 422
# X $1covtypeNorm.arff OBagAd 500 0 0 160
# X $1covtypeNorm.arff OBagAd 500 0 0 802
# X $1covtypeNorm.arff OBagAd 500 0 0 1444
# X $1covtypeNorm.arff OBagASHT 500 0 0 146
# X $1covtypeNorm.arff OBagASHT 500 0 0 733
# X $1covtypeNorm.arff OBagASHT 500 0 0 1321
# X $1covtypeNorm.arff OBag 500 0 0 193
# X $1covtypeNorm.arff OBag 500 0 0 967
# X $1covtypeNorm.arff OBag 500 0 0 1742
# X $1kyoto_binary.arff ARF 500 0 0 335
# X $1kyoto_binary.arff ARF 500 0 0 1675
# X $1kyoto_binary.arff ARF 500 0 0 3016
# X $1kyoto_binary.arff LBag 500 0 0 341
# X $1kyoto_binary.arff LBag 500 0 0 1705
# X $1kyoto_binary.arff LBag 500 0 0 3069
# X $1kyoto_binary.arff SRP 500 0 0 119
# X $1kyoto_binary.arff SRP 500 0 0 595
# X $1kyoto_binary.arff SRP 500 0 0 1071
# X $1kyoto_binary.arff OBagAd 500 0 0 674
# X $1kyoto_binary.arff OBagAd 500 0 0 3373
# X $1kyoto_binary.arff OBagAd 500 0 0 6071
# X $1kyoto_binary.arff OBagASHT 500 0 0 738
# X $1kyoto_binary.arff OBagASHT 500 0 0 3693
# X $1kyoto_binary.arff OBagASHT 500 0 0 6647
# X $1kyoto_binary.arff OBag 500 0 0 721
# X $1kyoto_binary.arff OBag 500 0 0 3608
# X $1kyoto_binary.arff OBag 500 0 0 6495
# X $1GMSC.arff ARF 500 0 0 244
# X $1GMSC.arff ARF 500 0 0 1223
# X $1GMSC.arff ARF 500 0 0 2201
# X $1GMSC.arff LBag 500 0 0 335
# X $1GMSC.arff LBag 500 0 0 1679
# X $1GMSC.arff LBag 500 0 0 3022
# X $1GMSC.arff SRP 500 0 0 141
# X $1GMSC.arff SRP 500 0 0 708
# X $1GMSC.arff SRP 500 0 0 1275
# X $1GMSC.arff OBagAd 500 0 0 869
# X $1GMSC.arff OBagAd 500 0 0 4346
# X $1GMSC.arff OBagAd 500 0 0 7823
# X $1GMSC.arff OBagASHT 500 0 0 1290
# X $1GMSC.arff OBagASHT 500 0 0 6451
# X $1GMSC.arff OBagASHT 500 0 0 11611
# X $1GMSC.arff OBag 500 0 0 930
# X $1GMSC.arff OBag 500 0 0 4650
# X $1GMSC.arff OBag 500 0 0 8371
# X $1airlines.arff ARF 500 0 0 53
# X $1airlines.arff ARF 500 0 0 266
# X $1airlines.arff ARF 500 0 0 480
# X $1airlines.arff LBag 500 0 0 22
# X $1airlines.arff LBag 500 0 0 112
# X $1airlines.arff LBag 500 0 0 202
# X $1airlines.arff SRP 500 0 0 49
# X $1airlines.arff SRP 500 0 0 247
# X $1airlines.arff SRP 500 0 0 446
# X $1airlines.arff OBagAd 500 0 0 162
# X $1airlines.arff OBagAd 500 0 0 814
# X $1airlines.arff OBagAd 500 0 0 1466
# X $1airlines.arff OBagASHT 500 0 0 353
# X $1airlines.arff OBagASHT 500 0 0 1769
# X $1airlines.arff OBagASHT 500 0 0 3184
# X $1airlines.arff OBag 500 0 0 325
# X $1airlines.arff OBag 500 0 0 1626
# X $1airlines.arff OBag 500 0 0 2926
# X $1elecNormNew.arff ARF 500 0 0 194
# X $1elecNormNew.arff ARF 500 0 0 972
# X $1elecNormNew.arff ARF 500 0 0 1750
# X $1elecNormNew.arff LBag 500 0 0 289
# X $1elecNormNew.arff LBag 500 0 0 1449
# X $1elecNormNew.arff LBag 500 0 0 2609
# X $1elecNormNew.arff SRP 500 0 0 88
# X $1elecNormNew.arff SRP 500 0 0 440
# X $1elecNormNew.arff SRP 500 0 0 792
# X $1elecNormNew.arff OBagAd 500 0 0 543
# X $1elecNormNew.arff OBagAd 500 0 0 2716
# X $1elecNormNew.arff OBagAd 500 0 0 4890
# X $1elecNormNew.arff OBagASHT 500 0 0 525
# X $1elecNormNew.arff OBagASHT 500 0 0 2628
# X $1elecNormNew.arff OBagASHT 500 0 0 4730
# X $1elecNormNew.arff OBag 500 0 0 611
# X $1elecNormNew.arff OBag 500 0 0 3059
# X $1elecNormNew.arff OBag 500 0 0 5506
#
#
#
# ------------------------------ pi ------------------------------
# --------------------
# pi
# esize 25
# bsize 50
# with incremental: True
#
# X $1airlines.arff ARF 50 7 17 17
# X $1airlines.arff ARF 50 37 85 85
# X $1airlines.arff ARF 50 67 153 154
# X $1airlines.arff LBag 50 5 15 13
# X $1airlines.arff LBag 50 27 76 66
# X $1airlines.arff LBag 50 49 138 119
# X $1airlines.arff SRP 50 7 16 19
# X $1airlines.arff SRP 50 35 82 97
# X $1airlines.arff SRP 50 64 148 175
# X $1airlines.arff OBagAd 50 21 27 47
# X $1airlines.arff OBagAd 50 107 135 239
# X $1airlines.arff OBagAd 50 194 243 430
# X $1airlines.arff OBagASHT 50 26 57 136
# X $1airlines.arff OBagASHT 50 131 287 684
# X $1airlines.arff OBagASHT 50 235 517 1232
# X $1airlines.arff OBag 50 30 105 163
# X $1airlines.arff OBag 50 153 527 817
# X $1airlines.arff OBag 50 276 948 1471
# X $1elecNormNew.arff ARF 50 32 46 86
# X $1elecNormNew.arff ARF 50 160 234 433
# X $1elecNormNew.arff ARF 50 289 421 780
# X $1elecNormNew.arff LBag 50 52 66 128
# X $1elecNormNew.arff LBag 50 263 330 641
# X $1elecNormNew.arff LBag 50 473 594 1154
# X $1elecNormNew.arff SRP 50 16 26 43
# X $1elecNormNew.arff SRP 50 82 133 219
# X $1elecNormNew.arff SRP 50 149 240 395
# X $1elecNormNew.arff OBagAd 50 119 108 225
# X $1elecNormNew.arff OBagAd 50 597 540 1128
# X $1elecNormNew.arff OBagAd 50 1075 973 2031
# X $1elecNormNew.arff OBagASHT 50 156 127 269
# X $1elecNormNew.arff OBagASHT 50 784 638 1346
# X $1elecNormNew.arff OBagASHT 50 1411 1149 2423
# X $1elecNormNew.arff OBag 50 164 129 263
# X $1elecNormNew.arff OBag 50 820 648 1319
# X $1elecNormNew.arff OBag 50 1476 1168 2374
# X $1GMSC.arff ARF 50 54 61 133
# X $1GMSC.arff ARF 50 271 306 669
# X $1GMSC.arff ARF 50 488 551 1205
# X $1GMSC.arff LBag 50 71 84 186
# X $1GMSC.arff LBag 50 359 420 933
# X $1GMSC.arff LBag 50 647 757 1679
# X $1GMSC.arff SRP 50 28 30 70
# X $1GMSC.arff SRP 50 143 154 351
# X $1GMSC.arff SRP 50 258 278 631
# X $1GMSC.arff OBagAd 50 170 169 409
# X $1GMSC.arff OBagAd 50 852 847 2046
# X $1GMSC.arff OBagAd 50 1533 1525 3682
# X $1GMSC.arff OBagASHT 50 224 184 407
# X $1GMSC.arff OBagASHT 50 1121 921 2038
# X $1GMSC.arff OBagASHT 50 2018 1658 3668
# X $1GMSC.arff OBag 50 223 177 385
# X $1GMSC.arff OBag 50 1115 886 1926
# X $1GMSC.arff OBag 50 2008 1594 3467
# X $1covtypeNorm.arff ARF 50 23 36 72
# X $1covtypeNorm.arff ARF 50 117 182 361
# X $1covtypeNorm.arff ARF 50 211 328 650
# X $1covtypeNorm.arff LBag 50 18 26 53
# X $1covtypeNorm.arff LBag 50 90 131 266
# X $1covtypeNorm.arff LBag 50 162 236 479
# X $1covtypeNorm.arff SRP 50 6 11 17
# X $1covtypeNorm.arff SRP 50 32 59 89
# X $1covtypeNorm.arff SRP 50 58 107 160
# X $1covtypeNorm.arff OBagAd 50 34 42 74
# X $1covtypeNorm.arff OBagAd 50 174 213 374
# X $1covtypeNorm.arff OBagAd 50 314 383 673
# X $1covtypeNorm.arff OBagASHT 50 32 44 84
# X $1covtypeNorm.arff OBagASHT 50 162 221 422
# X $1covtypeNorm.arff OBagASHT 50 291 398 760
# X $1covtypeNorm.arff OBag 50 37 44 83
# X $1covtypeNorm.arff OBag 50 187 223 415
# X $1covtypeNorm.arff OBag 50 338 401 748
# X $1kyoto_binary.arff ARF 50 70 96 147
# X $1kyoto_binary.arff ARF 50 354 483 737
# X $1kyoto_binary.arff ARF 50 637 869 1327
# X $1kyoto_binary.arff LBag 50 83 84 224
# X $1kyoto_binary.arff LBag 50 417 421 1122
# X $1kyoto_binary.arff LBag 50 751 758 2019
# X $1kyoto_binary.arff SRP 50 45 39 69
# X $1kyoto_binary.arff SRP 50 228 197 348
# X $1kyoto_binary.arff SRP 50 412 356 627
# X $1kyoto_binary.arff OBagAd 50 188 182 338
# X $1kyoto_binary.arff OBagAd 50 942 914 1690
# X $1kyoto_binary.arff OBagAd 50 1696 1646 3042
# X $1kyoto_binary.arff OBagASHT 50 219 164 367
# X $1kyoto_binary.arff OBagASHT 50 1096 820 1838
# X $1kyoto_binary.arff OBagASHT 50 1974 1477 3309
# X $1kyoto_binary.arff OBag 50 235 156 364
# X $1kyoto_binary.arff OBag 50 1178 782 1821
# X $1kyoto_binary.arff OBag 50 2121 1408 3279
#
#
#
# --------------------
# pi
# esize 25
# bsize 250
# with incremental: False
#
# X $1airlines.arff ARF 250 0 0 20
# X $1airlines.arff ARF 250 0 0 102
# X $1airlines.arff ARF 250 0 0 184
# X $1airlines.arff LBag 250 0 0 17
# X $1airlines.arff LBag 250 0 0 85
# X $1airlines.arff LBag 250 0 0 154
# X $1airlines.arff SRP 250 0 0 21
# X $1airlines.arff SRP 250 0 0 106
# X $1airlines.arff SRP 250 0 0 191
# X $1airlines.arff OBagAd 250 0 0 49
# X $1airlines.arff OBagAd 250 0 0 245
# X $1airlines.arff OBagAd 250 0 0 441
# X $1airlines.arff OBagASHT 250 0 0 154
# X $1airlines.arff OBagASHT 250 0 0 772
# X $1airlines.arff OBagASHT 250 0 0 1390
# X $1airlines.arff OBag 250 0 0 182
# X $1airlines.arff OBag 250 0 0 910
# X $1airlines.arff OBag 250 0 0 1639
# X $1elecNormNew.arff ARF 250 0 0 84
# X $1elecNormNew.arff ARF 250 0 0 424
# X $1elecNormNew.arff ARF 250 0 0 764
# X $1elecNormNew.arff LBag 250 0 0 140
# X $1elecNormNew.arff LBag 250 0 0 701
# X $1elecNormNew.arff LBag 250 0 0 1263
# X $1elecNormNew.arff SRP 250 0 0 42
# X $1elecNormNew.arff SRP 250 0 0 213
# X $1elecNormNew.arff SRP 250 0 0 384
# X $1elecNormNew.arff OBagAd 250 0 0 220
# X $1elecNormNew.arff OBagAd 250 0 0 1101
# X $1elecNormNew.arff OBagAd 250 0 0 1981
# X $1elecNormNew.arff OBagASHT 250 0 0 269
# X $1elecNormNew.arff OBagASHT 250 0 0 1346
# X $1elecNormNew.arff OBagASHT 250 0 0 2423
# X $1elecNormNew.arff OBag 250 0 0 289
# X $1elecNormNew.arff OBag 250 0 0 1449
# X $1elecNormNew.arff OBag 250 0 0 2609
# X $1GMSC.arff ARF 250 0 0 134
# X $1GMSC.arff ARF 250 0 0 673
# X $1GMSC.arff ARF 250 0 0 1212
# X $1GMSC.arff LBag 250 0 0 191
# X $1GMSC.arff LBag 250 0 0 958
# X $1GMSC.arff LBag 250 0 0 1725
# X $1GMSC.arff SRP 250 0 0 78
# X $1GMSC.arff SRP 250 0 0 391
# X $1GMSC.arff SRP 250 0 0 704
# X $1GMSC.arff OBagAd 250 0 0 429
# X $1GMSC.arff OBagAd 250 0 0 2145
# X $1GMSC.arff OBagAd 250 0 0 3862
# X $1GMSC.arff OBagASHT 250 0 0 499
# X $1GMSC.arff OBagASHT 250 0 0 2499
# X $1GMSC.arff OBagASHT 250 0 0 4499
# X $1GMSC.arff OBag 250 0 0 472
# X $1GMSC.arff OBag 250 0 0 2362
# X $1GMSC.arff OBag 250 0 0 4253
# X $1covtypeNorm.arff ARF 250 0 0 78
# X $1covtypeNorm.arff ARF 250 0 0 391
# X $1covtypeNorm.arff ARF 250 0 0 705
# X $1covtypeNorm.arff LBag 250 0 0 63
# X $1covtypeNorm.arff LBag 250 0 0 319
# X $1covtypeNorm.arff LBag 250 0 0 575
# X $1covtypeNorm.arff SRP 250 0 0 19
# X $1covtypeNorm.arff SRP 250 0 0 97
# X $1covtypeNorm.arff SRP 250 0 0 174
# X $1covtypeNorm.arff OBagAd 250 0 0 96
# X $1covtypeNorm.arff OBagAd 250 0 0 482
# X $1covtypeNorm.arff OBagAd 250 0 0 868
# X $1covtypeNorm.arff OBagASHT 250 0 0 98
# X $1covtypeNorm.arff OBagASHT 250 0 0 490
# X $1covtypeNorm.arff OBagASHT 250 0 0 883
# X $1covtypeNorm.arff OBag 250 0 0 102
# X $1covtypeNorm.arff OBag 250 0 0 510
# X $1covtypeNorm.arff OBag 250 0 0 918
# X $1kyoto_binary.arff ARF 250 0 0 136
# X $1kyoto_binary.arff ARF 250 0 0 683
# X $1kyoto_binary.arff ARF 250 0 0 1230
# X $1kyoto_binary.arff LBag 250 0 0 235
# X $1kyoto_binary.arff LBag 250 0 0 1175
# X $1kyoto_binary.arff LBag 250 0 0 2115
# X $1kyoto_binary.arff SRP 250 0 0 68
# X $1kyoto_binary.arff SRP 250 0 0 340
# X $1kyoto_binary.arff SRP 250 0 0 613
# X $1kyoto_binary.arff OBagAd 250 0 0 434
# X $1kyoto_binary.arff OBagAd 250 0 0 2171
# X $1kyoto_binary.arff OBagAd 250 0 0 3908
# X $1kyoto_binary.arff OBagASHT 250 0 0 435
# X $1kyoto_binary.arff OBagASHT 250 0 0 2179
# X $1kyoto_binary.arff OBagASHT 250 0 0 3922
# X $1kyoto_binary.arff OBag 250 0 0 421
# X $1kyoto_binary.arff OBag 250 0 0 2107
# X $1kyoto_binary.arff OBag 250 0 0 3793
#
#
#
# --------------------
# pi
# esize 25
# bsize 500
# with incremental: False
#
# X $1airlines.arff ARF 500 0 0 19
# X $1airlines.arff ARF 500 0 0 96
# X $1airlines.arff ARF 500 0 0 172
# X $1airlines.arff LBag 500 0 0 17
# X $1airlines.arff LBag 500 0 0 86
# X $1airlines.arff LBag 500 0 0 154
# X $1airlines.arff SRP 500 0 0 19
# X $1airlines.arff SRP 500 0 0 99
# X $1airlines.arff SRP 500 0 0 179
# X $1airlines.arff OBagAd 500 0 0 56
# X $1airlines.arff OBagAd 500 0 0 281
# X $1airlines.arff OBagAd 500 0 0 506
# X $1airlines.arff OBagASHT 500 0 0 146
# X $1airlines.arff OBagASHT 500 0 0 731
# X $1airlines.arff OBagASHT 500 0 0 1317
# X $1airlines.arff OBag 500 0 0 175
# X $1airlines.arff OBag 500 0 0 875
# X $1airlines.arff OBag 500 0 0 1575
# X $1elecNormNew.arff ARF 500 0 0 85
# X $1elecNormNew.arff ARF 500 0 0 428
# X $1elecNormNew.arff ARF 500 0 0 770
# X $1elecNormNew.arff LBag 500 0 0 143
# X $1elecNormNew.arff LBag 500 0 0 716
# X $1elecNormNew.arff LBag 500 0 0 1290
# X $1elecNormNew.arff SRP 500 0 0 40
# X $1elecNormNew.arff SRP 500 0 0 203
# X $1elecNormNew.arff SRP 500 0 0 365
# X $1elecNormNew.arff OBagAd 500 0 0 256
# X $1elecNormNew.arff OBagAd 500 0 0 1282
# X $1elecNormNew.arff OBagAd 500 0 0 2308
# X $1elecNormNew.arff OBagASHT 500 0 0 303
# X $1elecNormNew.arff OBagASHT 500 0 0 1515
# X $1elecNormNew.arff OBagASHT 500 0 0 2727
# X $1elecNormNew.arff OBag 500 0 0 309
# X $1elecNormNew.arff OBag 500 0 0 1549
# X $1elecNormNew.arff OBag 500 0 0 2788
# X $1GMSC.arff ARF 500 0 0 140
# X $1GMSC.arff ARF 500 0 0 704
# X $1GMSC.arff ARF 500 0 0 1268
# X $1GMSC.arff LBag 500 0 0 184
# X $1GMSC.arff LBag 500 0 0 922
# X $1GMSC.arff LBag 500 0 0 1661
# X $1GMSC.arff SRP 500 0 0 72
# X $1GMSC.arff SRP 500 0 0 364
# X $1GMSC.arff SRP 500 0 0 655
# X $1GMSC.arff OBagAd 500 0 0 442
# X $1GMSC.arff OBagAd 500 0 0 2211
# X $1GMSC.arff OBagAd 500 0 0 3980
# X $1GMSC.arff OBagASHT 500 0 0 520
# X $1GMSC.arff OBagASHT 500 0 0 2604
# X $1GMSC.arff OBagASHT 500 0 0 4687
# X $1GMSC.arff OBag 500 0 0 485
# X $1GMSC.arff OBag 500 0 0 2425
# X $1GMSC.arff OBag 500 0 0 4365
# X $1covtypeNorm.arff ARF 500 0 0 86
# X $1covtypeNorm.arff ARF 500 0 0 432
# X $1covtypeNorm.arff ARF 500 0 0 777
# X $1covtypeNorm.arff LBag 500 0 0 55
# X $1covtypeNorm.arff LBag 500 0 0 279
# X $1covtypeNorm.arff LBag 500 0 0 503
# X $1covtypeNorm.arff SRP 500 0 0 16
# X $1covtypeNorm.arff SRP 500 0 0 83
# X $1covtypeNorm.arff SRP 500 0 0 149
# X $1covtypeNorm.arff OBagAd 500 0 0 96
# X $1covtypeNorm.arff OBagAd 500 0 0 484
# X $1covtypeNorm.arff OBagAd 500 0 0 872
# X $1covtypeNorm.arff OBagASHT 500 0 0 101
# X $1covtypeNorm.arff OBagASHT 500 0 0 508
# X $1covtypeNorm.arff OBagASHT 500 0 0 915
# X $1covtypeNorm.arff OBag 500 0 0 103
# X $1covtypeNorm.arff OBag 500 0 0 515
# X $1covtypeNorm.arff OBag 500 0 0 928
# X $1kyoto_binary.arff ARF 500 0 0 159
# X $1kyoto_binary.arff ARF 500 0 0 799
# X $1kyoto_binary.arff ARF 500 0 0 1439
# X $1kyoto_binary.arff LBag 500 0 0 211
# X $1kyoto_binary.arff LBag 500 0 0 1059
# X $1kyoto_binary.arff LBag 500 0 0 1906
# X $1kyoto_binary.arff SRP 500 0 0 74
# X $1kyoto_binary.arff SRP 500 0 0 373
# X $1kyoto_binary.arff SRP 500 0 0 673
# X $1kyoto_binary.arff OBagAd 500 0 0 445
# X $1kyoto_binary.arff OBagAd 500 0 0 2227
# X $1kyoto_binary.arff OBagAd 500 0 0 4009
# X $1kyoto_binary.arff OBagASHT 500 0 0 455
# X $1kyoto_binary.arff OBagASHT 500 0 0 2279
# X $1kyoto_binary.arff OBagASHT 500 0 0 4102
# X $1kyoto_binary.arff OBag 500 0 0 437
# X $1kyoto_binary.arff OBag 500 0 0 2187
# X $1kyoto_binary.arff OBag 500 0 0 3936
#
#
#
# ------------------------------ xeon ------------------------------
# --------------------
# xeon
# esize 100
# bsize 50
# with incremental: True
#
# X $1kyoto_binary.arff ARF 50 106 91 320
# X $1kyoto_binary.arff ARF 50 530 457 1600
# X $1kyoto_binary.arff ARF 50 954 823 2881
# X $1kyoto_binary.arff LBag 50 134 85 325
# X $1kyoto_binary.arff LBag 50 673 425 1628
# X $1kyoto_binary.arff LBag 50 1213 765 2930
# X $1kyoto_binary.arff SRP 50 65 60 169
# X $1kyoto_binary.arff SRP 50 326 301 849
# X $1kyoto_binary.arff SRP 50 587 542 1528
# X $1kyoto_binary.arff OBagAd 50 340 103 438
# X $1kyoto_binary.arff OBagAd 50 1700 519 2191
# X $1kyoto_binary.arff OBagAd 50 3060 935 3944
# X $1kyoto_binary.arff OBagASHT 50 396 111 452
# X $1kyoto_binary.arff OBagASHT 50 1980 558 2264
# X $1kyoto_binary.arff OBagASHT 50 3564 1005 4076
# X $1kyoto_binary.arff OBag 50 353 106 374
# X $1kyoto_binary.arff OBag 50 1765 530 1870
# X $1kyoto_binary.arff OBag 50 3177 955 3366
# X $1airlines.arff ARF 50 17 26 62
# X $1airlines.arff ARF 50 89 133 311
# X $1airlines.arff ARF 50 161 240 560
# X $1airlines.arff LBag 50 16 38 90
# X $1airlines.arff LBag 50 81 191 451
# X $1airlines.arff LBag 50 146 344 813
# X $1airlines.arff SRP 50 16 26 66
# X $1airlines.arff SRP 50 82 130 333
# X $1airlines.arff SRP 50 148 234 600
# X $1airlines.arff OBagAd 50 51 39 144
# X $1airlines.arff OBagAd 50 257 197 723
# X $1airlines.arff OBagAd 50 462 354 1302
# X $1airlines.arff OBagASHT 50 117 37 221
# X $1airlines.arff OBagASHT 50 589 185 1109
# X $1airlines.arff OBagASHT 50 1060 333 1997
# X $1airlines.arff OBag 50 170 71 212
# X $1airlines.arff OBag 50 850 357 1063
# X $1airlines.arff OBag 50 1530 643 1913
# X $1elecNormNew.arff ARF 50 54 55 198
# X $1elecNormNew.arff ARF 50 271 278 994
# X $1elecNormNew.arff ARF 50 489 501 1789
# X $1elecNormNew.arff LBag 50 96 62 234
# X $1elecNormNew.arff LBag 50 483 314 1173
# X $1elecNormNew.arff LBag 50 869 566 2112
# X $1elecNormNew.arff SRP 50 27 33 114
# X $1elecNormNew.arff SRP 50 138 165 574
# X $1elecNormNew.arff SRP 50 249 297 1034
# X $1elecNormNew.arff OBagAd 50 234 85 342
# X $1elecNormNew.arff OBagAd 50 1174 428 1713
# X $1elecNormNew.arff OBagAd 50 2113 770 3083
# X $1elecNormNew.arff OBagASHT 50 252 85 349
# X $1elecNormNew.arff OBagASHT 50 1263 427 1745
# X $1elecNormNew.arff OBagASHT 50 2274 768 3141
# X $1elecNormNew.arff OBag 50 293 105 365
# X $1elecNormNew.arff OBag 50 1465 528 1826
# X $1elecNormNew.arff OBag 50 2637 951 3287
# X $1GMSC.arff ARF 50 85 55 179
# X $1GMSC.arff ARF 50 426 276 898
# X $1GMSC.arff ARF 50 767 498 1617
# X $1GMSC.arff LBag 50 110 64 253
# X $1GMSC.arff LBag 50 550 322 1269
# X $1GMSC.arff LBag 50 991 580 2285
# X $1GMSC.arff SRP 50 48 35 121
# X $1GMSC.arff SRP 50 244 176 608
# X $1GMSC.arff SRP 50 440 317 1094
# X $1GMSC.arff OBagAd 50 302 111 514
# X $1GMSC.arff OBagAd 50 1510 559 2570
# X $1GMSC.arff OBagAd 50 2719 1006 4627
# X $1GMSC.arff OBagASHT 50 487 122 666
# X $1GMSC.arff OBagASHT 50 2435 613 3330
# X $1GMSC.arff OBagASHT 50 4383 1104 5995
# X $1GMSC.arff OBag 50 361 113 411
# X $1GMSC.arff OBag 50 1807 567 2059
# X $1GMSC.arff OBag 50 3253 1020 3707
# X $1covtypeNorm.arff ARF 50 45 42 158
# X $1covtypeNorm.arff ARF 50 228 211 791
# X $1covtypeNorm.arff ARF 50 411 381 1424
# X $1covtypeNorm.arff LBag 50 37 29 112
# X $1covtypeNorm.arff LBag 50 189 147 560
# X $1covtypeNorm.arff LBag 50 340 265 1008
# X $1covtypeNorm.arff SRP 50 14 13 68
# X $1covtypeNorm.arff SRP 50 70 66 340
# X $1covtypeNorm.arff SRP 50 126 119 612
# X $1covtypeNorm.arff OBagAd 50 76 37 124
# X $1covtypeNorm.arff OBagAd 50 381 186 624
# X $1covtypeNorm.arff OBagAd 50 686 336 1124
# X $1covtypeNorm.arff OBagASHT 50 85 38 121
# X $1covtypeNorm.arff OBagASHT 50 427 193 609
# X $1covtypeNorm.arff OBagASHT 50 769 349 1097
# X $1covtypeNorm.arff OBag 50 102 39 124
# X $1covtypeNorm.arff OBag 50 510 199 620
# X $1covtypeNorm.arff OBag 50 918 358 1116
#
#
#
# --------------------
# xeon
# esize 100
# bsize 250
# with incremental: False
#
# X $1kyoto_binary.arff ARF 250 0 0 474
# X $1kyoto_binary.arff ARF 250 0 0 2372
# X $1kyoto_binary.arff ARF 250 0 0 4271
# X $1kyoto_binary.arff LBag 250 0 0 434
# X $1kyoto_binary.arff LBag 250 0 0 2171
# X $1kyoto_binary.arff LBag 250 0 0 3909
# X $1kyoto_binary.arff SRP 250 0 0 260
# X $1kyoto_binary.arff SRP 250 0 0 1303
# X $1kyoto_binary.arff SRP 250 0 0 2346
# X $1kyoto_binary.arff OBagAd 250 0 0 636
# X $1kyoto_binary.arff OBagAd 250 0 0 3180
# X $1kyoto_binary.arff OBagAd 250 0 0 5724
# X $1kyoto_binary.arff OBagASHT 250 0 0 716
# X $1kyoto_binary.arff OBagASHT 250 0 0 3583
# X $1kyoto_binary.arff OBagASHT 250 0 0 6449
# X $1kyoto_binary.arff OBag 250 0 0 541
# X $1kyoto_binary.arff OBag 250 0 0 2705
# X $1kyoto_binary.arff OBag 250 0 0 4870
# X $1airlines.arff ARF 250 0 0 103
# X $1airlines.arff ARF 250 0 0 517
# X $1airlines.arff ARF 250 0 0 932
# X $1airlines.arff LBag 250 0 0 135
# X $1airlines.arff LBag 250 0 0 679
# X $1airlines.arff LBag 250 0 0 1223
# X $1airlines.arff SRP 250 0 0 91
# X $1airlines.arff SRP 250 0 0 459
# X $1airlines.arff SRP 250 0 0 827
# X $1airlines.arff OBagAd 250 0 0 219
# X $1airlines.arff OBagAd 250 0 0 1098
# X $1airlines.arff OBagAd 250 0 0 1977
# X $1airlines.arff OBagASHT 250 0 0 361
# X $1airlines.arff OBagASHT 250 0 0 1808
# X $1airlines.arff OBagASHT 250 0 0 3254
# X $1airlines.arff OBag 250 0 0 274
# X $1airlines.arff OBag 250 0 0 1374
# X $1airlines.arff OBag 250 0 0 2474
# X $1elecNormNew.arff ARF 250 0 0 298
# X $1elecNormNew.arff ARF 250 0 0 1490
# X $1elecNormNew.arff ARF 250 0 0 2683
# X $1elecNormNew.arff LBag 250 0 0 401
# X $1elecNormNew.arff LBag 250 0 0 2006
# X $1elecNormNew.arff LBag 250 0 0 3611
# X $1elecNormNew.arff SRP 250 0 0 161
# X $1elecNormNew.arff SRP 250 0 0 808
# X $1elecNormNew.arff SRP 250 0 0 1454
# X $1elecNormNew.arff OBagAd 250 0 0 501
# X $1elecNormNew.arff OBagAd 250 0 0 2505
# X $1elecNormNew.arff OBagAd 250 0 0 4509
# X $1elecNormNew.arff OBagASHT 250 0 0 536
# X $1elecNormNew.arff OBagASHT 250 0 0 2683
# X $1elecNormNew.arff OBagASHT 250 0 0 4830
# X $1elecNormNew.arff OBag 250 0 0 557
# X $1elecNormNew.arff OBag 250 0 0 2789
# X $1elecNormNew.arff OBag 250 0 0 5020
# X $1GMSC.arff ARF 250 0 0 251
# X $1GMSC.arff ARF 250 0 0 1258
# X $1GMSC.arff ARF 250 0 0 2264
# X $1GMSC.arff LBag 250 0 0 360
# X $1GMSC.arff LBag 250 0 0 1801
# X $1GMSC.arff LBag 250 0 0 3243
# X $1GMSC.arff SRP 250 0 0 160
# X $1GMSC.arff SRP 250 0 0 803
# X $1GMSC.arff SRP 250 0 0 1446
# X $1GMSC.arff OBagAd 250 0 0 715
# X $1GMSC.arff OBagAd 250 0 0 3577
# X $1GMSC.arff OBagAd 250 0 0 6439
# X $1GMSC.arff OBagASHT 250 0 0 1035
# X $1GMSC.arff OBagASHT 250 0 0 5179
# X $1GMSC.arff OBagASHT 250 0 0 9322
# X $1GMSC.arff OBag 250 0 0 625
# X $1GMSC.arff OBag 250 0 0 3129
# X $1GMSC.arff OBag 250 0 0 5632
# X $1covtypeNorm.arff ARF 250 0 0 263
# X $1covtypeNorm.arff ARF 250 0 0 1319
# X $1covtypeNorm.arff ARF 250 0 0 2374
# X $1covtypeNorm.arff LBag 250 0 0 142
# X $1covtypeNorm.arff LBag 250 0 0 713
# X $1covtypeNorm.arff LBag 250 0 0 1284
# X $1covtypeNorm.arff SRP 250 0 0 82
# X $1covtypeNorm.arff SRP 250 0 0 411
# X $1covtypeNorm.arff SRP 250 0 0 740
# X $1covtypeNorm.arff OBagAd 250 0 0 169
# X $1covtypeNorm.arff OBagAd 250 0 0 845
# X $1covtypeNorm.arff OBagAd 250 0 0 1521
# X $1covtypeNorm.arff OBagASHT 250 0 0 150
# X $1covtypeNorm.arff OBagASHT 250 0 0 750
# X $1covtypeNorm.arff OBagASHT 250 0 0 1350
# X $1covtypeNorm.arff OBag 250 0 0 172
# X $1covtypeNorm.arff OBag 250 0 0 863
# X $1covtypeNorm.arff OBag 250 0 0 1555
#
#
#
# --------------------
# xeon
# esize 100
# bsize 500
# with incremental: False
#
# X $1kyoto_binary.arff ARF 500 0 0 565
# X $1kyoto_binary.arff ARF 500 0 0 2827
# X $1kyoto_binary.arff ARF 500 0 0 5088
# X $1kyoto_binary.arff LBag 500 0 0 466
# X $1kyoto_binary.arff LBag 500 0 0 2333
# X $1kyoto_binary.arff LBag 500 0 0 4200
# X $1kyoto_binary.arff SRP 500 0 0 279
# X $1kyoto_binary.arff SRP 500 0 0 1398
# X $1kyoto_binary.arff SRP 500 0 0 2517
# X $1kyoto_binary.arff OBagAd 500 0 0 698
# X $1kyoto_binary.arff OBagAd 500 0 0 3490
# X $1kyoto_binary.arff OBagAd 500 0 0 6282
# X $1kyoto_binary.arff OBagASHT 500 0 0 807
# X $1kyoto_binary.arff OBagASHT 500 0 0 4039
# X $1kyoto_binary.arff OBagASHT 500 0 0 7271
# X $1kyoto_binary.arff OBag 500 0 0 635
# X $1kyoto_binary.arff OBag 500 0 0 3178
# X $1kyoto_binary.arff OBag 500 0 0 5721
# X $1airlines.arff ARF 500 0 0 124
# X $1airlines.arff ARF 500 0 0 620
# X $1airlines.arff ARF 500 0 0 1116
# X $1airlines.arff LBag 500 0 0 171
# X $1airlines.arff LBag 500 0 0 855
# X $1airlines.arff LBag 500 0 0 1539
# X $1airlines.arff SRP 500 0 0 100
# X $1airlines.arff SRP 500 0 0 504
# X $1airlines.arff SRP 500 0 0 908
# X $1airlines.arff OBagAd 500 0 0 242
# X $1airlines.arff OBagAd 500 0 0 1212
# X $1airlines.arff OBagAd 500 0 0 2181
# X $1airlines.arff OBagASHT 500 0 0 406
# X $1airlines.arff OBagASHT 500 0 0 2032
# X $1airlines.arff OBagASHT 500 0 0 3658
# X $1airlines.arff OBag 500 0 0 321
# X $1airlines.arff OBag 500 0 0 1608
# X $1airlines.arff OBag 500 0 0 2894
# X $1elecNormNew.arff ARF 500 0 0 333
# X $1elecNormNew.arff ARF 500 0 0 1667
# X $1elecNormNew.arff ARF 500 0 0 3002
# X $1elecNormNew.arff LBag 500 0 0 427
# X $1elecNormNew.arff LBag 500 0 0 2139
# X $1elecNormNew.arff LBag 500 0 0 3850
# X $1elecNormNew.arff SRP 500 0 0 164
# X $1elecNormNew.arff SRP 500 0 0 820
# X $1elecNormNew.arff SRP 500 0 0 1477
# X $1elecNormNew.arff OBagAd 500 0 0 662
# X $1elecNormNew.arff OBagAd 500 0 0 3314
# X $1elecNormNew.arff OBagAd 500 0 0 5966
# X $1elecNormNew.arff OBagASHT 500 0 0 603
# X $1elecNormNew.arff OBagASHT 500 0 0 3016
# X $1elecNormNew.arff OBagASHT 500 0 0 5429
# X $1elecNormNew.arff OBag 500 0 0 629
# X $1elecNormNew.arff OBag 500 0 0 3145
# X $1elecNormNew.arff OBag 500 0 0 5661
# X $1GMSC.arff ARF 500 0 0 282
# X $1GMSC.arff ARF 500 0 0 1414
# X $1GMSC.arff ARF 500 0 0 2545
# X $1GMSC.arff LBag 500 0 0 370
# X $1GMSC.arff LBag 500 0 0 1853
# X $1GMSC.arff LBag 500 0 0 3336
# X $1GMSC.arff SRP 500 0 0 176
# X $1GMSC.arff SRP 500 0 0 880
# X $1GMSC.arff SRP 500 0 0 1585
# X $1GMSC.arff OBagAd 500 0 0 777
# X $1GMSC.arff OBagAd 500 0 0 3889
# X $1GMSC.arff OBagAd 500 0 0 7001
# X $1GMSC.arff OBagASHT 500 0 0 1268
# X $1GMSC.arff OBagASHT 500 0 0 6344
# X $1GMSC.arff OBagASHT 500 0 0 11419
# X $1GMSC.arff OBag 500 0 0 734
# X $1GMSC.arff OBag 500 0 0 3673
# X $1GMSC.arff OBag 500 0 0 6611
# X $1covtypeNorm.arff ARF 500 0 0 284
# X $1covtypeNorm.arff ARF 500 0 0 1420
# X $1covtypeNorm.arff ARF 500 0 0 2556
# X $1covtypeNorm.arff LBag 500 0 0 145
# X $1covtypeNorm.arff LBag 500 0 0 727
# X $1covtypeNorm.arff LBag 500 0 0 1309
# X $1covtypeNorm.arff SRP 500 0 0 85
# X $1covtypeNorm.arff SRP 500 0 0 425
# X $1covtypeNorm.arff SRP 500 0 0 766
# X $1covtypeNorm.arff OBagAd 500 0 0 179
# X $1covtypeNorm.arff OBagAd 500 0 0 896
# X $1covtypeNorm.arff OBagAd 500 0 0 1614
# X $1covtypeNorm.arff OBagASHT 500 0 0 167
# X $1covtypeNorm.arff OBagASHT 500 0 0 836
# X $1covtypeNorm.arff OBagASHT 500 0 0 1505
# X $1covtypeNorm.arff OBag 500 0 0 200
# X $1covtypeNorm.arff OBag 500 0 0 1004
# X $1covtypeNorm.arff OBag 500 0 0 1807
