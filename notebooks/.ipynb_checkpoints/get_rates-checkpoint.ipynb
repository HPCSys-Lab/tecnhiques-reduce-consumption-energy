# %% [markdown]
# # To use this notebook, make sure you cd into the main folder of the cloned repository in the next cell

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# %mkdir -p parsed_csvs figures
# %cd results
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results

# %% [markdown]
# ## Folders inside results directory that contains all the MOA dump files for these experiments
#
# ### Ideally results should be in this hierarchy:
#
#
# ```bash
# ├─ results
# │   ├── Energy
#         ├── pi
#         │   ├── get_rates
#         │   └── socket
#         ├── vostro
#         │   ├── get_rates
#         │   └── socket
#         └── xeon
#             ├── get_rates
#             └── socket
#
# ```

# %% [markdown]
# ## folder variables

# %%
#should probably find automatically...

moaDumpFolders = ["optimized/08-07-2022/results/4/first"]
wantedCSVfilename = ["pi-600x1200-get_rates.csv"]

# %% [markdown]
# ## Calibrating the workload generator based on maximum throughput

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ***
# ## Parsing preliminary results to find maximum rate

# %%
def parse_folder_to_file(folder, outfilename):
    directory = os.fsencode(folder)
    header_printed = False
    with open(f"{outfilename}", "w+") as output:
        output.write('dataset,algorithm,ensemble_size,cores,batch_size,rate,instances,time,acc,prec,recall,change\n')
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("dump-"): 
                s = parse(f'{os.fsdecode(directory)}/{filename}')
                output.write(f"{s}\n")

# %%
def parse(fname):
    columns = []
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    pstr = ''
    spname = fname.split('/')[-1].split('-')
    spline = []
    got = False
    for s in spname[1:]:
        pstr += s + ','
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        if 'GMSC' in spname and 'ASHT' in spname[2]:
            for c in columns[:-2]:
                pstr += str(spline[c]) + ','
            pstr += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        else:
            for c in columns:
                pstr += str(spline[c]) + ','
            if len(columns) == 5:
                pstr += '0,'
        return (pstr[:-1])

# %%
def load_df(filename):
    df = pd.read_csv(filename)
    return select_columns_and_rename_values(df)

# %%
def select_columns_and_rename_values(df):
    df = df.loc[:,['dataset', 'algorithm', 'ensemble_size', 'cores', 'batch_size', 'instances', 'time', 'acc']]
    df['algorithm'] = df["algorithm"].str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df["algorithm"].str.replace("ARF$", "ARFSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB+")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    return df

# %%
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %% [markdown]
# ## Finding rate for Socket experiments

# %%
def calculate_rate_bsize(df,desired_esize, desired_bsize, incremental_included=False, rates=[0.1, 0.5, 0.9]):
     algorithms = ['LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
     file_algs = {'LBag': 'LBag', 'SRP': 'SRP', 'OBAdwin': 'OBagAd', 'OBASHT': 'OBagASHT', 'OB': 'OBag'}

    for ds in df.dataset.unique():
        dsdf = df[df.dataset == ds]
        for alg in algorithms:
            s = f'X $1{ds}.arff {file_algs[alg]}'
            adf = filter_by_substring_algorithm(dsdf, alg)
            dfres = adf[adf.ensemble_size == desired_esize]
            #if we are just testing with all versions (sequential, parallel and mini-batch parallel)
            if incremental_included:
                # get sequential
                dfseq = dfres[(dfres.batch_size == 1) & (dfres.cores == 1)]
                # sanity check
                seq_rate = list((dfseq.IPS))[0] if dfseq.size else 0
                # get runper
                dfrunp = dfres[(dfres.batch_size == 1) & (dfres.cores != 1)]
                runper_rate = list(dfrunp.IPS)[0] if dfrunp.size else 0
            # if we are testing only the mini-batch parallel version
            else:
                seq_rate = 0
                runper_rate = 0
            # get Mini-Batch
            dfmb = dfres[(dfres.batch_size == desired_bsize) & (dfres.cores != 1)]
            mb_rate = list(dfmb.IPS)[0] if dfmb.size else 0
            #we have max rates, now we need the parameter rates (default = 10, 50 and 90)
            if mb_rate != 'NaN':
                for load in rates:
                    print(f'{s} {desired_bsize} {int(load*seq_rate)} {int(load*runper_rate)} {int(load*mb_rate)}')
# Out:
#   File <tokenize>:7
#     for ds in df.dataset.unique():
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def calculate_rate_csv(csvFilename, arch, batch_sizes=[5,15,25,50,75,100,250,500,2000], incre=True):
    df = load_df(csvFilename)
    df['IPS'] = df['instances'] / df['time']
    incre = True
    esize = df.ensemble_size.unique()[0]
    for bsize in batch_sizes:
        print(f"--------------------\n{arch}\nesize {esize}\nbsize {bsize}\nwith incremental: {incre}\n")
        calculate_rate_bsize(df,esize, bsize, incre)
        incre = True
        print("\n\n")

# %% [markdown]
# ### MAIN PORTION
#
# - This `for` iterates through all files on the lists defined in the beginning
# - Then, it parses the folders in the respective `moaDumpFolder` and creates the csv
# - Finally, it calculates and prints the correct workloads to paste on the scripts that will execute the energy experiments
# - Outputs are identified with architecture, ensemble size, batch size and a boolean indicating if only the mini-batch rate was printed or the incremental rates are printed too
# - You have to **copy all outputs from a given architecture and paste at the end of the script that runs the experiments**

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

for i in range(len(moaDumpFolders)):
    architecture=moaDumpFolders[i].split('/')[0]
    print(f"------------------------------ {architecture} ------------------------------ ")
    parse_folder_to_file(f"results/{moaDumpFolders[i]}", f"parsed_csvs/{wantedCSVfilename[i]}")
    calculate_rate_csv(f'parsed_csvs/{wantedCSVfilename[i]}', architecture)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# ------------------------------ optimized ------------------------------
# --------------------
# optimized
# esize 25
# bsize 5
# with incremental: True
#
# X $1elecNormNew.arff ARF 5 31 47 73
# X $1elecNormNew.arff ARF 5 156 236 365
# X $1elecNormNew.arff ARF 5 281 426 657
# X $1elecNormNew.arff OBag 5 164 134 306
# X $1elecNormNew.arff OBag 5 821 670 1531
# X $1elecNormNew.arff OBag 5 1478 1206 2757
# X $1covtypeNorm.arff ARF 5 20 37 70
# X $1covtypeNorm.arff ARF 5 104 189 352
# X $1covtypeNorm.arff ARF 5 187 341 634
# X $1covtypeNorm.arff OBag 5 30 40 231
# X $1covtypeNorm.arff OBag 5 150 202 1159
# X $1covtypeNorm.arff OBag 5 270 363 2087
# X $1airlines.arff ARF 5 6 17 20
# X $1airlines.arff ARF 5 33 85 102
# X $1airlines.arff ARF 5 60 154 184
# X $1airlines.arff OBag 5 16 101 367
# X $1airlines.arff OBag 5 84 506 1837
# X $1airlines.arff OBag 5 152 911 3306
# X $1GMSC.arff ARF 5 54 63 129
# X $1GMSC.arff ARF 5 270 319 646
# X $1GMSC.arff ARF 5 486 575 1164
# X $1GMSC.arff OBag 5 224 179 521
# X $1GMSC.arff OBag 5 1123 898 2605
# X $1GMSC.arff OBag 5 2022 1616 4690
#
#
#
# --------------------
# optimized
# esize 25
# bsize 15
# with incremental: True
#
# X $1elecNormNew.arff ARF 15 31 47 83
# X $1elecNormNew.arff ARF 15 156 236 419
# X $1elecNormNew.arff ARF 15 281 426 754
# X $1elecNormNew.arff OBag 15 164 134 382
# X $1elecNormNew.arff OBag 15 821 670 1911
# X $1elecNormNew.arff OBag 15 1478 1206 3440
# X $1covtypeNorm.arff ARF 15 20 37 91
# X $1covtypeNorm.arff ARF 15 104 189 456
# X $1covtypeNorm.arff ARF 15 187 341 821
# X $1covtypeNorm.arff OBag 15 30 40 259
# X $1covtypeNorm.arff OBag 15 150 202 1298
# X $1covtypeNorm.arff OBag 15 270 363 2337
# X $1airlines.arff ARF 15 6 17 21
# X $1airlines.arff ARF 15 33 85 108
# X $1airlines.arff ARF 15 60 154 195
# X $1airlines.arff OBag 15 16 101 432
# X $1airlines.arff OBag 15 84 506 2163
# X $1airlines.arff OBag 15 152 911 3894
# X $1GMSC.arff ARF 15 54 63 156
# X $1GMSC.arff ARF 15 270 319 783
# X $1GMSC.arff ARF 15 486 575 1409
# X $1GMSC.arff OBag 15 224 179 594
# X $1GMSC.arff OBag 15 1123 898 2973
# X $1GMSC.arff OBag 15 2022 1616 5352
#
#
#
# --------------------
# optimized
# esize 25
# bsize 25
# with incremental: True
#
# X $1elecNormNew.arff ARF 25 31 47 86
# X $1elecNormNew.arff ARF 25 156 236 432
# X $1elecNormNew.arff ARF 25 281 426 778
# X $1elecNormNew.arff OBag 25 164 134 395
# X $1elecNormNew.arff OBag 25 821 670 1976
# X $1elecNormNew.arff OBag 25 1478 1206 3558
# X $1covtypeNorm.arff ARF 25 20 37 83
# X $1covtypeNorm.arff ARF 25 104 189 418
# X $1covtypeNorm.arff ARF 25 187 341 753
# X $1covtypeNorm.arff OBag 25 30 40 275
# X $1covtypeNorm.arff OBag 25 150 202 1378
# X $1covtypeNorm.arff OBag 25 270 363 2480
# X $1airlines.arff ARF 25 6 17 22
# X $1airlines.arff ARF 25 33 85 110
# X $1airlines.arff ARF 25 60 154 198
# X $1airlines.arff OBag 25 16 101 479
# X $1airlines.arff OBag 25 84 506 2395
# X $1airlines.arff OBag 25 152 911 4311
# X $1GMSC.arff ARF 25 54 63 157
# X $1GMSC.arff ARF 25 270 319 785
# X $1GMSC.arff ARF 25 486 575 1414
# X $1GMSC.arff OBag 25 224 179 640
# X $1GMSC.arff OBag 25 1123 898 3201
# X $1GMSC.arff OBag 25 2022 1616 5762
#
#
#
# --------------------
# optimized
# esize 25
# bsize 50
# with incremental: True
#
# X $1elecNormNew.arff ARF 50 31 47 92
# X $1elecNormNew.arff ARF 50 156 236 460
# X $1elecNormNew.arff ARF 50 281 426 828
# X $1elecNormNew.arff OBag 50 164 134 421
# X $1elecNormNew.arff OBag 50 821 670 2106
# X $1elecNormNew.arff OBag 50 1478 1206 3791
# X $1covtypeNorm.arff ARF 50 20 37 94
# X $1covtypeNorm.arff ARF 50 104 189 474
# X $1covtypeNorm.arff ARF 50 187 341 853
# X $1covtypeNorm.arff OBag 50 30 40 295
# X $1covtypeNorm.arff OBag 50 150 202 1479
# X $1covtypeNorm.arff OBag 50 270 363 2663
# X $1airlines.arff ARF 50 6 17 22
# X $1airlines.arff ARF 50 33 85 112
# X $1airlines.arff ARF 50 60 154 203
# X $1airlines.arff OBag 50 16 101 526
# X $1airlines.arff OBag 50 84 506 2630
# X $1airlines.arff OBag 50 152 911 4735
# X $1GMSC.arff ARF 50 54 63 149
# X $1GMSC.arff ARF 50 270 319 748
# X $1GMSC.arff ARF 50 486 575 1347
# X $1GMSC.arff OBag 50 224 179 700
# X $1GMSC.arff OBag 50 1123 898 3502
# X $1GMSC.arff OBag 50 2022 1616 6304
#
#
#
# --------------------
# optimized
# esize 25
# bsize 75
# with incremental: True
#
# X $1elecNormNew.arff ARF 75 31 47 93
# X $1elecNormNew.arff ARF 75 156 236 466
# X $1elecNormNew.arff ARF 75 281 426 840
# X $1elecNormNew.arff OBag 75 164 134 422
# X $1elecNormNew.arff OBag 75 821 670 2111
# X $1elecNormNew.arff OBag 75 1478 1206 3800
# X $1covtypeNorm.arff ARF 75 20 37 88
# X $1covtypeNorm.arff ARF 75 104 189 443
# X $1covtypeNorm.arff ARF 75 187 341 798
# X $1covtypeNorm.arff OBag 75 30 40 316
# X $1covtypeNorm.arff OBag 75 150 202 1581
# X $1covtypeNorm.arff OBag 75 270 363 2846
# X $1airlines.arff ARF 75 6 17 23
# X $1airlines.arff ARF 75 33 85 116
# X $1airlines.arff ARF 75 60 154 210
# X $1airlines.arff OBag 75 16 101 567
# X $1airlines.arff OBag 75 84 506 2836
# X $1airlines.arff OBag 75 152 911 5106
# X $1GMSC.arff ARF 75 54 63 158
# X $1GMSC.arff ARF 75 270 319 794
# X $1GMSC.arff ARF 75 486 575 1429
# X $1GMSC.arff OBag 75 224 179 747
# X $1GMSC.arff OBag 75 1123 898 3737
# X $1GMSC.arff OBag 75 2022 1616 6727
#
#
#
# --------------------
# optimized
# esize 25
# bsize 100
# with incremental: True
#
# X $1elecNormNew.arff ARF 100 31 47 91
# X $1elecNormNew.arff ARF 100 156 236 459
# X $1elecNormNew.arff ARF 100 281 426 827
# X $1elecNormNew.arff OBag 100 164 134 458
# X $1elecNormNew.arff OBag 100 821 670 2294
# X $1elecNormNew.arff OBag 100 1478 1206 4130
# X $1covtypeNorm.arff ARF 100 20 37 87
# X $1covtypeNorm.arff ARF 100 104 189 435
# X $1covtypeNorm.arff ARF 100 187 341 784
# X $1covtypeNorm.arff OBag 100 30 40 321
# X $1covtypeNorm.arff OBag 100 150 202 1607
# X $1covtypeNorm.arff OBag 100 270 363 2893
# X $1airlines.arff ARF 100 6 17 23
# X $1airlines.arff ARF 100 33 85 117
# X $1airlines.arff ARF 100 60 154 211
# X $1airlines.arff OBag 100 16 101 569
# X $1airlines.arff OBag 100 84 506 2845
# X $1airlines.arff OBag 100 152 911 5121
# X $1GMSC.arff ARF 100 54 63 155
# X $1GMSC.arff ARF 100 270 319 775
# X $1GMSC.arff ARF 100 486 575 1396
# X $1GMSC.arff OBag 100 224 179 763
# X $1GMSC.arff OBag 100 1123 898 3819
# X $1GMSC.arff OBag 100 2022 1616 6875
#
#
#
# --------------------
# optimized
# esize 25
# bsize 250
# with incremental: True
#
# X $1elecNormNew.arff ARF 250 31 47 95
# X $1elecNormNew.arff ARF 250 156 236 478
# X $1elecNormNew.arff ARF 250 281 426 861
# X $1elecNormNew.arff OBag 250 164 134 476
# X $1elecNormNew.arff OBag 250 821 670 2383
# X $1elecNormNew.arff OBag 250 1478 1206 4290
# X $1covtypeNorm.arff ARF 250 20 37 97
# X $1covtypeNorm.arff ARF 250 104 189 485
# X $1covtypeNorm.arff ARF 250 187 341 873
# X $1covtypeNorm.arff OBag 250 30 40 361
# X $1covtypeNorm.arff OBag 250 150 202 1805
# X $1covtypeNorm.arff OBag 250 270 363 3250
# X $1airlines.arff ARF 250 6 17 25
# X $1airlines.arff ARF 250 33 85 128
# X $1airlines.arff ARF 250 60 154 230
# X $1airlines.arff OBag 250 16 101 605
# X $1airlines.arff OBag 250 84 506 3025
# X $1airlines.arff OBag 250 152 911 5446
# X $1GMSC.arff ARF 250 54 63 159
# X $1GMSC.arff ARF 250 270 319 797
# X $1GMSC.arff ARF 250 486 575 1436
# X $1GMSC.arff OBag 250 224 179 843
# X $1GMSC.arff OBag 250 1123 898 4219
# X $1GMSC.arff OBag 250 2022 1616 7594
#
#
#
# --------------------
# optimized
# esize 25
# bsize 500
# with incremental: True
#
# X $1elecNormNew.arff ARF 500 31 47 95
# X $1elecNormNew.arff ARF 500 156 236 476
# X $1elecNormNew.arff ARF 500 281 426 857
# X $1elecNormNew.arff OBag 500 164 134 476
# X $1elecNormNew.arff OBag 500 821 670 2381
# X $1elecNormNew.arff OBag 500 1478 1206 4286
# X $1covtypeNorm.arff ARF 500 20 37 97
# X $1covtypeNorm.arff ARF 500 104 189 487
# X $1covtypeNorm.arff ARF 500 187 341 877
# X $1covtypeNorm.arff OBag 500 30 40 363
# X $1covtypeNorm.arff OBag 500 150 202 1816
# X $1covtypeNorm.arff OBag 500 270 363 3270
# X $1airlines.arff ARF 500 6 17 27
# X $1airlines.arff ARF 500 33 85 136
# X $1airlines.arff ARF 500 60 154 245
# X $1airlines.arff OBag 500 16 101 619
# X $1airlines.arff OBag 500 84 506 3095
# X $1airlines.arff OBag 500 152 911 5571
# X $1GMSC.arff ARF 500 54 63 160
# X $1GMSC.arff ARF 500 270 319 802
# X $1GMSC.arff ARF 500 486 575 1444
# X $1GMSC.arff OBag 500 224 179 876
# X $1GMSC.arff OBag 500 1123 898 4380
# X $1GMSC.arff OBag 500 2022 1616 7885
#
#
#
# --------------------
# optimized
# esize 25
# bsize 2000
# with incremental: True
#
# X $1elecNormNew.arff ARF 2000 31 47 90
# X $1elecNormNew.arff ARF 2000 156 236 452
# X $1elecNormNew.arff ARF 2000 281 426 814
# X $1elecNormNew.arff OBag 2000 164 134 448
# X $1elecNormNew.arff OBag 2000 821 670 2241
# X $1elecNormNew.arff OBag 2000 1478 1206 4034
# X $1covtypeNorm.arff ARF 2000 20 37 92
# X $1covtypeNorm.arff ARF 2000 104 189 461
# X $1covtypeNorm.arff ARF 2000 187 341 829
# X $1covtypeNorm.arff OBag 2000 30 40 356
# X $1covtypeNorm.arff OBag 2000 150 202 1781
# X $1covtypeNorm.arff OBag 2000 270 363 3206
# X $1airlines.arff ARF 2000 6 17 28
# X $1airlines.arff ARF 2000 33 85 144
# X $1airlines.arff ARF 2000 60 154 259
# X $1airlines.arff OBag 2000 16 101 621
# X $1airlines.arff OBag 2000 84 506 3107
# X $1airlines.arff OBag 2000 152 911 5592
# X $1GMSC.arff ARF 2000 54 63 159
# X $1GMSC.arff ARF 2000 270 319 795
# X $1GMSC.arff ARF 2000 486 575 1432
# X $1GMSC.arff OBag 2000 224 179 792
# X $1GMSC.arff OBag 2000 1123 898 3961
# X $1GMSC.arff OBag 2000 2022 1616 7131
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_16991/1232116270.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_16991/1232116270.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("ARF$", "ARFSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_16991/1232116270.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_16991/1232116270.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_16991/1232116270.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
