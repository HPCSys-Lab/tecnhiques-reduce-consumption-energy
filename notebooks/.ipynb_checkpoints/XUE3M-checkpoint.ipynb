# %% [markdown]
# # Analisy results to XUE3M tecnhique
#
# The tecnhique XUE3M utilize DPM to set cores actives and what frequency that cores is run. To this experiment use follows variables.
#
# - 2 core with frequency 600MHz by 600MHz
# - 2 core with frequency 1200MHz by 1200MHz
# - 3 core with frequency 600MHz by 600MHz
# - 3 core with frequency 1200MHz by 1200MHz
# - 4 core with frequency 600MHz by 600MHz
# - 4 core with frequency 1200MHz by 1200MHz
#
# With this variables and configs it will be possible to say better configurations optimize more eficiency energy and has better performance.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Accuracy
#
# First will see accuracy data for general cores in minimum and maximum frequency

# %%
def parse(fname):
    global header_printed
    #index of wanted columns
    columns = []
    #column names to get the data from
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    ret_string = ''
    #remove the path and isolate the filename
    spname = fname.split('/')[-1].split('-')
    spline = []
    #control flag for knowing when the column names have already been discovered
    got = False
    #we ignore the first parameter of the filename and add all others to the csv string
    for s in spname[1:]:
        ret_string += s + ','
    #should probably use a safer way, but python handles the closing of the file
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                #sometimes the dump file has multiple results in it, so we get the index of wanted columns only once
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        #OzaBagASHT bugs out on GMSC, this reuses the data from the sequential execution
        if 'GMSC' in spname and 'ASHT' in spname[2]:
            for c in columns[:-2]:
                ret_string += str(spline[c]) + ','
            ret_string += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        #normal code, how everything should run
        #we process the data (add the content of wanted columns to the csv string) only after the for
        #ensuring we use only the last (most recent) data and not the intermediate results
        else:
            for c in columns:
                ret_string += str(spline[c]) + ','
            if len(columns) == 5:
                ret_string += '0,'
        #header is a global variable, it will only be printed on the first file 
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,instances,time,acc,prec,recall,change'
            ret_string = f"{head}\n{ret_string}"
            header_printed = True
        #remove the last comma ,
        return (ret_string[:-1])

# %%
def add_label_column_df(df):
    for index, row in df.iterrows():
        _str = row["algorithm"]

        if "RUNPER" in _str:
            df.at[index, 'label'] = "Parallel"
        else:
            df.at[index, 'label'] = "Sequential"
            
    return df

# %%
#loads the csv as a dataframe and standardizes the algorithm names 
def load_df(filename):
    df = pd.read_csv(filename, index_col=False)
    df = add_label_column_df(df)
    return select_columns_and_rename_values(df)

# %%
#standardize algorithm names
def select_columns_and_rename_values(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    df.batch_size.unique()
    return df

# %%
#filters by substring (there are multiple OzaBag algorithms)
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %%
#plots precision and recall with markers of one parameter configuration
def gen_lines(df, ax, alg_order, markers):
    lwidth = 0.75
    if markers:
        colors=['go', 'bs', 'rP', 'md', 'y+' , 'k*']
    else:
        colors=['g', 'b', 'r', 'm', 'y' , 'k']

    labels = df.label
    alg = df.algorithm.unique()[0]
    x = np.arange(len(labels))
    
    ax.plot(x, pd.to_numeric(df.prec), f'{colors[alg_order]}--', linewidth=lwidth, label=f'{alg}-prec')
    ax.plot(x, pd.to_numeric(df.recall), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')

    #ax.plot(x,pd.to_numeric(df.prec), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_ylim(50,95)

# %%
#iterates over the parameter configurations and creates the chart grid
def gen_chart(df, markers=True, tables=False):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
    #dictionary containing the correct name to be printed
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    #creates a 2x2 grid for plotting the charts
    #sharey=row means that all charts in a row share the same Y-axis
    fig, axs = plt.subplots(2, 2, figsize=(8,8), sharey='row')
    filename = "batch-size-vs-prediction-mark" if markers else "batch-size-vs-prediction"
    #each chart presents the results for a given dataset and contains the series for all algorithms
    for ds in datasets:
        title = ''
        my_id = datasets.index(ds)
        #selects the correct position in the grid
        ax = axs[int(my_id/2)][my_id%2]
        ax.set_title(f'{dsformalname[ds]}')
        #for each algorithm
        for alg in algorithms:
            #filters the df to contain the wanted values
            df_aux = filter_by_substring_algorithm(df[df.dataset == ds].sort_values(by=['label'], ascending=False), alg)
            if tables:
                display(df_aux)
            #plot (include) the series in the chart
            gen_lines(df_aux, ax, algorithms.index(alg), markers)
            #if its the first column, print Y-axis label
            if my_id%2 == 0:
                ax.set_ylabel('Percentage')
            #if its the last row, print the X-axis label
            if int(my_id/2) == 1:
                ax.set_xlabel('Batch sizes')
    #retrieves the handles and labels to create a global legend
    handles, labels = axs[0][0].get_legend_handles_labels()
    lgd = fig.legend(handles, labels, loc = 'lower center', ncol = math.ceil(len(algorithms)/2), bbox_to_anchor=(0.5,-0.1))
    fig.tight_layout()
    plt.savefig(f'figures/{filename}.png')
    plt.savefig(f'figures/{filename}.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/06-03-2022/600/600/first"
wantedCSVfilename = "data-batch-vs-acc-600-600.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

df = load_df(f'{csvFile}')
df = df.drop(['cores', 'time'], axis=1)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3079571633.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
#false makes the chart without markers
gen_chart(df)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Analise precisão 600x600
#
# Essa analise consiste em validar se a acurácia dos algoritmos permanence com a mesma qualidade com a frequencia alterada. Para analisar utilizamos dois tipos de implementação dos algoritmos a sequencial MOA padrão e a paralela implementação feita por Cassales. O comportamento da precisão e recall entre os dois algorimtos se mantem para determinados algoritmos como OzaBaga para os datasets GMSC por exemplo, mas outros datasets como Covertype e eletriticy a precisão aumenta já para o algoritmo LBAG a precisão cai consideravelmente de 80 para 70 assim mas isso apenas no dataset GMSC.

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/06-03-2022/1200/1200/first"
wantedCSVfilename = "data-batch-vs-acc-1200-1200.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

df = load_df(f'{csvFile}')
df = df.drop(['cores', 'time'], axis=1)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3079571633.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
#false makes the chart without markers
gen_chart(df)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Analise precisão 1200x1200
#
# O comportamento é identico na frequencia anterior de 600x600.

# %% [markdown]
# ## Highlights about accuracy results
#
# To accuracy to minimum and maximum frequency us can see similar precision and recall to both executions.

# %% [markdown]
# # Efficiency Energy
#
# From this moment it will analisy results to eficciency energy to each isolate core and frequency. First we see rate taxe eficiency to each frequency.
#
# ## 2 Cores

# %%
PATH_TO_RESULTS = '/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/socket/19-03-2022/'

# %%
#filters by substring (there are multiple OzaBag algorithms)
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %%
def parse_MOA(fname):
    global header_printed
    columns = []
    wanted = ['learning evaluation instances', 'Wall Time (Actual Time)', 'Avg Delay (ms)', 'outRate (inst/s)', 'classifications correct (percent)']
    pstr = ''
    spname = fname.split('/')[-1].split('-')
    spline = []
    for s in spname[1:]:
        pstr += s + ','
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                spline = line.split(',')
                for s in spline:
                    if s in wanted:
                        columns.append(spline.index(s))
            else:
                spline = line.split(',')
        for c in columns:
            pstr += spline[c] + ','
        if len(columns) == 2:
            pstr += '1,'
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,inc_rate,instances,time,delay,out_rate,acc'
            pstr = f"{head}\n{pstr}"
            header_printed = True
        return (pstr[:-1])

# %%
def parse_SSH(fname):
    fname = os.fsdecode(fname)
    read_ssh = False
    alg = ''
    dataset = ''
    rate = ''
    d = {'algorithm': [], 'dataset': [], 'batch_size': [], 'inc_rate': [], 'prod_rate': [], 'tt_inst_prod': []}
    with open (fname, "r") as file:
        for line in file:
            if not read_ssh:
                if 'ssh-' in line:
                    read_ssh = True
                    spline = line.split('-')
                    if "MAX" in line:
                        if len(spline[1:]) == 3:
                            dataset, alg, rate = spline[1:]
                            bsize = 500
                        else:
                            dataset, alg, bsize, rate = spline[1:]
                    else:
                        dataset, alg, bsize, rate = spline[1:]
                        bsize = 1
                    d['algorithm'].append(alg)
                    d['dataset'].append(dataset)
                    d['inc_rate'].append(rate.strip())
                    d['batch_size'].append(bsize)
            else:
                if 'Total instances Producer' in line:
                    tt_inst = float(line.split(': ')[1])
                    d['tt_inst_prod'].append(tt_inst)
                elif 'Producer Rate' in line:
                    prod_rate = float(line.split(': ')[1])
                    d['prod_rate'].append(prod_rate)
                    read_ssh = False
    return pd.DataFrame.from_dict(d).astype({'inc_rate': 'int64'})

# %%
def read_MOA(folder, out_file):
    directory = os.fsencode(folder)
    global header_printed

    with open(out_file, "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("term-"): 
                output.write(f"{parse_MOA(f'{os.fsdecode(directory)}/{filename}')}\n")
    fname = os.fsdecode(out_file)
    df = pd.read_csv(fname)

    df['inc_rate'].astype('int64')
    return df[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'instances', 'time', 'delay', 'out_rate', 'acc']]

# %%
def read_data_create_final_dataframe(freq, DEBUG=False):
    d = {}
    global header_printed
    header_printed = False
    folder_path = f"{PATH_TO_RESULTS}{freq['cores']}/{freq['minimum']}/{freq['maximum']}"
    min = freq['minimum']
    max = freq['maximum']
    moaDF = read_MOA(f"{folder_path}", f"{folder_path}/inst-and-delay.csv")
    moaDF = moaDF[["algorithm", "dataset", "cores", "batch_size", "inc_rate", "out_rate", "instances", "time", "delay", "acc"]]
    measureDF = load_Wmeas(f'{folder_path}/Wm-log.log')
    d = exper_order_to_dict(f'{folder_path}/exper_order-freq-max-{max}-freq-min-{min}.log', d)
    d = populate_dict(d, measureDF)
    mdf = append_dict_to_df(d)
    sshDF = parse_SSH(f'{folder_path}/ssh-log')
    sshDF['batch_size'] = sshDF['batch_size'].astype(int)
    if DEBUG:
        print(f'moaDF: {len(moaDF)}    mdf: {len(mdf)}     sshDF: {len(sshDF)}')
    
    #join dfs
    finaldf = moaDF.merge(mdf, on=['algorithm', 'dataset', 'cores', 'batch_size', 'inc_rate'])
    finaldf = finaldf.merge(sshDF, 'left', on=['algorithm', 'dataset', 'batch_size', 'inc_rate'])

    finaldf['joules'] = finaldf['avg_measure'] * finaldf['time']
    finaldf['JPI'] = finaldf['joules'] / finaldf['instances']
    finaldf['freq_minimum'] = min
    finaldf['freq_maximum'] = max
    
    # Add PERC column to identify if it used 90, 50 or 10% max rate
    # Before merging rows with the same batch size, we need to differentiate the experiments with different work loads
    # We use the **PERC**entage column for that
    tdf = finaldf.sort_values(by=['dataset','algorithm','batch_size','inc_rate'], ascending=False)
    tdf['PERC'] = 0
    if DEBUG:
        tdf.to_csv(f"{PATH_TO_RESULTS}tdf-{min}x{max}.csv")
    masks = {'90':[], '50': [], '10': []}
    for k, v in zip(masks.keys(), [0, 1, 2]):
        for i in range(len(tdf)):
            masks[k].append(i % 3 == v)
    
    tdf.loc[masks['90'], 'PERC'] = '90'
    tdf.loc[masks['50'], 'PERC'] = '50'
    tdf.loc[masks['10'], 'PERC'] = '10'
    
    tdf['tput'] = tdf['instances'] / tdf['time']
    
    tdf = add_label_column_df(tdf)
    return tdf

# %%
def load_Wmeas(filename):
    return pd.read_csv(filename, header=None, names=['date', 'time', 'measure'])

# %%
def exper_order_to_dict(filename, d):
    with open(filename) as forder:
        got_timestamp = False
        dataset = algorithm = Esize = cores = Bsize = ''
        dnow=None
        for line in forder:
            if not got_timestamp:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
                if dnow:
                    dnow['finish'] = date_time_obj - datetime.timedelta(seconds=1)
            elif ':' not in line:
                spline = line.split('/')[-1].strip().split('-')
                #print(spline)
                if len(spline) == 6:
                    dataset,algorithm,Esize,cores,Bsize,rate = spline
                else:
                    dataset,algorithm,Esize,cores,Bsize,rate = *spline,1
                if algorithm not in d:
                    d[algorithm] = {}
                if dataset not in d[algorithm]:
                    d[algorithm][dataset] = {}
                if Esize not in d[algorithm][dataset]:
                    d[algorithm][dataset][Esize] = {}
                if cores not in d[algorithm][dataset][Esize]:
                    d[algorithm][dataset][Esize][cores] = {}
                if Bsize not in d[algorithm][dataset][Esize][cores]:
                    d[algorithm][dataset][Esize][cores][Bsize] = {}
                if rate not in d[algorithm][dataset][Esize][cores][Bsize]:
                    d[algorithm][dataset][Esize][cores][Bsize][rate] = {'start': date_time_obj, 'finish': ''}
                    dnow = d[algorithm][dataset][Esize][cores][Bsize][rate]
                got_timestamp = False
            else:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
    return d

# %%
def populate_dict(d, df):
    df['datetime'] = df['date'] + ' ' + df['time']
    for k, v in d.items():
        for k1, v1 in v.items():
            for k2, v2 in v1.items():
                for k3, v3 in v2.items():
                    for k4, v4 in v3.items():
                        for k5, v5 in v4.items():
                            if 'seconds' not in v5:
                                st = v5['start']
                                ed = v5['finish']
                                v5['seconds'] = (ed - st).seconds
                                new_df = df[(df.datetime <= f'{ed.strftime("%d/%m/%y")} {ed.strftime("%X")}')
                                          & (df.datetime >= f'{st.strftime("%d/%m/%y")} {st.strftime("%X")}')]
                                v5['avg_measure'] = new_df['measure'].mean()
                                v5['sum_measure'] = new_df['measure'].sum()
                                v5['avg_times_seconds'] = v5['avg_measure'] * v5['seconds']
    return d

# %%
def append_dict_to_df(d, ensemble_size=False):
    dappend = {'algorithm': [], 'dataset': [], 'ensemble_size': [], 'cores': [], 
               'batch_size': [], 'duration': [], 'inc_rate': [], 'avg_measure': [], 'sum_measure': [], 'avg_times_seconds': []}
    for kalg,valg in d.items():
        for kds,vds in valg.items():
            for kens,vens in vds.items():
                for kcore,vcore in vens.items():
                    for kmbs,vmbs in vcore.items():
                        for krate,vrate in vmbs.items():
                            dappend['algorithm'].append(kalg)
                            dappend['dataset'].append(kds)
                            dappend['ensemble_size'].append(kens)
                            dappend['cores'].append(kcore)
                            dappend['batch_size'].append(kmbs)
                            dappend['duration'].append(vrate['seconds'])
                            dappend['inc_rate'].append(krate)
                            for key in ['avg_measure', 'sum_measure','avg_times_seconds']:
                                dappend[key].append(vrate[key])
    adf = pd.DataFrame(data=dappend)
    adf = adf.sort_values(['algorithm','dataset']).astype({'inc_rate': 'int64', 
                                                           'cores': 'int64',
                                                           'batch_size': 'int64'})
    if ensemble_size:
        return adf[['algorithm', 'dataset', 'ensemble_size', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]
    return adf[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]

# %%
def filter_fields(df):
    wanted = ['algorithm', 'dataset', 'batch_size', 'cores', 'out_rate', 'instances', 'delay', 'joules', 'JPI']
    return df[[
        l for l in df.columns if any([w in l for w in wanted])
    ]]

# %%
def rename_columns_by_rate(df):
    rate = df.PERC.iloc[0]
    return df.rename(columns={"out_rate": f"out_rate_{rate}", "instances": f"instances_{rate}", 
                                "delay": f"delay_{rate}", "joules": f"joules_{rate}", 
                                "JPI": f"JPI_{rate}", "tput": f"tput_{rate}"})

# %%
def show_graph_JPI_delay(df, ax, mJPI, mDel, legend=False, title=False, ylabels=False, ds='', bar=False, share_y=False, log_y=False, norm=False, hide=True):
    if norm:
        df = my_norm(df, x=norm)
    global rate
    global twin
    width = 0.15
    alg_order = ['Sequential', 'Parallel - 2 Cores', 'Parallel - 4 Cores']
    labels = ['10%', '50%', '90%']
    line_format = ['-', '--', ':', '-.', (0, (3, 5, 1, 5, 1, 5))]
    linfo = '--'
    x = np.arange(len(labels))
    lns_l = []
    versions = 3
    for i in range(versions):
        adf = df.iloc[i]
        values_j = [adf.JPI_10, adf.JPI_50, adf.JPI_90]
        if bar:
            lns_l += ax.bar(x - ((1 - i) * width), values_j, width, label=f'JPI-{alg_order[i]}')            
        else:
            lns_l += ax.plot(x, values_j, label=f'JPI-{alg_order[i]}')

    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax_r = ax.twinx()
    twin = ax_r
    if log_y:
        ax.set_yscale('log')
        ax_r.set_yscale('log')
    if title:
        alg_title = re.sub('Sequential', '', df.algorithm.iloc[0])
        ax.set_title(f'{alg_title}')
    if ylabels:
        ax.set_ylabel(ds)
    if last:
        ax.set_ymargin(2)
    for i in range(versions): 
        adf = df.iloc[i]
        values_d = [ x/1000 for x in [adf.delay_10, adf.delay_50, adf.delay_90]]
        if bar:
            linfo = f'k{line_format[i]}'
            lns_l += ax_r.plot(x, values_d, color='black', linestyle=line_format[i], label=f'delay-{alg_order[i]}')
        else:
            lns_l += ax_r.plot(x, values_d, linfo, label=f'delay-{alg_order[i]}')
    labs = [l.get_label() for l in lns_l]
    if legend:
        ax.legend(lns_l, labs, loc=0)
    if hide:
        ax_r.set_yticklabels([])
    if share_y == 'row':
        ax.set_ylim(top=mJPI)
        ax_r.set_ylim(top=mDel/1000)

# %%
def aux_graphNx1(ds, axis, id_ds, df, bar=False, share_y='row', log_y=False, norm=False):
    rates = ['10', '50', '90']
    algs = ['Ada', 'L', 'Patches', 'Adwin', 'ASHT', 'OzaBag']
    global title
    global labels
    hide_axis = True
#     fig.suptitle(f'JPI and delay for {ds}', fontsize=18, y=1)
#     get max value from delay for all rates on all algorithms for this dataset
    mLstJPI = []
    mLstDel = []
    if share_y == 'row':
        for rt in rates:
            rtDF = df[df.PERC == rt]
            mLstJPI.append(rtDF.JPI.max())
            mLstDel.append(rtDF.delay.max())
        mJPI = max(mLstJPI)*1.05
        mDel = max(mLstDel)*1.05
    else:
        mJPI = mDel = 0
    for alg in algs:
        dsalgdf = filter_by_substring_algorithm(df, alg).sort_values(['algorithm','batch_size','cores'])
#         if alg == 'L' and ds == 'kyoto_binary':
#             display(dsalgdf)
        for rt in rates:
            if rt == '10':
                showdf = rename_columns_by_rate(dsalgdf[dsalgdf.PERC == rt])
            else:
                to_join = dsalgdf[dsalgdf.PERC == rt]
                showdf = showdf.merge(rename_columns_by_rate(to_join),
                                  on=['algorithm', 'dataset', 'batch_size', 'cores']).sort_values(['batch_size','cores'])


        for index, row in showdf.iterrows():
            cores = row["cores"]
            already_in_dataframe = []
            
            if not cores in already_in_dataframe:
                showdf.drop(index)
                already_in_dataframe.append(row['cores'])

        N = 7 # remove a duplicidade de experimentos com um core
        showdf = showdf.iloc[N: , :]

        # debug print, if it shows it is wrong
        # if len(showdf) != 5:
        #     display(showdf)

        if 'Ada' in alg:
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, ylabels=True, ds=ds, bar=bar, share_y=share_y, log_y=log_y, norm=norm)
        else:
            if algs[-1] == alg:
                hide_axis = False
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, bar=bar, share_y=share_y, log_y=log_y, norm=norm, hide=hide_axis)

# %%
def gen_graph(df, bars=False, share_y='row', log_y=False, norm=False, freq='600', tput=False):
    ps = f'{freq}\nbars: {bars}\nshare_y: {share_y}\nlog_y: {log_y} '
    datasets = ['airlines', 'GMSC','elecNormNew','covtypeNorm']

    fig, axis = plt.subplots(len(datasets), 6, figsize=(16,12), tight_layout=True, sharey=share_y)
    global title
    global labels
    global last
    global twin
    leg = False
    labls = True
    title = True
    last = False
    twin = axis[0][0]
    for ds in datasets:
        if datasets.index(ds) == (len(datasets) - 1):
            last = True
        dsdf = df[df.dataset == ds]
        aux_graphNx1(ds, axis, datasets.index(ds), dsdf, bar=bars, share_y=share_y, log_y=log_y, norm=norm)
        title = True
    lines_1, labels_1 = axis[0][0].get_legend_handles_labels()
    lines_2, labels_2 = twin.get_legend_handles_labels()
    lines = lines_1 + lines_2
    labels = labels_1 + labels_2
    lgd = fig.legend(lines, labels, loc=8, ncol=5, bbox_to_anchor=(0.5, -0.02))
    lgd.set_in_layout(True)
    fig.subplots_adjust(bottom=-0.5)
    filename = 'all-4x1-JPI-delay'
    if bars:
        filename = f'bars-{filename}'
    if share_y:
        filename = f'sharey-{filename}'
    if log_y:
        filename = f'logy-{filename}'
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.eps', pad_inches=0.2, bbox_inches='tight')
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.png', pad_inches=0.2, bbox_inches='tight')
    plt.show()

# %%
freqs = [
    {'minimum': '600', 'maximum': '600', 'cores': 2}, 
    {'minimum': '1200', 'maximum': '1200', 'cores': 2},
    {'minimum': '600', 'maximum': '600', 'cores': 4},
    {'minimum': '1200', 'maximum': '1200', 'cores': 4},
]

# mergear o 0 com o 2 -> 600x600 2 cores e 600x600 4 cores
# mergear o 1 com o 3 -> 1200x1200 2 cores e 1200x1200 4 cores

dataframes = []
for f in freqs:
    dataframes.append(read_data_create_final_dataframe(f, True))
    
dataframes_minimum_freq = pd.merge(dataframes[0], dataframes[2], how = 'outer')
dataframes_maximum_freq = pd.merge(dataframes[1], dataframes[3], how = 'outer')
# Out:
# moaDF: 144    mdf: 144     sshDF: 144
# moaDF: 144    mdf: 144     sshDF: 144
# moaDF: 144    mdf: 144     sshDF: 144
# moaDF: 144    mdf: 144     sshDF: 144

# %%
gen_graph(dataframes_minimum_freq, bars=True, freq="Minimum Frequency")
gen_graph(dataframes_maximum_freq, bars=True, freq="Maximum Frequency")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Consumo energético para 2 cores
#
# Nestes gráficos podemos observar o consumo energético para a frequencia minima de 600 com a frequencia maxima de 600 e também para as frequencias minima de 1200 com a frequencia máxima de 1200. As duas barras são em azul o algoritmo sequencial sem alteração e a em laranja o paralelo com alteração. Os comportamentos destes algoritmos em geral são em questão de eficiencia energética muito similares, salvo algumas exceções como o streaming random patches que deve um ganho em eficiencia ao ser implementado o algoritmo paralelo nas taxas de 50% e 90%. Para analisar a diferença energética entre as frequencias iremos fixar a analise no OzaBag que já foi comprovado ter um melhor desempenho energético por conta da sua estrutura de dados. No OzaBag no dataset airlines o maior consumo em JPI foi de 0.1 já para a maior frequencia isso ficou em 0.05.  Pegando o proximo dataset GMSC temos que o maior consumo ficou em um pouco mais de 0.025 e na frequencia maior em 0.02, no dataset electNormNew ficou em 0.05 e 0.02, já no covTypeNorm isso ficou em 0.2 e 0.10. No geral a utilização de uma frequencia menor não trouxe grandes impactos em eficiência energética para essa execução.

# %% [markdown]
# #### Analisy accuracy x JPI x IPS
#
# To each core and each frequency

# %%
for f,df in zip(freqs, dataframes_two_cores):
    print(f'\n\n\n----------------- {f} -----------------')
    df['joules'] = df['joules'].replace(np.nan, 0)
    df = df.reset_index()

    total = 0
    average = 0 
    for index, row in df.iterrows():
        if int(row['joules']) > 0:
            total += row['joules']

    average = total / len(df.index)
    print(average)
# Out:
# ----------------- {'minimum': '600', 'maximum': '600'} -----------------
# 400.6402624825852
#
#
#
# ----------------- {'minimum': '1200', 'maximum': '1200'} -----------------
# 452.97138241996714

# %%
def plot(ax, dsdf, my_id, x):
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}
    c1 = 'tab:red'
    c2 = 'tab:blue'
    c3 = 'tab:green'
    ds = list(dsdf.dataset)[0]
    ax.set_title(f'{dsformalname[ds]}')
    ax.plot(x, pd.to_numeric(dsdf.acc), color=c1, label='Acuraccy')
    ax.tick_params(axis='y', labelcolor=c1)
    ax.set_xticks(x)
    ax.set_xticklabels(dsdf.label)
    ax.set_ylim(0,100)
    ax2 = ax.twinx()
    ax2.plot(x, pd.to_numeric(dsdf.IPS), color=c2, label='IPS')
    ax2.tick_params(axis='y', labelcolor=c2)
    ax3 = ax.twinx()
    ax3.plot(x, pd.to_numeric(dsdf.JPI), color=c3, label='JPI')
    ax3.tick_params(axis='y', labelcolor=c3)
    ax3.spines["right"].set_position(("axes", 1.14))
    ax3.set_label('JPI')
    if int(my_id/2) == 1:
        ax.set_xlabel('MOA Mode (Sequential or Parallel)')
        ax.legend(loc='upper center', bbox_to_anchor=(0, -0.20), fancybox=True, shadow=True, ncol=5)
        ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.20), fancybox=True, shadow=True, ncol=5)
        ax3.legend(loc='upper center', bbox_to_anchor=(1, -0.20), fancybox=True, shadow=True, ncol=5)

# %%
def gen_graph_initial_peralg(df, display_df=False, freq=''):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']

    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']

    filename = f"pi-rates"
    for alg in algorithms:
        fig, axs = plt.subplots(2, 2, figsize=(14,9))
        # set the spacing between subplots
        plt.subplots_adjust(left=0.1,
                            bottom=0.1, 
                            right=0.9, 
                            top=0.9, 
                            wspace=0.4, 
                            hspace=0.4)
        dfalg = filter_by_substring_algorithm(df, alg)
        fig.suptitle(f'{alg} - Frequency {freq}')
        for ds in datasets:
            dsdf = dfalg[(dfalg.dataset == ds)]
            x = np.arange(len(dsdf.batch_size))
            my_id = datasets.index(ds)
            ax = axs[int(my_id/2)][my_id%2]
            plot(ax, dsdf, my_id, x)
        plt.savefig(f'{filename}.eps', bbox_inches='tight')

# %%
for f,df in zip(freqs, dataframes_two_cores):
    print(f'\n\n\n----------------- {f} -----------------')
    df = df[df.PERC == '90']
    df = df.loc[:,['dataset','algorithm','batch_size','acc', 'instances', 'time', 'JPI']]
    df = select_columns_and_rename_values(df)
    df = add_label_column_df(df).sort_values(by=['label'], ascending=False)
    df['IPS'] = df['instances'] / df['time']
    gen_graph_initial_peralg(df, display_df=False, freq=f)
# Out:
# ----------------- {'minimum': '600', 'maximum': '600'} -----------------
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# ----------------- {'minimum': '1200', 'maximum': '1200'} -----------------
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Analise acuracia x IPS x JPI
#
# Nesta seção do notebook iremos analisar o comportamento em relação a acuracia e os valores de instancias por segundo (IPS) e os Joules por instancia (JPI). Para essa analise irei fixar novamente no algoritmo OzaBag nas frequencias minimas e máximas. Começando pela frequencia minima o comportamento do Ozabag tem uma linha reta em relação a acurácia em todos os datasets e também um comportamento onde quanto maior o IPS menor o JPI. O maior IPS foi de 880 com um JPI máximo de 0.0044 isso para o dataset GMSC. Na frequencia máxima, a acurácia e o comportamento se replica, mas temos uma diferença nos valores de processamento, novamente no dataset GMSC temos um processamento máximo de 1650 instancias por segundo e o maior JPI em 0.0034. Esse número representa o dobro de instancias processadas por segundo com um valor de JPI muito próximo ao de menor frequência.
#
# Ainda na mesma analise iremos olhar agora o algoritmo StreamingRandomPatches por ser o que teve o maior consumo energético em todas as chamadas. Na frequencia minima o SRP tem o maior IPS em 165 e JPI em 0.24 nos datasets GMSC e Airlines. Já na frequencia máxima, o maior IPS foi de 298 e o JPI de 0.16 também para os datasets GMSC e Airlines. No dataset GMSC o maior JPI ficou em 0.014636 na frequencia máxima e na minima de 0.0245, isso mostra que mesmo o JPI sendo maior na frequencia minima isso reflete muito em quantos IPS terão na execução.

# %% [markdown]
# ## 4 Cores

# %%
PATH_TO_RESULTS = '/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/socket/19-03-2022/4/'

# %%
freqs = [{'minimum': '600', 'maximum': '600'}, {'minimum': '1200', 'maximum': '1200'}]
dataframes_four_cores = []
for f in freqs:
    dataframes_four_cores.append(read_data_create_final_dataframe(f, True))
# Out:
# moaDF: 144    mdf: 144     sshDF: 144
# moaDF: 144    mdf: 144     sshDF: 144

# %%
for f,df in zip(freqs, dataframes_four_cores):
    print(f'\n\n\n----------------- {f} -----------------')
    df['joules'] = df['joules'].replace(np.nan, 0)
    df = df.reset_index()

    total = 0
    average = 0 
    for index, row in df.iterrows():
        if int(row['joules']) > 0:
            total += row['joules']

    average = total / len(df.index)
    print(average)
# Out:
# ----------------- {'minimum': '600', 'maximum': '600'} -----------------
# 405.203533919132
#
#
#
# ----------------- {'minimum': '1200', 'maximum': '1200'} -----------------
# 455.3699778435674

# %%
for f,df in zip(freqs, dataframes_four_cores):
    print(f'\n\n\n----------------- {f} -----------------')
    gen_graph(df, bars=True, freq=f"{f['minimum']}x{f['maximum']}")
# Out:
# ----------------- {'minimum': '600', 'maximum': '600'} -----------------
#                                 algorithm      dataset  cores  batch_size  \
# 66   StreamingRandomPatchesExecutorRUNPER  elecNormNew      4           1
# 56   StreamingRandomPatchesExecutorRUNPER  elecNormNew      4           1
# 87   StreamingRandomPatchesExecutorRUNPER  elecNormNew      4           1
# 36                 StreamingRandomPatches  elecNormNew      1           1
# 46                 StreamingRandomPatches  elecNormNew      1           1
# 97                 StreamingRandomPatches  elecNormNew      1           1
# 126                  OzaBagExecutorRUNPER  elecNormNew      4           1
# 114                  OzaBagExecutorRUNPER  elecNormNew      4           1
# 24                   OzaBagExecutorRUNPER  elecNormNew      4           1
# 123             OzaBagAdwinExecutorRUNPER  elecNormNew      4           1
# 106             OzaBagAdwinExecutorRUNPER  elecNormNew      4           1
# 70              OzaBagAdwinExecutorRUNPER  elecNormNew      4           1
# 25                            OzaBagAdwin  elecNormNew      1           1
# 30                            OzaBagAdwin  elecNormNew      1           1
# 139                           OzaBagAdwin  elecNormNew      1           1
# 111              OzaBagASHTExecutorRUNPER  elecNormNew      4           1
# 108              OzaBagASHTExecutorRUNPER  elecNormNew      4           1
# 61               OzaBagASHTExecutorRUNPER  elecNormNew      4           1
# 75                             OzaBagASHT  elecNormNew      1           1
# 79                             OzaBagASHT  elecNormNew      1           1
# 132                            OzaBagASHT  elecNormNew      1           1
# 85                                 OzaBag  elecNormNew      1           1
# 73                                 OzaBag  elecNormNew      1           1
# 40                                 OzaBag  elecNormNew      1           1
# 107                         LeveragingBag  elecNormNew      1           1
# 138                         LeveragingBag  elecNormNew      1           1
# 134                         LeveragingBag  elecNormNew      1           1
# 140                    LBagExecutorRUNPER  elecNormNew      4           1
# 119                    LBagExecutorRUNPER  elecNormNew      4           1
# 98                     LBagExecutorRUNPER  elecNormNew      4           1
# 96         AdaptiveRandomForestSequential  elecNormNew      1           1
# 45         AdaptiveRandomForestSequential  elecNormNew      1           1
# 32         AdaptiveRandomForestSequential  elecNormNew      1           1
# 17     AdaptiveRandomForestExecutorRUNPER  elecNormNew      4           1
# 128    AdaptiveRandomForestExecutorRUNPER  elecNormNew      4           1
# 136    AdaptiveRandomForestExecutorRUNPER  elecNormNew      4           1
# 5    StreamingRandomPatchesExecutorRUNPER  covtypeNorm      4           1
# 9    StreamingRandomPatchesExecutorRUNPER  covtypeNorm      4           1
# 102  StreamingRandomPatchesExecutorRUNPER  covtypeNorm      4           1
# 125                StreamingRandomPatches  covtypeNorm      1           1
# 109                StreamingRandomPatches  covtypeNorm      1           1
# 135                StreamingRandomPatches  covtypeNorm      1           1
# 59                   OzaBagExecutorRUNPER  covtypeNorm      4           1
# 78                   OzaBagExecutorRUNPER  covtypeNorm      4           1
# 16                   OzaBagExecutorRUNPER  covtypeNorm      4           1
# 44              OzaBagAdwinExecutorRUNPER  covtypeNorm      4           1
# 86              OzaBagAdwinExecutorRUNPER  covtypeNorm      4           1
# 12              OzaBagAdwinExecutorRUNPER  covtypeNorm      4           1
# 64                            OzaBagAdwin  covtypeNorm      1           1
# 1                             OzaBagAdwin  covtypeNorm      1           1
# 74                            OzaBagAdwin  covtypeNorm      1           1
# 48               OzaBagASHTExecutorRUNPER  covtypeNorm      4           1
# 31               OzaBagASHTExecutorRUNPER  covtypeNorm      4           1
# 116              OzaBagASHTExecutorRUNPER  covtypeNorm      4           1
# 141                            OzaBagASHT  covtypeNorm      1           1
# 130                            OzaBagASHT  covtypeNorm      1           1
# 7                              OzaBagASHT  covtypeNorm      1           1
# 20                                 OzaBag  covtypeNorm      1           1
# 68                                 OzaBag  covtypeNorm      1           1
# 131                                OzaBag  covtypeNorm      1           1
# 81                          LeveragingBag  covtypeNorm      1           1
# 19                          LeveragingBag  covtypeNorm      1           1
# 43                          LeveragingBag  covtypeNorm      1           1
# 4                      LBagExecutorRUNPER  covtypeNorm      4           1
# 127                    LBagExecutorRUNPER  covtypeNorm      4           1
# 84                     LBagExecutorRUNPER  covtypeNorm      4           1
# 71         AdaptiveRandomForestSequential  covtypeNorm      1           1
# 93         AdaptiveRandomForestSequential  covtypeNorm      1           1
# 23         AdaptiveRandomForestSequential  covtypeNorm      1           1
# 49     AdaptiveRandomForestExecutorRUNPER  covtypeNorm      4           1
# 77     AdaptiveRandomForestExecutorRUNPER  covtypeNorm      4           1
# 3      AdaptiveRandomForestExecutorRUNPER  covtypeNorm      4           1
# 95   StreamingRandomPatchesExecutorRUNPER     airlines      4           1
# 113  StreamingRandomPatchesExecutorRUNPER     airlines      4           1
# 58   StreamingRandomPatchesExecutorRUNPER     airlines      4           1
# 39                 StreamingRandomPatches     airlines      1           1
# 22                 StreamingRandomPatches     airlines      1           1
# 124                StreamingRandomPatches     airlines      1           1
# 92                   OzaBagExecutorRUNPER     airlines      4           1
# 103                  OzaBagExecutorRUNPER     airlines      4           1
# 2                    OzaBagExecutorRUNPER     airlines      4           1
# 10              OzaBagAdwinExecutorRUNPER     airlines      4           1
# 89              OzaBagAdwinExecutorRUNPER     airlines      4           1
# 129             OzaBagAdwinExecutorRUNPER     airlines      4           1
# 41                            OzaBagAdwin     airlines      1           1
# 112                           OzaBagAdwin     airlines      1           1
# 100                           OzaBagAdwin     airlines      1           1
# 14               OzaBagASHTExecutorRUNPER     airlines      4           1
# 47               OzaBagASHTExecutorRUNPER     airlines      4           1
# 110              OzaBagASHTExecutorRUNPER     airlines      4           1
# 65                             OzaBagASHT     airlines      1           1
# 35                             OzaBagASHT     airlines      1           1
# 11                             OzaBagASHT     airlines      1           1
# 123 438.42    Parallel
# 106 244.74    Parallel
# 70   45.00    Parallel
# 25  439.21  Sequential
# 30  244.72  Sequential
# 139  44.99  Sequential
# 111 547.07    Parallel
# 108 304.55    Parallel
# 61   59.97    Parallel
# 75  552.51  Sequential
# 79  304.67  Sequential
# 132  59.93  Sequential
# 85  572.94  Sequential
# 73  319.65  Sequential
# 40   60.00  Sequential
# 107 244.13  Sequential
# 138 149.87  Sequential
# 134  30.01  Sequential
# 140 274.60    Parallel
# 119 149.89    Parallel
# 98   30.01    Parallel
# 96  135.98  Sequential
# 45   99.84  Sequential
# 32   20.00  Sequential
# 17  179.78    Parallel
# 128  99.93    Parallel
# 136  20.00    Parallel
# 5    44.86    Parallel
# 9    24.99    Parallel
# 102   5.00    Parallel
# 125  41.63  Sequential
# 109  24.97  Sequential
# 135   5.00  Sequential
# 59  131.06    Parallel
# 78   74.88    Parallel
# 16   15.00    Parallel
# 44  108.86    Parallel
# 86   79.86    Parallel
# 12   15.00    Parallel
# 64   90.27  Sequential
# 1    79.91  Sequential
# 74   15.00  Sequential
# 48  104.88    Parallel
# 31   59.91    Parallel
# 116  10.00    Parallel
# 141 102.06  Sequential
# 130  59.91  Sequential
# 7    10.00  Sequential
# 20  128.74  Sequential
# 68   74.88  Sequential
# 131  15.00  Sequential
# 81   63.77  Sequential
# 19   62.32  Sequential
# 43    9.96  Sequential
# 4   102.35    Parallel
# 127  64.90    Parallel
# 84   10.00    Parallel
# 71   91.44  Sequential
# 93   79.92  Sequential
# 23   15.00  Sequential
# 49  145.76    Parallel
# 77   79.87    Parallel
# 3    15.00    Parallel
# 95   27.91    Parallel
# 113  24.86    Parallel
# 58    4.99    Parallel
# 39   14.49  Sequential
# 22   14.51  Sequential
# 124   4.99  Sequential
# 92   83.53    Parallel
# 103  84.56    Parallel
# 2    34.94    Parallel
# 10   80.69    Parallel
# 89   49.92    Parallel
# 129   9.99    Parallel
# 41   73.36  Sequential
# 112  49.68  Sequential
# 100   9.99  Sequential
# 14   81.20    Parallel
# 47   82.70    Parallel
# 110  19.99    Parallel
# 65   73.68  Sequential
# 35   73.06  Sequential
# 11   19.99  Sequential
# 21   72.78  Sequential
# 34   76.28  Sequential
# 117  34.93  Sequential
# 67   24.14  Sequential
# 18   22.44  Sequential
# 120   4.99  Sequential
# 63   39.42    Parallel
# 8    24.95    Parallel
# 0     4.99    Parallel
# 88   19.17  Sequential
# 72   19.49  Sequential
# 54    4.98  Sequential
# 76   34.57    Parallel
# 83   29.93    Parallel
# 143   4.98    Parallel
# 26  154.81    Parallel
# 133  84.86    Parallel
# 142  15.00    Parallel
# 38  150.46  Sequential
# 99   84.07  Sequential
# 105  15.00  Sequential
# 118 782.45    Parallel
# 137 434.37    Parallel
# 62   84.87    Parallel
# 51  648.43    Parallel
# 104 359.61    Parallel
# 122  69.89    Parallel
# 42  648.20  Sequential
# 82  359.50  Sequential
# 60   69.97  Sequential
# 37  797.34    Parallel
# 27  444.38    Parallel
# 69   84.87    Parallel
# 115 797.27  Sequential
# 90  444.40  Sequential
# 13   84.86  Sequential
# 80  782.49  Sequential
# 101 434.37  Sequential
# 121  84.86  Sequential
# 94  351.79  Sequential
# 52  204.78  Sequential
# 6    39.93  Sequential
# 55  364.17    Parallel
# 91  204.85    Parallel
# 53   39.94    Parallel
# 28  260.65  Sequential
# 15  159.85  Sequential
# 33   30.00  Sequential
# 50  284.54    Parallel
# 57  159.89    Parallel
# 29   30.01    Parallel
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ----------------- {'minimum': '1200', 'maximum': '1200'} -----------------
#                                 algorithm      dataset  cores  batch_size  \
# 3    StreamingRandomPatchesExecutorRUNPER  elecNormNew      4           1
# 41   StreamingRandomPatchesExecutorRUNPER  elecNormNew      4           1
# 16   StreamingRandomPatchesExecutorRUNPER  elecNormNew      4           1
# 133                StreamingRandomPatches  elecNormNew      1           1
# 89                 StreamingRandomPatches  elecNormNew      1           1
# 20                 StreamingRandomPatches  elecNormNew      1           1
# 27                   OzaBagExecutorRUNPER  elecNormNew      4           1
# 59                   OzaBagExecutorRUNPER  elecNormNew      4           1
# 101                  OzaBagExecutorRUNPER  elecNormNew      4           1
# 117             OzaBagAdwinExecutorRUNPER  elecNormNew      4           1
# 79              OzaBagAdwinExecutorRUNPER  elecNormNew      4           1
# 88              OzaBagAdwinExecutorRUNPER  elecNormNew      4           1
# 69                            OzaBagAdwin  elecNormNew      1           1
# 73                            OzaBagAdwin  elecNormNew      1           1
# 56                            OzaBagAdwin  elecNormNew      1           1
# 25               OzaBagASHTExecutorRUNPER  elecNormNew      4           1
# 139              OzaBagASHTExecutorRUNPER  elecNormNew      4           1
# 127              OzaBagASHTExecutorRUNPER  elecNormNew      4           1
# 141                            OzaBagASHT  elecNormNew      1           1
# 118                            OzaBagASHT  elecNormNew      1           1
# 97                             OzaBagASHT  elecNormNew      1           1
# 90                                 OzaBag  elecNormNew      1           1
# 29                                 OzaBag  elecNormNew      1           1
# 138                                OzaBag  elecNormNew      1           1
# 45                          LeveragingBag  elecNormNew      1           1
# 84                          LeveragingBag  elecNormNew      1           1
# 57                          LeveragingBag  elecNormNew      1           1
# 71                     LBagExecutorRUNPER  elecNormNew      4           1
# 105                    LBagExecutorRUNPER  elecNormNew      4           1
# 23                     LBagExecutorRUNPER  elecNormNew      4           1
# 119        AdaptiveRandomForestSequential  elecNormNew      1           1
# 65         AdaptiveRandomForestSequential  elecNormNew      1           1
# 26         AdaptiveRandomForestSequential  elecNormNew      1           1
# 72     AdaptiveRandomForestExecutorRUNPER  elecNormNew      4           1
# 121    AdaptiveRandomForestExecutorRUNPER  elecNormNew      4           1
# 136    AdaptiveRandomForestExecutorRUNPER  elecNormNew      4           1
# 18   StreamingRandomPatchesExecutorRUNPER  covtypeNorm      4           1
# 142  StreamingRandomPatchesExecutorRUNPER  covtypeNorm      4           1
# 0    StreamingRandomPatchesExecutorRUNPER  covtypeNorm      4           1
# 52                 StreamingRandomPatches  covtypeNorm      1           1
# 28                 StreamingRandomPatches  covtypeNorm      1           1
# 131                StreamingRandomPatches  covtypeNorm      1           1
# 67                   OzaBagExecutorRUNPER  covtypeNorm      4           1
# 50                   OzaBagExecutorRUNPER  covtypeNorm      4           1
# 81                   OzaBagExecutorRUNPER  covtypeNorm      4           1
# 35              OzaBagAdwinExecutorRUNPER  covtypeNorm      4           1
# 63              OzaBagAdwinExecutorRUNPER  covtypeNorm      4           1
# 15              OzaBagAdwinExecutorRUNPER  covtypeNorm      4           1
# 19                            OzaBagAdwin  covtypeNorm      1           1
# 43                            OzaBagAdwin  covtypeNorm      1           1
# 82                            OzaBagAdwin  covtypeNorm      1           1
# 34               OzaBagASHTExecutorRUNPER  covtypeNorm      4           1
# 64               OzaBagASHTExecutorRUNPER  covtypeNorm      4           1
# 51               OzaBagASHTExecutorRUNPER  covtypeNorm      4           1
# 99                             OzaBagASHT  covtypeNorm      1           1
# 124                            OzaBagASHT  covtypeNorm      1           1
# 77                             OzaBagASHT  covtypeNorm      1           1
# 36                                 OzaBag  covtypeNorm      1           1
# 13                                 OzaBag  covtypeNorm      1           1
# 75                                 OzaBag  covtypeNorm      1           1
# 32                          LeveragingBag  covtypeNorm      1           1
# 1                           LeveragingBag  covtypeNorm      1           1
# 125                         LeveragingBag  covtypeNorm      1           1
# 102                    LBagExecutorRUNPER  covtypeNorm      4           1
# 96                     LBagExecutorRUNPER  covtypeNorm      4           1
# 8                      LBagExecutorRUNPER  covtypeNorm      4           1
# 91         AdaptiveRandomForestSequential  covtypeNorm      1           1
# 128        AdaptiveRandomForestSequential  covtypeNorm      1           1
# 110        AdaptiveRandomForestSequential  covtypeNorm      1           1
# 47     AdaptiveRandomForestExecutorRUNPER  covtypeNorm      4           1
# 6      AdaptiveRandomForestExecutorRUNPER  covtypeNorm      4           1
# 98     AdaptiveRandomForestExecutorRUNPER  covtypeNorm      4           1
# 143  StreamingRandomPatchesExecutorRUNPER     airlines      4           1
# 53   StreamingRandomPatchesExecutorRUNPER     airlines      4           1
# 48   StreamingRandomPatchesExecutorRUNPER     airlines      4           1
# 49                 StreamingRandomPatches     airlines      1           1
# 104                StreamingRandomPatches     airlines      1           1
# 112                StreamingRandomPatches     airlines      1           1
# 31                   OzaBagExecutorRUNPER     airlines      4           1
# 83                   OzaBagExecutorRUNPER     airlines      4           1
# 137                  OzaBagExecutorRUNPER     airlines      4           1
# 2               OzaBagAdwinExecutorRUNPER     airlines      4           1
# 103             OzaBagAdwinExecutorRUNPER     airlines      4           1
# 60              OzaBagAdwinExecutorRUNPER     airlines      4           1
# 100                           OzaBagAdwin     airlines      1           1
# 30                            OzaBagAdwin     airlines      1           1
# 37                            OzaBagAdwin     airlines      1           1
# 54               OzaBagASHTExecutorRUNPER     airlines      4           1
# 87               OzaBagASHTExecutorRUNPER     airlines      4           1
# 108              OzaBagASHTExecutorRUNPER     airlines      4           1
# 9                              OzaBagASHT     airlines      1           1
# 134                            OzaBagASHT     airlines      1           1
# 58                             OzaBagASHT     airlines      1           1
# 107                                OzaBag     airlines      1           1
# 4                                  OzaBag     airlines      1           1
# 21                                 OzaBag     airlines      1           1
# 126                         LeveragingBag     airlines      1           1
# 12                          LeveragingBag     airlines      1           1
# 78                          LeveragingBag     airlines      1           1
# 130                    LBagExecutorRUNPER     airlines      4           1
# 14                     LBagExecutorRUNPER     airlines      4           1
# 85                     LBagExecutorRUNPER     airlines      4           1
# 115        AdaptiveRandomForestSequential     airlines      1           1
# 74         AdaptiveRandomForestSequential     airlines      1           1
# 55         AdaptiveRandomForestSequential     airlines      1           1
# 135    AdaptiveRandomForestExecutorRUNPER     airlines      4           1
# 62     AdaptiveRandomForestExecutorRUNPER     airlines      4           1
# 66     AdaptiveRandomForestExecutorRUNPER     airlines      4           1
# 22   StreamingRandomPatchesExecutorRUNPER         GMSC      4           1
# 24   StreamingRandomPatchesExecutorRUNPER         GMSC      4           1
# 92   StreamingRandomPatchesExecutorRUNPER         GMSC      4           1
# 44                 StreamingRandomPatches         GMSC      1           1
# 40                 StreamingRandomPatches         GMSC      1           1
# 132                StreamingRandomPatches         GMSC      1           1
# 114                  OzaBagExecutorRUNPER         GMSC      4           1
# 123                  OzaBagExecutorRUNPER         GMSC      4           1
# 46                   OzaBagExecutorRUNPER         GMSC      4           1
# 7               OzaBagAdwinExecutorRUNPER         GMSC      4           1
# 95              OzaBagAdwinExecutorRUNPER         GMSC      4           1
# 42              OzaBagAdwinExecutorRUNPER         GMSC      4           1
# 38                            OzaBagAdwin         GMSC      1           1
# 111                           OzaBagAdwin         GMSC      1           1
# 61                            OzaBagAdwin         GMSC      1           1
# 113              OzaBagASHTExecutorRUNPER         GMSC      4           1
# 93               OzaBagASHTExecutorRUNPER         GMSC      4           1
# 94               OzaBagASHTExecutorRUNPER         GMSC      4           1
# 106                            OzaBagASHT         GMSC      1           1
# 11                             OzaBagASHT         GMSC      1           1
# 10                             OzaBagASHT         GMSC      1           1
# 33                                 OzaBag         GMSC      1           1
# 86                                 OzaBag         GMSC      1           1
# 5                                  OzaBag         GMSC      1           1
# 76                          LeveragingBag         GMSC      1           1
# 70                          LeveragingBag         GMSC      1           1
# 68                          LeveragingBag         GMSC      1           1
# 39                     LBagExecutorRUNPER         GMSC      4           1
# 109                    LBagExecutorRUNPER         GMSC      4           1
# 17                     LBagExecutorRUNPER         GMSC      4           1
# 122        AdaptiveRandomForestSequential         GMSC      1           1
# 80         AdaptiveRandomForestSequential         GMSC      1           1
# 129        AdaptiveRandomForestSequential         GMSC      1           1
# 116    AdaptiveRandomForestExecutorRUNPER         GMSC      4           1
# 140    AdaptiveRandomForestExecutorRUNPER         GMSC      4           1
# 120    AdaptiveRandomForestExecutorRUNPER         GMSC      4           1
#
#      inc_rate  out_rate  instances   time     delay   acc  duration  \
# 3         229    224.68  26,955.00 119.97    889.00 90.27       124
# 41        127    124.88  14,975.00 119.91    158.00 91.23       124
# 16         25     25.00   3,000.00 119.98     20.00 92.07       124
# 133       229    172.46  20,695.00 120.00  7,466.00 91.33       124
# 89        127    124.73  14,968.00 120.01    282.00 91.58       124
# ...
# 5         184    179.95  21,564.00 119.83     14.00 93.55       126
# 76        814    703.21  84,386.00 120.00  5,679.00 93.48       126
# 10          3.44       788.20     189.67     22,762.00  412.50 0.02   10
# 33          4.00       671.60   1,655.10    150,000.00  362.00 0.00   90
# 86          3.68       830.80     916.80    110,032.00  440.83 0.00   50
# 5           3.43       785.10     179.69     21,564.00  410.82 0.02   10
# 76          4.14       943.50     807.52     97,038.00  496.58 0.01   90
# 70          3.87       882.50     448.89     53,910.00  464.48 0.01   50
# 68          3.54       802.70      89.86     10,800.00  424.37 0.04   10
# 39          4.49       987.00     807.51     97,038.00  538.37 0.01   90
# 109         4.02       908.00     448.86     53,910.00  482.14 0.01   50
# 17          3.55       812.70      89.85     10,800.00  425.88 0.04   10
# 122         4.16       919.10     628.32     75,474.00  499.07 0.01   90
# 80          3.91       884.30     349.24     41,930.00  469.52 0.01   50
# 129         3.52       789.50      69.89      8,400.00  422.95 0.05   10
# 116         4.63     1,038.10     628.32     75,474.00  556.14 0.01   90
# 140         4.08       913.00     349.23     41,930.00  488.94 0.01   50
# 120         3.54       793.80      69.89      8,400.00  425.25 0.05   10
#
#         tput       label
# 3     224.68    Parallel
# 41    124.88    Parallel
# 16     25.00    Parallel
# 133   172.46  Sequential
# 89    124.73  Sequential
# 20     25.00  Sequential
# 27  1,198.35    Parallel
# 59    688.10    Parallel
# 101   134.95    Parallel
# 117 1,007.79    Parallel
# 79    573.32    Parallel
# 88    114.96    Parallel
# 69  1,026.14  Sequential
# 73    573.34  Sequential
# 56    114.97  Sequential
# 25  1,175.07    Parallel
# 139   667.96    Parallel
# 127   129.95    Parallel
# 141 1,189.54  Sequential
# 118   668.04  Sequential
# 97    129.97  Sequential
# 90  1,220.99  Sequential
# 29    688.16  Sequential
# 138   134.96  Sequential
# 45    513.36  Sequential
# 84    339.12  Sequential
# 57     64.90  Sequential
# 71    610.89    Parallel
# 105   339.33    Parallel
# 23     64.90    Parallel
# 119   302.67  Sequential
# 65    214.75  Sequential
# 26     39.97  Sequential
# 72    394.05    Parallel
# 121   214.80    Parallel
# 136    40.00    Parallel
# 18    103.62    Parallel
# 142    59.90    Parallel
# 0      10.00    Parallel
# 52     74.45  Sequential
# 28     59.75  Sequential
# 131    10.00  Sequential
# 67    301.48    Parallel
# 50    214.67    Parallel
# 81     39.99    Parallel
# 35    311.35    Parallel
# 63    209.68    Parallel
# 15     39.97    Parallel
# 19    195.94  Sequential
# 43    202.35  Sequential
# 82     39.97  Sequential
# 34    307.53    Parallel
# 64    214.67    Parallel
# 51     39.98    Parallel
# 99    194.52  Sequential
# 124   204.17  Sequential
# 77     39.97  Sequential
# 36    271.70  Sequential
# 13    214.61  Sequential
# 75     39.99  Sequential
# 32    128.53  Sequential
# 1     128.85  Sequential
# 125    25.00  Sequential
# 102   259.40    Parallel
# 96    144.87    Parallel
# 8      25.00    Parallel
# 91    222.25  Sequential
# 128   198.60  Sequential
# 110    40.00  Sequential
# 47    350.87    Parallel
# 6     199.80    Parallel
# 98     40.00    Parallel
# 143    52.25    Parallel
# 53     49.58    Parallel
# 48     14.99    Parallel
# 49     26.78  Sequential
# 104    26.62  Sequential
# 112    14.97  Sequential
# 31    138.08    Parallel
# 83    131.74    Parallel
# 137    79.79    Parallel
# 2     144.19    Parallel
# 103   109.20    Parallel
# 60     19.99    Parallel
# 100   125.96  Sequential
# 30    106.45  Sequential
# 37     19.99  Sequential
# 54    138.94    Parallel
# 87    138.30    Parallel
# 108    54.89    Parallel
# 9     123.08  Sequential
# 134   127.74  Sequential
# 58     54.92  Sequential
# 107   108.33  Sequential
# 4     122.63  Sequential
# 21     79.87  Sequential
# 126    36.17  Sequential
# 12     36.20  Sequential
# 78     14.99  Sequential
# 130    59.51    Parallel
# 14     60.34    Parallel
# 85     14.99    Parallel
# 115    36.95  Sequential
# 74     36.83  Sequential
# 55     14.99  Sequential
# 135    55.37    Parallel
# 62     59.91    Parallel
# 66     14.99    Parallel
# 22    299.48    Parallel
# 24    164.87    Parallel
# 92     30.00    Parallel
# 44    297.31  Sequential
# 40    164.81  Sequential
# 132    30.00  Sequential
# 114 1,651.11    Parallel
# 123   916.90    Parallel
# 46    179.90    Parallel
# 7   1,565.55    Parallel
# 95    872.03    Parallel
# 42    174.92    Parallel
# 38  1,570.34  Sequential
# 111   872.04  Sequential
# 61    174.95  Sequential
# 113 1,714.03    Parallel
# 93    952.25    Parallel
# 94    189.95    Parallel
# 106 1,721.31  Sequential
# 11    952.39  Sequential
# 10    189.93  Sequential
# 33  1,656.49  Sequential
# 86    917.57  Sequential
# 5     179.95  Sequential
# 76    703.21  Sequential
# 70    448.89  Sequential
# 68     89.85  Sequential
# 39    806.53    Parallel
# 109   448.99    Parallel
# 17     89.86    Parallel
# 122   507.37  Sequential
# 80    349.43  Sequential
# 129    69.89  Sequential
# 116   622.85    Parallel
# 140   349.53    Parallel
# 120    69.91    Parallel
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Consumo energético para 4 cores
#
# Nestes gráficos podemos observar o consumo energético para a frequencia minima de 600 com a frequencia maxima de 600 e também para as frequencias minima de 1200 com a frequencia máxima de 1200. As duas barras são em azul o algoritmo sequencial sem alteração e a em laranja o paralelo com alteração. Os comportamentos destes algoritmos em geral são em questão de eficiencia energética muito similares, salvo algumas exceções como o streaming random patches que deve um ganho em eficiencia ao ser implementado o algoritmo paralelo nas taxas de 50% e 90%. Para analisar a diferença energética entre as frequencias iremos fixar a analise no OzaBag que já foi comprovado ter um melhor desempenho energético por conta da sua estrutura de dados. As execuções também se comporta com uma aparencia muito similar ao resultado de 2 cores. O ganho energético entre utilização de frequencias menores o maiores não trazem muita diferença entre os valores finais.

# %% [markdown]
# # Consumo energético entre 4 e 2 cores
#
# Se olhamos o que mais consumiu em 2 cores foi o algoritmo StreamingRandomPatches na frequencia 600x600 com o consumo de JPI em 0.30 agora olhando o que maior consumiu em 4 cores também foi o mesmo algoritmo na mesma frequencia. A média de frequencia entre os cores ficaram muito similares em ambos cores. O que está bem diferente é o consumo médio em relação a frequencia menores, de acordo com a literatura o ganho energético se daria quando utilizassemos frequencias menores.

# %%
for f,df in zip(freqs, dataframes_four_cores):
    print(f'\n\n\n----------------- {f} -----------------')
    df = df[df.PERC == '90']
    df = df.loc[:,['dataset','algorithm','batch_size','acc', 'instances', 'time', 'JPI']]
    df = select_columns_and_rename_values(df)
    df = add_label_column_df(df).sort_values(by=['label'], ascending=False)
    df['IPS'] = df['instances'] / df['time']
    gen_graph_initial_peralg(df, display_df=False, freq=f)
# Out:
# ----------------- {'minimum': '600', 'maximum': '600'} -----------------
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_58754/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# ----------------- {'minimum': '1200', 'maximum': '1200'} -----------------
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Analise acuracia x IPS x JPI
#
# Nesta seção do notebook iremos analisar o comportamento em relação a acuracia e os valores de instancias por segundo (IPS) e os Joules por instancia (JPI). Para essa analise irei fixar novamente no algoritmo OzaBag nas frequencias minimas e máximas. Iniciando pela frequencia minima  temos que o maior IPS foi de 897 com um valor máximo de JPI de 0.00410 no mesmo dataset, na frequencia máxima os valores do IPS máximo foi de 1656 e JPI de 0.00270.
#
# Olhando outro algoritmo, SRP, temos que o maior IPS na frequencia minima ficou de 180 no dataset GMSC com um JPI máximo neste dataset de 0.0240, já na frequencia máxima para o mesmo dataset e algoritmo, temos um IPS de 299 com JPI de 0.01434. Novamente mostrando que mesmo a frequencia minima consumindo mais em geral, para o consumo por instancia o JPI para frequencias maiores é melhor pois consegue processar muito mais instancias utilizando um valor próximo de JPI.

# %% [markdown]
# # Conclusão
#
# As perguntas que gostariamos de responder com esses experimentos estão descritas no inicio desde notebook, como, qual core e qual frequencia tem o melhor ganho em performance e energia, mudar os valores de frequencia e os cores disponiveis afetam a qualidade preditiva do software e em relação ao mini-batching utilizar as técnias de DPM e DVFS utilizadas aqui melhoram o consumo energético. Neste sentido, olhamos os dados disponiveis e gerados, e observamos alguns fatos como ao contrário do que era esperado o JPI não ficou menor ao utilizar frequencias menores ou menos cores disponiveis. Mas ao utilizar essas frequencias menores consumimos a mesma quantidade de energia ou muito proximas quando utilizamos mais recursos como mais cores e mais frequencia, pois com mais recursos foi possivel processar o dobro de informação utilizando menos JPI.
#
# A qualidade preditiva em todas as execuções mesmo mudando os valores de frequencia e cores disponiveis se mantém, a qualidade só é perdida quando utilizamos o MOA paralelo, mas independente da execução é mantido sua qualidade a execução anterior. Em relação ao número de cores disponivei podemos ver que não há grande diferença sobre o número de JPI nem o número de IPS. Na minima frequencia com 2 cores foi possivel processar um IPS de 880 já em 4 cores esse número ficou em 897, com o JPI respectivamente em 0.0044 e 0.00410, e na frequencia máxima, para 2 cores o IPS ficou em 1650 e para 4 cores 1656, com o JPI de 0.0034 e 0.00270.
#
# Em relação aos resultados do mini-batching temos a qualidade preditiva se mantém utilizando as frequencias menores ou maiores, e por vez superiores, já que o mini-batching em alguns algoritmos perde a sua qualidade preditiva. No consumo energético geral, temos que o maior consumo foi referente ao SRP em uma taxa de saída de 90% no dataset airlines com um JPI de 0.25, já para 2 cores o maior consumo ficou em 0.35 para a frequencia de 1200x1200 e em 4 cores também 0.35 na frequencia máxima. Na analise individual do IPS por algoritmo o OzaBag do mini-batching tem um IPS máximo de 3700 e de JPI em 0.00170 que é muito maior do que a melhor execução das frequencias máximas e minimas e dos cores disponiveis.
