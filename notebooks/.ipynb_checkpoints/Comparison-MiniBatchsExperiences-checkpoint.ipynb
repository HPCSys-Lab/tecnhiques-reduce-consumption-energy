# %% [markdown]
# # Introduçao
#
# Esse notebook tem como objetivo comparar as duas execuções do mini-batching. A execução anterior utilizava dois loops com o mesmos indices, o novo algoritmo utiliza somente um for e evita duplicidade de palelização imaginamos que ficaria mais otimizado. Para o algoritmo otimizado utilizamos uma faixa de mini-batchins de 5 a 2000 (5, 15, 25, 50, 75, 100, 500, 2000) rodando os algoritmos ARF e o OzaBag, com os datasets Airlines e elecNormNew, foram feitas 3 execuções com o Rasperry PI em frequencia normal.
#
# Iremos observar se a nova execução traz ganhos em otimização energética processando mais instancias com menos joules e também se ela mantém a acurácia dos algoritmos para os datasets escolhidos inicialmente.

# %% [markdown]
# ## Resultados com otimização

# %%
# %run "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/MOA-MiniBatchingOptimized-Preliminary.ipynb"
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66035/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66035/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_66035/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# ...

# %% [markdown]
# ### Precision e Recall
#
# Os resultados de precision e recall ficaram estaveis para todos os tamanhos de mini-batchings na execução do algoritmo ARF. Já no algoritmo OzaBag em todas execuções há pequenas distoções, a que representa a maior queda é no tamanho 25 e também 75, apesar destas distoções nao serem tão altas elas acontecem e ficam variando entre 60%, 61% e 58%. Outro ponto interessante é podemos observar que nas 3 execuções elas permanecem com o mesmo valor nao variando independente da execução.
#
# ### Thoughput e Delay
#
# Iremos analisar o gasto de Joules por thoughput e também o delay de cada execução. Novamente, foram feitos 3 experimentos com a mesma configuração para obter os dados necessários para analise. Primeiro, vamos falar sobre as distoções na primeira e terceira execução tem duas colunas bem diferente do restante nao pude entender o real motivo destes valores mas acredito que seja apenas a coleta do Watts que não fez o output correto no arquivo de ssh-log. Na primeira execução o melhor desempenho foi para o thoughtput de 50% no algoritmo ARF e o mesmo no OzaBag para o dataset airlines. Em outras execuções as médias se mantevem. Já para o dataset ElecNormNew as execuções tiveram um melhor desempenho em 90% apesar de ter ganho significativo em 50%.
#
# ### Acuracia, Joules por Instancia e Instancias por segundo
#
# No último gráfico analisamos as três variaveis Acuracia, JPI e IPS. A ideia é quanto maior o IPS e menor o JPI melhor o desempenho energético e otimização do algoritmo desde que se mantenha a acuracia. Assim como as outras execuções esta foi executada 3 vezes com as mesmas configurações para entendemos o valor médio já que o Joules e IPS pode variar um pouco. Para facilitar, vamos analisar primeiro todas execuções do ARF com Airlines e Elecnormnew e na seguencia as execuções do OzaBag com ambos datasets.
#
# No ARF rodando no airlines na primeira execução o melhor mini-batching é o tamanho 500 pois tem o menor JPI e o maior IPS. Já para o algoritmo ElecnormNew o melhor foi o tamanho 25. Nas outras execuções o valor é similar apesar das distoções. Um ponto de atenção é que na terceira execução o airlines ficou com o JPI zerado até o mini-batching de 500, parece novamente um erro de coleta de dados. Outro comportamento importante é que no elecnormnew podemos observar um balão inverso no gráfico, exemplo com o mini-batching menor de 5 ele começa com um JPI muito alto e o IPS muito baixom as ao chegar em 25 até 250, 500 temos uma estabilização de melhores JPI e IPS, mas ao chegar em um mini-batching do tamanho 2000 os valores se cruzam novamente diminuindo o IPS e aumentando o JPI.
#
# No algoritmo OzaBag tivemos melhores coletas de dados e menos distoções. Analisando o primeiro dataset airlines nas três execuçõe podemos observar que os menores mini-batchings tem um gasto maior de JPI e o processamento menor em IPS, exceto na terceira execução podemos observar que quanto maior o mini-batching melhor foi o seu desempenho energetico e de processamento. Apesar que a partir do mini-batching 2000 vemos o gráfico aumento em JPI novamente e diminuindo em IPS, assim como ocorreu em outras interações. Novamente no dataset electricity temos um comportamento parecido ao ARF vemos um balão de melhoria nos mini-batchings intermediarios do 15 ao 500 e uma piora no mini-batching de 2000. Dentro das distoções podemos observar que isso ocorre para todas execuções.

# %% [markdown]
# ## Resultados sem otimização

# %%
# %run "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/MOA-MiniBatching-Batchs.ipynb"
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_5356/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_5356/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_5356/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# ...

# %% [markdown]
# ### Observações
#
# Para estas execuções foram executados todos os algoritmos, mas podemos nos atentar principalmente no ARF e OzaBag para analise com o anterior.
#
# ### Precision e Recall
#
# Nessa primeira parte estamos analisando o precision e recall para os batchs de tamanho grande. 50, 500 e 2000. Pegando o dataset Electricity e sua precisão e recall podemos observar que ao utilizar o os batch-sizes de tamanho entre 50 à 2000eles pedem um pouco em relação ao MOA comum e ao MOA paralelo. No dataset GMSC para o algoritmo OzaBag temos uma linha estável de precisão e recall para todos os cenários. O algoritmo OzaBag também em outros datasets é o que mais tem estabilidade ao utilizar o mini-batching ou sem ele. Já no dataset covertype podemos observar uma linha um pouco mais de instabilidade ao adicionamos a paralelização no algoritmos, alguns casos descem como o Ozabag e outros como o LBag melhoram a precisão porém com os mini-batchs esses dados são estabilizados.
#
# ### Thoughput e Delay
#
# As taxas de vazão e delay para os experimentos sem otimização também tem uma tendencia em diminuir conforme o tamanho da carga aumenta. Neste caso o melhor é quanto menor o JPI gasto e menor o delay melhor o resultado isso acontece tanto no batchs pequenos quanto nos grandes, apesar de haver uma alteração em 3 execuções para o batch grande a tendencia é que quanot maior a taxa de vazão menor o gasto em JPI e delay. Observando apenas o ARF e o OzaBag no airlines podemos ver que os resultados em JPI tem a mesma tendencia e também no dataset elecNormNew.
#
# ### Acuracia, Joules por Instancia e Instancias por segundo
#
#
# No consumo de JPI x IPS a tendencia para o Airlines com ARF é diminuir até o batch de tamanho 500 e depois aumentar, assim também ocorre no elecNormNew. Já no OB para o dataset airlines ele começa com um bom desempenho no menor mini-batching e tem uma tendencia a pior nos demais, para o dataset elecNormNew vemos novamente o balão onde os números intemerdiarios tem um melhor desempenho em relação os menos e maiores batchs. Quando falado númericamente, a melhor execução no ARF tem um JPI de 0.068 e IPS de 95 com o mini-batching de tamanho 500 no dataset Airlines, já para o ElecNormNew o melhor tamanho ficou em 50 com um JPI de 0.0090 com um IPS de 660. Para o OB temos o melhor desempenho no mini-batching 75 com um JPI em 0.032 e IPS de 210 no dataset airlines, já no dataset elecNormNew o melhor mini-batching também é o de 75 com um IPS de 2400 e um JPI de 0.0027.

# %% [markdown]
# ## Conclusões
#
# Após as analises e resultados as primeiras evidencias que podemos assumir, é que não há uma piora em nenhuma execução com a otimização do algoritmo. Todos os gráficos tem uma tendencia muito parecida com as execuções anteriores sem a otimização do algoritmo. Isso se deve por não temos feitos grandes mudanças em como o calculo dos pesos e dos ensembles são feitos apenas fizemos pequenas alterações estruturais.
#
# Já quanto ao desempenho energético em relação as execuções anteriores sem a otimização podemos ver uma tendencia muito similar as execuções anteriores exceto que os números são bem diferentes. Na execução sem otimização por exemplo no algoritmo ARF com dataset Airlines no mini-batching de tamanho 75 temos um IPS aproximadamente 90 e um JPI de 0.070, já na execução com otimização as mesmas configurações tem um IPS de 95 e um JPI de 0.060. Olhando o mesmo dataset e tamanho de mini-batching mas no algoritmo OzaBag temos que o IPS ficou em 210 e o JPI em 0.032 sem a otimização e com a otimização o IPS ficou em 1900 e o JPI em 0.0030 que representa um desempenho muito melhor em ambas execuções.
#
# Podemos dizer que com esses resultados iniciais a otimização traz ganho em desempenho energético. Mas ainda precisa ser analisado se também houve uma melhora em speedup com essa otimização. Outro fato é que nos dois casos tanto o otimizado quanto o não otimizado há um balão entre os valores intermediários de mini-batching, podemos ver em todos os gráficos uma tendencia nos valores de 25 à 500 que o IPS são maiores e o JPI menores.
