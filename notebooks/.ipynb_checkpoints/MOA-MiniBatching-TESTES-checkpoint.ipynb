# %% [markdown]
# # Analisy results MOA mini-batching
#
# The results compareds this work use follow variables.
#
# Frequencies in MHz:
#
#     - Minimum: 600Mhz, Maximum: 1200Mhz
#
# Size mini-batching uses are:
#
#     - 1 (Sequential without mini-batching)
#     - 1 (Sequential with mini-batching)
#     - 25 (Paralel 4 CPUs with mini batching)
#     - 75 (Paralel 4 CPUs with mini batching)
#     - 50 (Paralel 4 CPUs with mini batching)
#     - 100 (Paralel 4 CPUs with mini batching)
#
# All executions are used ensemble size 25.

# %% [markdown]
# # Main Question
#
# Qual é o consumo energético e a acuracia para os batch-size de 25 à 100.

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
# %mkdir -p parsed_csvs figures
# %cd results
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %%
def parse(fname):
    global header_printed
    #index of wanted columns
    columns = []
    #column names to get the data from
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    ret_string = ''
    #remove the path and isolate the filename
    spname = fname.split('/')[-1].split('-')
    spline = []
    #control flag for knowing when the column names have already been discovered
    got = False
    #we ignore the first parameter of the filename and add all others to the csv string
    for s in spname[1:]:
        ret_string += s + ','
    #should probably use a safer way, but python handles the closing of the file
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                #sometimes the dump file has multiple results in it, so we get the index of wanted columns only once
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        #OzaBagASHT bugs out on GMSC, this reuses the data from the sequential execution
        if 'GMSC' in spname and 'ASHT' in spname[2]:
            for c in columns[:-2]:
                ret_string += str(spline[c]) + ','
            ret_string += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        #normal code, how everything should run
        #we process the data (add the content of wanted columns to the csv string) only after the for
        #ensuring we use only the last (most recent) data and not the intermediate results
        else:
            for c in columns:
                ret_string += str(spline[c]) + ','
            if len(columns) == 5:
                ret_string += '0,'
        #header is a global variable, it will only be printed on the first file 
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,instances,time,acc,prec,recall,change'
            ret_string = f"{head}\n{ret_string}"
            header_printed = True
        #remove the last comma ,
        return (ret_string[:-1])

# %%
#loads the csv as a dataframe and standardizes the algorithm names 
def load_df(filename):
    df = pd.read_csv(filename, index_col=False)
    return select_columns_and_rename_values(df)

# %%
#standardize algorithm names
def select_columns_and_rename_values(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    df.batch_size.unique()
    return df

# %%
#filters by substring (there are multiple OzaBag algorithms)
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %%
#plots precision and recall with markers of one parameter configuration
def gen_lines(df, ax, alg_order, markers):
    lwidth = 0.75
    if markers:
        colors=['go', 'bs', 'rP', 'md', 'y+' , 'k*']
    else:
        colors=['g', 'b', 'r', 'm', 'y' , 'k']

    labels = df.batch_size
    alg = df.algorithm.unique()[0]
    x = np.arange(len(labels))
    
    ax.plot(x, pd.to_numeric(df.prec), f'{colors[alg_order]}--', linewidth=lwidth, label=f'{alg}-prec')
    ax.plot(x, pd.to_numeric(df.recall), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')

    #ax.plot(x,pd.to_numeric(df.prec), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_ylim(50,95)

# %%
#iterates over the parameter configurations and creates the chart grid
def gen_chart(df, markers=True, tables=False):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
    #dictionary containing the correct name to be printed
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    #creates a 2x2 grid for plotting the charts
    #sharey=row means that all charts in a row share the same Y-axis
    fig, axs = plt.subplots(2, 2, figsize=(8,8), sharey='row')
    filename = "batch-size-vs-prediction-mark" if markers else "batch-size-vs-prediction"
    #each chart presents the results for a given dataset and contains the series for all algorithms
    for ds in datasets:
        title = ''
        my_id = datasets.index(ds)
        #selects the correct position in the grid
        ax = axs[int(my_id/2)][my_id%2]
        ax.set_title(f'{dsformalname[ds]}')
        #for each algorithm
        for alg in algorithms:
            #filters the df to contain the wanted values
            df_aux = filter_by_substring_algorithm(df[df.dataset == ds].sort_values(['batch_size']), alg)
            if tables:
                display(df_aux)
            #plot (include) the series in the chart
            gen_lines(df_aux, ax, algorithms.index(alg), markers)
            #if its the first column, print Y-axis label
            if my_id%2 == 0:
                ax.set_ylabel('Percentage')
            #if its the last row, print the X-axis label
            if int(my_id/2) == 1:
                ax.set_xlabel('Batch sizes')
    #retrieves the handles and labels to create a global legend
    handles, labels = axs[0][0].get_legend_handles_labels()
    lgd = fig.legend(handles, labels, loc = 'lower center', ncol = math.ceil(len(algorithms)/2), bbox_to_anchor=(0.5,-0.1))
    fig.tight_layout()
    plt.savefig(f'figures/{filename}.png')
    plt.savefig(f'figures/{filename}.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/06-03-2022/600/1200/first"
wantedCSVfilename = "data-batch-vs-acc-600-1200.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

df = load_df(f'{csvFile}')
df = df.drop(['cores', 'time'], axis=1)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_89198/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_89198/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_89198/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_89198/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_89198/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
#false makes the chart without markers
gen_chart(df)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Pegando o dataset Electricity e sua precisão e recall podemos observar que ao utilizar o os batch-sizes de tamanho entre 25 à 100 eles pedem um pouco em relação ao MOA comum e ao MOA paralelo. No dataset GMSC para o algoritmo OzaBag temos uma linha estável de precisão e recall para todos os cenários. O algoritmo OzaBag também em outros datasets é o que mais tem estabilidade ao utilizar o mini-batching ou sem ele. Já no dataset covertype podemos observar uma linha um pouco mais de instabilidade ao adicionamos a paralelização no algoritmos, alguns casos descem como o Ozabag e outros como o LBag melhoram a precisão porém com os mini-batchs esses dados são estabilizados.

# %% [markdown]
# # Consumer Energy

# %%
PATH_TO_RESULTS = '/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/socket/06-03-2022/'

# %%
def parse_MOA(fname):
    global header_printed
    columns = []
    wanted = ['learning evaluation instances', 'Wall Time (Actual Time)', 'Avg Delay (ms)', 'outRate (inst/s)', 'classifications correct (percent)']
    pstr = ''
    spname = fname.split('/')[-1].split('-')
    spline = []
    for s in spname[1:]:
        pstr += s + ','
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                spline = line.split(',')
                for s in spline:
                    if s in wanted:
                        columns.append(spline.index(s))
            else:
                spline = line.split(',')
        for c in columns:
            pstr += spline[c] + ','
        if len(columns) == 2:
            pstr += '1,'
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,inc_rate,instances,time,delay,out_rate,acc'
            pstr = f"{head}\n{pstr}"
            header_printed = True
        return (pstr[:-1])

# %%
def read_MOA(folder, out_file):
    directory = os.fsencode(folder)
    global header_printed

    with open(out_file, "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("term-"): 
                output.write(f"{parse_MOA(f'{os.fsdecode(directory)}/{filename}')}\n")
    fname = os.fsdecode(out_file)
    df = pd.read_csv(fname)

    df['inc_rate'].astype('int64')
    return df[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'instances', 'time', 'delay', 'out_rate', 'acc']]

# %% [markdown]
# # Read Energy Data

# %%
def load_Wmeas(filename):
    return pd.read_csv(filename, header=None, names=['date', 'time', 'measure'])

# %%
def exper_order_to_dict(filename, d):
    with open(filename) as forder:
        got_timestamp = False
        dataset = algorithm = Esize = cores = Bsize = ''
        dnow=None
        for line in forder:
            if not got_timestamp:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
                if dnow:
                    dnow['finish'] = date_time_obj - datetime.timedelta(seconds=1)
            elif ':' not in line:
                spline = line.split('/')[-1].strip().split('-')
                #print(spline)
                if len(spline) == 6:
                    dataset,algorithm,Esize,cores,Bsize,rate = spline
                else:
                    dataset,algorithm,Esize,cores,Bsize,rate = *spline,1
                if algorithm not in d:
                    d[algorithm] = {}
                if dataset not in d[algorithm]:
                    d[algorithm][dataset] = {}
                if Esize not in d[algorithm][dataset]:
                    d[algorithm][dataset][Esize] = {}
                if cores not in d[algorithm][dataset][Esize]:
                    d[algorithm][dataset][Esize][cores] = {}
                if Bsize not in d[algorithm][dataset][Esize][cores]:
                    d[algorithm][dataset][Esize][cores][Bsize] = {}
                if rate not in d[algorithm][dataset][Esize][cores][Bsize]:
                    d[algorithm][dataset][Esize][cores][Bsize][rate] = {'start': date_time_obj, 'finish': ''}
                    dnow = d[algorithm][dataset][Esize][cores][Bsize][rate]
                got_timestamp = False
            else:
                spline = [i.strip() for i in line.split(' ')]
                sdate,stime = spline
                date_time_obj = datetime.datetime.strptime(f'{sdate} {stime}', '%d/%m/%y %H:%M:%S')
                got_timestamp = True
    return d

# %%
def populate_dict(d, df):
    df['datetime'] = df['date'] + ' ' + df['time']
    for k, v in d.items():
        for k1, v1 in v.items():
            for k2, v2 in v1.items():
                for k3, v3 in v2.items():
                    for k4, v4 in v3.items():
                        for k5, v5 in v4.items():
                            if 'seconds' not in v5:
                                st = v5['start']
                                ed = v5['finish']
                                v5['seconds'] = (ed - st).seconds
                                new_df = df[(df.datetime <= f'{ed.strftime("%d/%m/%y")} {ed.strftime("%X")}')
                                          & (df.datetime >= f'{st.strftime("%d/%m/%y")} {st.strftime("%X")}')]
                                v5['avg_measure'] = new_df['measure'].mean()
                                v5['sum_measure'] = new_df['measure'].sum()
                                v5['avg_times_seconds'] = v5['avg_measure'] * v5['seconds']
    return d

# %%
def append_dict_to_df(d, ensemble_size=False):
    dappend = {'algorithm': [], 'dataset': [], 'ensemble_size': [], 'cores': [], 
               'batch_size': [], 'duration': [], 'inc_rate': [], 'avg_measure': [], 'sum_measure': [], 'avg_times_seconds': []}
    for kalg,valg in d.items():
        for kds,vds in valg.items():
            for kens,vens in vds.items():
                for kcore,vcore in vens.items():
                    for kmbs,vmbs in vcore.items():
                        for krate,vrate in vmbs.items():
                            dappend['algorithm'].append(kalg)
                            dappend['dataset'].append(kds)
                            dappend['ensemble_size'].append(kens)
                            dappend['cores'].append(kcore)
                            dappend['batch_size'].append(kmbs)
                            dappend['duration'].append(vrate['seconds'])
                            dappend['inc_rate'].append(krate)
                            for key in ['avg_measure', 'sum_measure','avg_times_seconds']:
                                dappend[key].append(vrate[key])
    adf = pd.DataFrame(data=dappend)
    adf = adf.sort_values(['algorithm','dataset']).astype({'inc_rate': 'int64', 
                                                           'cores': 'int64',
                                                           'batch_size': 'int64'})
    if ensemble_size:
        return adf[['algorithm', 'dataset', 'ensemble_size', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]
    return adf[['algorithm', 'dataset', 'inc_rate', 'cores', 'batch_size',
               'duration', 'avg_measure', 'sum_measure']]

# %% [markdown]
# # Parse SSH Logs

# %%
def parse_SSH(fname):
    fname = os.fsdecode(fname)
    read_ssh = False
    alg = ''
    dataset = ''
    rate = ''
    d = {'algorithm': [], 'dataset': [], 'batch_size': [], 'inc_rate': [], 'prod_rate': [], 'tt_inst_prod': []}
    with open (fname, "r") as file:
        for line in file:
            if not read_ssh:
                if 'ssh-' in line:
                    read_ssh = True
                    spline = line.split('-')
                    if "MAX" in line:
                        if len(spline[1:]) == 3:
                            dataset, alg, rate = spline[1:]
                            bsize = 500
                        else:
                            dataset, alg, bsize, rate = spline[1:]
                    else:
                        dataset, alg, rate = spline[1:]
                        bsize = 1
                    d['algorithm'].append(alg)
                    d['dataset'].append(dataset)
                    d['inc_rate'].append(rate.strip())
                    d['batch_size'].append(bsize)
            else:
                if 'Total instances Producer' in line:
                    tt_inst = float(line.split(': ')[1])
                    d['tt_inst_prod'].append(tt_inst)
                elif 'Producer Rate' in line:
                    prod_rate = float(line.split(': ')[1])
                    d['prod_rate'].append(prod_rate)
                    read_ssh = False
    return pd.DataFrame.from_dict(d).astype({'inc_rate': 'int64'})

# %% [markdown]
# # Showing and preparing for charts

# %%
def filter_fields(df):
    wanted = ['algorithm', 'dataset', 'batch_size', 'cores', 'out_rate', 'instances', 'delay', 'joules', 'JPI']
    return df[[
        l for l in df.columns if any([w in l for w in wanted])
    ]]

# %%
def rename_columns_by_rate(df):
    rate = df.PERC.iloc[0]
    return df.rename(columns={"out_rate": f"out_rate_{rate}", "instances": f"instances_{rate}", 
                                "delay": f"delay_{rate}", "joules": f"joules_{rate}", 
                                "JPI": f"JPI_{rate}", "tput": f"tput_{rate}"})

# %%
def show_graph_JPI_delay(df, ax, mJPI, mDel, legend=False, title=False, ylabels=False, ds='', bar=False, share_y=False, log_y=False, norm=False, hide=True):
    if norm:
        df = my_norm(df, x=norm)
    global rate
    global twin
    width = 0.15
    alg_order = ['B25', 'B50', 'B75', 'B100']
    labels = ['10%', '50%', '90%']
    line_format = ['-', '--', ':', '-.', (0, (3, 5, 1, 5, 1, 5))]
    linfo = '--'
    x = np.arange(len(labels))
    lns_l = []
    versions = 4
    for i in range(versions):
        adf = df.iloc[i]
        values_j = [adf.JPI_10, adf.JPI_50, adf.JPI_90]
        if bar:
            lns_l += ax.bar(x - ((1 - i) * width), values_j, width, label=f'JPI-{alg_order[i]}')            
        else:
            lns_l += ax.plot(x, values_j, label=f'JPI-{alg_order[i]}')

    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax_r = ax.twinx()
    twin = ax_r
    if log_y:
        ax.set_yscale('log')
        ax_r.set_yscale('log')
    if title:
        alg_title = re.sub('Sequential', '', df.algorithm.iloc[0])
        ax.set_title(f'{alg_title}')
    if ylabels:
        ax.set_ylabel(ds)
    if last:
        ax.set_ymargin(2)
    for i in range(versions): 
        adf = df.iloc[i]
        values_d = [ x/1000 for x in [adf.delay_10, adf.delay_50, adf.delay_90]]
        if bar:
            linfo = f'k{line_format[i]}'
            lns_l += ax_r.plot(x, values_d, color='black', linestyle=line_format[i], label=f'delay-{alg_order[i]}')
        else:
            lns_l += ax_r.plot(x, values_d, linfo, label=f'delay-{alg_order[i]}')
    labs = [l.get_label() for l in lns_l]
    if legend:
        ax.legend(lns_l, labs, loc=0)
    if hide:
        ax_r.set_yticklabels([])
    if share_y == 'row':
        ax.set_ylim(top=mJPI)
        ax_r.set_ylim(top=mDel/1000)

# %%
def aux_graphNx1(ds, axis, id_ds, df, bar=False, share_y='row', log_y=False, norm=False):
    rates = ['10', '50', '90']
    algs = ['Ada', 'L', 'Patches', 'Adwin', 'ASHT', 'OzaBag']
    global title
    global labels
    hide_axis = True
#     fig.suptitle(f'JPI and delay for {ds}', fontsize=18, y=1)
#     get max value from delay for all rates on all algorithms for this dataset
    mLstJPI = []
    mLstDel = []
    if share_y == 'row':
        for rt in rates:
            rtDF = df[df.PERC == rt]
            mLstJPI.append(rtDF.JPI.max())
            mLstDel.append(rtDF.delay.max())
        mJPI = max(mLstJPI)*1.05
        mDel = max(mLstDel)*1.05
    else:
        mJPI = mDel = 0
    for alg in algs:
        dsalgdf = filter_by_substring_algorithm(df, alg).sort_values(['algorithm','batch_size','cores'])
#         if alg == 'L' and ds == 'kyoto_binary':
#             display(dsalgdf)
        for rt in rates:
            if rt == '10':
                showdf = rename_columns_by_rate(dsalgdf[dsalgdf.PERC == rt])
            else:
                to_join = dsalgdf[dsalgdf.PERC == rt]
                showdf = showdf.merge(rename_columns_by_rate(to_join),
                                  on=['algorithm', 'dataset', 'batch_size', 'cores']).sort_values(['batch_size','cores'])
       
        # debug print, if it shows it is wrong
        # if len(showdf) != 5:
        #     display(showdf)

        if 'Ada' in alg:
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, ylabels=True, ds=ds, bar=bar, share_y=share_y, log_y=log_y, norm=norm)
        else:
            if algs[-1] == alg:
                hide_axis = False
            show_graph_JPI_delay(showdf, axis[id_ds][algs.index(alg)], mJPI, mDel, title=title, bar=bar, share_y=share_y, log_y=log_y, norm=norm, hide=hide_axis)

# %%
def gen_graph(df, bars=False, share_y='row', log_y=False, norm=False, freq='600', tput=False):
    ps = f'{freq}\nbars: {bars}\nshare_y: {share_y}\nlog_y: {log_y} '
    datasets = ['airlines', 'GMSC','elecNormNew','covtypeNorm']

    fig, axis = plt.subplots(len(datasets), 6, figsize=(16,12), tight_layout=True, sharey=share_y)
    global title
    global labels
    global last
    global twin
    leg = False
    labls = True
    title = True
    last = False
    twin = axis[0][0]
    for ds in datasets:
        if datasets.index(ds) == (len(datasets) - 1):
            last = True
        dsdf = df[df.dataset == ds]
        aux_graphNx1(ds, axis, datasets.index(ds), dsdf, bar=bars, share_y=share_y, log_y=log_y, norm=norm)
        title = True
    lines_1, labels_1 = axis[0][0].get_legend_handles_labels()
    lines_2, labels_2 = twin.get_legend_handles_labels()
    lines = lines_1 + lines_2
    labels = labels_1 + labels_2
    lgd = fig.legend(lines, labels, loc=8, ncol=5, bbox_to_anchor=(0.5, -0.02))
    lgd.set_in_layout(True)
    fig.subplots_adjust(bottom=-0.5)
    filename = 'all-4x1-JPI-delay'
    if bars:
        filename = f'bars-{filename}'
    if share_y:
        filename = f'sharey-{filename}'
    if log_y:
        filename = f'logy-{filename}'
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.eps', pad_inches=0.2, bbox_inches='tight')
    plt.savefig(f'/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/figures/{freq}-{filename}.png', pad_inches=0.2, bbox_inches='tight')
    plt.show()

# %%
def debug(df):
    df = select_columns_and_rename_values(df)
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    dfalg = filter_by_substring_algorithm(df, alg)
    for ds in datasets:
        dsdf = dfalg[(dfalg.dataset == ds)]
        display(dsdf)

# %% [markdown]
# # Run methods to obtained visible results

# %%
def read_data_create_final_dataframe(freq, DEBUG=False):
    d = {}
    global header_printed
    header_printed = False
    folder_path = f"{PATH_TO_RESULTS}{freq['minimum']}/{freq['maximum']}"
    min = freq['minimum']
    max = freq['maximum']
    moaDF = read_MOA(f"{folder_path}", f"{folder_path}/inst-and-delay.csv")
    moaDF = moaDF[["algorithm", "dataset", "cores", "batch_size", "inc_rate", "out_rate", "instances", "time", "delay", "acc"]]
    measureDF = load_Wmeas(f'{folder_path}/Wm-log.log')
    d = exper_order_to_dict(f'{folder_path}/exper_order-freq-max-{max}-freq-min-{min}.log', d)
    d = populate_dict(d, measureDF)
    mdf = append_dict_to_df(d)
    sshDF = parse_SSH(f'{folder_path}/ssh-log')
    sshDF['batch_size'] = sshDF['batch_size'].astype(int)
    if DEBUG:
        print(f'moaDF: {len(moaDF)}    mdf: {len(mdf)}     sshDF: {len(sshDF)}')
    
    #join dfs
    finaldf = moaDF.merge(mdf, on=['algorithm', 'dataset', 'cores', 'batch_size', 'inc_rate'])
    finaldf = finaldf.merge(sshDF, 'left', on=['algorithm', 'dataset', 'batch_size', 'inc_rate'])

    finaldf['joules'] = finaldf['avg_measure'] * finaldf['time']
    finaldf['JPI'] = finaldf['joules'] / finaldf['instances']
    # Add PERC column to identify if it used 90, 50 or 10% max rate
    # Before merging rows with the same batch size, we need to differentiate the experiments with different work loads
    # We use the **PERC**entage column for that
    tdf = finaldf.sort_values(by=['dataset','algorithm','batch_size','inc_rate'], ascending=False)
    display(tdf)
    tdf['PERC'] = 0

    masks = {'90':[], '50': [], '10': []}
    for k, v in zip(masks.keys(), [0, 1, 2]):
        for i in range(len(tdf)):
            masks[k].append(i % 3 == v)
    
    tdf.loc[masks['90'], 'PERC'] = '90'
    tdf.loc[masks['50'], 'PERC'] = '50'
    tdf.loc[masks['10'], 'PERC'] = '10'
    
    tdf['tput'] = tdf['instances'] / tdf['time']
    if DEBUG:
        tdf.to_csv(f"{PATH_TO_RESULTS}tdf-{min}x{max}.csv")    
    return tdf

# %%
freqs = [{'minimum': '600', 'maximum': '1200'}]
dataframes = []
for f in freqs:
    dataframes.append(read_data_create_final_dataframe(f, True))
# Out:
# moaDF: 288    mdf: 288     sshDF: 288
#                                   algorithm      dataset  cores  batch_size  \
# 42   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4         100
# 106  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4         100
# 277  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4         100
# 117  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          75
# 138  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          75
# 56   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          75
# 31   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          50
# 141  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          50
# 8    StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          50
# 98   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          25
# 60   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          25
# 23   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          25
# 91                   OzaBagExecutorMAXChunk  elecNormNew      4         100
# 236                  OzaBagExecutorMAXChunk  elecNormNew      4         100
# 69                   OzaBagExecutorMAXChunk  elecNormNew      4         100
# 253                  OzaBagExecutorMAXChunk  elecNormNew      4          75
# 273                  OzaBagExecutorMAXChunk  elecNormNew      4          75
# 120                  OzaBagExecutorMAXChunk  elecNormNew      4          75
# 14                   OzaBagExecutorMAXChunk  elecNormNew      4          50
# 47                   OzaBagExecutorMAXChunk  elecNormNew      4          50
# 272                  OzaBagExecutorMAXChunk  elecNormNew      4          50
# 242                  OzaBagExecutorMAXChunk  elecNormNew      4          25
# 164                  OzaBagExecutorMAXChunk  elecNormNew      4          25
# 189                  OzaBagExecutorMAXChunk  elecNormNew      4          25
# 233             OzaBagAdwinExecutorMAXChunk  elecNormNew      4         100
# 284             OzaBagAdwinExecutorMAXChunk  elecNormNew      4         100
# 234             OzaBagAdwinExecutorMAXChunk  elecNormNew      4         100
# 210             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          75
# 59              OzaBagAdwinExecutorMAXChunk  elecNormNew      4          75
# 278             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          75
# 132             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          50
# 230             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          50
# 268             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          50
# 112             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          25
# 285             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          25
# 259             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          25
# 188              OzaBagASHTExecutorMAXChunk  elecNormNew      4         100
# 151              OzaBagASHTExecutorMAXChunk  elecNormNew      4         100
# 257              OzaBagASHTExecutorMAXChunk  elecNormNew      4         100
# 1                OzaBagASHTExecutorMAXChunk  elecNormNew      4          75
# 87               OzaBagASHTExecutorMAXChunk  elecNormNew      4          75
# 142              OzaBagASHTExecutorMAXChunk  elecNormNew      4          75
# 66               OzaBagASHTExecutorMAXChunk  elecNormNew      4          50
# 146              OzaBagASHTExecutorMAXChunk  elecNormNew      4          50
# 114              OzaBagASHTExecutorMAXChunk  elecNormNew      4          50
# 43               OzaBagASHTExecutorMAXChunk  elecNormNew      4          25
# 266              OzaBagASHTExecutorMAXChunk  elecNormNew      4          25
# 100              OzaBagASHTExecutorMAXChunk  elecNormNew      4          25
# 21                     LBagExecutorMAXChunk  elecNormNew      4         100
# 186                    LBagExecutorMAXChunk  elecNormNew      4         100
# 173                    LBagExecutorMAXChunk  elecNormNew      4         100
# 9                      LBagExecutorMAXChunk  elecNormNew      4          75
# 29                     LBagExecutorMAXChunk  elecNormNew      4          75
# 10                     LBagExecutorMAXChunk  elecNormNew      4          75
# 219                    LBagExecutorMAXChunk  elecNormNew      4          50
# 156                    LBagExecutorMAXChunk  elecNormNew      4          50
# 261                    LBagExecutorMAXChunk  elecNormNew      4          50
# 67                     LBagExecutorMAXChunk  elecNormNew      4          25
# 51                     LBagExecutorMAXChunk  elecNormNew      4          25
# 244                    LBagExecutorMAXChunk  elecNormNew      4          25
# 12     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4         100
# 99     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4         100
# 240    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4         100
# 181    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          75
# 238    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          75
# 95     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          75
# 128    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          50
# 224    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          50
# 107    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          50
# 77     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          25
# 176    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          25
# 161    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          25
# 286  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4         100
# 281  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4         100
# 17   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4         100
# 172  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          75
# 144  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          75
# 15   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          75
# 32   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          50
# 44   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          50
# 62   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          50
# 237  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          25
# 86   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          25
# 39   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          25
# 214                  OzaBagExecutorMAXChunk  covtypeNorm      4         100
# 167                  OzaBagExecutorMAXChunk  covtypeNorm      4         100
# 0                    OzaBagExecutorMAXChunk  covtypeNorm      4         100
# 229                  OzaBagExecutorMAXChunk  covtypeNorm      4          75
# 145                  OzaBagExecutorMAXChunk  covtypeNorm      4          75
# 74                   OzaBagExecutorMAXChunk  covtypeNorm      4          75
# 37                   OzaBagExecutorMAXChunk  covtypeNorm      4          50
# 270                  OzaBagExecutorMAXChunk  covtypeNorm      4          50
# 7                    OzaBagExecutorMAXChunk  covtypeNorm      4          50
# 197                  OzaBagExecutorMAXChunk  covtypeNorm      4          25
# 200                  OzaBagExecutorMAXChunk  covtypeNorm      4          25
# 126                  OzaBagExecutorMAXChunk  covtypeNorm      4          25
# 226             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4         100
# 171             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4         100
# 4               OzaBagAdwinExecutorMAXChunk  covtypeNorm      4         100
# 97              OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          75
# 165             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          75
# 79              OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          75
# 121             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          50
# 116             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          50
# 110             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          50
# 177             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          25
# 287             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          25
# 275             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          25
# 27               OzaBagASHTExecutorMAXChunk  covtypeNorm      4         100
# 241              OzaBagASHTExecutorMAXChunk  covtypeNorm      4         100
# 283              OzaBagASHTExecutorMAXChunk  covtypeNorm      4         100
# 57               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          75
# 103              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          75
# 3                OzaBagASHTExecutorMAXChunk  covtypeNorm      4          75
# 33               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          50
# 133              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          50
# 72               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          50
# 65               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          25
# 182              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          25
# 225              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          25
# 137                    LBagExecutorMAXChunk  covtypeNorm      4         100
# 30                     LBagExecutorMAXChunk  covtypeNorm      4         100
# 153                    LBagExecutorMAXChunk  covtypeNorm      4         100
# 193                    LBagExecutorMAXChunk  covtypeNorm      4          75
# 76                     LBagExecutorMAXChunk  covtypeNorm      4          75
# 279                    LBagExecutorMAXChunk  covtypeNorm      4          75
# 61                     LBagExecutorMAXChunk  covtypeNorm      4          50
# 102                    LBagExecutorMAXChunk  covtypeNorm      4          50
# 89                     LBagExecutorMAXChunk  covtypeNorm      4          50
# 250                    LBagExecutorMAXChunk  covtypeNorm      4          25
# 235                    LBagExecutorMAXChunk  covtypeNorm      4          25
# 213                    LBagExecutorMAXChunk  covtypeNorm      4          25
# 78     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4         100
# 175    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4         100
# 217    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4         100
# 48     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          75
# 83     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          75
# 11     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          75
# 185    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          50
# 129    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          50
# 55     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          50
# 58     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          25
# 251    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          25
# 212    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          25
# 49   StreamingRandomPatchesExecutorMAXChunk     airlines      4         100
# 70   StreamingRandomPatchesExecutorMAXChunk     airlines      4         100
# 195  StreamingRandomPatchesExecutorMAXChunk     airlines      4         100
# 187  StreamingRandomPatchesExecutorMAXChunk     airlines      4          75
# 143  StreamingRandomPatchesExecutorMAXChunk     airlines      4          75
# 163  StreamingRandomPatchesExecutorMAXChunk     airlines      4          75
# 94   StreamingRandomPatchesExecutorMAXChunk     airlines      4          50
# 203  StreamingRandomPatchesExecutorMAXChunk     airlines      4          50
# 207  StreamingRandomPatchesExecutorMAXChunk     airlines      4          50
# 170  StreamingRandomPatchesExecutorMAXChunk     airlines      4          25
# 68   StreamingRandomPatchesExecutorMAXChunk     airlines      4          25
# 221  StreamingRandomPatchesExecutorMAXChunk     airlines      4          25
# 252                  OzaBagExecutorMAXChunk     airlines      4         100
# 274                  OzaBagExecutorMAXChunk     airlines      4         100
# 276                  OzaBagExecutorMAXChunk     airlines      4         100
# 162                  OzaBagExecutorMAXChunk     airlines      4          75
# 159                  OzaBagExecutorMAXChunk     airlines      4          75
# 105                  OzaBagExecutorMAXChunk     airlines      4          75
# 223                  OzaBagExecutorMAXChunk     airlines      4          50
# 108                  OzaBagExecutorMAXChunk     airlines      4          50
# 155                  OzaBagExecutorMAXChunk     airlines      4          50
# 50                   OzaBagExecutorMAXChunk     airlines      4          25
# 139                  OzaBagExecutorMAXChunk     airlines      4          25
# 247                  OzaBagExecutorMAXChunk     airlines      4          25
# 119             OzaBagAdwinExecutorMAXChunk     airlines      4         100
# 169             OzaBagAdwinExecutorMAXChunk     airlines      4         100
# 130             OzaBagAdwinExecutorMAXChunk     airlines      4         100
# 201             OzaBagAdwinExecutorMAXChunk     airlines      4          75
# 82              OzaBagAdwinExecutorMAXChunk     airlines      4          75
# 16              OzaBagAdwinExecutorMAXChunk     airlines      4          75
# 73              OzaBagAdwinExecutorMAXChunk     airlines      4          50
# 52              OzaBagAdwinExecutorMAXChunk     airlines      4          50
# 63              OzaBagAdwinExecutorMAXChunk     airlines      4          50
# 220             OzaBagAdwinExecutorMAXChunk     airlines      4          25
# 154             OzaBagAdwinExecutorMAXChunk     airlines      4          25
# 194             OzaBagAdwinExecutorMAXChunk     airlines      4          25
# 149              OzaBagASHTExecutorMAXChunk     airlines      4         100
# 243              OzaBagASHTExecutorMAXChunk     airlines      4         100
# 232              OzaBagASHTExecutorMAXChunk     airlines      4         100
# 267              OzaBagASHTExecutorMAXChunk     airlines      4          75
# 80               OzaBagASHTExecutorMAXChunk     airlines      4          75
# 180              OzaBagASHTExecutorMAXChunk     airlines      4          75
# 46               OzaBagASHTExecutorMAXChunk     airlines      4          50
# 239              OzaBagASHTExecutorMAXChunk     airlines      4          50
# 245              OzaBagASHTExecutorMAXChunk     airlines      4          50
# 38               OzaBagASHTExecutorMAXChunk     airlines      4          25
# 255              OzaBagASHTExecutorMAXChunk     airlines      4          25
# 168              OzaBagASHTExecutorMAXChunk     airlines      4          25
# 88                     LBagExecutorMAXChunk     airlines      4         100
# 158                    LBagExecutorMAXChunk     airlines      4         100
# 124                    LBagExecutorMAXChunk     airlines      4         100
# 263                    LBagExecutorMAXChunk     airlines      4          75
# 184                    LBagExecutorMAXChunk     airlines      4          75
# 93                     LBagExecutorMAXChunk     airlines      4          75
# 166                    LBagExecutorMAXChunk     airlines      4          50
# 123                    LBagExecutorMAXChunk     airlines      4          50
# 131                    LBagExecutorMAXChunk     airlines      4          50
# 254                    LBagExecutorMAXChunk     airlines      4          25
# 111                    LBagExecutorMAXChunk     airlines      4          25
# 135                    LBagExecutorMAXChunk     airlines      4          25
# 24     AdaptiveRandomForestExecutorMAXChunk     airlines      4         100
# 249    AdaptiveRandomForestExecutorMAXChunk     airlines      4         100
# 53     AdaptiveRandomForestExecutorMAXChunk     airlines      4         100
# 231    AdaptiveRandomForestExecutorMAXChunk     airlines      4          75
# 104    AdaptiveRandomForestExecutorMAXChunk     airlines      4          75
# 157    AdaptiveRandomForestExecutorMAXChunk     airlines      4          75
# 199    AdaptiveRandomForestExecutorMAXChunk     airlines      4          50
# 92     AdaptiveRandomForestExecutorMAXChunk     airlines      4          50
# 206    AdaptiveRandomForestExecutorMAXChunk     airlines      4          50
# 134    AdaptiveRandomForestExecutorMAXChunk     airlines      4          25
# 258    AdaptiveRandomForestExecutorMAXChunk     airlines      4          25
# 196    AdaptiveRandomForestExecutorMAXChunk     airlines      4          25
# 5    StreamingRandomPatchesExecutorMAXChunk         GMSC      4         100
# 96   StreamingRandomPatchesExecutorMAXChunk         GMSC      4         100
# 222  StreamingRandomPatchesExecutorMAXChunk         GMSC      4         100
# 190  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          75
# 85   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          75
# 147  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          75
# 36   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          50
# 215  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          50
# 198  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          50
# 84   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          25
# 20   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          25
# 45   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          25
# 191                  OzaBagExecutorMAXChunk         GMSC      4         100
# 264                  OzaBagExecutorMAXChunk         GMSC      4         100
# 152                  OzaBagExecutorMAXChunk         GMSC      4         100
# 202                  OzaBagExecutorMAXChunk         GMSC      4          75
# 81                   OzaBagExecutorMAXChunk         GMSC      4          75
# 178                  OzaBagExecutorMAXChunk         GMSC      4          75
# 113                  OzaBagExecutorMAXChunk         GMSC      4          50
# 246                  OzaBagExecutorMAXChunk         GMSC      4          50
# 248                  OzaBagExecutorMAXChunk         GMSC      4          50
# 179                  OzaBagExecutorMAXChunk         GMSC      4          25
# 280                  OzaBagExecutorMAXChunk         GMSC      4          25
# 109                  OzaBagExecutorMAXChunk         GMSC      4          25
# 2               OzaBagAdwinExecutorMAXChunk         GMSC      4         100
# 192             OzaBagAdwinExecutorMAXChunk         GMSC      4         100
# 269             OzaBagAdwinExecutorMAXChunk         GMSC      4         100
# 26              OzaBagAdwinExecutorMAXChunk         GMSC      4          75
# 148             OzaBagAdwinExecutorMAXChunk         GMSC      4          75
# 205             OzaBagAdwinExecutorMAXChunk         GMSC      4          75
# 127             OzaBagAdwinExecutorMAXChunk         GMSC      4          50
# 35              OzaBagAdwinExecutorMAXChunk         GMSC      4          50
# 136             OzaBagAdwinExecutorMAXChunk         GMSC      4          50
# 140             OzaBagAdwinExecutorMAXChunk         GMSC      4          25
# 211             OzaBagAdwinExecutorMAXChunk         GMSC      4          25
# 118             OzaBagAdwinExecutorMAXChunk         GMSC      4          25
# 75               OzaBagASHTExecutorMAXChunk         GMSC      4         100
# 90               OzaBagASHTExecutorMAXChunk         GMSC      4         100
# 282              OzaBagASHTExecutorMAXChunk         GMSC      4         100
# 18               OzaBagASHTExecutorMAXChunk         GMSC      4          75
# 260              OzaBagASHTExecutorMAXChunk         GMSC      4          75
# 204              OzaBagASHTExecutorMAXChunk         GMSC      4          75
# 54               OzaBagASHTExecutorMAXChunk         GMSC      4          50
# 174              OzaBagASHTExecutorMAXChunk         GMSC      4          50
# 208              OzaBagASHTExecutorMAXChunk         GMSC      4          50
# 216              OzaBagASHTExecutorMAXChunk         GMSC      4          25
# 218              OzaBagASHTExecutorMAXChunk         GMSC      4          25
# 64               OzaBagASHTExecutorMAXChunk         GMSC      4          25
# 271                    LBagExecutorMAXChunk         GMSC      4         100
# 13                     LBagExecutorMAXChunk         GMSC      4         100
# 101                    LBagExecutorMAXChunk         GMSC      4         100
# 28                     LBagExecutorMAXChunk         GMSC      4          75
# 41                     LBagExecutorMAXChunk         GMSC      4          75
# 160                    LBagExecutorMAXChunk         GMSC      4          75
# 262                    LBagExecutorMAXChunk         GMSC      4          50
# 115                    LBagExecutorMAXChunk         GMSC      4          50
# 25                     LBagExecutorMAXChunk         GMSC      4          50
# 150                    LBagExecutorMAXChunk         GMSC      4          25
# 40                     LBagExecutorMAXChunk         GMSC      4          25
# 183                    LBagExecutorMAXChunk         GMSC      4          25
# 265    AdaptiveRandomForestExecutorMAXChunk         GMSC      4         100
# 227    AdaptiveRandomForestExecutorMAXChunk         GMSC      4         100
# 125    AdaptiveRandomForestExecutorMAXChunk         GMSC      4         100
# 19     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          75
# 71     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          75
# 256    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          75
# 209    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          50
# 228    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          50
# 34     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          50
# 22     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          25
# 6      AdaptiveRandomForestExecutorMAXChunk         GMSC      4          25
# 122    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          25
#
#      inc_rate  out_rate  instances   time    delay   acc  duration  \
# 42        365    363.90  43,700.00 120.09   262.00 79.90       124
# 106       203    199.92  23,960.00 119.85   380.00 80.97       124
# 277        40     39.95   4,800.00 120.14 1,445.00 80.66       124
# 117       352    349.37  41,925.00 120.00   194.00 79.98       125
# 138       195    194.36  23,325.00 120.01   310.00 81.93       123
# 56         39     34.97   4,200.00 120.10 1,231.00 80.97       124
# 31        351    349.55  41,930.00 119.95   131.00 80.95       125
# 141       195    194.80  23,361.00 119.92   196.00 82.61       124
# 8          39     34.99   4,200.00 120.04   820.00 82.48       123
# 98        332    329.31  39,525.00 120.02    68.00 82.23       125
# 60        184    179.88  21,564.00 119.88   101.00 84.83       123
# 23         36     35.00   4,200.00 120.02   402.00 83.86       124
# 91       2519  2,333.75  42,934.00  18.40    42.00 78.85        24
# 236      1399  1,392.16  45,312.00  32.55    56.00 78.36        37
# 69        279    274.77  32,945.00 119.90   199.00 77.56       126
# 253      2531  2,418.59  43,496.00  17.98    31.00 78.51        23
# 273      1406  1,401.63  45,312.00  32.33    41.00 78.57        38
# 120       281    279.78  33,544.00 119.90   147.00 79.28       125
# 14       2318  2,222.73  43,510.00  19.58    21.00 78.67        24
# 47       1288  1,281.34  45,312.00  35.36    29.00 78.73        41
# 272       257    254.85  30,549.00 119.87   107.00 79.64       125
# 242      2328  2,265.48  44,272.00  19.54    11.00 79.49        24
# 164      1293  1,289.51  45,312.00  35.14    14.00 79.67        41
# 189       258    254.83  30,549.00 119.88    52.00 79.29       125
# 233      2096  2,023.07  43,927.00  21.71    48.00 79.10        28
# 284      1164  1,157.01  45,312.00  39.16    64.00 79.09        44
# 234       232    229.89  27,554.00 119.86   245.00 80.69       126
# 210      2108  2,020.99  43,609.00  21.58    36.00 78.66        26
# 59       1171  1,168.53  45,312.00  38.78    50.00 79.15        45
# 278       234    229.81  27,554.00 119.90   184.00 80.71       125
# 132      1931  1,806.45  42,484.00  23.52    26.00 79.48        29
# 230      1072  1,067.87  45,312.00  42.43    35.00 79.56        47
# 268       214    209.89  25,158.00 119.86   130.00 81.64       126
# 112      1652  1,606.72  44,204.00  27.51    15.00 80.86        32
# 285       917    912.74  45,312.00  49.64    21.00 80.39        56
# 259       183    179.93  21,564.00 119.84    76.00 83.95       125
# 188      2573  2,417.63  42,780.00  17.69    41.00 78.40        23
# 151      1429  1,426.70  45,312.00  31.76    53.00 78.22        38
# 257       285    284.77  34,143.00 119.90   198.00 78.12       125
# 1        2493  2,220.78  44,158.00  19.88    33.00 79.30        26
# 87       1385  1,384.59  45,312.00  32.73    41.00 79.23        38
# 142       277    274.76  32,945.00 119.90   144.00 78.33       126
# 66       2439  2,295.92  43,758.00  19.06    21.00 79.37        25
# 146      1355  1,351.15  45,312.00  33.54    30.00 79.37        38
# 114       271    269.83  32,346.00 119.88    99.00 78.99       126
# 43       2303  2,188.12  43,187.00  19.74    11.00 80.07        26
# 266      1279  1,272.27  45,312.00  35.62    14.00 80.59        40
# 100       255    254.82  30,549.00 119.88    53.00 80.70       126
# 21       1087  1,005.88  42,105.00  41.86    95.00 79.77        47
# 186       604    598.93  45,312.00  75.65   116.00 79.92        81
# 173       120    119.98  14,376.00 119.82   482.00 81.93       125
# 9        1043    977.65  42,694.00  43.67    72.00 80.47        49
# 29        579    573.38  45,312.00  79.03    96.00 80.33        84
# 10        115    114.98  13,777.00 119.82   382.00 82.19       126
# 219      1017    958.91  42,962.00  44.80    48.00 81.39        51
# 156       565    564.50  45,312.00  80.27    64.00 81.71        85
# 261       113    109.82  13,179.00 120.00   259.00 83.21       125
# 67        976    923.03  43,040.00  46.63    25.00 83.02        52
# 51        542    539.09  45,312.00  84.05    34.00 83.53        89
# 244       108    104.96  12,579.00 119.85   133.00 85.37       126
# 12        676    645.37  43,424.00  67.29   143.00 79.29        71
# 99        375    374.49  44,925.00 119.96   184.00 79.31       124
# 240        75     74.88   8,986.00 120.00   780.00 80.65       124
# 181       713    672.42  43,042.00  64.01   103.00 79.52        69
# 238       396    394.15  45,312.00 114.96   138.00 79.35       119
# 95         79     74.88   8,986.00 120.00   517.00 80.42       123
# 128       694    662.88  43,654.00  65.86    68.00 80.72        70
# 224       386    384.15  45,312.00 117.96    95.00 80.24       122
# 107        77     74.88   8,986.00 120.01   370.00 80.90       124
# 77        619    605.32  44,711.00  73.86    36.00 81.60        77
# 176       344    339.52  40,732.00 119.97    52.00 81.27       124
# 161        68     64.90   7,788.00 120.00   218.00 81.45       124
# 286       125    124.97  14,975.00 119.82   712.00 71.77       125
# 281        69     64.77   7,800.00 120.42 1,170.00 73.31       125
# 17         13      9.97   1,200.00 120.39 5,726.00 62.73       125
# 172       135    134.92  16,173.00 119.87   521.00 73.79       124
# 144        75     74.61   9,000.00 120.63   744.00 75.32       125
# 15         15     14.97   1,800.00 120.21 2,879.00 67.25       125
# 32        126    124.85  14,975.00 119.94   338.00 75.44       125
# 44         70     69.89   8,387.00 120.00   552.00 76.89       123
# 62         14      9.98   1,200.00 120.19 2,783.00 66.87       125
# 237       114    109.74  13,175.00 120.05   191.00 77.98       124
# 86         63     59.92   7,200.00 120.15   297.00 78.76       125
# 39         12      9.99   1,200.00 120.09 1,384.00 68.26       124
# 214       668    657.30  78,900.00 120.04   148.00 81.41       125
# 167       371    369.41  44,326.00 119.99   245.00 75.27       126
# 0          74     69.86   8,400.00 120.25   921.00 60.43       125
# 229       600    595.60  71,475.00 120.00   120.00 81.03       126
# 145       333    329.46  39,534.00 120.00   196.00 73.64       125
# 74         66     64.86   7,800.00 120.26   787.00 60.94       126
# 37        652    643.20  77,200.00 120.03    75.00 81.89       125
# 270       362    359.53  43,128.00 119.96   123.00 75.39       126
# 7          72     69.90   8,400.00 120.18   488.00 61.43       125
# 197       595    586.62  70,400.00 120.01    41.00 81.63       125
# 200       330    329.48  39,534.00 119.99    66.00 74.36       126
# 126        66     64.90   7,788.00 120.00   250.00 62.99       125
# 226       635    627.49  75,300.00 120.00   151.00 83.73       126
# 171       353    349.53  41,930.00 119.96   230.00 78.10       126
# 4          70     69.85   8,400.00 120.26   944.00 64.23       125
# 97        608    593.25  71,250.00 120.10   119.00 84.16       125
# 165       338    334.58  40,133.00 119.95   186.00 77.57       126
# 79         67     64.90   7,788.00 120.00   804.00 65.03       126
# 121       556    551.19  66,150.00 120.01    87.00 83.41       126
# 116       309    304.62  36,539.00 119.95   136.00 76.98       125
# 110        61     59.90   7,200.00 120.19   561.00 66.84       126
# 177       472    408.28  49,000.00 120.02    61.00 81.82       126
# 287       262    259.75  31,148.00 119.92    78.00 77.47       126
# 275        52     49.97   6,000.00 120.07   291.00 70.49       125
# 27        651    643.17  77,200.00 120.03   151.00 81.30       126
# 241       361    359.52  43,128.00 119.96   244.00 75.18       126
# 283        72     69.81   8,400.00 120.33   975.00 60.47       125
# 57        664    654.29  78,525.00 120.02   109.00 81.55       125
# 103       369    364.42  43,727.00 119.99   179.00 75.41       126
# 3          73     69.88   8,400.00 120.20   696.00 60.71       126
# 33        626    619.54  74,350.00 120.01    76.00 81.67       126
# 133       347    344.57  41,331.00 119.95   129.00 75.09       126
# 72         69     64.90   7,788.00 120.00   517.00 61.98       125
# 65        575    570.82  68,500.00 120.00    43.00 81.30       126
# 182       319    314.34  37,725.00 120.01    67.00 74.25       126
# 225        63     59.96   7,200.00 120.09   265.00 63.32       125
# 137       427    423.26  50,800.00 120.02   211.00 85.63       125
# 30        237    234.90  28,153.00 119.85   363.00 77.76       126
# 153        47     44.89   5,400.00 120.30 1,403.00 69.60       126
# 193       417    413.70  49,650.00 120.01   162.00 85.46       126
# 76        232    229.65  27,554.00 119.98   274.00 78.08       125
# 279        46     44.92   5,400.00 120.21 1,037.00 70.65       126
# 61        402    399.11  47,900.00 120.02   115.00 85.43       125
# 102       223    219.79  26,356.00 119.91   186.00 78.67       126
# 89         44     39.95   4,800.00 120.16   763.00 71.35       125
# 250       340    339.36  40,725.00 120.01    68.00 81.71       125
# 235       189    184.87  22,163.00 119.89   112.00 77.47       126
# 213        37     34.98   4,200.00 120.06   429.00 71.93       125
# 78        624    597.16  71,700.00 120.07   155.00 86.12       123
# 175       346    340.90  40,876.00 119.90   239.00 81.07       125
# 217        69     64.94   7,800.00 120.11   942.00 69.45       125
# 48        548    527.78  63,375.00 120.08   118.00 85.67       124
# 83        304    299.06  35,880.00 119.97   184.00 79.39       124
# 11         60     59.96   7,200.00 120.08   742.00 70.44       124
# 185       530    517.28  62,100.00 120.05    85.00 86.23       124
# 129       294    289.46  34,723.00 119.96   133.00 79.95       124
# 55         58     54.96   6,600.00 120.08   560.00 72.89       124
# 58        499    481.97  57,850.00 120.03    44.00 86.78       124
# 251       277    274.36  32,925.00 120.01    65.00 80.72       124
# 212        55     54.94   6,593.00 120.00   266.00 74.33       123
# 49        164     71.32   8,600.00 120.58 1,399.00 65.31       124
# 70         91     71.68   8,700.00 121.37 1,388.00 65.47       126
# 195        18     14.79   1,800.00 121.69 4,387.00 75.12       126
# 187       156     68.94   8,325.00 120.76 1,086.00 65.94       125
# 143        86     68.09   8,175.00 120.07 1,097.00 65.56       124
# 163        17     14.82   1,800.00 121.44 3,229.00 75.19       125
# 94        156     68.60   8,250.00 120.27   728.00 65.52       124
# 203        87     69.42   8,350.00 120.28   718.00 65.61       125
# 207        17     14.88   1,800.00 120.98 2,172.00 75.49       125
# 170       153     69.97   8,425.00 120.40   357.00 65.64       125
# 68         85     66.60   8,000.00 120.13   375.00 65.96       124
# 221        17     14.98   1,800.00 120.14 1,053.00 74.65       124
# 252      1672    192.90  23,700.00 122.86   518.00 64.44       128
# 274       929    216.08  26,200.00 121.25   462.00 64.65       127
# 276       185    180.37  22,100.00 122.53   471.00 63.32       129
# 162      1630    209.12  25,125.00 120.15   358.00 64.68       126
# 159       905    208.51  25,575.00 122.65   359.00 65.15       128
# 105       181    179.97  21,564.00 119.82   343.00 63.60       125
# 223      1627    204.16  24,700.00 120.98   244.00 66.19       127
# 108       904    220.40  26,800.00 121.60   226.00 64.79       127
# 155       180    179.83  21,564.00 119.91   226.00 63.33       125
# 50       1558    173.48  21,200.00 122.21   144.00 65.25       128
# 139       865    213.52  26,025.00 121.89   117.00 64.14       128
# 247       173    169.90  20,366.00 119.87   117.00 63.52       125
# 119       477    375.58  45,200.00 120.35   266.00 68.58       125
# 169       265    264.00  31,700.00 120.08   349.00 66.75       125
# 130        53     49.89   6,000.00 120.25 1,127.00 66.27       126
# 201       476    366.86  44,025.00 120.01   204.00 68.90       126
# 82        264    259.57  31,148.00 120.00   265.00 67.17       125
# 16         52     49.92   6,000.00 120.20   873.00 66.70       125
# 73        479    384.40  46,150.00 120.06   129.00 68.65       126
# 52        266    264.64  31,747.00 119.96   164.00 66.97       125
# 63         53     49.98   6,000.00 120.05   519.00 66.74       125
# 220       509    339.66  40,775.00 120.04    73.00 68.58       125
# 154       283    279.56  33,544.00 119.99    82.00 66.91       125
# 194        56     54.97   6,600.00 120.06   272.00 66.52       126
# 149      1383    271.25  33,100.00 122.03   368.00 67.40       127
# 243       768    281.81  34,200.00 121.36   354.00 64.95       127
# 232       153    149.75  17,971.00 120.00   521.00 63.26       125
# 267      1389    186.74  22,500.00 120.49   401.00 65.79       126
# 80        771    175.60  21,075.00 120.02   426.00 65.03       126
# 180       154    149.75  17,971.00 120.01   376.00 63.35       125
# 46       1358    281.36  34,300.00 121.91   177.00 67.76       128
# 239       754    310.71  37,950.00 122.14   160.00 66.85       128
# 245       150    149.75  17,971.00 120.01   246.00 63.06       125
# 38       1203    168.15  20,225.00 120.28   148.00 65.19       126
# 255       668     74.80   9,075.00 121.32   334.00 63.64       127
# 168       133    129.69  15,575.00 120.09   136.00 63.18       126
# 88        163     68.18   8,400.00 123.20 1,463.00 61.98       128
# 158        90     68.36   8,400.00 122.87 1,428.00 61.95       128
# 124        18     14.96   1,800.00 120.30 3,959.00 71.94       126
# 263       162     77.99   9,375.00 120.21   960.00 61.72       126
# 184        90     71.81   8,775.00 122.20 1,005.00 62.21       128
# 93         18     14.92   1,800.00 120.68 2,888.00 72.52       126
# 166       161     77.28   9,300.00 120.34   646.00 61.81       126
# 123        89     79.57   9,550.00 120.03   587.00 61.55       125
# 131        17     14.99   1,800.00 120.11 1,954.00 72.74       125
# 254       156    119.74  14,375.00 120.05   208.00 60.86       125
# 111        87     84.87  10,185.00 120.00   267.00 61.49       125
# 135        17     15.00   1,800.00 120.01   962.00 72.23       125
# 24        179     88.19  10,600.00 120.19 1,131.00 65.76       124
# 249        99     88.70  10,700.00 120.63 1,119.00 65.11       125
# 53         19     14.94   1,800.00 120.49 4,200.00 74.82       124
# 231       178     87.74  10,650.00 121.38   853.00 65.11       125
# 104        99     84.37  10,125.00 120.01   878.00 65.83       124
# 157        19     14.96   1,800.00 120.32 3,086.00 74.67       125
# 199       174     93.59  11,250.00 120.20   533.00 65.95       125
# 92         97     84.53  10,150.00 120.08   583.00 65.97       124
# 206        19     14.97   1,800.00 120.25 2,087.00 74.63       125
# 134       170     83.81  10,075.00 120.21   298.00 65.35       125
# 258        94     73.87   8,875.00 120.14   332.00 65.80       124
# 196        18     14.99   1,800.00 120.06 1,025.00 74.42       124
# 5         615    613.20  73,600.00 120.03   151.00 93.49       124
# 96        342    339.46  40,732.00 119.99   221.00 93.48       124
# 222        68     64.94   7,800.00 120.11   903.00 93.60       124
# 190       592    588.08  70,575.00 120.01   117.00 93.43       124
# 85        329    324.26  38,925.00 120.04   166.00 93.51       124
# 147        65     64.95   7,800.00 120.09   684.00 93.67       124
# 36        572    568.60  68,250.00 120.03    79.00 93.43       125
# 215       317    314.69  37,737.00 119.92   116.00 93.49       124
# 198        63     59.98   7,200.00 120.05   475.00 93.65       123
# 84        605    603.29  72,400.00 120.01    38.00 93.40       124
# 20        336    334.58  40,133.00 119.95    54.00 93.47       124
# 45         67     64.98   7,800.00 120.03   220.00 93.65       123
# 191      3781  3,758.21 149,607.00  39.81    25.00 93.40        46
# 264      2101  2,094.42 150,000.00  71.62    34.00 93.54        76
# 152       420    419.60  50,316.00 119.92   130.00 93.35       126
# 202      3701  3,691.49 150,000.00  40.63    19.00 93.50        45
# 81       2056  2,051.90 150,000.00  73.10    27.00 93.48        79
# 178       411    409.61  49,118.00 119.91   102.00 93.41       125
# 113      3520  3,027.19 149,625.00  49.43    16.00 93.39        55
# 246      1955  1,951.02 150,000.00  76.88    19.00 93.50        82
# 248       391    389.62  46,722.00 119.92    70.00 93.51       126
# 179      3111  3,098.98 150,000.00  48.40     7.00 93.49        54
# 280      1728  1,722.61 150,000.00  87.08    10.00 93.49        92
# 109       345    344.72  41,331.00 119.90    39.00 93.45       126
# 2        3523  3,508.42 149,922.00  42.73    27.00 93.39        49
# 192      1957  1,951.32 150,000.00  76.87    37.00 93.34        83
# 269       391    389.66  46,722.00 119.90   145.00 93.39       125
# 26       3722  3,689.71 149,068.00  40.40    19.00 93.34        46
# 148      2068  2,060.16 150,000.00  72.81    28.00 93.36        78
# 205       413    409.68  49,118.00 119.89   103.00 93.46       126
# 127      3278  3,248.01 149,259.00  45.95    14.00 93.33        51
# 35       1821  1,815.17 150,000.00  82.64    19.00 93.34        88
# 136       364    359.73  43,128.00 119.89    76.00 93.41       125
# 140      2428  2,418.54 150,000.00  62.02     9.00 93.38        68
# 211      1349  1,340.00 150,000.00 111.94    13.00 93.32       117
# 118       269    264.85  31,747.00 119.87    50.00 93.58       126
# 75       3854  3,840.25 150,000.00  39.06    24.00 93.35        44
# 90       2141  2,135.32 150,000.00  70.25    34.00 93.37        76
# 282       428    424.56  50,915.00 119.92   127.00 93.32       125
# 18       3839  3,825.16 150,000.00  39.21    18.00 93.36        45
# 260      2133  2,123.68 150,000.00  70.63    26.00 93.38        75
# 204       426    424.62  50,915.00 119.91    94.00 93.38       126
# 54       3660  3,649.90 150,000.00  41.10    13.00 93.36        47
# 174      2033  2,025.74 150,000.00  74.05    18.00 93.35        79
# 208       406    404.63  48,519.00 119.91    68.00 93.37       126
# 216      3308  3,299.46 150,000.00  45.46     7.00 93.44        50
# 218      1838  1,831.64 150,000.00  81.89    10.00 93.33        88
# 64        367    364.70  43,727.00 119.90    37.00 93.43       125
# 271      1449  1,438.26 150,000.00 104.29    62.00 93.37       109
# 13        805    802.21  96,300.00 120.04    95.00 93.50       125
# 101       161    159.98  19,168.00 119.81   359.00 93.59       125
# 28       1556  1,537.21 148,771.00  96.78    46.00 93.39       103
# 41        864    857.39 102,900.00 120.02    66.00 93.35       124
# 160       172    169.98  20,366.00 119.81   260.00 93.51       126
# 262      1408  1,399.55 150,000.00 107.18    31.00 93.34       113
# 115       782    777.80  93,350.00 120.02    46.00 93.40       126
# 25        156    154.94  18,569.00 119.85   185.00 93.53       125
# 150      1343  1,334.57 150,000.00 112.40    17.00 93.40       117
# 40        746    742.88  89,150.00 120.01    24.00 93.35       126
# 183       149    144.97  17,371.00 119.83    96.00 93.44       125
# 265      1096  1,091.38 130,962.00 120.00    84.00 93.56       125
# 227       608    604.15  72,479.00 119.97   122.00 93.47       124
# 125       121    119.99  14,376.00 119.81   484.00 93.56       124
# 19       1052  1,046.75 125,580.00 119.97    62.00 93.54       124
# 71        584    578.73  69,450.00 120.00    94.00 93.47       124
# 256       116    114.81  13,778.00 120.00   381.00 93.41       124
# 209      1000    996.97 119,600.00 119.96    36.00 93.53       124
# 228       555    554.21  66,489.00 119.97    63.00 93.40       124
# 34        111    109.82  13,179.00 120.01   259.00 93.41       124
# 22       1071  1,066.21 127,950.00 120.00    21.00 93.54       124
# 6         595    593.70  71,250.00 120.01    30.00 93.46       124
# 122       119    114.97  13,777.00 119.83   121.00 93.48       124
#
#      avg_measure  sum_measure  prod_rate  tt_inst_prod  joules  JPI
# 42          5.89     1,325.90     364.14     43,727.00  707.67 0.02
# 106         4.94     1,111.40     199.62     23,960.00  591.99 0.02
# 277         4.09       920.60      39.94      4,800.00  491.55 0.10
# 117         5.70     1,289.30     349.17     41,930.00  684.59 0.02
# 138         4.84     1,084.50     194.63     23,361.00  581.03 0.02
# 56          3.99       894.20      34.95      4,200.00  479.43 0.11
# 31          5.87     1,332.00     349.19     41,930.00  703.87 0.02
# 141         4.86     1,093.70     194.62     23,361.00  582.93 0.02
# 8           3.83       854.80      34.95      4,200.00  460.15 0.11
# 98          5.58     1,265.90     329.21     39,534.00  669.33 0.02
# 60          4.57     1,019.70     179.66     21,564.00  548.17 0.03
# 23          3.95       892.90      34.95      4,200.00  474.17 0.11
# 91          5.18       233.30   2,479.86     45,312.00   95.38 0.00
# 236         4.78       324.80   1,385.98     45,312.00  155.46 0.00
# 69          3.82       855.70     274.42     32,945.00  458.03 0.01
# 253         5.13       220.40   2,507.30     45,312.00   92.18 0.00
# 273         4.44       311.00   1,394.09     45,312.00  143.63 0.00
# 120         3.78       858.60     279.38     33,544.00  453.49 0.01
# 14          5.12       230.60   2,303.38     45,312.00  100.31 0.00
# 47          4.55       345.60   1,275.35     45,312.00  160.81 0.00
# 272         3.82       863.60     254.48     30,549.00  458.06 0.01
# 242         5.16       232.30   2,303.49     45,312.00  100.88 0.00
# 164         4.61       350.10   1,284.06     45,312.00  161.87 0.00
# 189         3.82       867.90     254.46     30,549.00  458.34 0.02
# 233         5.18       274.60   2,072.07     45,312.00  112.50 0.00
# 284         4.48       358.30   1,152.19     45,312.00  175.40 0.00
# 234         3.88       888.70     229.53     27,554.00  465.13 0.02
# 210         5.44       261.00   2,091.19     45,312.00  117.33 0.00
# 59          4.64       385.30   1,163.91     45,312.00  180.01 0.00
# 278         3.88       881.30     229.52     27,554.00  465.49 0.02
# 132         5.20       275.70   1,914.56     45,312.00  122.34 0.00
# 230         4.61       377.80   1,064.49     45,312.00  195.50 0.00
# 268         3.88       889.10     209.59     25,158.00  465.37 0.02
# 112         5.16       304.30   1,638.41     45,312.00  141.90 0.00
# 285         4.60       432.00     909.92     45,312.00  228.15 0.01
# 259         3.94       890.70     179.66     21,564.00  472.32 0.02
# 188         5.17       222.20   2,535.65     45,312.00   91.44 0.00
# 151         4.46       312.10   1,421.60     45,312.00  141.60 0.00
# 257         3.81       865.60     284.37     34,143.00  457.19 0.01
# 1           5.09       244.30   2,481.49     45,312.00  101.20 0.00
# 87          4.49       319.00   1,377.60     45,312.00  147.04 0.00
# 142         3.84       848.40     274.42     32,945.00  460.30 0.01
# 66          5.04       237.00   2,401.53     45,312.00   96.11 0.00
# 146         4.77       339.00   1,344.09     45,312.00  160.12 0.00
# 114         3.85       878.20     269.42     32,346.00  461.74 0.01
# 43          4.98       238.90   2,280.42     45,312.00   98.23 0.00
# 266         4.48       331.30   1,267.43     45,312.00  159.45 0.00
# 100         3.81       872.00     254.46     30,549.00  456.50 0.01
# 21          5.74       493.30   1,079.71     45,312.00  240.11 0.01
# 186         4.76       662.10     597.68     45,312.00  360.37 0.01
# 173         4.00       903.50     119.79     14,376.00  479.00 0.03
# 9           5.65       508.30   1,035.23     45,312.00  246.64 0.01
# 29          4.77       735.30     571.97     45,312.00  377.32 0.01
# 10          4.03       898.30     114.80     13,777.00  482.65 0.04
# 219         5.57       523.40   1,007.63     45,312.00  249.47 0.01
# 156         4.75       730.90     563.46     45,312.00  380.97 0.01
# 261         4.09       927.80     109.82     13,200.00  490.49 0.04
# 67          5.62       534.00     968.58     45,312.00  262.10 0.01
# 51          4.68       758.30     537.99     45,312.00  393.44 0.01
# 244         3.95       904.80     104.82     12,579.00  473.53 0.04
# 12          5.76       749.40     672.24     45,312.00  387.87 0.01
# 99          4.76     1,070.20     374.13     44,925.00  570.59 0.01
# 240         3.92       881.80      74.88      9,000.00  470.31 0.05
# 181         5.68       715.60     705.77     45,312.00  363.54 0.01
# 238         4.71     1,018.40     393.73     45,312.00  542.02 0.01
# 95          3.82       855.60      74.88      9,000.00  458.38 0.05
# 128         5.58       714.20     686.42     45,312.00  367.45 0.01
# 224         4.73     1,008.10     383.67     45,312.00  558.26 0.01
# 107         4.05       912.30      74.88      9,000.00  486.59 0.05
# 77          5.45       763.00     612.17     45,312.00  402.56 0.01
# 176         4.62     1,015.40     339.18     40,732.00  553.72 0.01
# 161         3.98       895.70      64.90      7,800.00  477.73 0.06
# 286         5.23     1,182.20     124.78     14,975.00  626.80 0.04
# 281         4.47     1,020.00      64.90      7,800.00  538.73 0.07
# 17          3.78       853.50       9.99      1,200.00  454.65 0.38
# 172         5.28     1,140.90     134.76     16,173.00  633.17 0.04
# 144         4.06       920.90      74.88      9,000.00  489.39 0.05
# 15          4.19       947.10      14.98      1,800.00  503.76 0.28
# 32          5.24     1,194.40     124.79     14,975.00  628.32 0.04
# 44          4.42       959.40      69.89      8,400.00  530.56 0.06
# 62          4.06       926.00       9.99      1,200.00  488.12 0.41
# 237         5.15     1,159.60     109.81     13,178.00  618.72 0.05
# 86          4.40       984.70      59.91      7,200.00  528.19 0.07
# 39          3.80       836.00       9.99      1,200.00  456.33 0.38
# 214         4.65     1,051.30     662.97     79,667.00  558.38 0.01
# 167         4.46       985.40     369.04     44,326.00  535.01 0.01
# 0           3.82       867.00      69.89      8,400.00  459.27 0.05
# 229         4.64     1,058.70     598.27     71,880.00  557.23 0.01
# 145         4.36       993.60     329.17     39,534.00  522.93 0.01
# 74          3.88       864.20      64.90      7,800.00  466.06 0.06
# 37          4.66     1,057.60     648.14     77,870.00  559.20 0.01
# 270         4.39     1,005.60     359.04     43,128.00  526.76 0.01
# 7           3.87       874.50      69.89      8,400.00  465.02 0.06
# 197         4.61     1,047.60     593.16     71,281.00  553.84 0.01
# 200         4.30       979.40     329.20     39,534.00  515.43 0.01
# 126         3.88       881.10      64.90      7,800.00  465.79 0.06
# 226         4.82     1,100.00     633.12     76,073.00  578.96 0.01
# 171         4.36       997.70     349.14     41,930.00  522.64 0.01
# 4           3.93       871.70      69.89      8,400.00  472.22 0.06
# 97          4.84     1,098.40     603.20     72,479.00  581.15 0.01
# 165         4.55     1,042.10     334.20     40,133.00  545.85 0.01
# 79          3.92       894.10      64.90      7,800.00  470.58 0.06
# 121         4.80     1,099.80     553.36     66,489.00  576.38 0.01
# 116         4.51     1,024.60     304.31     36,539.00  541.41 0.01
# 110         3.96       904.00      59.90      7,200.00  476.55 0.07
# 177         4.85     1,110.70     468.67     56,306.00  582.10 0.01
# 287         4.36       993.50     259.45     31,148.00  522.52 0.02
# 275         4.14       940.10      49.93      6,000.00  497.25 0.08
# 27          4.76     1,085.80     648.09     77,870.00  571.62 0.01
# 241         4.24       971.10     359.13     43,128.00  508.70 0.01
# 283         3.86       876.30      69.89      8,400.00  464.52 0.06
# 57          4.70     1,065.90     658.04     79,068.00  563.55 0.01
# 103         4.51     1,032.90     364.07     43,727.00  541.22 0.01
# 3           3.88       884.40      69.89      8,400.00  466.26 0.06
# 33          4.65     1,023.50     623.15     74,875.00  558.31 0.01
# 133         4.40     1,007.80     344.17     41,331.00  527.88 0.01
# 72          3.90       882.40      64.90      7,800.00  468.55 0.06
# 65          4.63     1,037.90     573.31     68,885.00  556.03 0.01
# 182         4.30       979.70     314.25     37,737.00  515.68 0.01
# 225         3.82       867.50      59.91      7,200.00  458.92 0.06
# 137         4.98     1,131.50     423.84     50,915.00  598.25 0.01
# 30          4.65     1,065.10     234.52     28,153.00  557.44 0.02
# 153         3.91       891.30      44.94      5,400.00  470.29 0.09
# 193         5.01     1,146.20     413.89     49,717.00  600.70 0.01
# 76          4.49     1,018.90     229.52     27,554.00  538.55 0.02
# 279         3.99       910.70      44.94      5,400.00  480.15 0.09
# 61          5.01     1,131.40     398.97     47,920.00  600.83 0.01
# 102         4.54     1,040.80     219.54     26,356.00  545.00 0.02
# 89          3.89       882.20      39.94      4,800.00  466.98 0.10
# 250         4.92     1,116.40     339.12     40,732.00  590.20 0.01
# 235         4.60     1,048.50     184.63     22,163.00  551.32 0.02
# 213         3.99       906.30      34.95      4,200.00  479.34 0.11
# 78          5.36     1,158.10     618.06     74,276.00  643.75 0.01
# 175         4.87     1,101.10     344.16     41,331.00  584.19 0.01
# 217         4.06       921.20      64.90      7,800.00  487.44 0.06
# 48          5.04     1,138.40     543.44     65,291.00  604.85 0.01
# 83          4.70     1,052.80     299.34     35,940.00  563.88 0.02
# 11          3.91       863.80      59.91      7,200.00  469.36 0.07
# 185         5.21     1,167.10     528.51     63,494.00  625.49 0.01
# 129         4.75     1,072.40     289.33     34,742.00  569.22 0.02
# 55          4.01       862.40      54.92      6,600.00  481.65 0.07
# 58          5.10     1,147.30     493.54     59,301.00  612.04 0.01
# 251         4.65     1,045.40     274.37     32,945.00  557.57 0.02
# 212         3.99       890.70      54.91      6,600.00  479.30 0.07
# 49          6.24     1,404.20     159.73     19,168.00  752.55 0.09
# 70          6.13     1,398.40      89.86     10,800.00  744.38 0.09
# 195         4.17       959.20      14.98      1,800.00  507.50 0.28
# 187         6.17     1,400.30     154.74     18,600.00  744.95 0.09
# 143         6.06     1,362.70      84.87     10,200.00  727.17 0.09
# 163         4.01       909.20      14.98      1,800.00  486.42 0.27
# 94          6.07     1,359.80     154.73     18,569.00  730.10 0.09
# 203         6.04     1,377.50      84.87     10,200.00  726.70 0.09
# 207         4.15       937.40      14.98      1,800.00  501.82 0.28
# 170         6.09     1,383.50     149.75     17,970.00  733.83 0.09
# 68          6.02     1,355.60      84.86     10,200.00  723.76 0.09
# 221         4.02       904.30      14.98      1,800.00  482.86 0.27
# 252         6.36     1,475.10   1,664.03    199,732.00  781.18 0.03
# 274         6.26     1,446.20     921.91    110,630.00  759.12 0.03
# 276         5.19     1,214.20     184.68     22,163.00  635.77 0.03
# 162         6.33     1,443.30   1,624.20    194,948.00  760.57 0.03
# 159         6.29     1,458.50     901.99    108,419.00  771.08 0.03
# 105         4.88     1,108.80     179.69     21,564.00  585.26 0.03
# 223         6.31     1,457.20   1,619.52    194,350.00  763.18 0.03
# 108         6.20     1,432.70     897.04    107,820.00  754.18 0.03
# 155         5.20     1,176.30     179.69     21,564.00  624.13 0.03
# 50          5.83     1,323.20   1,549.33    185,978.00  712.34 0.03
# 139         6.08     1,415.70     862.09    103,454.00  740.58 0.03
# 247         4.99     1,133.40     169.71     20,366.00  598.50 0.03
# 119         6.21     1,409.40     473.82     56,905.00  747.21 0.02
# 169         5.43     1,227.20     264.47     31,747.00  652.03 0.02
# 130         3.95       905.10      49.93      6,000.00  475.30 0.08
# 201         6.04     1,329.40     473.80     56,905.00  725.16 0.02
# 82          5.37     1,214.20     259.50     31,148.00  644.70 0.02
# 16          3.97       900.40      49.93      6,000.00  476.79 0.08
# 73          6.06     1,375.70     473.85     56,905.00  727.59 0.02
# 52          5.33     1,187.60     264.47     31,747.00  638.86 0.02
# 63          3.88       880.60      49.93      6,000.00  465.71 0.08
# 220         5.58     1,266.00     503.68     60,499.00  669.50 0.02
# 154         5.33     1,162.20     279.43     33,544.00  639.67 0.02
# 194         4.09       932.80      54.92      6,600.00  491.17 0.07
# 149         6.23     1,432.70   1,374.83    165,048.00  760.13 0.02
# 243         6.20     1,395.90     762.71     91,647.00  752.91 0.02
# 232         4.78     1,084.90     149.76     18,000.00  573.54 0.03
# 267         5.64     1,290.60   1,380.00    165,646.00  679.04 0.03
# 80          5.63     1,282.60     767.70     92,246.00  675.16 0.03
# 180         5.34     1,212.90     149.75     18,000.00  641.22 0.04
# 46          6.19     1,435.90   1,350.04    162,058.00  754.53 0.02
# 239         6.07     1,408.60     747.75     89,850.00  741.58 0.02
# 245         5.33     1,215.60     149.75     18,000.00  639.82 0.04
# 38          5.31     1,209.70   1,195.36    143,520.00  638.16 0.03
# 255         4.72     1,085.70     663.23     79,667.00  572.70 0.06
# 168         4.56     1,043.50     129.78     15,600.00  547.23 0.04
# 88          6.37     1,426.90     159.74     19,200.00  784.77 0.09
# 158         6.21     1,439.60      89.86     10,800.00  762.45 0.09
# 124         3.99       910.30      14.98      1,800.00  480.29 0.27
# 263         6.41     1,460.40     159.74     19,200.00  769.98 0.08
# 184         6.14     1,394.60      89.86     10,800.00  750.74 0.09
# 93          3.82       873.90      14.98      1,800.00  460.53 0.26
# 166         6.41     1,468.20     159.73     19,168.00  771.53 0.08
# 123         5.73     1,299.70      84.86     10,200.00  687.22 0.07
# 131         4.02       877.30      14.98      1,800.00  483.38 0.27
# 254         6.40     1,452.90     154.74     18,569.00  768.37 0.05
# 111         5.49     1,245.50      84.87     10,200.00  658.42 0.06
# 135         3.91       863.10      14.98      1,800.00  468.70 0.26
# 24          6.09     1,370.10     174.71     21,000.00  731.90 0.07
# 249         5.98     1,357.90      94.85     11,400.00  721.60 0.07
# 53          4.03       906.10      14.98      1,800.00  485.22 0.27
# 231         5.97     1,354.80     174.71     20,965.00  724.40 0.07
# 104         5.94     1,336.10      94.85     11,400.00  712.66 0.07
# 157         3.92       890.00      14.98      1,800.00  471.75 0.26
# 199         6.04     1,371.80     169.71     20,366.00  726.39 0.06
# 92          5.92     1,331.00      94.85     11,400.00  710.32 0.07
# 206         3.97       901.70      14.98      1,800.00  477.64 0.27
# 134         5.90     1,340.30     169.72     20,400.00  709.76 0.07
# 258         5.74     1,290.80      89.86     10,800.00  689.21 0.08
# 196         4.07       915.30      14.98      1,800.00  488.38 0.27
# 5           5.52     1,246.60     613.37     73,677.00  662.06 0.01
# 96          4.63     1,037.10     339.26     40,732.00  555.54 0.01
# 222         3.91       882.70      64.90      7,800.00  469.10 0.06
# 190         5.50     1,237.80     588.46     70,682.00  660.22 0.01
# 85          4.60     1,035.60     324.32     38,935.00  552.52 0.01
# 147         3.98       895.90      64.90      7,800.00  478.17 0.06
# 36          5.45     1,230.80     568.56     68,286.00  653.70 0.01
# 215         4.60     1,040.30     314.34     37,737.00  551.99 0.01
# 198         3.86       861.50      59.91      7,200.00  463.78 0.06
# 84          5.44     1,223.40     603.39     72,479.00  652.52 0.01
# 20          4.60     1,035.30     334.30     40,133.00  551.93 0.01
# 45          3.92       873.10      64.90      7,800.00  469.95 0.06
# 191         4.98       423.00   3,758.08    150,000.00  198.10 0.00
# 264         4.55       632.30   2,089.34    150,000.00  325.79 0.00
# 152         3.83       873.90     419.03     50,316.00  459.62 0.01
# 202         4.96       411.80   3,685.23    150,000.00  201.60 0.00
# 81          4.42       636.00   2,049.04    150,000.00  322.87 0.00
# 178         3.85       874.20     409.04     49,118.00  461.80 0.01
# 113         5.21       520.80   3,497.73    150,000.00  257.42 0.00
# 246         4.35       653.20   1,947.52    150,000.00  334.80 0.00
# 248         3.83       873.20     389.10     46,722.00  459.26 0.01
# 179         4.83       478.50   3,089.15    150,000.00  233.95 0.00
# 280         4.35       730.20   1,719.95    150,000.00  378.47 0.00
# 109         3.82       870.70     344.24     41,331.00  457.87 0.01
# 2           5.16       464.50   3,495.77    150,000.00  220.54 0.00
# 192         4.50       683.60   1,947.57    150,000.00  345.72 0.00
# 269         3.86       871.30     389.11     46,722.00  462.26 0.01
# 26          5.25       441.30   3,703.80    150,000.00  212.25 0.00
# 148         4.50       639.00   2,055.61    150,000.00  327.64 0.00
# 205         3.92       896.90     409.07     49,118.00  469.57 0.01
# 127         5.20       447.20   3,250.69    150,000.00  238.96 0.00
# 35          4.38       701.50   1,811.22    150,000.00  362.31 0.00
# 136         3.87       878.30     359.19     43,128.00  463.87 0.01
# 140         4.81       596.90   2,412.89    150,000.00  298.55 0.00
# 211         4.28       889.20   1,338.45    150,000.00  478.54 0.00
# 118         3.83       872.70     264.46     31,747.00  458.81 0.01
# 75          5.05       363.30   3,836.02    150,000.00  197.09 0.00
# 90          4.42       614.60   2,130.50    150,000.00  310.60 0.00
# 282         3.85       870.60     423.99     50,915.00  461.97 0.01
# 18          5.12       419.70   3,817.18    150,000.00  200.71 0.00
# 260         4.49       615.80   2,118.31    150,000.00  317.48 0.00
# 204         3.85       861.80     423.99     50,915.00  461.32 0.01
# 54          5.04       433.80   3,648.92    150,000.00  207.30 0.00
# 174         4.44       639.90   2,021.62    150,000.00  329.05 0.00
# 208         3.85       882.00     404.04     48,519.00  461.84 0.01
# 216         4.94       454.90   3,295.91    150,000.00  224.79 0.00
# 218         4.40       703.50   1,828.87    150,000.00  360.08 0.00
# 64          3.84       871.30     364.16     43,727.00  460.21 0.01
# 271         5.42     1,046.40   1,436.38    150,000.00  565.45 0.00
# 13          4.60     1,043.80     802.53     96,439.00  551.99 0.01
# 101         3.88       877.80     159.73     19,168.00  465.36 0.02
# 28          5.42     1,018.50   1,547.38    150,000.00  524.31 0.00
# 41          4.73     1,016.10     857.26    103,028.00  567.20 0.01
# 160         3.99       913.40     169.71     20,366.00  477.89 0.02
# 262         5.24     1,074.30   1,398.63    150,000.00  561.66 0.00
# 115         4.57     1,041.10     777.69     93,444.00  548.03 0.01
# 25          3.93       876.30     154.73     18,569.00  470.95 0.03
# 150         5.34     1,138.20   1,333.51    150,000.00  600.61 0.00
# 40          4.67     1,064.50     742.68     89,251.00  560.29 0.01
# 183         3.94       863.60     144.75     17,371.00  472.52 0.03
# 265         5.44     1,240.20   1,090.95    130,962.00  652.72 0.00
# 227         4.61     1,032.60     603.45     72,479.00  553.03 0.01
# 125         3.94       889.60     119.80     14,376.00  471.61 0.03
# 19          5.31     1,195.50   1,046.32    125,580.00  637.45 0.01
# 71          4.56     1,025.00     578.51     69,484.00  546.68 0.01
# 256         3.96       890.90     114.81     13,800.00  475.17 0.03
# 209         5.21     1,166.10     996.53    119,600.00  624.51 0.01
# 228         4.59     1,037.30     553.60     66,489.00  550.65 0.01
# 34          3.94       881.80     109.82     13,200.00  472.43 0.04
# 22          5.35     1,203.40   1,065.97    127,972.00  641.84 0.01
# 6           4.63     1,042.70     593.41     71,281.00  556.15 0.01
# 122         3.96       890.70     114.80     13,777.00  474.38 0.03

# %%
#standardize algorithm names
def select_columns_and_rename_values_basic(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "")
    df.batch_size.unique()
    return df

# %%
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    df = select_columns_and_rename_values_basic(df)
    gen_graph(df, bars=True, freq=f"{f['minimum']}x{f['maximum']}")
# Out:
# ----------------- {'minimum': '600', 'maximum': '1200'} -----------------
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Neste gráfico podemos analisar a quantidade de Joules por instancia (JPI) para cada taxa de saída 10%, 50%, 90%. A taxa de saída representa a quantidade de instancias que serão enviadas ao socket para serem processadas para obtenção do tamanho necessário do mini-batch a ser processado. Pois bem, podemos ver que em todos os algoritmos quanto maior a taxa de saída menor é o JPI e também seu delay, o delay é o tempo necessário que o algoritmo vai ficar em standby para fazer um novo processamento. Analisando todos os casos podemos ver que os algorimos OzaBag obtém um melhor desempenho energético em relação aos outros algoritmos. Segundo o trabalho do Cassales, isso se dever pela limitação do tamanho da estrutura de dados que ele carrega para processar em relação aos outros algoritmos processados.

# %% [markdown]
# # Average Consumer By Frequency

# %%
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    df['joules'] = df['joules'].replace(np.nan, 0)
    df = df.reset_index()

    total = 0
    average = 0 
    for index, row in df.iterrows():
        if int(row['joules']) > 0:
            total += row['joules']

    average = total / len(df.index)
    print(average)
# Out:
# ----------------- {'minimum': '600', 'maximum': '1200'} -----------------
# 498.6450141081419

# %% [markdown]
# Este é o consumo médio em Joules gasto pela aplicação durante toda sua execução

# %% [markdown]
# # Compare Accuracy and IPS
#
# - The IPS has some ligation when accuracy?
# - IPS is minor when is frequency is minimum?
# - IPS is major when is frequency is maximum?
# - IPS is major when utilized mini-batching?

# %%
def plot(ax, dsdf, my_id, x):
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}
    c1 = 'tab:red'
    c2 = 'tab:blue'
    c3 = 'tab:green'
    ds = list(dsdf.dataset)[0]
    ax.set_title(f'{dsformalname[ds]}')
    ax.plot(x, pd.to_numeric(dsdf.acc), color=c1, label='Acuraccy')
    ax.tick_params(axis='y', labelcolor=c1)
    ax.set_xticks(x)
    ax.set_xticklabels(dsdf.batch_size)
    ax.set_ylim(0,100)
    ax2 = ax.twinx()
    ax2.plot(x, pd.to_numeric(dsdf.IPS), color=c2, label='IPS')
    ax2.tick_params(axis='y', labelcolor=c2)
    ax3 = ax.twinx()
    ax3.plot(x, pd.to_numeric(dsdf.JPI), color=c3, label='JPI')
    ax3.tick_params(axis='y', labelcolor=c3)
    ax3.spines["right"].set_position(("axes", 1.14))
    ax3.set_label('JPI')
    if int(my_id/2) == 1:
        ax.set_xlabel('Batch size')
        ax.legend(loc='upper center', bbox_to_anchor=(0, -0.20), fancybox=True, shadow=True, ncol=5)
        ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.20), fancybox=True, shadow=True, ncol=5)
        ax3.legend(loc='upper center', bbox_to_anchor=(1, -0.20), fancybox=True, shadow=True, ncol=5)

# %%
def gen_graph_initial_peralg(df, display_df=False, freq=''):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']

    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    #algorithms = ['OB']
    filename = f"pi-rates"
    for alg in algorithms:
        fig, axs = plt.subplots(2, 2, figsize=(14,9))
        # set the spacing between subplots
        plt.subplots_adjust(left=0.1,
                            bottom=0.1, 
                            right=0.9, 
                            top=0.9, 
                            wspace=0.4, 
                            hspace=0.4)
        dfalg = filter_by_substring_algorithm(df, alg)
        fig.suptitle(f'{alg} - Frequency {freq}')
        for ds in datasets:
            dsdf = dfalg[(dfalg.dataset == ds)]
            x = np.arange(len(dsdf.batch_size))
            my_id = datasets.index(ds)
            ax = axs[int(my_id/2)][my_id%2]
            plot(ax, dsdf, my_id, x)
        plt.savefig(f'{filename}.eps', bbox_inches='tight')

# %%
freqs = [{'minimum': '600', 'maximum': '1200'}]
dataframes = []
for f in freqs:
    dataframes.append(read_data_create_final_dataframe(f, True))
# Out:
# moaDF: 288    mdf: 288     sshDF: 288
#                                   algorithm      dataset  cores  batch_size  \
# 42   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4         100
# 106  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4         100
# 277  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4         100
# 117  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          75
# 138  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          75
# 56   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          75
# 31   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          50
# 141  StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          50
# 8    StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          50
# 98   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          25
# 60   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          25
# 23   StreamingRandomPatchesExecutorMAXChunk  elecNormNew      4          25
# 91                   OzaBagExecutorMAXChunk  elecNormNew      4         100
# 236                  OzaBagExecutorMAXChunk  elecNormNew      4         100
# 69                   OzaBagExecutorMAXChunk  elecNormNew      4         100
# 253                  OzaBagExecutorMAXChunk  elecNormNew      4          75
# 273                  OzaBagExecutorMAXChunk  elecNormNew      4          75
# 120                  OzaBagExecutorMAXChunk  elecNormNew      4          75
# 14                   OzaBagExecutorMAXChunk  elecNormNew      4          50
# 47                   OzaBagExecutorMAXChunk  elecNormNew      4          50
# 272                  OzaBagExecutorMAXChunk  elecNormNew      4          50
# 242                  OzaBagExecutorMAXChunk  elecNormNew      4          25
# 164                  OzaBagExecutorMAXChunk  elecNormNew      4          25
# 189                  OzaBagExecutorMAXChunk  elecNormNew      4          25
# 233             OzaBagAdwinExecutorMAXChunk  elecNormNew      4         100
# 284             OzaBagAdwinExecutorMAXChunk  elecNormNew      4         100
# 234             OzaBagAdwinExecutorMAXChunk  elecNormNew      4         100
# 210             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          75
# 59              OzaBagAdwinExecutorMAXChunk  elecNormNew      4          75
# 278             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          75
# 132             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          50
# 230             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          50
# 268             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          50
# 112             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          25
# 285             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          25
# 259             OzaBagAdwinExecutorMAXChunk  elecNormNew      4          25
# 188              OzaBagASHTExecutorMAXChunk  elecNormNew      4         100
# 151              OzaBagASHTExecutorMAXChunk  elecNormNew      4         100
# 257              OzaBagASHTExecutorMAXChunk  elecNormNew      4         100
# 1                OzaBagASHTExecutorMAXChunk  elecNormNew      4          75
# 87               OzaBagASHTExecutorMAXChunk  elecNormNew      4          75
# 142              OzaBagASHTExecutorMAXChunk  elecNormNew      4          75
# 66               OzaBagASHTExecutorMAXChunk  elecNormNew      4          50
# 146              OzaBagASHTExecutorMAXChunk  elecNormNew      4          50
# 114              OzaBagASHTExecutorMAXChunk  elecNormNew      4          50
# 43               OzaBagASHTExecutorMAXChunk  elecNormNew      4          25
# 266              OzaBagASHTExecutorMAXChunk  elecNormNew      4          25
# 100              OzaBagASHTExecutorMAXChunk  elecNormNew      4          25
# 21                     LBagExecutorMAXChunk  elecNormNew      4         100
# 186                    LBagExecutorMAXChunk  elecNormNew      4         100
# 173                    LBagExecutorMAXChunk  elecNormNew      4         100
# 9                      LBagExecutorMAXChunk  elecNormNew      4          75
# 29                     LBagExecutorMAXChunk  elecNormNew      4          75
# 10                     LBagExecutorMAXChunk  elecNormNew      4          75
# 219                    LBagExecutorMAXChunk  elecNormNew      4          50
# 156                    LBagExecutorMAXChunk  elecNormNew      4          50
# 261                    LBagExecutorMAXChunk  elecNormNew      4          50
# 67                     LBagExecutorMAXChunk  elecNormNew      4          25
# 51                     LBagExecutorMAXChunk  elecNormNew      4          25
# 244                    LBagExecutorMAXChunk  elecNormNew      4          25
# 12     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4         100
# 99     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4         100
# 240    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4         100
# 181    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          75
# 238    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          75
# 95     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          75
# 128    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          50
# 224    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          50
# 107    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          50
# 77     AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          25
# 176    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          25
# 161    AdaptiveRandomForestExecutorMAXChunk  elecNormNew      4          25
# 286  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4         100
# 281  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4         100
# 17   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4         100
# 172  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          75
# 144  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          75
# 15   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          75
# 32   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          50
# 44   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          50
# 62   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          50
# 237  StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          25
# 86   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          25
# 39   StreamingRandomPatchesExecutorMAXChunk  covtypeNorm      4          25
# 214                  OzaBagExecutorMAXChunk  covtypeNorm      4         100
# 167                  OzaBagExecutorMAXChunk  covtypeNorm      4         100
# 0                    OzaBagExecutorMAXChunk  covtypeNorm      4         100
# 229                  OzaBagExecutorMAXChunk  covtypeNorm      4          75
# 145                  OzaBagExecutorMAXChunk  covtypeNorm      4          75
# 74                   OzaBagExecutorMAXChunk  covtypeNorm      4          75
# 37                   OzaBagExecutorMAXChunk  covtypeNorm      4          50
# 270                  OzaBagExecutorMAXChunk  covtypeNorm      4          50
# 7                    OzaBagExecutorMAXChunk  covtypeNorm      4          50
# 197                  OzaBagExecutorMAXChunk  covtypeNorm      4          25
# 200                  OzaBagExecutorMAXChunk  covtypeNorm      4          25
# 126                  OzaBagExecutorMAXChunk  covtypeNorm      4          25
# 226             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4         100
# 171             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4         100
# 4               OzaBagAdwinExecutorMAXChunk  covtypeNorm      4         100
# 97              OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          75
# 165             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          75
# 79              OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          75
# 121             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          50
# 116             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          50
# 110             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          50
# 177             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          25
# 287             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          25
# 275             OzaBagAdwinExecutorMAXChunk  covtypeNorm      4          25
# 27               OzaBagASHTExecutorMAXChunk  covtypeNorm      4         100
# 241              OzaBagASHTExecutorMAXChunk  covtypeNorm      4         100
# 283              OzaBagASHTExecutorMAXChunk  covtypeNorm      4         100
# 57               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          75
# 103              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          75
# 3                OzaBagASHTExecutorMAXChunk  covtypeNorm      4          75
# 33               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          50
# 133              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          50
# 72               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          50
# 65               OzaBagASHTExecutorMAXChunk  covtypeNorm      4          25
# 182              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          25
# 225              OzaBagASHTExecutorMAXChunk  covtypeNorm      4          25
# 137                    LBagExecutorMAXChunk  covtypeNorm      4         100
# 30                     LBagExecutorMAXChunk  covtypeNorm      4         100
# 153                    LBagExecutorMAXChunk  covtypeNorm      4         100
# 193                    LBagExecutorMAXChunk  covtypeNorm      4          75
# 76                     LBagExecutorMAXChunk  covtypeNorm      4          75
# 279                    LBagExecutorMAXChunk  covtypeNorm      4          75
# 61                     LBagExecutorMAXChunk  covtypeNorm      4          50
# 102                    LBagExecutorMAXChunk  covtypeNorm      4          50
# 89                     LBagExecutorMAXChunk  covtypeNorm      4          50
# 250                    LBagExecutorMAXChunk  covtypeNorm      4          25
# 235                    LBagExecutorMAXChunk  covtypeNorm      4          25
# 213                    LBagExecutorMAXChunk  covtypeNorm      4          25
# 78     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4         100
# 175    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4         100
# 217    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4         100
# 48     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          75
# 83     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          75
# 11     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          75
# 185    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          50
# 129    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          50
# 55     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          50
# 58     AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          25
# 251    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          25
# 212    AdaptiveRandomForestExecutorMAXChunk  covtypeNorm      4          25
# 49   StreamingRandomPatchesExecutorMAXChunk     airlines      4         100
# 70   StreamingRandomPatchesExecutorMAXChunk     airlines      4         100
# 195  StreamingRandomPatchesExecutorMAXChunk     airlines      4         100
# 187  StreamingRandomPatchesExecutorMAXChunk     airlines      4          75
# 143  StreamingRandomPatchesExecutorMAXChunk     airlines      4          75
# 163  StreamingRandomPatchesExecutorMAXChunk     airlines      4          75
# 94   StreamingRandomPatchesExecutorMAXChunk     airlines      4          50
# 203  StreamingRandomPatchesExecutorMAXChunk     airlines      4          50
# 207  StreamingRandomPatchesExecutorMAXChunk     airlines      4          50
# 170  StreamingRandomPatchesExecutorMAXChunk     airlines      4          25
# 68   StreamingRandomPatchesExecutorMAXChunk     airlines      4          25
# 221  StreamingRandomPatchesExecutorMAXChunk     airlines      4          25
# 252                  OzaBagExecutorMAXChunk     airlines      4         100
# 274                  OzaBagExecutorMAXChunk     airlines      4         100
# 276                  OzaBagExecutorMAXChunk     airlines      4         100
# 162                  OzaBagExecutorMAXChunk     airlines      4          75
# 159                  OzaBagExecutorMAXChunk     airlines      4          75
# 105                  OzaBagExecutorMAXChunk     airlines      4          75
# 223                  OzaBagExecutorMAXChunk     airlines      4          50
# 108                  OzaBagExecutorMAXChunk     airlines      4          50
# 155                  OzaBagExecutorMAXChunk     airlines      4          50
# 50                   OzaBagExecutorMAXChunk     airlines      4          25
# 139                  OzaBagExecutorMAXChunk     airlines      4          25
# 247                  OzaBagExecutorMAXChunk     airlines      4          25
# 119             OzaBagAdwinExecutorMAXChunk     airlines      4         100
# 169             OzaBagAdwinExecutorMAXChunk     airlines      4         100
# 130             OzaBagAdwinExecutorMAXChunk     airlines      4         100
# 201             OzaBagAdwinExecutorMAXChunk     airlines      4          75
# 82              OzaBagAdwinExecutorMAXChunk     airlines      4          75
# 16              OzaBagAdwinExecutorMAXChunk     airlines      4          75
# 73              OzaBagAdwinExecutorMAXChunk     airlines      4          50
# 52              OzaBagAdwinExecutorMAXChunk     airlines      4          50
# 63              OzaBagAdwinExecutorMAXChunk     airlines      4          50
# 220             OzaBagAdwinExecutorMAXChunk     airlines      4          25
# 154             OzaBagAdwinExecutorMAXChunk     airlines      4          25
# 194             OzaBagAdwinExecutorMAXChunk     airlines      4          25
# 149              OzaBagASHTExecutorMAXChunk     airlines      4         100
# 243              OzaBagASHTExecutorMAXChunk     airlines      4         100
# 232              OzaBagASHTExecutorMAXChunk     airlines      4         100
# 267              OzaBagASHTExecutorMAXChunk     airlines      4          75
# 80               OzaBagASHTExecutorMAXChunk     airlines      4          75
# 180              OzaBagASHTExecutorMAXChunk     airlines      4          75
# 46               OzaBagASHTExecutorMAXChunk     airlines      4          50
# 239              OzaBagASHTExecutorMAXChunk     airlines      4          50
# 245              OzaBagASHTExecutorMAXChunk     airlines      4          50
# 38               OzaBagASHTExecutorMAXChunk     airlines      4          25
# 255              OzaBagASHTExecutorMAXChunk     airlines      4          25
# 168              OzaBagASHTExecutorMAXChunk     airlines      4          25
# 88                     LBagExecutorMAXChunk     airlines      4         100
# 158                    LBagExecutorMAXChunk     airlines      4         100
# 124                    LBagExecutorMAXChunk     airlines      4         100
# 263                    LBagExecutorMAXChunk     airlines      4          75
# 184                    LBagExecutorMAXChunk     airlines      4          75
# 93                     LBagExecutorMAXChunk     airlines      4          75
# 166                    LBagExecutorMAXChunk     airlines      4          50
# 123                    LBagExecutorMAXChunk     airlines      4          50
# 131                    LBagExecutorMAXChunk     airlines      4          50
# 254                    LBagExecutorMAXChunk     airlines      4          25
# 111                    LBagExecutorMAXChunk     airlines      4          25
# 135                    LBagExecutorMAXChunk     airlines      4          25
# 24     AdaptiveRandomForestExecutorMAXChunk     airlines      4         100
# 249    AdaptiveRandomForestExecutorMAXChunk     airlines      4         100
# 53     AdaptiveRandomForestExecutorMAXChunk     airlines      4         100
# 231    AdaptiveRandomForestExecutorMAXChunk     airlines      4          75
# 104    AdaptiveRandomForestExecutorMAXChunk     airlines      4          75
# 157    AdaptiveRandomForestExecutorMAXChunk     airlines      4          75
# 199    AdaptiveRandomForestExecutorMAXChunk     airlines      4          50
# 92     AdaptiveRandomForestExecutorMAXChunk     airlines      4          50
# 206    AdaptiveRandomForestExecutorMAXChunk     airlines      4          50
# 134    AdaptiveRandomForestExecutorMAXChunk     airlines      4          25
# 258    AdaptiveRandomForestExecutorMAXChunk     airlines      4          25
# 196    AdaptiveRandomForestExecutorMAXChunk     airlines      4          25
# 5    StreamingRandomPatchesExecutorMAXChunk         GMSC      4         100
# 96   StreamingRandomPatchesExecutorMAXChunk         GMSC      4         100
# 222  StreamingRandomPatchesExecutorMAXChunk         GMSC      4         100
# 190  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          75
# 85   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          75
# 147  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          75
# 36   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          50
# 215  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          50
# 198  StreamingRandomPatchesExecutorMAXChunk         GMSC      4          50
# 84   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          25
# 20   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          25
# 45   StreamingRandomPatchesExecutorMAXChunk         GMSC      4          25
# 191                  OzaBagExecutorMAXChunk         GMSC      4         100
# 264                  OzaBagExecutorMAXChunk         GMSC      4         100
# 152                  OzaBagExecutorMAXChunk         GMSC      4         100
# 202                  OzaBagExecutorMAXChunk         GMSC      4          75
# 81                   OzaBagExecutorMAXChunk         GMSC      4          75
# 178                  OzaBagExecutorMAXChunk         GMSC      4          75
# 113                  OzaBagExecutorMAXChunk         GMSC      4          50
# 246                  OzaBagExecutorMAXChunk         GMSC      4          50
# 248                  OzaBagExecutorMAXChunk         GMSC      4          50
# 179                  OzaBagExecutorMAXChunk         GMSC      4          25
# 280                  OzaBagExecutorMAXChunk         GMSC      4          25
# 109                  OzaBagExecutorMAXChunk         GMSC      4          25
# 2               OzaBagAdwinExecutorMAXChunk         GMSC      4         100
# 192             OzaBagAdwinExecutorMAXChunk         GMSC      4         100
# 269             OzaBagAdwinExecutorMAXChunk         GMSC      4         100
# 26              OzaBagAdwinExecutorMAXChunk         GMSC      4          75
# 148             OzaBagAdwinExecutorMAXChunk         GMSC      4          75
# 205             OzaBagAdwinExecutorMAXChunk         GMSC      4          75
# 127             OzaBagAdwinExecutorMAXChunk         GMSC      4          50
# 35              OzaBagAdwinExecutorMAXChunk         GMSC      4          50
# 136             OzaBagAdwinExecutorMAXChunk         GMSC      4          50
# 140             OzaBagAdwinExecutorMAXChunk         GMSC      4          25
# 211             OzaBagAdwinExecutorMAXChunk         GMSC      4          25
# 118             OzaBagAdwinExecutorMAXChunk         GMSC      4          25
# 75               OzaBagASHTExecutorMAXChunk         GMSC      4         100
# 90               OzaBagASHTExecutorMAXChunk         GMSC      4         100
# 282              OzaBagASHTExecutorMAXChunk         GMSC      4         100
# 18               OzaBagASHTExecutorMAXChunk         GMSC      4          75
# 260              OzaBagASHTExecutorMAXChunk         GMSC      4          75
# 204              OzaBagASHTExecutorMAXChunk         GMSC      4          75
# 54               OzaBagASHTExecutorMAXChunk         GMSC      4          50
# 174              OzaBagASHTExecutorMAXChunk         GMSC      4          50
# 208              OzaBagASHTExecutorMAXChunk         GMSC      4          50
# 216              OzaBagASHTExecutorMAXChunk         GMSC      4          25
# 218              OzaBagASHTExecutorMAXChunk         GMSC      4          25
# 64               OzaBagASHTExecutorMAXChunk         GMSC      4          25
# 271                    LBagExecutorMAXChunk         GMSC      4         100
# 13                     LBagExecutorMAXChunk         GMSC      4         100
# 101                    LBagExecutorMAXChunk         GMSC      4         100
# 28                     LBagExecutorMAXChunk         GMSC      4          75
# 41                     LBagExecutorMAXChunk         GMSC      4          75
# 160                    LBagExecutorMAXChunk         GMSC      4          75
# 262                    LBagExecutorMAXChunk         GMSC      4          50
# 115                    LBagExecutorMAXChunk         GMSC      4          50
# 25                     LBagExecutorMAXChunk         GMSC      4          50
# 150                    LBagExecutorMAXChunk         GMSC      4          25
# 40                     LBagExecutorMAXChunk         GMSC      4          25
# 183                    LBagExecutorMAXChunk         GMSC      4          25
# 265    AdaptiveRandomForestExecutorMAXChunk         GMSC      4         100
# 227    AdaptiveRandomForestExecutorMAXChunk         GMSC      4         100
# 125    AdaptiveRandomForestExecutorMAXChunk         GMSC      4         100
# 19     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          75
# 71     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          75
# 256    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          75
# 209    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          50
# 228    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          50
# 34     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          50
# 22     AdaptiveRandomForestExecutorMAXChunk         GMSC      4          25
# 6      AdaptiveRandomForestExecutorMAXChunk         GMSC      4          25
# 122    AdaptiveRandomForestExecutorMAXChunk         GMSC      4          25
#
#      inc_rate  out_rate  instances   time    delay   acc  duration  \
# 42        365    363.90  43,700.00 120.09   262.00 79.90       124
# 106       203    199.92  23,960.00 119.85   380.00 80.97       124
# 277        40     39.95   4,800.00 120.14 1,445.00 80.66       124
# 117       352    349.37  41,925.00 120.00   194.00 79.98       125
# 138       195    194.36  23,325.00 120.01   310.00 81.93       123
# 56         39     34.97   4,200.00 120.10 1,231.00 80.97       124
# 31        351    349.55  41,930.00 119.95   131.00 80.95       125
# 141       195    194.80  23,361.00 119.92   196.00 82.61       124
# 8          39     34.99   4,200.00 120.04   820.00 82.48       123
# 98        332    329.31  39,525.00 120.02    68.00 82.23       125
# 60        184    179.88  21,564.00 119.88   101.00 84.83       123
# 23         36     35.00   4,200.00 120.02   402.00 83.86       124
# 91       2519  2,333.75  42,934.00  18.40    42.00 78.85        24
# 236      1399  1,392.16  45,312.00  32.55    56.00 78.36        37
# 69        279    274.77  32,945.00 119.90   199.00 77.56       126
# 253      2531  2,418.59  43,496.00  17.98    31.00 78.51        23
# 273      1406  1,401.63  45,312.00  32.33    41.00 78.57        38
# 120       281    279.78  33,544.00 119.90   147.00 79.28       125
# 14       2318  2,222.73  43,510.00  19.58    21.00 78.67        24
# 47       1288  1,281.34  45,312.00  35.36    29.00 78.73        41
# 272       257    254.85  30,549.00 119.87   107.00 79.64       125
# 242      2328  2,265.48  44,272.00  19.54    11.00 79.49        24
# 164      1293  1,289.51  45,312.00  35.14    14.00 79.67        41
# 189       258    254.83  30,549.00 119.88    52.00 79.29       125
# 233      2096  2,023.07  43,927.00  21.71    48.00 79.10        28
# 284      1164  1,157.01  45,312.00  39.16    64.00 79.09        44
# 234       232    229.89  27,554.00 119.86   245.00 80.69       126
# 210      2108  2,020.99  43,609.00  21.58    36.00 78.66        26
# 59       1171  1,168.53  45,312.00  38.78    50.00 79.15        45
# 278       234    229.81  27,554.00 119.90   184.00 80.71       125
# 132      1931  1,806.45  42,484.00  23.52    26.00 79.48        29
# 230      1072  1,067.87  45,312.00  42.43    35.00 79.56        47
# 268       214    209.89  25,158.00 119.86   130.00 81.64       126
# 112      1652  1,606.72  44,204.00  27.51    15.00 80.86        32
# 285       917    912.74  45,312.00  49.64    21.00 80.39        56
# 259       183    179.93  21,564.00 119.84    76.00 83.95       125
# 188      2573  2,417.63  42,780.00  17.69    41.00 78.40        23
# 151      1429  1,426.70  45,312.00  31.76    53.00 78.22        38
# 257       285    284.77  34,143.00 119.90   198.00 78.12       125
# 1        2493  2,220.78  44,158.00  19.88    33.00 79.30        26
# 87       1385  1,384.59  45,312.00  32.73    41.00 79.23        38
# 142       277    274.76  32,945.00 119.90   144.00 78.33       126
# 66       2439  2,295.92  43,758.00  19.06    21.00 79.37        25
# 146      1355  1,351.15  45,312.00  33.54    30.00 79.37        38
# 114       271    269.83  32,346.00 119.88    99.00 78.99       126
# 43       2303  2,188.12  43,187.00  19.74    11.00 80.07        26
# 266      1279  1,272.27  45,312.00  35.62    14.00 80.59        40
# 100       255    254.82  30,549.00 119.88    53.00 80.70       126
# 21       1087  1,005.88  42,105.00  41.86    95.00 79.77        47
# 186       604    598.93  45,312.00  75.65   116.00 79.92        81
# 173       120    119.98  14,376.00 119.82   482.00 81.93       125
# 9        1043    977.65  42,694.00  43.67    72.00 80.47        49
# 29        579    573.38  45,312.00  79.03    96.00 80.33        84
# 10        115    114.98  13,777.00 119.82   382.00 82.19       126
# 219      1017    958.91  42,962.00  44.80    48.00 81.39        51
# 156       565    564.50  45,312.00  80.27    64.00 81.71        85
# 261       113    109.82  13,179.00 120.00   259.00 83.21       125
# 67        976    923.03  43,040.00  46.63    25.00 83.02        52
# 51        542    539.09  45,312.00  84.05    34.00 83.53        89
# 244       108    104.96  12,579.00 119.85   133.00 85.37       126
# 12        676    645.37  43,424.00  67.29   143.00 79.29        71
# 99        375    374.49  44,925.00 119.96   184.00 79.31       124
# 240        75     74.88   8,986.00 120.00   780.00 80.65       124
# 181       713    672.42  43,042.00  64.01   103.00 79.52        69
# 238       396    394.15  45,312.00 114.96   138.00 79.35       119
# 95         79     74.88   8,986.00 120.00   517.00 80.42       123
# 128       694    662.88  43,654.00  65.86    68.00 80.72        70
# 224       386    384.15  45,312.00 117.96    95.00 80.24       122
# 107        77     74.88   8,986.00 120.01   370.00 80.90       124
# 77        619    605.32  44,711.00  73.86    36.00 81.60        77
# 176       344    339.52  40,732.00 119.97    52.00 81.27       124
# 161        68     64.90   7,788.00 120.00   218.00 81.45       124
# 286       125    124.97  14,975.00 119.82   712.00 71.77       125
# 281        69     64.77   7,800.00 120.42 1,170.00 73.31       125
# 17         13      9.97   1,200.00 120.39 5,726.00 62.73       125
# 172       135    134.92  16,173.00 119.87   521.00 73.79       124
# 144        75     74.61   9,000.00 120.63   744.00 75.32       125
# 15         15     14.97   1,800.00 120.21 2,879.00 67.25       125
# 32        126    124.85  14,975.00 119.94   338.00 75.44       125
# 44         70     69.89   8,387.00 120.00   552.00 76.89       123
# 62         14      9.98   1,200.00 120.19 2,783.00 66.87       125
# 237       114    109.74  13,175.00 120.05   191.00 77.98       124
# 86         63     59.92   7,200.00 120.15   297.00 78.76       125
# 39         12      9.99   1,200.00 120.09 1,384.00 68.26       124
# 214       668    657.30  78,900.00 120.04   148.00 81.41       125
# 167       371    369.41  44,326.00 119.99   245.00 75.27       126
# 0          74     69.86   8,400.00 120.25   921.00 60.43       125
# 229       600    595.60  71,475.00 120.00   120.00 81.03       126
# 145       333    329.46  39,534.00 120.00   196.00 73.64       125
# 74         66     64.86   7,800.00 120.26   787.00 60.94       126
# 37        652    643.20  77,200.00 120.03    75.00 81.89       125
# 270       362    359.53  43,128.00 119.96   123.00 75.39       126
# 7          72     69.90   8,400.00 120.18   488.00 61.43       125
# 197       595    586.62  70,400.00 120.01    41.00 81.63       125
# 200       330    329.48  39,534.00 119.99    66.00 74.36       126
# 126        66     64.90   7,788.00 120.00   250.00 62.99       125
# 226       635    627.49  75,300.00 120.00   151.00 83.73       126
# 171       353    349.53  41,930.00 119.96   230.00 78.10       126
# 4          70     69.85   8,400.00 120.26   944.00 64.23       125
# 97        608    593.25  71,250.00 120.10   119.00 84.16       125
# 165       338    334.58  40,133.00 119.95   186.00 77.57       126
# 79         67     64.90   7,788.00 120.00   804.00 65.03       126
# 121       556    551.19  66,150.00 120.01    87.00 83.41       126
# 116       309    304.62  36,539.00 119.95   136.00 76.98       125
# 110        61     59.90   7,200.00 120.19   561.00 66.84       126
# 177       472    408.28  49,000.00 120.02    61.00 81.82       126
# 287       262    259.75  31,148.00 119.92    78.00 77.47       126
# 275        52     49.97   6,000.00 120.07   291.00 70.49       125
# 27        651    643.17  77,200.00 120.03   151.00 81.30       126
# 241       361    359.52  43,128.00 119.96   244.00 75.18       126
# 283        72     69.81   8,400.00 120.33   975.00 60.47       125
# 57        664    654.29  78,525.00 120.02   109.00 81.55       125
# 103       369    364.42  43,727.00 119.99   179.00 75.41       126
# 3          73     69.88   8,400.00 120.20   696.00 60.71       126
# 33        626    619.54  74,350.00 120.01    76.00 81.67       126
# 133       347    344.57  41,331.00 119.95   129.00 75.09       126
# 72         69     64.90   7,788.00 120.00   517.00 61.98       125
# 65        575    570.82  68,500.00 120.00    43.00 81.30       126
# 182       319    314.34  37,725.00 120.01    67.00 74.25       126
# 225        63     59.96   7,200.00 120.09   265.00 63.32       125
# 137       427    423.26  50,800.00 120.02   211.00 85.63       125
# 30        237    234.90  28,153.00 119.85   363.00 77.76       126
# 153        47     44.89   5,400.00 120.30 1,403.00 69.60       126
# 193       417    413.70  49,650.00 120.01   162.00 85.46       126
# 76        232    229.65  27,554.00 119.98   274.00 78.08       125
# 279        46     44.92   5,400.00 120.21 1,037.00 70.65       126
# 61        402    399.11  47,900.00 120.02   115.00 85.43       125
# 102       223    219.79  26,356.00 119.91   186.00 78.67       126
# 89         44     39.95   4,800.00 120.16   763.00 71.35       125
# 250       340    339.36  40,725.00 120.01    68.00 81.71       125
# 235       189    184.87  22,163.00 119.89   112.00 77.47       126
# 213        37     34.98   4,200.00 120.06   429.00 71.93       125
# 78        624    597.16  71,700.00 120.07   155.00 86.12       123
# 175       346    340.90  40,876.00 119.90   239.00 81.07       125
# 217        69     64.94   7,800.00 120.11   942.00 69.45       125
# 48        548    527.78  63,375.00 120.08   118.00 85.67       124
# 83        304    299.06  35,880.00 119.97   184.00 79.39       124
# 11         60     59.96   7,200.00 120.08   742.00 70.44       124
# 185       530    517.28  62,100.00 120.05    85.00 86.23       124
# 129       294    289.46  34,723.00 119.96   133.00 79.95       124
# 55         58     54.96   6,600.00 120.08   560.00 72.89       124
# 58        499    481.97  57,850.00 120.03    44.00 86.78       124
# 251       277    274.36  32,925.00 120.01    65.00 80.72       124
# 212        55     54.94   6,593.00 120.00   266.00 74.33       123
# 49        164     71.32   8,600.00 120.58 1,399.00 65.31       124
# 70         91     71.68   8,700.00 121.37 1,388.00 65.47       126
# 195        18     14.79   1,800.00 121.69 4,387.00 75.12       126
# 187       156     68.94   8,325.00 120.76 1,086.00 65.94       125
# 143        86     68.09   8,175.00 120.07 1,097.00 65.56       124
# 163        17     14.82   1,800.00 121.44 3,229.00 75.19       125
# 94        156     68.60   8,250.00 120.27   728.00 65.52       124
# 203        87     69.42   8,350.00 120.28   718.00 65.61       125
# 207        17     14.88   1,800.00 120.98 2,172.00 75.49       125
# 170       153     69.97   8,425.00 120.40   357.00 65.64       125
# 68         85     66.60   8,000.00 120.13   375.00 65.96       124
# 221        17     14.98   1,800.00 120.14 1,053.00 74.65       124
# 252      1672    192.90  23,700.00 122.86   518.00 64.44       128
# 274       929    216.08  26,200.00 121.25   462.00 64.65       127
# 276       185    180.37  22,100.00 122.53   471.00 63.32       129
# 162      1630    209.12  25,125.00 120.15   358.00 64.68       126
# 159       905    208.51  25,575.00 122.65   359.00 65.15       128
# 105       181    179.97  21,564.00 119.82   343.00 63.60       125
# 223      1627    204.16  24,700.00 120.98   244.00 66.19       127
# 108       904    220.40  26,800.00 121.60   226.00 64.79       127
# 155       180    179.83  21,564.00 119.91   226.00 63.33       125
# 50       1558    173.48  21,200.00 122.21   144.00 65.25       128
# 139       865    213.52  26,025.00 121.89   117.00 64.14       128
# 247       173    169.90  20,366.00 119.87   117.00 63.52       125
# 119       477    375.58  45,200.00 120.35   266.00 68.58       125
# 169       265    264.00  31,700.00 120.08   349.00 66.75       125
# 130        53     49.89   6,000.00 120.25 1,127.00 66.27       126
# 201       476    366.86  44,025.00 120.01   204.00 68.90       126
# 82        264    259.57  31,148.00 120.00   265.00 67.17       125
# 16         52     49.92   6,000.00 120.20   873.00 66.70       125
# 73        479    384.40  46,150.00 120.06   129.00 68.65       126
# 52        266    264.64  31,747.00 119.96   164.00 66.97       125
# 63         53     49.98   6,000.00 120.05   519.00 66.74       125
# 220       509    339.66  40,775.00 120.04    73.00 68.58       125
# 154       283    279.56  33,544.00 119.99    82.00 66.91       125
# 194        56     54.97   6,600.00 120.06   272.00 66.52       126
# 149      1383    271.25  33,100.00 122.03   368.00 67.40       127
# 243       768    281.81  34,200.00 121.36   354.00 64.95       127
# 232       153    149.75  17,971.00 120.00   521.00 63.26       125
# 267      1389    186.74  22,500.00 120.49   401.00 65.79       126
# 80        771    175.60  21,075.00 120.02   426.00 65.03       126
# 180       154    149.75  17,971.00 120.01   376.00 63.35       125
# 46       1358    281.36  34,300.00 121.91   177.00 67.76       128
# 239       754    310.71  37,950.00 122.14   160.00 66.85       128
# 245       150    149.75  17,971.00 120.01   246.00 63.06       125
# 38       1203    168.15  20,225.00 120.28   148.00 65.19       126
# 255       668     74.80   9,075.00 121.32   334.00 63.64       127
# 168       133    129.69  15,575.00 120.09   136.00 63.18       126
# 88        163     68.18   8,400.00 123.20 1,463.00 61.98       128
# 158        90     68.36   8,400.00 122.87 1,428.00 61.95       128
# 124        18     14.96   1,800.00 120.30 3,959.00 71.94       126
# 263       162     77.99   9,375.00 120.21   960.00 61.72       126
# 184        90     71.81   8,775.00 122.20 1,005.00 62.21       128
# 93         18     14.92   1,800.00 120.68 2,888.00 72.52       126
# 166       161     77.28   9,300.00 120.34   646.00 61.81       126
# 123        89     79.57   9,550.00 120.03   587.00 61.55       125
# 131        17     14.99   1,800.00 120.11 1,954.00 72.74       125
# 254       156    119.74  14,375.00 120.05   208.00 60.86       125
# 111        87     84.87  10,185.00 120.00   267.00 61.49       125
# 135        17     15.00   1,800.00 120.01   962.00 72.23       125
# 24        179     88.19  10,600.00 120.19 1,131.00 65.76       124
# 249        99     88.70  10,700.00 120.63 1,119.00 65.11       125
# 53         19     14.94   1,800.00 120.49 4,200.00 74.82       124
# 231       178     87.74  10,650.00 121.38   853.00 65.11       125
# 104        99     84.37  10,125.00 120.01   878.00 65.83       124
# 157        19     14.96   1,800.00 120.32 3,086.00 74.67       125
# 199       174     93.59  11,250.00 120.20   533.00 65.95       125
# 92         97     84.53  10,150.00 120.08   583.00 65.97       124
# 206        19     14.97   1,800.00 120.25 2,087.00 74.63       125
# 134       170     83.81  10,075.00 120.21   298.00 65.35       125
# 258        94     73.87   8,875.00 120.14   332.00 65.80       124
# 196        18     14.99   1,800.00 120.06 1,025.00 74.42       124
# 5         615    613.20  73,600.00 120.03   151.00 93.49       124
# 96        342    339.46  40,732.00 119.99   221.00 93.48       124
# 222        68     64.94   7,800.00 120.11   903.00 93.60       124
# 190       592    588.08  70,575.00 120.01   117.00 93.43       124
# 85        329    324.26  38,925.00 120.04   166.00 93.51       124
# 147        65     64.95   7,800.00 120.09   684.00 93.67       124
# 36        572    568.60  68,250.00 120.03    79.00 93.43       125
# 215       317    314.69  37,737.00 119.92   116.00 93.49       124
# 198        63     59.98   7,200.00 120.05   475.00 93.65       123
# 84        605    603.29  72,400.00 120.01    38.00 93.40       124
# 20        336    334.58  40,133.00 119.95    54.00 93.47       124
# 45         67     64.98   7,800.00 120.03   220.00 93.65       123
# 191      3781  3,758.21 149,607.00  39.81    25.00 93.40        46
# 264      2101  2,094.42 150,000.00  71.62    34.00 93.54        76
# 152       420    419.60  50,316.00 119.92   130.00 93.35       126
# 202      3701  3,691.49 150,000.00  40.63    19.00 93.50        45
# 81       2056  2,051.90 150,000.00  73.10    27.00 93.48        79
# 178       411    409.61  49,118.00 119.91   102.00 93.41       125
# 113      3520  3,027.19 149,625.00  49.43    16.00 93.39        55
# 246      1955  1,951.02 150,000.00  76.88    19.00 93.50        82
# 248       391    389.62  46,722.00 119.92    70.00 93.51       126
# 179      3111  3,098.98 150,000.00  48.40     7.00 93.49        54
# 280      1728  1,722.61 150,000.00  87.08    10.00 93.49        92
# 109       345    344.72  41,331.00 119.90    39.00 93.45       126
# 2        3523  3,508.42 149,922.00  42.73    27.00 93.39        49
# 192      1957  1,951.32 150,000.00  76.87    37.00 93.34        83
# 269       391    389.66  46,722.00 119.90   145.00 93.39       125
# 26       3722  3,689.71 149,068.00  40.40    19.00 93.34        46
# 148      2068  2,060.16 150,000.00  72.81    28.00 93.36        78
# 205       413    409.68  49,118.00 119.89   103.00 93.46       126
# 127      3278  3,248.01 149,259.00  45.95    14.00 93.33        51
# 35       1821  1,815.17 150,000.00  82.64    19.00 93.34        88
# 136       364    359.73  43,128.00 119.89    76.00 93.41       125
# 140      2428  2,418.54 150,000.00  62.02     9.00 93.38        68
# 211      1349  1,340.00 150,000.00 111.94    13.00 93.32       117
# 118       269    264.85  31,747.00 119.87    50.00 93.58       126
# 75       3854  3,840.25 150,000.00  39.06    24.00 93.35        44
# 90       2141  2,135.32 150,000.00  70.25    34.00 93.37        76
# 282       428    424.56  50,915.00 119.92   127.00 93.32       125
# 18       3839  3,825.16 150,000.00  39.21    18.00 93.36        45
# 260      2133  2,123.68 150,000.00  70.63    26.00 93.38        75
# 204       426    424.62  50,915.00 119.91    94.00 93.38       126
# 54       3660  3,649.90 150,000.00  41.10    13.00 93.36        47
# 174      2033  2,025.74 150,000.00  74.05    18.00 93.35        79
# 208       406    404.63  48,519.00 119.91    68.00 93.37       126
# 216      3308  3,299.46 150,000.00  45.46     7.00 93.44        50
# 218      1838  1,831.64 150,000.00  81.89    10.00 93.33        88
# 64        367    364.70  43,727.00 119.90    37.00 93.43       125
# 271      1449  1,438.26 150,000.00 104.29    62.00 93.37       109
# 13        805    802.21  96,300.00 120.04    95.00 93.50       125
# 101       161    159.98  19,168.00 119.81   359.00 93.59       125
# 28       1556  1,537.21 148,771.00  96.78    46.00 93.39       103
# 41        864    857.39 102,900.00 120.02    66.00 93.35       124
# 160       172    169.98  20,366.00 119.81   260.00 93.51       126
# 262      1408  1,399.55 150,000.00 107.18    31.00 93.34       113
# 115       782    777.80  93,350.00 120.02    46.00 93.40       126
# 25        156    154.94  18,569.00 119.85   185.00 93.53       125
# 150      1343  1,334.57 150,000.00 112.40    17.00 93.40       117
# 40        746    742.88  89,150.00 120.01    24.00 93.35       126
# 183       149    144.97  17,371.00 119.83    96.00 93.44       125
# 265      1096  1,091.38 130,962.00 120.00    84.00 93.56       125
# 227       608    604.15  72,479.00 119.97   122.00 93.47       124
# 125       121    119.99  14,376.00 119.81   484.00 93.56       124
# 19       1052  1,046.75 125,580.00 119.97    62.00 93.54       124
# 71        584    578.73  69,450.00 120.00    94.00 93.47       124
# 256       116    114.81  13,778.00 120.00   381.00 93.41       124
# 209      1000    996.97 119,600.00 119.96    36.00 93.53       124
# 228       555    554.21  66,489.00 119.97    63.00 93.40       124
# 34        111    109.82  13,179.00 120.01   259.00 93.41       124
# 22       1071  1,066.21 127,950.00 120.00    21.00 93.54       124
# 6         595    593.70  71,250.00 120.01    30.00 93.46       124
# 122       119    114.97  13,777.00 119.83   121.00 93.48       124
#
#      avg_measure  sum_measure  prod_rate  tt_inst_prod  joules  JPI
# 42          5.89     1,325.90     364.14     43,727.00  707.67 0.02
# 106         4.94     1,111.40     199.62     23,960.00  591.99 0.02
# 277         4.09       920.60      39.94      4,800.00  491.55 0.10
# 117         5.70     1,289.30     349.17     41,930.00  684.59 0.02
# 138         4.84     1,084.50     194.63     23,361.00  581.03 0.02
# 56          3.99       894.20      34.95      4,200.00  479.43 0.11
# 31          5.87     1,332.00     349.19     41,930.00  703.87 0.02
# 141         4.86     1,093.70     194.62     23,361.00  582.93 0.02
# 8           3.83       854.80      34.95      4,200.00  460.15 0.11
# 98          5.58     1,265.90     329.21     39,534.00  669.33 0.02
# 60          4.57     1,019.70     179.66     21,564.00  548.17 0.03
# 23          3.95       892.90      34.95      4,200.00  474.17 0.11
# 91          5.18       233.30   2,479.86     45,312.00   95.38 0.00
# 236         4.78       324.80   1,385.98     45,312.00  155.46 0.00
# 69          3.82       855.70     274.42     32,945.00  458.03 0.01
# 253         5.13       220.40   2,507.30     45,312.00   92.18 0.00
# 273         4.44       311.00   1,394.09     45,312.00  143.63 0.00
# 120         3.78       858.60     279.38     33,544.00  453.49 0.01
# 14          5.12       230.60   2,303.38     45,312.00  100.31 0.00
# 47          4.55       345.60   1,275.35     45,312.00  160.81 0.00
# 272         3.82       863.60     254.48     30,549.00  458.06 0.01
# 242         5.16       232.30   2,303.49     45,312.00  100.88 0.00
# 164         4.61       350.10   1,284.06     45,312.00  161.87 0.00
# 189         3.82       867.90     254.46     30,549.00  458.34 0.02
# 233         5.18       274.60   2,072.07     45,312.00  112.50 0.00
# 284         4.48       358.30   1,152.19     45,312.00  175.40 0.00
# 234         3.88       888.70     229.53     27,554.00  465.13 0.02
# 210         5.44       261.00   2,091.19     45,312.00  117.33 0.00
# 59          4.64       385.30   1,163.91     45,312.00  180.01 0.00
# 278         3.88       881.30     229.52     27,554.00  465.49 0.02
# 132         5.20       275.70   1,914.56     45,312.00  122.34 0.00
# 230         4.61       377.80   1,064.49     45,312.00  195.50 0.00
# 268         3.88       889.10     209.59     25,158.00  465.37 0.02
# 112         5.16       304.30   1,638.41     45,312.00  141.90 0.00
# 285         4.60       432.00     909.92     45,312.00  228.15 0.01
# 259         3.94       890.70     179.66     21,564.00  472.32 0.02
# 188         5.17       222.20   2,535.65     45,312.00   91.44 0.00
# 151         4.46       312.10   1,421.60     45,312.00  141.60 0.00
# 257         3.81       865.60     284.37     34,143.00  457.19 0.01
# 1           5.09       244.30   2,481.49     45,312.00  101.20 0.00
# 87          4.49       319.00   1,377.60     45,312.00  147.04 0.00
# 142         3.84       848.40     274.42     32,945.00  460.30 0.01
# 66          5.04       237.00   2,401.53     45,312.00   96.11 0.00
# 146         4.77       339.00   1,344.09     45,312.00  160.12 0.00
# 114         3.85       878.20     269.42     32,346.00  461.74 0.01
# 43          4.98       238.90   2,280.42     45,312.00   98.23 0.00
# 266         4.48       331.30   1,267.43     45,312.00  159.45 0.00
# 100         3.81       872.00     254.46     30,549.00  456.50 0.01
# 21          5.74       493.30   1,079.71     45,312.00  240.11 0.01
# 186         4.76       662.10     597.68     45,312.00  360.37 0.01
# 173         4.00       903.50     119.79     14,376.00  479.00 0.03
# 9           5.65       508.30   1,035.23     45,312.00  246.64 0.01
# 29          4.77       735.30     571.97     45,312.00  377.32 0.01
# 10          4.03       898.30     114.80     13,777.00  482.65 0.04
# 219         5.57       523.40   1,007.63     45,312.00  249.47 0.01
# 156         4.75       730.90     563.46     45,312.00  380.97 0.01
# 261         4.09       927.80     109.82     13,200.00  490.49 0.04
# 67          5.62       534.00     968.58     45,312.00  262.10 0.01
# 51          4.68       758.30     537.99     45,312.00  393.44 0.01
# 244         3.95       904.80     104.82     12,579.00  473.53 0.04
# 12          5.76       749.40     672.24     45,312.00  387.87 0.01
# 99          4.76     1,070.20     374.13     44,925.00  570.59 0.01
# 240         3.92       881.80      74.88      9,000.00  470.31 0.05
# 181         5.68       715.60     705.77     45,312.00  363.54 0.01
# 238         4.71     1,018.40     393.73     45,312.00  542.02 0.01
# 95          3.82       855.60      74.88      9,000.00  458.38 0.05
# 128         5.58       714.20     686.42     45,312.00  367.45 0.01
# 224         4.73     1,008.10     383.67     45,312.00  558.26 0.01
# 107         4.05       912.30      74.88      9,000.00  486.59 0.05
# 77          5.45       763.00     612.17     45,312.00  402.56 0.01
# 176         4.62     1,015.40     339.18     40,732.00  553.72 0.01
# 161         3.98       895.70      64.90      7,800.00  477.73 0.06
# 286         5.23     1,182.20     124.78     14,975.00  626.80 0.04
# 281         4.47     1,020.00      64.90      7,800.00  538.73 0.07
# 17          3.78       853.50       9.99      1,200.00  454.65 0.38
# 172         5.28     1,140.90     134.76     16,173.00  633.17 0.04
# 144         4.06       920.90      74.88      9,000.00  489.39 0.05
# 15          4.19       947.10      14.98      1,800.00  503.76 0.28
# 32          5.24     1,194.40     124.79     14,975.00  628.32 0.04
# 44          4.42       959.40      69.89      8,400.00  530.56 0.06
# 62          4.06       926.00       9.99      1,200.00  488.12 0.41
# 237         5.15     1,159.60     109.81     13,178.00  618.72 0.05
# 86          4.40       984.70      59.91      7,200.00  528.19 0.07
# 39          3.80       836.00       9.99      1,200.00  456.33 0.38
# 214         4.65     1,051.30     662.97     79,667.00  558.38 0.01
# 167         4.46       985.40     369.04     44,326.00  535.01 0.01
# 0           3.82       867.00      69.89      8,400.00  459.27 0.05
# 229         4.64     1,058.70     598.27     71,880.00  557.23 0.01
# 145         4.36       993.60     329.17     39,534.00  522.93 0.01
# 74          3.88       864.20      64.90      7,800.00  466.06 0.06
# 37          4.66     1,057.60     648.14     77,870.00  559.20 0.01
# 270         4.39     1,005.60     359.04     43,128.00  526.76 0.01
# 7           3.87       874.50      69.89      8,400.00  465.02 0.06
# 197         4.61     1,047.60     593.16     71,281.00  553.84 0.01
# 200         4.30       979.40     329.20     39,534.00  515.43 0.01
# 126         3.88       881.10      64.90      7,800.00  465.79 0.06
# 226         4.82     1,100.00     633.12     76,073.00  578.96 0.01
# 171         4.36       997.70     349.14     41,930.00  522.64 0.01
# 4           3.93       871.70      69.89      8,400.00  472.22 0.06
# 97          4.84     1,098.40     603.20     72,479.00  581.15 0.01
# 165         4.55     1,042.10     334.20     40,133.00  545.85 0.01
# 79          3.92       894.10      64.90      7,800.00  470.58 0.06
# 121         4.80     1,099.80     553.36     66,489.00  576.38 0.01
# 116         4.51     1,024.60     304.31     36,539.00  541.41 0.01
# 110         3.96       904.00      59.90      7,200.00  476.55 0.07
# 177         4.85     1,110.70     468.67     56,306.00  582.10 0.01
# 287         4.36       993.50     259.45     31,148.00  522.52 0.02
# 275         4.14       940.10      49.93      6,000.00  497.25 0.08
# 27          4.76     1,085.80     648.09     77,870.00  571.62 0.01
# 241         4.24       971.10     359.13     43,128.00  508.70 0.01
# 283         3.86       876.30      69.89      8,400.00  464.52 0.06
# 57          4.70     1,065.90     658.04     79,068.00  563.55 0.01
# 103         4.51     1,032.90     364.07     43,727.00  541.22 0.01
# 3           3.88       884.40      69.89      8,400.00  466.26 0.06
# 33          4.65     1,023.50     623.15     74,875.00  558.31 0.01
# 133         4.40     1,007.80     344.17     41,331.00  527.88 0.01
# 72          3.90       882.40      64.90      7,800.00  468.55 0.06
# 65          4.63     1,037.90     573.31     68,885.00  556.03 0.01
# 182         4.30       979.70     314.25     37,737.00  515.68 0.01
# 225         3.82       867.50      59.91      7,200.00  458.92 0.06
# 137         4.98     1,131.50     423.84     50,915.00  598.25 0.01
# 30          4.65     1,065.10     234.52     28,153.00  557.44 0.02
# 153         3.91       891.30      44.94      5,400.00  470.29 0.09
# 193         5.01     1,146.20     413.89     49,717.00  600.70 0.01
# 76          4.49     1,018.90     229.52     27,554.00  538.55 0.02
# 279         3.99       910.70      44.94      5,400.00  480.15 0.09
# 61          5.01     1,131.40     398.97     47,920.00  600.83 0.01
# 102         4.54     1,040.80     219.54     26,356.00  545.00 0.02
# 89          3.89       882.20      39.94      4,800.00  466.98 0.10
# 250         4.92     1,116.40     339.12     40,732.00  590.20 0.01
# 235         4.60     1,048.50     184.63     22,163.00  551.32 0.02
# 213         3.99       906.30      34.95      4,200.00  479.34 0.11
# 78          5.36     1,158.10     618.06     74,276.00  643.75 0.01
# 175         4.87     1,101.10     344.16     41,331.00  584.19 0.01
# 217         4.06       921.20      64.90      7,800.00  487.44 0.06
# 48          5.04     1,138.40     543.44     65,291.00  604.85 0.01
# 83          4.70     1,052.80     299.34     35,940.00  563.88 0.02
# 11          3.91       863.80      59.91      7,200.00  469.36 0.07
# 185         5.21     1,167.10     528.51     63,494.00  625.49 0.01
# 129         4.75     1,072.40     289.33     34,742.00  569.22 0.02
# 55          4.01       862.40      54.92      6,600.00  481.65 0.07
# 58          5.10     1,147.30     493.54     59,301.00  612.04 0.01
# 251         4.65     1,045.40     274.37     32,945.00  557.57 0.02
# 212         3.99       890.70      54.91      6,600.00  479.30 0.07
# 49          6.24     1,404.20     159.73     19,168.00  752.55 0.09
# 70          6.13     1,398.40      89.86     10,800.00  744.38 0.09
# 195         4.17       959.20      14.98      1,800.00  507.50 0.28
# 187         6.17     1,400.30     154.74     18,600.00  744.95 0.09
# 143         6.06     1,362.70      84.87     10,200.00  727.17 0.09
# 163         4.01       909.20      14.98      1,800.00  486.42 0.27
# 94          6.07     1,359.80     154.73     18,569.00  730.10 0.09
# 203         6.04     1,377.50      84.87     10,200.00  726.70 0.09
# 207         4.15       937.40      14.98      1,800.00  501.82 0.28
# 170         6.09     1,383.50     149.75     17,970.00  733.83 0.09
# 68          6.02     1,355.60      84.86     10,200.00  723.76 0.09
# 221         4.02       904.30      14.98      1,800.00  482.86 0.27
# 252         6.36     1,475.10   1,664.03    199,732.00  781.18 0.03
# 274         6.26     1,446.20     921.91    110,630.00  759.12 0.03
# 276         5.19     1,214.20     184.68     22,163.00  635.77 0.03
# 162         6.33     1,443.30   1,624.20    194,948.00  760.57 0.03
# 159         6.29     1,458.50     901.99    108,419.00  771.08 0.03
# 105         4.88     1,108.80     179.69     21,564.00  585.26 0.03
# 223         6.31     1,457.20   1,619.52    194,350.00  763.18 0.03
# 108         6.20     1,432.70     897.04    107,820.00  754.18 0.03
# 155         5.20     1,176.30     179.69     21,564.00  624.13 0.03
# 50          5.83     1,323.20   1,549.33    185,978.00  712.34 0.03
# 139         6.08     1,415.70     862.09    103,454.00  740.58 0.03
# 247         4.99     1,133.40     169.71     20,366.00  598.50 0.03
# 119         6.21     1,409.40     473.82     56,905.00  747.21 0.02
# 169         5.43     1,227.20     264.47     31,747.00  652.03 0.02
# 130         3.95       905.10      49.93      6,000.00  475.30 0.08
# 201         6.04     1,329.40     473.80     56,905.00  725.16 0.02
# 82          5.37     1,214.20     259.50     31,148.00  644.70 0.02
# 16          3.97       900.40      49.93      6,000.00  476.79 0.08
# 73          6.06     1,375.70     473.85     56,905.00  727.59 0.02
# 52          5.33     1,187.60     264.47     31,747.00  638.86 0.02
# 63          3.88       880.60      49.93      6,000.00  465.71 0.08
# 220         5.58     1,266.00     503.68     60,499.00  669.50 0.02
# 154         5.33     1,162.20     279.43     33,544.00  639.67 0.02
# 194         4.09       932.80      54.92      6,600.00  491.17 0.07
# 149         6.23     1,432.70   1,374.83    165,048.00  760.13 0.02
# 243         6.20     1,395.90     762.71     91,647.00  752.91 0.02
# 232         4.78     1,084.90     149.76     18,000.00  573.54 0.03
# 267         5.64     1,290.60   1,380.00    165,646.00  679.04 0.03
# 80          5.63     1,282.60     767.70     92,246.00  675.16 0.03
# 180         5.34     1,212.90     149.75     18,000.00  641.22 0.04
# 46          6.19     1,435.90   1,350.04    162,058.00  754.53 0.02
# 239         6.07     1,408.60     747.75     89,850.00  741.58 0.02
# 245         5.33     1,215.60     149.75     18,000.00  639.82 0.04
# 38          5.31     1,209.70   1,195.36    143,520.00  638.16 0.03
# 255         4.72     1,085.70     663.23     79,667.00  572.70 0.06
# 168         4.56     1,043.50     129.78     15,600.00  547.23 0.04
# 88          6.37     1,426.90     159.74     19,200.00  784.77 0.09
# 158         6.21     1,439.60      89.86     10,800.00  762.45 0.09
# 124         3.99       910.30      14.98      1,800.00  480.29 0.27
# 263         6.41     1,460.40     159.74     19,200.00  769.98 0.08
# 184         6.14     1,394.60      89.86     10,800.00  750.74 0.09
# 93          3.82       873.90      14.98      1,800.00  460.53 0.26
# 166         6.41     1,468.20     159.73     19,168.00  771.53 0.08
# 123         5.73     1,299.70      84.86     10,200.00  687.22 0.07
# 131         4.02       877.30      14.98      1,800.00  483.38 0.27
# 254         6.40     1,452.90     154.74     18,569.00  768.37 0.05
# 111         5.49     1,245.50      84.87     10,200.00  658.42 0.06
# 135         3.91       863.10      14.98      1,800.00  468.70 0.26
# 24          6.09     1,370.10     174.71     21,000.00  731.90 0.07
# 249         5.98     1,357.90      94.85     11,400.00  721.60 0.07
# 53          4.03       906.10      14.98      1,800.00  485.22 0.27
# 231         5.97     1,354.80     174.71     20,965.00  724.40 0.07
# 104         5.94     1,336.10      94.85     11,400.00  712.66 0.07
# 157         3.92       890.00      14.98      1,800.00  471.75 0.26
# 199         6.04     1,371.80     169.71     20,366.00  726.39 0.06
# 92          5.92     1,331.00      94.85     11,400.00  710.32 0.07
# 206         3.97       901.70      14.98      1,800.00  477.64 0.27
# 134         5.90     1,340.30     169.72     20,400.00  709.76 0.07
# 258         5.74     1,290.80      89.86     10,800.00  689.21 0.08
# 196         4.07       915.30      14.98      1,800.00  488.38 0.27
# 5           5.52     1,246.60     613.37     73,677.00  662.06 0.01
# 96          4.63     1,037.10     339.26     40,732.00  555.54 0.01
# 222         3.91       882.70      64.90      7,800.00  469.10 0.06
# 190         5.50     1,237.80     588.46     70,682.00  660.22 0.01
# 85          4.60     1,035.60     324.32     38,935.00  552.52 0.01
# 147         3.98       895.90      64.90      7,800.00  478.17 0.06
# 36          5.45     1,230.80     568.56     68,286.00  653.70 0.01
# 215         4.60     1,040.30     314.34     37,737.00  551.99 0.01
# 198         3.86       861.50      59.91      7,200.00  463.78 0.06
# 84          5.44     1,223.40     603.39     72,479.00  652.52 0.01
# 20          4.60     1,035.30     334.30     40,133.00  551.93 0.01
# 45          3.92       873.10      64.90      7,800.00  469.95 0.06
# 191         4.98       423.00   3,758.08    150,000.00  198.10 0.00
# 264         4.55       632.30   2,089.34    150,000.00  325.79 0.00
# 152         3.83       873.90     419.03     50,316.00  459.62 0.01
# 202         4.96       411.80   3,685.23    150,000.00  201.60 0.00
# 81          4.42       636.00   2,049.04    150,000.00  322.87 0.00
# 178         3.85       874.20     409.04     49,118.00  461.80 0.01
# 113         5.21       520.80   3,497.73    150,000.00  257.42 0.00
# 246         4.35       653.20   1,947.52    150,000.00  334.80 0.00
# 248         3.83       873.20     389.10     46,722.00  459.26 0.01
# 179         4.83       478.50   3,089.15    150,000.00  233.95 0.00
# 280         4.35       730.20   1,719.95    150,000.00  378.47 0.00
# 109         3.82       870.70     344.24     41,331.00  457.87 0.01
# 2           5.16       464.50   3,495.77    150,000.00  220.54 0.00
# 192         4.50       683.60   1,947.57    150,000.00  345.72 0.00
# 269         3.86       871.30     389.11     46,722.00  462.26 0.01
# 26          5.25       441.30   3,703.80    150,000.00  212.25 0.00
# 148         4.50       639.00   2,055.61    150,000.00  327.64 0.00
# 205         3.92       896.90     409.07     49,118.00  469.57 0.01
# 127         5.20       447.20   3,250.69    150,000.00  238.96 0.00
# 35          4.38       701.50   1,811.22    150,000.00  362.31 0.00
# 136         3.87       878.30     359.19     43,128.00  463.87 0.01
# 140         4.81       596.90   2,412.89    150,000.00  298.55 0.00
# 211         4.28       889.20   1,338.45    150,000.00  478.54 0.00
# 118         3.83       872.70     264.46     31,747.00  458.81 0.01
# 75          5.05       363.30   3,836.02    150,000.00  197.09 0.00
# 90          4.42       614.60   2,130.50    150,000.00  310.60 0.00
# 282         3.85       870.60     423.99     50,915.00  461.97 0.01
# 18          5.12       419.70   3,817.18    150,000.00  200.71 0.00
# 260         4.49       615.80   2,118.31    150,000.00  317.48 0.00
# 204         3.85       861.80     423.99     50,915.00  461.32 0.01
# 54          5.04       433.80   3,648.92    150,000.00  207.30 0.00
# 174         4.44       639.90   2,021.62    150,000.00  329.05 0.00
# 208         3.85       882.00     404.04     48,519.00  461.84 0.01
# 216         4.94       454.90   3,295.91    150,000.00  224.79 0.00
# 218         4.40       703.50   1,828.87    150,000.00  360.08 0.00
# 64          3.84       871.30     364.16     43,727.00  460.21 0.01
# 271         5.42     1,046.40   1,436.38    150,000.00  565.45 0.00
# 13          4.60     1,043.80     802.53     96,439.00  551.99 0.01
# 101         3.88       877.80     159.73     19,168.00  465.36 0.02
# 28          5.42     1,018.50   1,547.38    150,000.00  524.31 0.00
# 41          4.73     1,016.10     857.26    103,028.00  567.20 0.01
# 160         3.99       913.40     169.71     20,366.00  477.89 0.02
# 262         5.24     1,074.30   1,398.63    150,000.00  561.66 0.00
# 115         4.57     1,041.10     777.69     93,444.00  548.03 0.01
# 25          3.93       876.30     154.73     18,569.00  470.95 0.03
# 150         5.34     1,138.20   1,333.51    150,000.00  600.61 0.00
# 40          4.67     1,064.50     742.68     89,251.00  560.29 0.01
# 183         3.94       863.60     144.75     17,371.00  472.52 0.03
# 265         5.44     1,240.20   1,090.95    130,962.00  652.72 0.00
# 227         4.61     1,032.60     603.45     72,479.00  553.03 0.01
# 125         3.94       889.60     119.80     14,376.00  471.61 0.03
# 19          5.31     1,195.50   1,046.32    125,580.00  637.45 0.01
# 71          4.56     1,025.00     578.51     69,484.00  546.68 0.01
# 256         3.96       890.90     114.81     13,800.00  475.17 0.03
# 209         5.21     1,166.10     996.53    119,600.00  624.51 0.01
# 228         4.59     1,037.30     553.60     66,489.00  550.65 0.01
# 34          3.94       881.80     109.82     13,200.00  472.43 0.04
# 22          5.35     1,203.40   1,065.97    127,972.00  641.84 0.01
# 6           4.63     1,042.70     593.41     71,281.00  556.15 0.01
# 122         3.96       890.70     114.80     13,777.00  474.38 0.03

# %%
freqs = [{'minimum': '600', 'maximum': '1200'}]
for f,df in zip(freqs, dataframes):
    print(f'\n\n\n----------------- {f} -----------------')
    df = df[df.PERC == '90']
    df = df.loc[:,['dataset','algorithm','batch_size','acc', 'instances', 'time', 'JPI']].sort_values(by=['batch_size'])
    df = select_columns_and_rename_values(df)
    #display(df)
    df['IPS'] = df['instances'] / df['time']
    gen_graph_initial_peralg(df, display_df=False, freq=f)
# Out:
# ----------------- {'minimum': '600', 'maximum': '1200'} -----------------
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_3575/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_3575/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_3575/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_3575/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Agora iremos analisar a relação entre o número de instancias processadas por segundo (IPS) o JPI e a acurácia entre esses valores. Primeiro vamos analisar a linha azul que representa o IPS, individualmente irei analisar primeiro o dataset Airlines nos algoritmos Adaptive Random Forest (ARF), OzaBag (OB), LBag (LB). Para o ARF o IPS inicia com um processamento de 84 instancias e evolui para 94 no batch-size de tamanho 50 e cai para 88 no batch-size 75 e 100. A linha verde representa o JPI neste primeiro algoritmo observamos o comportamento de queda no maior numero de IPS mas no batch-size de 75 e 100 um novo aumento. No algoritmo OB temos um aumento no número de IPS em relação ao tamnho do batch-size somente caindo no 100. Já o número do JPI diminui em relação ao aumento do IPS exceto na quanto o IPS cai no batch-size 100. Por último vamos analisar o LB, para este algoritmo a tendência do batch-size aumenta o IPS diminui e o JPI tende a crescer. Vendo esses casos podemos dizer que para os algoritmos ARF e OB a têndencia é quanto maior o IPS menor será o JPI já no LBAG o oposto aconteceu pelo menos no dataset airlines, quanto menor o IPS maior o JPI. Já em outros dasets ocorreu de o IPS maior trazer um menor JPI.

# %% [markdown]
# # Conclusoes
#
# Neste cenário podemos observar que o tamanho do mini-batch não traz grande diferença no consumo energético quando seu tamanho é menor ou maior, mas sim em relação ao seu padrão de comportamento sequencial já comprovado no artigo do Cassales. Nesta analise constatamos alguns comportamentos tais como quando a quantidade de IPS aumenta em determinados algoritmos temos uma tendencia que o JPI diminua e que existem algoritmos que são mais eficiente energéticamente e mantem a mesma linha de precisão e acurácia como o OzaBag.
