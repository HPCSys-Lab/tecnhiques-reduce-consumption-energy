# %% [markdown]
# # Introduction
#
# This notebook has the objective compare two methods of execution mini-batching with loop fusion and without loop fusion. These experiments had mini-batching sizes between 5 to 2000 (5, 15, 25, 50, 75, 100, 500, 2000) running with algorithms ARF and OzaBag, on datasets Airlines and ElecNormNew. It was executed three times with rasp pi in standard frequency. We will explore what differences in execution by comparing Joules per Instance (JPI), Instances Per Second (IPS), Accuracy (ACC), and too average expenditure JPI by throughput rate.

# %% [markdown]
# # Resume
#
#  - Mini-batching with loop fusion maintain results similars with mini-batching without loop fusion.
#  - Mini-batching with loop fusion save more energy when compared with mini-batching without loop fusion.
#  - Mini-batching with loop fusion had better performance in IPS when compared with mini-batching without loop fusion.

# %% [markdown]
# ## Results with loop fusion (preliminary)

# %%
# %run "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/loop-fusion/MOA-MiniBatchingOptimized-Preliminary.ipynb"
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_10623/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_10623/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_10623/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# ...

# %% [markdown]
# ### Precision e Recall
#
# In results of precision and recall had a stable for all sizes of mini-batches on algorithm ARF. However, OzaBag executions had minor distortions representing a big drop size 25 and 75. Nevertheless, they stay between 58% to 61% despite these distortions. Another interesting point is that all executions maintain the same value variant independent of execution.
#
# ### Thoughput e Delay
#
# We will analyze Joules, throughput, and delay in each execution. Again, three executions with the same configurations obtain the information necessary for analysis. First, we will talk about the distortions in the first and third execution; the two bars are quite different from other bars, but this happens because the has a bit of distortion in collecting data in some executions. However, we can see the best execution to the Airlines dataset and ARF algorithm is 50% and same to Ozabag with too airlines dataset. As to the ElecNormNew dataset, the executions had better performance in 90%.
#
# ### Accuracy, JPI and IPS
#
# In the last graph, we will analyze three variables Accuracy (ACC), Joules per instance (JPI), and Instances per second (IPS). The better execution is when more IPS, minor JPI, and maintain ACC. All executions were trigged three times on the same configurations to understand average data three times, given that collecting data in JPI and IPS can distort. To quickly process, we will analyze all ARF executions with Airlines and ElecNormNew and in sequence executions of Ozabag in both datasets.
#
# In ARF with airlines on first execution, the better mini-batching is size 500; it has a lower JPI and more IPS. Given that dataset ElecNormNew, the better it was size 25. In others, execution is similar results, although distortions. An attention point is the third execution of the JPI to zero to mini-batching 500. Again, because of errors in collecting data. Another comportment important there in dataset ElecNormNew can observe a line inverse when more JPI minor IPS is between 25 to 500, and the mini-batching major is size 2000 the values IPS lower and JPI increase.
#
# In OzaBag, there was a better collection of data with minus distortions. Analyzing the first dataset Airlines we can see that smaller mini-batching has more JPI and minor processing in IPS, except in the third execution where we can see that significant mini-batching better was performance energy and processing. Although the mini-batching 2000 increased with major JPI and minor IPS. In algorithm ElecNormNew had behavior similar to Airlines, had lines inverse and better results between 15 to 500 with a decline in mini-batching 2000.

# %% [markdown]
# ## Results with loop fusion all algorithms and datasets

# %%
# %run "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/loop-fusion/MOA-MiniBatchingLoopFusion.ipynb"
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_10623/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_10623/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_10623/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# ...

# %% [markdown]
# ## Results without loop fusion

# %%
# %run "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/notebooks/mini-batching/MOA-MiniBatching-Batchs.ipynb"
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_10623/2209187601.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(filename, index_col=False)
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_10623/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_10623/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# ...

# %% [markdown]
# ### Observations
#
# For this execution, all algorithms were used, but can be maintained attention in ARF and OzaBag to analyze with an execution previous.
#
# ### Precision e Recall
#
# In this first part, we were analysis the precision and recall of batches of considerable size (50, 500, and 2000). In the dataset, Electricity can observe the precision and recall that batches-sizes from 50 to 2000 are loose compared to MOA standard and MOA parallel. As to dataset Airlines, the precision and recall maintain near with and without mini-batching to OzaBag and Airlines.
#
# ### Thoughput e Delay
#
# The throughput rate and delay for experiments without loop fusion tended to decrease when load size increased. In this case, the better scenario is when IPS is big, delay, and IPS more minor. To algorithms ARF and OzaBag, both datasets Airlines and ElecNormNew had similar results.
#
# ### IPS, JPI e ACC
#
#
# In consumer JPI, IPS, and ACC, Airlines' tendency with ARF is to decrease to batch 500 and begin to increase again. So it happens to ElecNormNew. On the other hand, OzaBag in Airlines begins with good performance in minor mini-batching and tends to lose in other sizes. So to ElecNormNew dataset we see different lines while IPS increases JPI decrease, on batches sizes intermediaries.

# %% [markdown]
# ## Conclusion
#
# Once the results are analyzed can assume that are no significant losses with loop fusion in an algorithm. All experiments with this tendency are similar to the execution without loop fusion. Because no significant changes in the algorithm as change formula calc weight and votes instances, only changed the algorithms with add technique of loop fusion, obtain results similars with technique without loop fusion.
#
#
# While energy save the tendency had similar in with loop fusion and without, the numbers are different. In execution without loop fusion, for example, on algorithm ARF with dataset Airlines, in mini-batching size 75 had IPS near 90 and a JPI of 0.070, simultaneously with same configurations had IPS of 96 and JPI of 0.060 in execution with loop fusion. On the other hand, with the same dataset and mini-batching size, but in the algorithm, OzaBag had an IPS of 210 and JPI of 0.032 without loop fusion, and with loop fusion, the IPS in 1900 and JPI of 0.0030 represent a significant improvement in performance and energy saving.
#
# Can be say that results initials the loop fusion tecnhique obtain gains in save energy and performance. Although we need analisy to speedup this algorithm and compare both methods. Other fact is both tecnhiques the betters results are in intemedium mini-batches sizes between from 25 to 500 while minor or major that not show good results.
