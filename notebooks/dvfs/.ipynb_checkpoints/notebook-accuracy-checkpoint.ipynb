# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %%
def parse(fname):
    global header_printed
    #index of wanted columns
    columns = []
    #column names to get the data from
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    ret_string = ''
    #remove the path and isolate the filename
    spname = fname.split('/')[-1].split('-')
    spline = []
    #control flag for knowing when the column names have already been discovered
    got = False
    #we ignore the first parameter of the filename and add all others to the csv string
    for s in spname[1:]:
        ret_string += s + ','
    #should probably use a safer way, but python handles the closing of the file
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                #sometimes the dump file has multiple results in it, so we get the index of wanted columns only once
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        #OzaBagASHT bugs out on GMSC, this reuses the data from the sequential execution
        # if 'GMSC' in spname and 'ASHT' in spname[2]:
        #     for c in columns[:-2]:
        #         ret_string += str(spline[c]) + ','
        #     ret_string += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        #normal code, how everything should run
        #we process the data (add the content of wanted columns to the csv string) only after the for
        #ensuring we use only the last (most recent) data and not the intermediate results
        else:
            for c in columns:
                ret_string += str(spline[c]) + ','
            if len(columns) == 5:
                ret_string += '0,'
        #header is a global variable, it will only be printed on the first file 
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,rate,instances,time,acc,prec,recall,change'
            ret_string = f"{head}\n{ret_string}"
            header_printed = True
        #remove the last comma ,
        return (ret_string[:-1])

# %%
def add_label_column_df(df):
    for index, row in df.iterrows():
        _str = row["algorithm"]

        if "RUNPER" in _str:
            df.at[index, 'label'] = "Parallel"
        else:
            df.at[index, 'label'] = "Sequential"
            
    return df

# %%
#loads the csv as a dataframe and standardizes the algorithm names 
def load_df(filename):
    df = pd.read_csv(filename, index_col=False)
    df = add_label_column_df(df)
    return select_columns_and_rename_values(df)

# %%
#standardize algorithm names
def select_columns_and_rename_values(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    df.batch_size.unique()
    return df

# %%
#filters by substring (there are multiple OzaBag algorithms)
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %%
#plots precision and recall with markers of one parameter configuration
def gen_lines(df, ax, alg_order, markers):
    lwidth = 0.75
    if markers:
        colors=['go', 'bs', 'rP', 'md', 'y+' , 'k*']
    else:
        colors=['g', 'b', 'r', 'm', 'y' , 'k']

    labels = df.label

    alg = df.algorithm.unique()[0]
    x = np.arange(len(labels))
  
    ax.plot(x, pd.to_numeric(df.acc), f'{colors[alg_order]}--', linewidth=lwidth, label=f'{alg.replace("RUNPER", "").replace("Sequential", "")}')
    
    # ax.plot(x, pd.to_numeric(df.prec), f'{colors[alg_order]}--', linewidth=lwidth, label=f'{alg}-prec')
    # ax.plot(x, pd.to_numeric(df.recall), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')

    #ax.plot(x,pd.to_numeric(df.prec), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_ylim(60,100)

# %%
#iterates over the parameter configurations and creates the chart grid
def gen_chart(df, markers=True, tables=False):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
    #dictionary containing the correct name to be printed
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    #creates a 2x2 grid for plotting the charts
    #sharey=row means that all charts in a row share the same Y-axis
    fig, axs = plt.subplots(1, 4, figsize=(12, 3), sharey='row')
    filename = datetime.datetime.now()
    #each chart presents the results for a given dataset and contains the series for all algorithms
    for ds in datasets:
        title = ''
        my_id = datasets.index(ds)
        #selects the correct position in the grid
        ax = axs[int(my_id)]
        ax.set_title(f'{dsformalname[ds]}')
        #for each algorithm
        for alg in algorithms:
            #filters the df to contain the wanted values
            df_aux = filter_by_substring_algorithm(df[df.dataset == ds], alg)
            if tables:
                display(df_aux)
            #plot (include) the series in the chart
            gen_lines(df_aux, ax, algorithms.index(alg), markers)
            #if its the first column, print Y-axis label
            if my_id%4 == 0:
                ax.set_ylabel('Percentage')
            #if its the last row, print the X-axis label
#             if int(my_id/2) == 1:
#                 ax.set_xlabel('Batch sizes')
    #retrieves the handles and labels to create a global legend
    handles, labels = axs[0].get_legend_handles_labels()
    lgd = fig.legend(handles, labels, loc = 'lower center', ncol = math.ceil(len(algorithms)), bbox_to_anchor=(0.5,-0.10))
    fig.tight_layout()
    plt.savefig(f'figures/{filename}.png')
    plt.savefig(f'figures/{filename}.eps', bbox_extra_artists=(lgd,), bbox_inches='tight', format='eps', dpi=1200)

# %%
from pandas.api.types import is_numeric_dtype

def mean_str(col):
    if is_numeric_dtype(col):
        return col.mean()
    else:
        return col.unique()[0] if col.nunique() == 1 else np.NaN

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/sem-coletor/dvfs/1200/1200/first"
wantedCSVfilename = "data-batch-vs-acc-1200-1200.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

dvf4 = load_df(f'{csvFile}')

# pega execução sequencial e bota em um novo dataframe
df_sequential = dvf4.loc[(dvf4.cores == 1) & (dvf4.batch_size == 1)]
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
#         dataset                             algorithm  ensemble_size  cores  \
# 0   elecNormNew              OzaBagASHTExecutorRUNPER             25      4
# 1   covtypeNorm  StreamingRandomPatchesExecutorRUNPER             25      4
# 2          GMSC                StreamingRandomPatches             25      1
# 3   elecNormNew                         LeveragingBag             25      1
# 4      airlines                         LeveragingBag             25      1
# 5   covtypeNorm    AdaptiveRandomForestExecutorRUNPER             25      4
# 6   elecNormNew    AdaptiveRandomForestExecutorRUNPER             25      4
# 7   covtypeNorm             OzaBagAdwinExecutorRUNPER             25      4
# 8          GMSC    AdaptiveRandomForestExecutorRUNPER             25      4
# 9   elecNormNew                            OzaBagASHT             25      1
# 10     airlines                    LBagExecutorRUNPER             25      4
# 11         GMSC                            OzaBagASHT             25      1
# 12  elecNormNew  StreamingRandomPatchesExecutorRUNPER             25      4
# 13  covtypeNorm              OzaBagASHTExecutorRUNPER             25      4
# 14  covtypeNorm                           OzaBagAdwin             25      1
# 15     airlines        AdaptiveRandomForestSequential             25      1
# 16         GMSC                         LeveragingBag             25      1
# 17  elecNormNew        AdaptiveRandomForestSequential             25      1
# 18  elecNormNew                           OzaBagAdwin             25      1
# 19         GMSC              OzaBagASHTExecutorRUNPER             25      4
# 20  elecNormNew             OzaBagAdwinExecutorRUNPER             25      4
# 21         GMSC        AdaptiveRandomForestSequential             25      1
# 22  covtypeNorm        AdaptiveRandomForestSequential             25      1
# 23     airlines                  OzaBagExecutorRUNPER             25      4
# 24  covtypeNorm                    LBagExecutorRUNPER             25      4
# 25  covtypeNorm                                OzaBag             25      1
# 26  elecNormNew                    LBagExecutorRUNPER             25      4
# 27     airlines              OzaBagASHTExecutorRUNPER             25      4
# 28  elecNormNew                  OzaBagExecutorRUNPER             25      4
# 29         GMSC                                OzaBag             25      1
# 30         GMSC                           OzaBagAdwin             25      1
# 31         GMSC                    LBagExecutorRUNPER             25      4
# 32         GMSC  StreamingRandomPatchesExecutorRUNPER             25      4
# 33  covtypeNorm                StreamingRandomPatches             25      1
# 34         GMSC                  OzaBagExecutorRUNPER             25      4
# 35  elecNormNew                                OzaBag             25      1
# 36         GMSC             OzaBagAdwinExecutorRUNPER             25      4
# 37     airlines                           OzaBagAdwin             25      1
# 38     airlines                                OzaBag             25      1
# 39     airlines             OzaBagAdwinExecutorRUNPER             25      4
# 40  covtypeNorm                  OzaBagExecutorRUNPER             25      4
# 41     airlines                            OzaBagASHT             25      1
# 42  elecNormNew                StreamingRandomPatches             25      1
# 43  covtypeNorm                            OzaBagASHT             25      1
# 44  covtypeNorm                         LeveragingBag             25      1
# 45     airlines                StreamingRandomPatches             25      1
# 46     airlines  StreamingRandomPatchesExecutorRUNPER             25      4
# 47     airlines    AdaptiveRandomForestExecutorRUNPER             25      4
#
#     batch_size  rate  instances     time   acc  prec  recall   change
# 0            1     1  45,312.00
0.00
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/sem-coletor/dvfs/1200/1200/first"
wantedCSVfilename = "data-batch-vs-acc-1200-1200.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

dvf4 = load_df(f'{csvFile}')
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
#Folder inside results directory that contains all the MOA dump files for these experiments
# results para os experimentos cl4 (4 cores e t)

def prepare_dataframe(experiments, folderMOADumps, wantedCSVfilename):
    total_experiments = len(experiments)
    count = 0
    acc_sum = 0
    dvf4_list = []
    for experiment in experiments:
        resultsFolder = f"{folderMOADumps}/{experiment}"
        csvFile = f"parsed_csvs/{wantedCSVfilename}"
        directory = os.fsencode(resultsFolder)
        header_printed = False

        with open(f"{csvFile}", "w+") as output:
            for file in os.listdir(directory):
                filename = os.fsdecode(file)
                if filename.startswith("dump-"): 
                    output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

        dvf4_temp = load_df(f'{csvFile}')
        dvf4_temp = add_label_column_df(dvf4_temp)

        dvf4_list.append(dvf4_temp)


    #concat the dflist along axis 0 to put the data frames on top of each other
    df_concat=pd.concat(dvf4_list,axis=0)

    dvf4 = df_concat.groupby(level=0).agg(mean_str)
    return dvf4
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
#Folder inside results directory that contains all the MOA dump files for these experiments
# results para os experimentos cl4 (4 cores e t)

experiments = ["experiment-1", "experiment-2", "experiment-3", "experiment-4",
               "experiment-5", "experiment-6", "experiment-7", "experiment-8", "experiment-9", "experiment-10"]
folderMOADumps = "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/sem-coletor/clf/4/1200/1200"
wantedCSVfilename = "data-batch-vs-acc-1200-1200-first.csv"

total_experiments = len(experiments)
count = 0
acc_sum = 0
dvf4_list = []
for experiment in experiments:
    resultsFolder = f"{folderMOADumps}/{experiment}"
    csvFile = f"parsed_csvs/{wantedCSVfilename}"
    directory = os.fsencode(resultsFolder)
    header_printed = False

    with open(f"{csvFile}", "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("dump-"): 
                output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

    dvf4_temp = load_df(f'{csvFile}')
    dvf4_temp = add_label_column_df(dvf4_temp)

    dvf4_list.append(dvf4_temp)


#concat the dflist along axis 0 to put the data frames on top of each other
df_concat=pd.concat(dvf4_list,axis=0)

# display(df_concat.sort_values(['dataset', 'algorithm']))

# # group by and calculating mean on index
dvf4 = df_concat.groupby(level=0).agg(mean_str)

display(dvf4)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
#         dataset                             algorithm  ensemble_size  cores  \
# 0   elecNormNew              OzaBagASHTExecutorRUNPER             25      4
# 1   covtypeNorm  StreamingRandomPatchesExecutorRUNPER             25      4
# 2   covtypeNorm    AdaptiveRandomForestExecutorRUNPER             25      4
# 3   elecNormNew    AdaptiveRandomForestExecutorRUNPER             25      4
# 4   covtypeNorm             OzaBagAdwinExecutorRUNPER             25      4
# 5          GMSC    AdaptiveRandomForestExecutorRUNPER             25      4
# 6      airlines                    LBagExecutorRUNPER             25      4
# 7   elecNormNew  StreamingRandomPatchesExecutorRUNPER             25      4
# 8   covtypeNorm              OzaBagASHTExecutorRUNPER             25      4
# 9          GMSC              OzaBagASHTExecutorRUNPER             25      4
# 10  elecNormNew             OzaBagAdwinExecutorRUNPER             25      4
# 11     airlines                  OzaBagExecutorRUNPER             25      4
# 12  covtypeNorm                    LBagExecutorRUNPER             25      4
# 13  elecNormNew                    LBagExecutorRUNPER             25      4
# 14     airlines              OzaBagASHTExecutorRUNPER             25      4
# 15  elecNormNew                  OzaBagExecutorRUNPER             25      4
# 16         GMSC                    LBagExecutorRUNPER             25      4
# 17         GMSC  StreamingRandomPatchesExecutorRUNPER             25      4
# 18         GMSC                  OzaBagExecutorRUNPER             25      4
# 19         GMSC             OzaBagAdwinExecutorRUNPER             25      4
# 20     airlines             OzaBagAdwinExecutorRUNPER             25      4
# 21  covtypeNorm                  OzaBagExecutorRUNPER             25      4
# 22     airlines  StreamingRandomPatchesExecutorRUNPER             25      4
# 23     airlines    AdaptiveRandomForestExecutorRUNPER             25      4
#
#     batch_size  rate  instances     time   acc  prec  recall   change
# 0            1     1  45,312.00    38.16 83.36 83.12   82.67     0.00
# 1            1     1  61,840.00   526.16 93.00 87.59   87.45     0.00
# 2            1     1 162,030.00   403.79 91.61 82.49   79.67     0.00
# 3            1     1  45,312.00   113.80 88.82 88.79   88.26     0.00
# 4            1     1 139,120.00   303.79 89.04 80.72   79.53     0.00
# 5            1     1 150,000.00   284.18 93.52 76.94   54.40     0.00
# 6            1     1 214,230.00 1,559.01 65.13 60.55   58.35 1,224.00
# 7            1     1  45,312.00   192.14 89.69 89.68   89.15     0.00
# 8            1     1 104,510.00   240.68 86.99 72.23   74.63     0.00
# 9            1     1 150,000.00    86.07 93.40 76.96   51.81     0.00
# 10           1     1  45,312.00    48.06 86.19 86.28   85.34     0.00
# 11           1     1 305,450.00   391.52 65.85 64.35   61.17     0.00
# 12           1     1 149,420.00   500.31 93.45 82.94   82.16   738.00
# 13           1     1  45,312.00    74.85 89.93 89.94   89.39   290.00
# 14           1     1 313,590.00   594.88 67.10 66.27   62.53     0.00
# 15           1     1  45,312.00    35.47 82.30 81.93   81.79     0.00
# 16           1     1 150,000.00   185.38 93.54 76.36   55.40     4.00
# 17           1     1 150,000.00   467.73 93.53 79.94   53.19     0.00
# 18           1     1 150,000.00    92.32 93.50 76.86   53.96     0.00
# 19           1     1 150,000.00
# 17         GMSC      SRPRUNPER          25.00   4.00        1.00  1.00
# 18         GMSC       OBRUNPER          25.00   4.00        1.00  1.00
# 19         GMSC  OBAdwinRUNPER          25.00   4.00        1.00  1.00
# 20     airlines  OBAdwinRUNPER          25.00   4.00        1.00  1.00
# 21  covtypeNorm       OBRUNPER          25.00   4.00        1.00  1.00
# 22     airlines      SRPRUNPER          25.00   4.00        1.00  1.00
# 23     airlines      ARFRUNPER          25.00   4.00        1.00  1.00
#
#     instances     time   acc  prec  recall   change     label
# 0   45,312.00    37.16 83.36 83.12   82.67     0.00  Parallel
# 1   57,583.00   520.60 92.73 87.38   87.29     0.00  Parallel
# 2  151,418.00   397.59 91.48 82.45   79.61     0.00  Parallel
# 3   45,312.00   104.73 88.82 88.79   88.26     0.00  Parallel
# 4  119,896.00   300.02 88.76 80.65   79.82     0.00  Parallel
# 5  150,000.00   257.40 93.52 76.94   54.40     0.00  Parallel
# 6  214,772.00 1,542.63 65.16 60.73   58.56 1,235.20  Parallel
# 7   45,312.00   192.39 89.51 89.51   88.94     0.00  Parallel
# 8   94,483.00   236.77 86.08 71.99   74.54     0.00  Parallel
# 9  150,000.00    89.32 93.40 76.96   51.81     0.00  Parallel
# 10  45,312.00    41.98 86.19 86.28   85.34     0.00  Parallel
# 11 319,450.00   391.74 65.89 64.51   61.41     0.00  Parallel
# 12 139,571.00   496.57 93.29 82.88   82.14   689.20  Parallel
# 13  45,312.00    69.67 89.93 89.94   89.39   290.00  Parallel
# 14 318,694.00   603.30 67.13 66.29   62.60     0.00  Parallel
# 15  45,312.00    35.41 82.30 81.93   81.79     0.00  Parallel
# 16 150,000.00   183.69 93.54 76.36   55.40     4.00  Parallel
# 17 148,381.00   471.21 93.54 79.93   53.18     0.00  Parallel
# 18 150,000.00    91.71 93.50 76.86   53.96     0.00  Parallel
# 19 150,000.00    96.47 93.48 77.54   53.16     0.00  Parallel
# 20 231,113.00 1,025.89 67.45 64.24   61.16     0.00  Parallel
# 21  91,654.00   232.82 85.57 71.80   74.25     0.00  Parallel
# 22 126,175.00   926.68 69.63 65.94   61.27     0.00  Parallel
# 23 178,890.00 1,250.60 67.88 63.40   61.40     0.00  Parallel

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/sem-coletor/dvfs/600/600/first"
wantedCSVfilename = "data-batch-vs-acc-600-600.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

dvh4 = load_df(f'{csvFile}')
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
#         dataset                             algorithm  ensemble_size  cores  \
# 0   elecNormNew              OzaBagASHTExecutorRUNPER             25      4
# 1   covtypeNorm  StreamingRandomPatchesExecutorRUNPER             25      4
# 2          GMSC                StreamingRandomPatches             25      1
# 3   elecNormNew                         LeveragingBag             25      1
# 4      airlines                         LeveragingBag             25      1
# 5   covtypeNorm    AdaptiveRandomForestExecutorRUNPER             25      4
# 6   elecNormNew    AdaptiveRandomForestExecutorRUNPER             25      4
# 7   covtypeNorm             OzaBagAdwinExecutorRUNPER             25      4
# 8          GMSC    AdaptiveRandomForestExecutorRUNPER             25      4
# 9   elecNormNew                            OzaBagASHT             25      1
# 10     airlines                    LBagExecutorRUNPER             25      4
# 11         GMSC                            OzaBagASHT             25      1
# 12  elecNormNew  StreamingRandomPatchesExecutorRUNPER             25      4
# 13  covtypeNorm              OzaBagASHTExecutorRUNPER             25      4
# 14  covtypeNorm                           OzaBagAdwin             25      1
# 15     airlines        AdaptiveRandomForestSequential             25      1
# 16         GMSC                         LeveragingBag             25      1
# 17  elecNormNew        AdaptiveRandomForestSequential             25      1
# 18  elecNormNew                           OzaBagAdwin             25      1
# 19         GMSC              OzaBagASHTExecutorRUNPER             25      4
# 20  elecNormNew             OzaBagAdwinExecutorRUNPER             25      4
# 21         GMSC        AdaptiveRandomForestSequential             25      1
# 22  covtypeNorm        AdaptiveRandomForestSequential             25      1
# 23     airlines                  OzaBagExecutorRUNPER             25      4
# 24  covtypeNorm                    LBagExecutorRUNPER             25      4
# 25  covtypeNorm                                OzaBag             25      1
# 26  elecNormNew                    LBagExecutorRUNPER             25      4
# 27     airlines              OzaBagASHTExecutorRUNPER             25      4
# 28  elecNormNew                  OzaBagExecutorRUNPER             25      4
# 29         GMSC                                OzaBag             25      1
# 30         GMSC                           OzaBagAdwin             25      1
# 31         GMSC                    LBagExecutorRUNPER             25      4
# 32         GMSC  StreamingRandomPatchesExecutorRUNPER             25      4
# 33  covtypeNorm                StreamingRandomPatches             25      1
# 34         GMSC                  OzaBagExecutorRUNPER             25      4
# 35  elecNormNew                                OzaBag             25      1
# 36         GMSC             OzaBagAdwinExecutorRUNPER             25      4
# 37     airlines                           OzaBagAdwin             25      1
# 38     airlines                                OzaBag             25      1
# 39     airlines             OzaBagAdwinExecutorRUNPER             25      4
# 40  covtypeNorm                  OzaBagExecutorRUNPER             25      4
# 41     airlines                            OzaBagASHT             25      1
# 42  elecNormNew                StreamingRandomPatches             25      1
# 43  covtypeNorm                            OzaBagASHT             25      1
# 44  covtypeNorm                         LeveragingBag             25      1
# 45     airlines                StreamingRandomPatches             25      1
# 46     airlines  StreamingRandomPatchesExecutorRUNPER             25      4
# 47     airlines    AdaptiveRandomForestExecutorRUNPER             25      4
#
#     batch_size  rate  instances     time   acc  prec  recall  change
# 0            1     1  45,312.00    63.13 83.36 83.12   82.67    0.00
# 1            1     1  30,010.00   509.26 88.41 85.79   85.65    0.00
# 2            1     1  17,780.00   122.10 93.62 74.64   51.24    0.00
# 3            1     1  31,260.00   121.42 89.86 89.93   89.22  186.00
# 4            1     1   3,610.00   124.74 68.42 56.63   54.34   12.00
# 5            1     1  72,950.00   369.47 90.04 82.27   81.59    0.00
# 6            1     1  45,312.00   173.90 88.82 88.79   88.26    0.00
# 7            1     1  54,990.00   271.00 86.78 80.42   80.25    0.00
# 8            1     1 150,000.00   383.78 93.52 76.94   54.40    0.00
# 9            1     1  45,312.00    57.56 83.26 83.12   82.43    0.00
# 10           1     1 158,390.00 1,982.61 65.75 59.97   57.70  891.00
# 11           1     1 145,850.00   121.60 93.34 75.09   50.35    0.00
# 6   covtypeNorm      SRPRUNPER             25      2           1     1
# 7   covtypeNorm      ARFRUNPER             25      2           1     1
# 8   elecNormNew      ARFRUNPER             25      2           1     1
# 9          GMSC   OBASHTRUNPER             25      2           1     1
# 10  elecNormNew  OBAdwinRUNPER             25      2           1     1
# 11     airlines       OBRUNPER             25      2           1     1
# 12  covtypeNorm     LBagRUNPER             25      2           1     1
# 13  elecNormNew     LBagRUNPER             25      2           1     1
# 14         GMSC       OBRUNPER             25      2           1     1
# 15         GMSC  OBAdwinRUNPER             25      2           1     1
# 16     airlines  OBAdwinRUNPER             25      2           1     1
# 17  covtypeNorm       OBRUNPER             25      2           1     1
# 18  elecNormNew       OBRUNPER             25      2           1     1
# 19     airlines   OBASHTRUNPER             25      2           1     1
# 20         GMSC     LBagRUNPER             25      2           1     1
# 21         GMSC      SRPRUNPER             25      2           1     1
# 22     airlines      SRPRUNPER             25      2           1     1
# 23     airlines      ARFRUNPER             25      2           1     1
#
#     instances     time   acc  prec  recall  change     label
# 0   59,740.00   344.72 87.21 80.66   80.34    0.00  Parallel
# 1  135,990.00   413.47 93.55 76.65   54.29    0.00  Parallel
# 2  134,060.00 2,323.56 65.80 59.94   57.65  747.00  Parallel
# 3   45,312.00   409.81 89.76 89.78   89.20    0.00  Parallel
# 4   37,580.00   235.19 75.73 68.55   71.45    0.00  Parallel
# 5   45,312.00    70.94 83.36 83.12   82.67    0.00  Parallel
# 6   29,640.00   578.15 88.36 85.72   85.76    0.00  Parallel
# 7   77,040.00   433.24 90.10 82.28   81.51    0.00  Parallel
# 8   45,312.00   216.68 88.82 88.79   88.26    0.00  Parallel
# 9  150,000.00   166.18 93.40 76.96   51.81    0.00  Parallel
# 10  45,312.00    90.50 86.19 86.28   85.34    0.00  Parallel
# 11 201,870.00   542.95 67.23 62.89   60.47    0.00  Parallel
# 12  62,720.00   478.47 90.77 82.60   82.34  393.00  Parallel
# 13  45,312.00   147.91 89.93 89.94   89.39  290.00  Parallel
# 14 150,000.00   169.29 93.50 76.86   53.96    0.00  Parallel
# 15 150,000.00   203.76 93.48 77.54   53.16    0.00  Parallel
# 16 142,320.00 1,372.70 68.45 63.41   59.52    0.00  Parallel
# 17  35,750.00   231.35 74.84 68.15   71.19    0.00  Parallel
# 18  45,312.00    69.31 82.30 81.93   81.79    0.00  Parallel
# 19 174,350.00   741.16 68.71 64.65   61.49    0.00  Parallel
# 20 150,000.00   359.13 93.54 76.36   55.40    4.00  Parallel
# 21  90,270.00   503.50 93.53 78.30   52.62    0.00  Parallel
# 22  84,080.00 1,419.33 69.27 66.05   61.88    0.00  Parallel
# 23 117,740.00 1,804.70 67.34 63.08   61.31    0.00  Parallel

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
#Folder inside results directory that contains all the MOA dump files for these experiments
# resultados para cl2 (apenas 2 cores e rodando na frequencia maxima 1200x1200)
experiments = ["experiment-1", "experiment-2", "experiment-3", "experiment-4",
               "experiment-5", "experiment-6", "experiment-7", "experiment-8", "experiment-9", "experiment-10"]
folderMOADumps = "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/sem-coletor/clf/2/1200/1200"
wantedCSVfilename = "data-batch-vs-acc-2-600-600-first.csv"

total_experiments = len(experiments)
count = 0
acc_sum = 0
dvf2_list = []
for experiment in experiments:
    resultsFolder = f"{folderMOADumps}/{experiment}"
    csvFile = f"parsed_csvs/{wantedCSVfilename}"
    directory = os.fsencode(resultsFolder)
    header_printed = False

    with open(f"{csvFile}", "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("dump-"): 
                output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

    dvf2_temp = load_df(f'{csvFile}')
    dvf2_temp = add_label_column_df(dvf2_temp)

    dvf2_list.append(dvf2_temp)


#concat the dflist along axis 0 to put the data frames on top of each other
df_concat=pd.concat(dvf2_list,axis=0)

# display(df_concat.sort_values(['dataset', 'algorithm']))

# # group by and calculating mean on index
dvf2 = df_concat.groupby(level=0).agg(mean_str)

display(dvf2)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
#         dataset      algorithm  ensemble_size  cores  batch_size  rate  \
# 0   covtypeNorm  OBAdwinRUNPER          25.00   2.00        1.00  1.00
# 1          GMSC      ARFRUNPER          25.00   2.00        1.00  1.00
# 2      airlines     LBagRUNPER          25.00   2.00        1.00  1.00
# 3   elecNormNew      SRPRUNPER          25.00   2.00        1.00  1.00
# 4   covtypeNorm   OBASHTRUNPER          25.00   2.00        1.00  1.00
# 5   elecNormNew   OBASHTRUNPER          25.00   2.00        1.00  1.00
# 6   covtypeNorm      SRPRUNPER          25.00   2.00        1.00  1.00
# 7   covtypeNorm      ARFRUNPER          25.00   2.00        1.00  1.00
# 8   elecNormNew      ARFRUNPER          25.00   2.00        1.00  1.00
# 9          GMSC   OBASHTRUNPER          25.00   2.00        1.00  1.00
# 10  elecNormNew  OBAdwinRUNPER          25.00   2.00        1.00  1.00
# 11     airlines       OBRUNPER          25.00   2.00        1.00  1.00
# 12  covtypeNorm     LBagRUNPER          25.00   2.00        1.00  1.00
# 13  elecNormNew     LBagRUNPER          25.00   2.00        1.00  1.00
# 14         GMSC       OBRUNPER          25.00   2.00        1.00  1.00
# 15         GMSC  OBAdwinRUNPER          25.00   2.00        1.00  1.00
# 16     airlines  OBAdwinRUNPER          25.00   2.00        1.00  1.00
# 17  covtypeNorm       OBRUNPER          25.00   2.00        1.00  1.00
# 18  elecNormNew       OBRUNPER          25.00   2.00        1.00  1.00
# 19     airlines   OBASHTRUNPER          25.00   2.00        1.00  1.00
# 20         GMSC     LBagRUNPER          25.00   2.00        1.00  1.00
# 21         GMSC      SRPRUNPER          25.00   2.00        1.00  1.00
# 22     airlines      SRPRUNPER          25.00   2.00        1.00  1.00
# 23     airlines      ARFRUNPER          25.00   2.00        1.00  1.00
#
#     instances     time   acc  prec  recall   change     label
# 0  118,316.00   333.25 89.13 80.74   79.87     0.00  Parallel
# 1  150,000.00   250.49 93.52 76.94   54.40     0.00  Parallel
# 2  204,786.00 1,858.52 65.42 60.44   58.16 1,178.30  Parallel
# 3   45,312.00   219.41 89.76 89.78   89.20     0.00  Parallel
# 4  105,074.00   274.39 87.03 72.23   74.67     0.00  Parallel
# 5   45,312.00    38.99 83.36 83.12   82.67     0.00  Parallel
# 6   62,237.00   587.52 93.10 87.45   87.37     0.00  Parallel
# 7  144,360.00   416.31 91.33 82.40   79.59     0.00  Parallel
# 8   45,312.00   116.78 88.82 88.79   88.26     0.00  Parallel
# 9  150,000.00    90.04 93.40 76.96   51.81     0.00  Parallel
# 10  45,312.00    48.94 86.19 86.28   85.34     0.00  Parallel
# 11 358,889.00   433.10 65.64 64.93   61.85     0.00  Parallel
# 12 131,843.00   510.79 93.10 82.80   82.14   658.40  Parallel
# 13  45,312.00    78.20 89.93 89.94   89.39   290.00  Parallel
# 14 150,000.00    92.24 93.50 76.86   53.96     0.00  Parallel
# 15 150,000.00   109.83 93.48 77.54   53.16     0.00  Parallel
# 16 227,541.00 1,162.06 67.54 64.37   61.22     0.00  Parallel
# 17 104,660.00   272.96 86.80 72.10   74.39     0.00  Parallel
# 18  45,312.00    37.97 82.30 81.93   81.79     0.00  Parallel
# 19 300,029.00   594.46 67.25 66.13   62.37     0.00  Parallel
# 20 150,000.00   193.22 93.54 76.36   55.40     4.00  Parallel
# 21 149,559.00   504.27 93.53 79.93   53.19     0.00  Parallel
# 22 139,202.00 1,176.90 70.00 66.06   61.06     0.00  Parallel
# 23 197,924.00 1,575.76 67.71 63.50   61.51     0.00  Parallel

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/sem-coletor/mini-batching-medium/600/1200/first"
wantedCSVfilename = "data-batch-vs-acc-600-1200.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

df_mb = load_df(f'{csvFile}')
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
def add_label_column_df(df):
    for index, row in df.iterrows():
        _str = row["algorithm"]

        if "RUNPER" in _str and row["batch_size"] == 1:
            df.at[index, 'label'] = "Parallel"
        elif row["batch_size"] == 1:
            df.at[index, 'label'] = "Seq"
        else:
            df.at[index, 'label'] = row["batch_size"]
            
    return df

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
#Folder inside results directory that contains all the MOA dump files for these experiments

experiments = ["experiment-1", "experiment-2", "experiment-3", "experiment-4",
               "experiment-5", "experiment-6", "experiment-7", "experiment-8", "experiment-9", "experiment-10"]
folderMOADumps = "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/loop-fusion/acc-redudance"
wantedCSVfilename = "data-batch-vs-acc-600-1200-first.csv"

total_experiments = len(experiments)
count = 0
acc_sum = 0
dfmblf = []
for experiment in experiments:
    resultsFolder = f"{folderMOADumps}/{experiment}"
    csvFile = f"parsed_csvs/{wantedCSVfilename}"
    directory = os.fsencode(resultsFolder)
    header_printed = False

    with open(f"{csvFile}", "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("dump-"): 
                output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

    dfmblf_temp = load_df(f'{csvFile}')
    dfmblf_temp = add_label_column_df(dfmblf_temp)
    dfmblf_temp = dfmblf_temp.loc[dfmblf_temp.batch_size == 50]
    dfmblf_temp['batch_size'] = 'MB-LF'

    dfmblf.append(dfmblf_temp)


#concat the dflist along axis 0 to put the data frames on top of each other
df_concat=pd.concat(dfmblf,axis=0)

# display(df_concat.sort_values(['dataset', 'algorithm']))

# # group by and calculating mean on index
dfmblf = df_concat.groupby(level=0).agg(mean_str)

display(dfmblf)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_24821/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
#         dataset  algorithm  ensemble_size  cores batch_size  rate  instances  \
# 0   elecNormNew       OBMB          25.00   4.00      MB-LF  1.00  45,312.00
# 1      airlines       OBMB          25.00   4.00      MB-LF  1.00 539,383.00
# 2          GMSC      SRPMB          25.00   4.00      MB-LF  1.00 150,000.00
# 3          GMSC      ARFMB          25.00   4.00      MB-LF  1.00 150,000.00
# 4   elecNormNew   OBASHTMB          25.00   4.00      MB-LF  1.00  45,312.00
# 5          GMSC       OBMB          25.00   4.00      MB-LF  1.00 150,000.00
# 6   elecNormNew  OBAdwinMB          25.00   4.00      MB-LF  1.00  45,312.00
# 7      airlines      ARFMB          25.00   4.00      MB-LF  1.00 539,383.00
# 8      airlines      SRPMB          25.00   4.00      MB-LF  1.00 539,383.00
# 9      airlines     LBagMB          25.00   4.00      MB-LF  1.00 539,383.00
# 10  elecNormNew      ARFMB          25.00   4.00      MB-LF  1.00  45,312.00
# 11  covtypeNorm   OBASHTMB          25.00   4.00      MB-LF  1.00 581,012.00
# 12  covtypeNorm      ARFMB          25.00   4.00      MB-LF  1.00 581,012.00
# 13     airlines  OBAdwinMB          25.00   4.00      MB-LF  1.00 539,383.00
# 14  covtypeNorm      SRPMB          25.00   4.00      MB-LF  1.00 581,012.00
# 15         GMSC  OBAdwinMB          25.00   4.00      MB-LF  1.00 150,000.00
# 16  elecNormNew      SRPMB          25.00   4.00      MB-LF  1.00  45,312.00
# 17         GMSC   OBASHTMB          25.00   4.00      MB-LF  1.00 150,000.00
# 18  elecNormNew     LBagMB          25.00   4.00      MB-LF  1.00  45,312.00
# 19  covtypeNorm       OBMB          25.00   4.00      MB-LF  1.00 581,012.00
# 20         GMSC     LBagMB          25.00   4.00      MB-LF  1.00 150,000.00
# 21     airlines   OBASHTMB          25.00   4.00      MB-LF  1.00 539,383.00
# 22  covtypeNorm     LBagMB          25.00   4.00      MB-LF  1.00 581,012.00
# 23  covtypeNorm  OBAdwinMB          25.00   4.00      MB-LF  1.00 581,012.00
#
#        time   acc  prec  recall    change  label
# 0     11.19 77.52 78.56   75.42      0.00  50.00
# 1    122.32 60.94 60.97   58.57      0.00  50.00
# 2    181.70 93.51 79.54   52.90      0.00  50.00
# 3    108.61 93.53 76.95   54.53      0.00  50.00
# 4     11.75 76.86 78.45   74.47      0.00  50.00
# 5     23.03 93.35 73.93   53.54      0.00  50.00
# 6     19.73 84.26 84.53   83.13      0.00  50.00
# 7  2,839.69 66.13 65.71   65.03      0.00  50.00
# 8  2,642.71 67.90 67.69   66.68      0.00  50.00
# 9  3,140.97 64.03 63.57   62.64 10,747.00  50.00
# 10    60.23 88.79 88.76   88.21      0.00  50.00
# 11   225.21 77.04 74.20   56.79      0.00  50.00
# 12   795.82 92.38 89.47   81.73      0.00  50.00
# 13   997.62 67.28 67.22   65.81      0.00  50.00
# 14 2,778.51 95.58 93.17   90.42      0.00  50.00
# 15    42.20 93.39 76.37   51.54      0.00  50.00
# 16   119.14 89.31 89.35   88.70      0.00  50.00
# 17    21.73 93.30 70.95   51.96      0.00  50.00
# 18    42.66 90.56 90.58   90.06    901.30  50.00
# 19   213.87 76.96 72.32   55.74      0.00  50.00
# 20    89.68 93.37 73.46   52.96  1,963.40  50.00
# 21   169.01 61.75 61.78   59.78      0.00  50.00
# 22 1,052.22 91.84 85.32   85.20 11,604.00  50.00
# 23   661.48 85.20 78.32   82.18      0.00  50.00

# %%
def build_label(df):
    for index, row in df.iterrows():
        if ((row['algorithm'].find('Sequential') > 0 or row['batch_size'] == 1) and row['cores'] == 1):
            df.at[index, 'label'] = "S"
            
        if (row['cores'] == 4 and row['batch_size'] == 50):
            df.at[index, 'label'] = "MB"
            
        if (row['cores'] == 4 and row['batch_size'] == "MB-LF"):
            df.at[index, 'label'] = "MB-LF"

        if (row['algorithm'].find('RUNPER') > 0 and row['cores'] == 2 and row['frequency_maximum'] == "600"):
            df.at[index, 'label'] = "FH2"
            
        if (row['algorithm'].find('RUNPER') > 0 and row['cores'] == 4 and row['frequency_maximum'] == "600"):
            df.at[index, 'label'] = "FH4"

        if (row['algorithm'].find('RUNPER') > 0 and row['cores'] == 2 and row['frequency_maximum'] == "1200"):
            df.at[index, 'label'] = "CL2"

        if (row['algorithm'].find('RUNPER') > 0 and row['cores'] == 4 and row['frequency_maximum'] == "1200"):
            df.at[index, 'label'] = "CL4"

    return df

# %%
dvh2 = dvh2.drop(dvh2[(dvh2.cores == 1) & (dvh2.batch_size == 1)].index) # rodado
dvh2['frequency_maximum'] = "600"
dvh4 = dvh4.drop(dvh4[(dvh4.cores == 1) & (dvh4.batch_size == 1)].index) # rodado
dvh4['frequency_maximum'] = "600"

dvf2 = dvf2.drop(dvf2[(dvf2.cores == 1) & (dvf2.batch_size == 1)].index) # rodado
dvf2['frequency_maximum'] = "1200"
dvf4 = dvf4.drop(dvf4[(dvf4.cores == 1) & (dvf4.batch_size == 1)].index) # rodado
dvf4['frequency_maximum'] = "1200"

# remove mb nao utilizados
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 1].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 25].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 75].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 100].index)

df = pd.concat([df_sequential, dvh2, dvh4, dvf2, dvf4, df_mb, dfmblf])
df = build_label(df.reset_index())

df_mapping = pd.DataFrame({
    'label': ['S', 'FH2', 'FH4', 'CL2', 'CL4', 'MB', 'MB-LF'],
})
sort_mapping = df_mapping.reset_index().set_index('label')
df['label_num'] = df['label'].map(sort_mapping['index'])

df = df.drop_duplicates().sort_values('label_num')

# %%
#false makes the chart without markers
gen_chart(df, False, False)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# pega execução sequencial e bota em um novo dataframe
df_sequential = dvf4.loc[(dvf4.cores == 1) & (dvf4.batch_size == 1)]

dvh2 = dvh2.drop(dvh2[(dvh2.cores == 1) & (dvh2.batch_size == 1)].index) # rodado
dvh2['frequency_maximum'] = "600"
dvh4 = dvh4.drop(dvh4[(dvh4.cores == 1) & (dvh4.batch_size == 1)].index) # rodado
dvh4['frequency_maximum'] = "600"

dvf2 = dvf2.drop(dvf2[(dvf2.cores == 1) & (dvf2.batch_size == 1)].index) # a rodar
dvf2['frequency_maximum'] = "1200"
dvf4 = dvf4.drop(dvf4[(dvf4.cores == 1) & (dvf4.batch_size == 1)].index) # rodado
dvf4['frequency_maximum'] = "1200"

# remove mb nao utilizados
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 1].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 25].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 75].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 100].index)

df = pd.concat([df_sequential, dvh2, dvh4, dvf2, dvf4, df_mb])
df = build_label(df.reset_index())

df_mapping = pd.DataFrame({
    'label': ['S', 'FH2', 'FH4', 'CL2', 'CL4', 'MB'],
})
sort_mapping = df_mapping.reset_index().set_index('label')
df['label_num'] = df['label'].map(sort_mapping['index'])

df = df.drop_duplicates().sort_values('label_num')

# %%
#false makes the chart without markers
# gen_chart(df, False)
