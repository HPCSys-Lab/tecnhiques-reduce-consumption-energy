# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %%
def parse(fname):
    global header_printed
    #index of wanted columns
    columns = []
    #column names to get the data from
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    ret_string = ''
    #remove the path and isolate the filename
    spname = fname.split('/')[-1].split('-')
    spline = []
    #control flag for knowing when the column names have already been discovered
    got = False
    #we ignore the first parameter of the filename and add all others to the csv string
    for s in spname[1:]:
        ret_string += s + ','
    #should probably use a safer way, but python handles the closing of the file
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                #sometimes the dump file has multiple results in it, so we get the index of wanted columns only once
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        #OzaBagASHT bugs out on GMSC, this reuses the data from the sequential execution
        # if 'GMSC' in spname and 'ASHT' in spname[2]:
        #     for c in columns[:-2]:
        #         ret_string += str(spline[c]) + ','
        #     ret_string += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        #normal code, how everything should run
        #we process the data (add the content of wanted columns to the csv string) only after the for
        #ensuring we use only the last (most recent) data and not the intermediate results
        else:
            for c in columns:
                ret_string += str(spline[c]) + ','
            if len(columns) == 5:
                ret_string += '0,'
        #header is a global variable, it will only be printed on the first file 
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,rate,instances,time,acc,prec,recall,change'
            ret_string = f"{head}\n{ret_string}"
            header_printed = True
        #remove the last comma ,
        return (ret_string[:-1])

# %%
def add_label_column_df(df):
    for index, row in df.iterrows():
        _str = row["algorithm"]

        if "RUNPER" in _str:
            df.at[index, 'label'] = "Parallel"
        else:
            df.at[index, 'label'] = "Sequential"
            
    return df

# %%
#loads the csv as a dataframe and standardizes the algorithm names 
def load_df(filename):
    df = pd.read_csv(filename, index_col=False)
    df = add_label_column_df(df)
    return select_columns_and_rename_values(df)

# %%
#standardize algorithm names
def select_columns_and_rename_values(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    df.batch_size.unique()
    return df

# %%
#filters by substring (there are multiple OzaBag algorithms)
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %%
#plots precision and recall with markers of one parameter configuration
def gen_lines(df, ax, alg_order, markers):
    lwidth = 0.75
    if markers:
        colors=['go', 'bs', 'rP', 'md', 'y+' , 'k*']
    else:
        colors=['g', 'b', 'r', 'm', 'y' , 'k']

    labels = df.label

    alg = df.algorithm.unique()[0]
    x = np.arange(len(labels))
  
    ax.plot(x, pd.to_numeric(df.acc), f'{colors[alg_order]}--', linewidth=lwidth, label=f'{alg.replace("RUNPER", "").replace("Sequential", "")}-acc')
    
    # ax.plot(x, pd.to_numeric(df.prec), f'{colors[alg_order]}--', linewidth=lwidth, label=f'{alg}-prec')
    # ax.plot(x, pd.to_numeric(df.recall), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')

    #ax.plot(x,pd.to_numeric(df.prec), f'{colors[alg_order]}-', linewidth=lwidth, label=f'{alg}-rec')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_ylim(60,100)

# %%
#iterates over the parameter configurations and creates the chart grid
def gen_chart(df, markers=True, tables=False):
    datasets = ['airlines', 'GMSC', 'elecNormNew', 'covtypeNorm']
    #dictionary containing the correct name to be printed
    dsformalname = {'elecNormNew': 'Electricity', 'GMSC': 'GMSC', 'airlines': 'Airlines', 'covtypeNorm': 'Covertype'}
    algorithms = ['ARF', 'LBag', 'SRP', 'OBAdwin', 'OBASHT', 'OB']
    #creates a 2x2 grid for plotting the charts
    #sharey=row means that all charts in a row share the same Y-axis
    fig, axs = plt.subplots(2, 2, figsize=(8,8), sharey='row')
    filename = "batch-size-vs-prediction-mark" if markers else "batch-size-vs-prediction"
    #each chart presents the results for a given dataset and contains the series for all algorithms
    for ds in datasets:
        title = ''
        my_id = datasets.index(ds)
        #selects the correct position in the grid
        ax = axs[int(my_id/2)][my_id%2]
        ax.set_title(f'{dsformalname[ds]}')
        #for each algorithm
        for alg in algorithms:
            #filters the df to contain the wanted values
            df_aux = filter_by_substring_algorithm(df[df.dataset == ds], alg)
            if tables:
                display(df_aux)
            #plot (include) the series in the chart
            gen_lines(df_aux, ax, algorithms.index(alg), markers)
            #if its the first column, print Y-axis label
            if my_id%2 == 0:
                ax.set_ylabel('Percentage')
            #if its the last row, print the X-axis label
#             if int(my_id/2) == 1:
#                 ax.set_xlabel('Batch sizes')
    #retrieves the handles and labels to create a global legend
    handles, labels = axs[0][0].get_legend_handles_labels()
    lgd = fig.legend(handles, labels, loc = 'lower center', ncol = math.ceil(len(algorithms)/2), bbox_to_anchor=(0.5,-0.1))
    fig.tight_layout()
    plt.savefig(f'figures/{filename}.png')
    plt.savefig(f'figures/{filename}.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/sem-coletor/dvfs/1200/1200/first"
wantedCSVfilename = "data-batch-vs-acc-1200-1200.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

dvf4 = load_df(f'{csvFile}')
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/sem-coletor/dvfs/600/600/first"
wantedCSVfilename = "data-batch-vs-acc-600-600.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

dvh4 = load_df(f'{csvFile}')
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/sem-coletor/dvfs/dpm/2/600"
wantedCSVfilename = "data-batch-vs-acc-600-600-2.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

dvh2 = load_df(f'{csvFile}')
display(dvh2)
# Out:
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
#         dataset      algorithm  ensemble_size  cores  batch_size  rate  \
# 0   covtypeNorm  OBAdwinRUNPER             25      2           1     1
# 1          GMSC      ARFRUNPER             25      2           1     1
# 2      airlines     LBagRUNPER             25      2           1     1
# 3   elecNormNew      SRPRUNPER             25      2           1     1
# 4   covtypeNorm   OBASHTRUNPER             25      2           1     1
# 5   elecNormNew   OBASHTRUNPER             25      2           1     1
# 6   covtypeNorm      SRPRUNPER             25      2           1     1
# 7   covtypeNorm      ARFRUNPER             25      2           1     1
# 8   elecNormNew      ARFRUNPER             25      2           1     1
# 9          GMSC   OBASHTRUNPER             25      2           1     1
# 10  elecNormNew  OBAdwinRUNPER             25      2           1     1
# 11     airlines       OBRUNPER             25      2           1     1
# 12  covtypeNorm     LBagRUNPER             25      2           1     1
# 13  elecNormNew     LBagRUNPER             25      2           1     1
# 14         GMSC       OBRUNPER             25      2           1     1
# 15         GMSC  OBAdwinRUNPER             25      2           1     1
# 16     airlines  OBAdwinRUNPER             25      2           1     1
# 17  covtypeNorm       OBRUNPER             25      2           1     1
# 18  elecNormNew       OBRUNPER             25      2           1     1
# 19     airlines   OBASHTRUNPER             25      2           1     1
# 20         GMSC     LBagRUNPER             25      2           1     1
# 21         GMSC      SRPRUNPER             25      2           1     1
# 22     airlines      SRPRUNPER             25      2           1     1
# 23     airlines      ARFRUNPER             25      2           1     1
#
#     instances     time   acc  prec  recall  change     label
# 0   59,740.00   344.72 87.21 80.66   80.34    0.00  Parallel
# 1  135,990.00   413.47 93.55 76.65   54.29    0.00  Parallel
# 2  134,060.00 2,323.56 65.80 59.94   57.65  747.00  Parallel
# 3   45,312.00   409.81 89.76 89.78   89.20    0.00  Parallel
# 4   37,580.00   235.19 75.73 68.55   71.45    0.00  Parallel
# 5   45,312.00    70.94 83.36 83.12   82.67    0.00  Parallel
# 6   29,640.00   578.15 88.36 85.72   85.76    0.00  Parallel
# 7   77,040.00   433.24 90.10 82.28   81.51    0.00  Parallel
# 8   45,312.00   216.68 88.82 88.79   88.26    0.00  Parallel
# 9  150,000.00   166.18 93.40 76.96   51.81    0.00  Parallel
# 10  45,312.00    90.50 86.19 86.28   85.34    0.00  Parallel
# 11 201,870.00   542.95 67.23 62.89   60.47    0.00  Parallel
# 12  62,720.00   478.47 90.77 82.60   82.34  393.00  Parallel
# 13  45,312.00   147.91 89.93 89.94   89.39  290.00  Parallel
# 14 150,000.00   169.29 93.50 76.86   53.96    0.00  Parallel
# 15 150,000.00   203.76 93.48 77.54   53.16    0.00  Parallel
# 16 142,320.00 1,372.70 68.45 63.41   59.52    0.00  Parallel
# 17  35,750.00   231.35 74.84 68.15   71.19    0.00  Parallel
# 18  45,312.00    69.31 82.30 81.93   81.79    0.00  Parallel
# 19 174,350.00   741.16 68.71 64.65   61.49    0.00  Parallel
# 20 150,000.00   359.13 93.54 76.36   55.40    4.00  Parallel
# 21  90,270.00   503.50 93.53 78.30   52.62    0.00  Parallel
# 22  84,080.00 1,419.33 69.27 66.05   61.88    0.00  Parallel
# 23 117,740.00 1,804.70 67.34 63.08   61.31    0.00  Parallel

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/sem-coletor/dvfs/dpm/2/1200/first"
wantedCSVfilename = "data-batch-vs-acc-1200-1200-2.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

dvf2 = load_df(f'{csvFile}')
display(dvf2)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
#         dataset      algorithm  ensemble_size  cores  batch_size  rate  \
# 0   covtypeNorm  OBAdwinRUNPER             25      2           1     1
# 1          GMSC      ARFRUNPER             25      2           1     1
# 2      airlines     LBagRUNPER             25      2           1     1
# 3   elecNormNew      SRPRUNPER             25      2           1     1
# 4   covtypeNorm   OBASHTRUNPER             25      2           1     1
# 5   elecNormNew   OBASHTRUNPER             25      2           1     1
# 6   covtypeNorm      SRPRUNPER             25      2           1     1
# 7   covtypeNorm      ARFRUNPER             25      2           1     1
# 8   elecNormNew      ARFRUNPER             25      2           1     1
# 9          GMSC   OBASHTRUNPER             25      2           1     1
# 10  elecNormNew  OBAdwinRUNPER             25      2           1     1
# 11     airlines       OBRUNPER             25      2           1     1
# 12  covtypeNorm     LBagRUNPER             25      2           1     1
# 13  elecNormNew     LBagRUNPER             25      2           1     1
# 14         GMSC       OBRUNPER             25      2           1     1
# 15         GMSC  OBAdwinRUNPER             25      2           1     1
# 16     airlines  OBAdwinRUNPER             25      2           1     1
# 17  covtypeNorm       OBRUNPER             25      2           1     1
# 18  elecNormNew       OBRUNPER             25      2           1     1
# 19     airlines   OBASHTRUNPER             25      2           1     1
# 20         GMSC     LBagRUNPER             25      2           1     1
# 21         GMSC      SRPRUNPER             25      2           1     1
# 22     airlines      SRPRUNPER             25      2           1     1
# 23     airlines      ARFRUNPER             25      2           1     1
#
#     instances     time   acc  prec  recall   change     label
# 0  119,180.00   332.59 89.10 80.73   79.82     0.00  Parallel
# 1  150,000.00   253.10 93.52 76.94   54.40     0.00  Parallel
# 2  209,130.00 1,860.20 65.32 60.49   58.24 1,219.00  Parallel
# 3   45,312.00   219.36 89.76 89.78   89.20     0.00  Parallel
# 4  103,930.00   275.06 86.94 72.21   74.67     0.00  Parallel
# 5   45,312.00    40.19 83.36 83.12   82.67     0.00  Parallel
# 6   62,340.00   584.13 93.19 87.49   87.34     0.00  Parallel
# 7  138,660.00   407.86 91.36 82.39   79.84     0.00  Parallel
# 8   45,312.00   116.13 88.82 88.79   88.26     0.00  Parallel
# 9  150,000.00    90.33 93.40 76.96   51.81     0.00  Parallel
# 10  45,312.00    49.19 86.19 86.28   85.34     0.00  Parallel
# 11 358,570.00   431.03 65.63 64.90   61.82     0.00  Parallel
# 12 134,090.00   515.73 93.17 82.81   82.15   659.00  Parallel
# 13  45,312.00    78.27 89.93 89.94   89.39   290.00  Parallel
# 14 150,000.00    91.80 93.50 76.86   53.96     0.00  Parallel
# 15 150,000.00   111.49 93.48 77.54   53.16     0.00  Parallel
# 16 230,750.00 1,151.24 67.48 64.40   61.34     0.00  Parallel
# 17 104,410.00   274.50 86.78 72.11   74.37     0.00  Parallel
# 18  45,312.00    37.65 82.30 81.93   81.79     0.00  Parallel
# 19 285,220.00   578.64 67.49 65.93   62.16     0.00  Parallel
# 20 150,000.00   193.68 93.54 76.36   55.40     4.00  Parallel
# 21 150,000.00   506.90 93.53 79.94   53.19     0.00  Parallel
# 22 139,480.00 1,149.26 70.04 66.25   61.04     0.00  Parallel
# 23 198,090.00 1,543.04 67.74 63.37   61.35     0.00  Parallel

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/

#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "results/sem-coletor/mini-batching-medium/600/1200/first"
wantedCSVfilename = "data-batch-vs-acc-600-1200.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

df_mb = load_df(f'{csvFile}')
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")

# %%
def add_label_column_df(df):
    for index, row in df.iterrows():
        _str = row["algorithm"]

        if "RUNPER" in _str and row["batch_size"] == 1:
            df.at[index, 'label'] = "Parallel"
        elif row["batch_size"] == 1:
            df.at[index, 'label'] = "Seq"
        else:
            df.at[index, 'label'] = row["batch_size"]
            
    return df

# %%
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
#Folder inside results directory that contains all the MOA dump files for these experiments
folderMOADumps = "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/loop-fusion/acc/second"
wantedCSVfilename = "data-batch-vs-acc-600-1200-first.csv"

resultsFolder = f"{folderMOADumps}"
csvFile = f"parsed_csvs/{wantedCSVfilename}"
directory = os.fsencode(resultsFolder)
header_printed = False

with open(f"{csvFile}", "w+") as output:
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.startswith("dump-"): 
            output.write(f"{parse(f'{os.fsdecode(directory)}/{filename}')}\n")

dfmblf = load_df(f'{csvFile}')
dfmblf = add_label_column_df(dfmblf)
dfmblf = dfmblf.loc[dfmblf.batch_size == 50]
dfmblf['batch_size'] = 'MB-LF'
display(dfmblf)
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
# /var/folders/bq/x5n78dm15dz0whvgzf_nj9j80000gp/T/ipykernel_72846/3478987594.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
#         dataset  algorithm  ensemble_size  cores batch_size  rate  instances  \
# 0   elecNormNew       OBMB             25      4      MB-LF     1  45,312.00
# 1      airlines       OBMB             25      4      MB-LF     1 539,383.00
# 2          GMSC      SRPMB             25      4      MB-LF     1 150,000.00
# 3          GMSC      ARFMB             25      4      MB-LF     1 150,000.00
# 4   elecNormNew   OBASHTMB             25      4      MB-LF     1  45,312.00
# 5          GMSC       OBMB             25      4      MB-LF     1 150,000.00
# 6   elecNormNew  OBAdwinMB             25      4      MB-LF     1  45,312.00
# 7      airlines      ARFMB             25      4      MB-LF     1 539,383.00
# 8      airlines      SRPMB             25      4      MB-LF     1 539,383.00
# 9      airlines     LBagMB             25      4      MB-LF     1 539,383.00
# 10  elecNormNew      ARFMB             25      4      MB-LF     1  45,312.00
# 11  covtypeNorm   OBASHTMB             25      4      MB-LF     1 581,012.00
# 12  covtypeNorm      ARFMB             25      4      MB-LF     1 581,012.00
# 13     airlines  OBAdwinMB             25      4      MB-LF     1 539,383.00
# 14  covtypeNorm      SRPMB             25      4      MB-LF     1 581,012.00
# 15         GMSC  OBAdwinMB             25      4      MB-LF     1 150,000.00
# 16  elecNormNew      SRPMB             25      4      MB-LF     1  45,312.00
# 17         GMSC   OBASHTMB             25      4      MB-LF     1 150,000.00
# 18  elecNormNew     LBagMB             25      4      MB-LF     1  45,312.00
# 19  covtypeNorm       OBMB             25      4      MB-LF     1 581,012.00
# 20         GMSC     LBagMB             25      4      MB-LF     1 150,000.00
# 21     airlines   OBASHTMB             25      4      MB-LF     1 539,383.00
# 22  covtypeNorm     LBagMB             25      4      MB-LF     1 581,012.00
# 23  covtypeNorm  OBAdwinMB             25      4      MB-LF     1 581,012.00
#
#        time   acc  prec  recall    change  label
# 0     10.74 78.41 79.05   76.55      0.00  50.00
# 1    112.33 60.43 60.80   57.43      0.00  50.00
# 2    176.57 93.53 80.43   52.99      0.00  50.00
# 3     98.83 93.55 77.35   54.72      0.00  50.00
# 4     10.85 76.35 78.97   73.42      0.00  50.00
# 5     21.77 93.39 74.83   52.57      0.00  50.00
# 6     19.52 85.96 86.33   84.87      0.00  50.00
# 7  2,679.95 66.22 65.82   65.11      0.00  50.00
# 8  2,703.51 67.73 67.48   66.53      0.00  50.00
# 9  3,001.13 64.00 63.54   62.60 10,746.00  50.00
# 10    49.64 88.87 88.87   88.28      0.00  50.00
# 11   198.36 77.29 74.79   59.67      0.00  50.00
# 12   735.90 92.42 89.42   81.56      0.00  50.00
# 13   967.10 87.46 87.91   86.79      0.00  50.00
# 14 2,687.39 95.55 93.08   90.41      0.00  50.00
# 15    40.96 93.50 83.07   52.16      0.00  50.00
# 16   116.60 89.82 89.84   89.28      0.00  50.00
# 17    20.41 93.31 70.80   51.02      0.00  50.00
# 18    35.79 90.63 90.65   90.11    902.00  50.00
# 19   195.05 75.76 74.90   53.19      0.00  50.00
# 20    83.49 93.34 72.62   52.47  2,768.00  50.00
# 21   161.61 62.00 63.94   58.74      0.00  50.00
# 22   965.29 91.86 85.29   85.33 11,604.00  50.00
# 23   594.36 86.62 80.49   85.85      0.00  50.00

# %%
def build_label(df):
    for index, row in df.iterrows():
        if ((row['algorithm'].find('Sequential') > 0 or row['batch_size'] == 1) and row['cores'] == 1):
            df.at[index, 'label'] = "S"
            
        if (row['cores'] == 4 and row['batch_size'] == 50):
            df.at[index, 'label'] = "MB"
            
        if (row['cores'] == 4 and row['batch_size'] == "MB-LF"):
            df.at[index, 'label'] = "MB-LF"

        if (row['algorithm'].find('RUNPER') > 0 and row['cores'] == 2 and row['frequency_maximum'] == "600"):
            df.at[index, 'label'] = "VFH2"
            
        if (row['algorithm'].find('RUNPER') > 0 and row['cores'] == 4 and row['frequency_maximum'] == "600"):
            df.at[index, 'label'] = "VFH4"

        if (row['algorithm'].find('RUNPER') > 0 and row['cores'] == 2 and row['frequency_maximum'] == "1200"):
            df.at[index, 'label'] = "CL2"

        if (row['algorithm'].find('RUNPER') > 0 and row['cores'] == 4 and row['frequency_maximum'] == "1200"):
            df.at[index, 'label'] = "CL4"

    return df

# %%
# pega execução sequencial e bota em um novo dataframe
df_sequential = dvf4.loc[(dvf4.cores == 1) & (dvf4.batch_size == 1)]

dvh2 = dvh2.drop(dvh2[(dvh2.cores == 1) & (dvh2.batch_size == 1)].index) # rodado
dvh2['frequency_maximum'] = "600"
dvh4 = dvh4.drop(dvh4[(dvh4.cores == 1) & (dvh4.batch_size == 1)].index) # rodado
dvh4['frequency_maximum'] = "600"

dvf2 = dvf2.drop(dvf2[(dvf2.cores == 1) & (dvf2.batch_size == 1)].index) # rodado
dvf2['frequency_maximum'] = "1200"
dvf4 = dvf4.drop(dvf4[(dvf4.cores == 1) & (dvf4.batch_size == 1)].index) # rodado
dvf4['frequency_maximum'] = "1200"

# remove mb nao utilizados
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 1].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 25].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 75].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 100].index)

df = pd.concat([df_sequential, dvh2, dvh4, dvf2, dvf4, df_mb, dfmblf])
df = build_label(df.reset_index())

df_mapping = pd.DataFrame({
    'label': ['S', 'VFH2', 'VFH4', 'CL2', 'CL4', 'MB', 'MB-LF'],
})
sort_mapping = df_mapping.reset_index().set_index('label')
df['label_num'] = df['label'].map(sort_mapping['index'])

df = df.drop_duplicates().sort_values('label_num')

# %%
#false makes the chart without markers
gen_chart(df, False, True)
# Out:
#      index   dataset  algorithm  ensemble_size  cores batch_size  rate  \
# 23      23  airlines  ARFRUNPER             25      2          1     1
# 47      47  airlines  ARFRUNPER             25      4          1     1
# 71      23  airlines  ARFRUNPER             25      2          1     1
# 95      47  airlines  ARFRUNPER             25      4          1     1
# 103     50  airlines      ARFMB             25      4         50     1
# 127      7  airlines      ARFMB             25      4      MB-LF     1
#
#      instances     time   acc  prec  recall  change  label frequency_maximum  \
# 23  117,740.00 1,804.70 67.34 63.08   61.31    0.00   VFH2               600
# 47  127,060.00 1,518.05 67.87 63.12   61.18    0.00   VFH4               600
# 71  198,090.00 1,543.04 67.74 63.37   61.35    0.00    CL2              1200
# 95  205,950.00 1,316.98 67.59 63.74   61.85    0.00    CL4              1200
# 103 539,383.00 2,777.55 66.07 65.66   64.94    0.00     MB               NaN
# 127 539,383.00 2,679.95 66.22 65.82   65.11    0.00  MB-LF               NaN
#
#      label_num
# 23           1
# 47           2
# 71           3
# 95           4
# 103          5
# 127          6
#      index   dataset   algorithm  ensemble_size  cores batch_size  rate  \
# 2        2  airlines  LBagRUNPER             25      2          1     1
# 30      10  airlines  LBagRUNPER             25      4          1     1
# 50       2  airlines  LBagRUNPER             25      2          1     1
# 78      10  airlines  LBagRUNPER             25      4          1     1
# 105     57  airlines      LBagMB             25      4         50     1
# 129      9  airlines      LBagMB             25      4      MB-LF     1
#
#      instances     time   acc  prec  recall    change  label  \
# 2   134,060.00 2,323.56 65.80 59.94   57.65    747.00   VFH2
# 30  158,390.00 1,982.61 65.75 59.97   57.70    891.00   VFH4
# 50  209,130.00 1,860.20 65.32 60.49   58.24  1,219.00    CL2
# 78  249,690.00 1,645.04 64.75 60.98   58.96  1,415.00    CL4
# 105 539,383.00 3,012.40 63.77 63.30   62.38 10,746.00     MB
# 129 539,383.00 3,001.13 64.00 63.54   62.60 10,746.00  MB-LF
#
#     frequency_maximum  label_num
# 2                 600          1
# 30                600          2
# 50               1200          3
# 78               1200          4
# 105               NaN          5
# 129               NaN          6
#      index   dataset  algorithm  ensemble_size  cores batch_size  rate  \
# 22      22  airlines  SRPRUNPER             25      2          1     1
# 46      46  airlines  SRPRUNPER             25      4          1     1
# 70      22  airlines  SRPRUNPER             25      2          1     1
# 94      46  airlines  SRPRUNPER             25      4          1     1
# 104     56  airlines      SRPMB             25      4         50     1
# 128      8  airlines      SRPMB             25      4      MB-LF     1
#
#      instances     time   acc  prec  recall  change  label frequency_maximum  \
# 22   84,080.00 1,419.33 69.27 66.05   61.88    0.00   VFH2               600
# 46   89,510.00 1,154.71 69.29 65.93   61.74    0.00   VFH4               600
# 70  139,480.00 1,149.26 70.04 66.25   61.04    0.00    CL2              1200
# 94  153,190.00   987.40 69.77 65.96   61.13    0.00    CL4              1200
# 104  20,950.00   120.15 67.18 66.19   64.69    0.00     MB               NaN
# 128 539,383.00 2,703.51 67.73 67.48   66.53    0.00  MB-LF               NaN
#
#      label_num
# 22           1
# 46           2
# 70           3
# 94           4
# 104          5
# 128          6
#      index   dataset      algorithm  ensemble_size  cores batch_size  rate  \
# 16      16  airlines  OBAdwinRUNPER             25      2          1     1
# 44      39  airlines  OBAdwinRUNPER             25      4          1     1
# 64      16  airlines  OBAdwinRUNPER             25      2          1     1
# 92      39  airlines  OBAdwinRUNPER             25      4          1     1
# 109     75  airlines      OBAdwinMB             25      4         50     1
# 133     13  airlines      OBAdwinMB             25      4      MB-LF     1
#
#      instances     time   acc  prec  recall  change  label frequency_maximum  \
# 16  142,320.00 1,372.70 68.45 63.41   59.52    0.00   VFH2               600
# 44  159,860.00 1,211.21 68.36 63.65   59.72    0.00   VFH4               600
# 64  230,750.00 1,151.24 67.48 64.40   61.34    0.00    CL2              1200
# 92  243,500.00 1,063.96 67.28 64.28   61.41    0.00    CL4              1200
# 109 539,383.00 1,013.27 67.12 67.06   65.63    0.00     MB               NaN
# 133 539,383.00   967.10 87.46 87.91   86.79    0.00  MB-LF               NaN
#
#      label_num
# 16           1
# 44           2
# 64           3
# 92           4
# 109          5
# 133          6
#      index   dataset     algorithm  ensemble_size  cores batch_size  rate  \
# 19      19  airlines  OBASHTRUNPER             25      2          1     1
# 38      27  airlines  OBASHTRUNPER             25      4          1     1
# 67      19  airlines  OBASHTRUNPER             25      2          1     1
# 86      27  airlines  OBASHTRUNPER             25      4          1     1
# 117    133  airlines      OBASHTMB             25      4         50     1
# 141     21  airlines      OBASHTMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 19  174,350.00 741.16 68.71 64.65   61.49    0.00   VFH2               600
# 38  185,800.00 666.59 68.87 64.75   61.46    0.00   VFH4               600
# 67  285,220.00 578.64 67.49 65.93   62.16    0.00    CL2              1200
# 86  313,820.00 565.36 67.10 66.27   62.53    0.00    CL4              1200
# 117 539,383.00 357.23 66.23 67.39   63.89    0.00     MB               NaN
# 141 539,383.00 161.61 62.00 63.94   58.74    0.00  MB-LF               NaN
#
#      label_num
# 19           1
# 38           2
# 67           3
# 86           4
# 117          5
# 141          6
#      index   dataset algorithm  ensemble_size  cores batch_size  rate  \
# 11      11  airlines  OBRUNPER             25      2          1     1
# 35      23  airlines  OBRUNPER             25      4          1     1
# 59      11  airlines  OBRUNPER             25      2          1     1
# 83      23  airlines  OBRUNPER             25      4          1     1
# 97       4  airlines      OBMB             25      4         50     1
# 121      1  airlines      OBMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 11  201,870.00 542.95 67.23 62.89   60.47    0.00   VFH2               600
# 35  193,670.00 425.38 67.73 63.08   60.69    0.00   VFH4               600
# 59  358,570.00 431.03 65.63 64.90   61.82    0.00    CL2              1200
# 83  302,370.00 375.38 65.94 64.33   61.16    0.00    CL4              1200
# 97  539,383.00 298.32 65.05 65.89   62.70    0.00     MB               NaN
# 121 539,383.00 112.33 60.43 60.80   57.43    0.00  MB-LF               NaN
#
#      label_num
# 11           1
# 35           2
# 59           3
# 83           4
# 97           5
# 121          6
#      index dataset  algorithm  ensemble_size  cores batch_size  rate  \
# 1        1    GMSC  ARFRUNPER             25      2          1     1
# 29       8    GMSC  ARFRUNPER             25      4          1     1
# 49       1    GMSC  ARFRUNPER             25      2          1     1
# 77       8    GMSC  ARFRUNPER             25      4          1     1
# 99      26    GMSC      ARFMB             25      4         50     1
# 123      3    GMSC      ARFMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 1   135,990.00 413.47 93.55 76.65   54.29    0.00   VFH2               600
# 29  150,000.00 383.78 93.52 76.94   54.40    0.00   VFH4               600
# 49  150,000.00 253.10 93.52 76.94   54.40    0.00    CL2              1200
# 77  150,000.00 214.08 93.52 76.94   54.40    0.00    CL4              1200
# 99  150,000.00 134.90 93.52 76.85   54.33    0.00     MB               NaN
# 123 150,000.00  98.83 93.55 77.35   54.72    0.00  MB-LF               NaN
#
#      label_num
# 1            1
# 29           2
# 49           3
# 77           4
# 99           5
# 123          6
#      index dataset   algorithm  ensemble_size  cores batch_size  rate  \
# 20      20    GMSC  LBagRUNPER             25      2          1     1
# 40      31    GMSC  LBagRUNPER             25      4          1     1
# 68      20    GMSC  LBagRUNPER             25      2          1     1
# 88      31    GMSC  LBagRUNPER             25      4          1     1
# 116    129    GMSC      LBagMB             25      4         50     1
# 140     20    GMSC      LBagMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall   change  label frequency_maximum  \
# 20  150,000.00 359.13 93.54 76.36   55.40     4.00   VFH2               600
# 40  150,000.00 301.92 93.54 76.36   55.40     4.00   VFH4               600
# 68  150,000.00 193.68 93.54 76.36   55.40     4.00    CL2              1200
# 88  150,000.00 165.85 93.54 76.36   55.40     4.00    CL4              1200
# 116 150,000.00  95.88 93.47 75.95   53.88 1,058.00     MB               NaN
# 140 150,000.00  83.49 93.34 72.62   52.47 2,768.00  MB-LF               NaN
#
#      label_num
# 20           1
# 40           2
# 68           3
# 88           4
# 116          5
# 140          6
#      index dataset  algorithm  ensemble_size  cores batch_size  rate  \
# 21      21    GMSC  SRPRUNPER             25      2          1     1
# 41      32    GMSC  SRPRUNPER             25      4          1     1
# 69      21    GMSC  SRPRUNPER             25      2          1     1
# 89      32    GMSC  SRPRUNPER             25      4          1     1
# 98      17    GMSC      SRPMB             25      4         50     1
# 122      2    GMSC      SRPMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 21   90,270.00 503.50 93.53 78.30   52.62    0.00   VFH2               600
# 41   94,140.00 458.38 93.54 78.62   52.69    0.00   VFH4               600
# 69  150,000.00 506.90 93.53 79.94   53.19    0.00    CL2              1200
# 89  150,000.00 448.14 93.53 79.94   53.19    0.00    CL4              1200
# 98  150,000.00 235.96 93.51 79.17   53.01    0.00     MB               NaN
# 122 150,000.00 176.57 93.53 80.43   52.99    0.00  MB-LF               NaN
#
#      label_num
# 21           1
# 41           2
# 69           3
# 89           4
# 98           5
# 122          6
#      index dataset      algorithm  ensemble_size  cores batch_size  rate  \
# 15      15    GMSC  OBAdwinRUNPER             25      2          1     1
# 43      36    GMSC  OBAdwinRUNPER             25      4          1     1
# 63      15    GMSC  OBAdwinRUNPER             25      2          1     1
# 91      36    GMSC  OBAdwinRUNPER             25      4          1     1
# 111     93    GMSC      OBAdwinMB             25      4         50     1
# 135     15    GMSC      OBAdwinMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 15  150,000.00 203.76 93.48 77.54   53.16    0.00   VFH2               600
# 43  150,000.00 161.10 93.48 77.54   53.16    0.00   VFH4               600
# 63  150,000.00 111.49 93.48 77.54   53.16    0.00    CL2              1200
# 91  150,000.00  85.51 93.48 77.54   53.16    0.00    CL4              1200
# 111 150,000.00  41.18 93.33 73.71   50.66    0.00     MB               NaN
# 135 150,000.00  40.96 93.50 83.07   52.16    0.00  MB-LF               NaN
#
#      label_num
# 15           1
# 43           2
# 63           3
# 91           4
# 111          5
# 135          6
#      index dataset     algorithm  ensemble_size  cores batch_size  rate  \
# 9        9    GMSC  OBASHTRUNPER             25      2          1     1
# 33      19    GMSC  OBASHTRUNPER             25      4          1     1
# 57       9    GMSC  OBASHTRUNPER             25      2          1     1
# 81      19    GMSC  OBASHTRUNPER             25      4          1     1
# 113    110    GMSC      OBASHTMB             25      4         50     1
# 137     17    GMSC      OBASHTMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 9   150,000.00 166.18 93.40 76.96   51.81    0.00   VFH2               600
# 33  150,000.00 145.80 93.40 76.96   51.81    0.00   VFH4               600
# 57  150,000.00  90.33 93.40 76.96   51.81    0.00    CL2              1200
# 81  150,000.00  78.15 93.40 76.96   51.81    0.00    CL4              1200
# 113 150,000.00  36.88 93.39 78.43   51.20    0.00     MB               NaN
# 137 150,000.00  20.41 93.31 70.80   51.02    0.00  MB-LF               NaN
#
#      label_num
# 9            1
# 33           2
# 57           3
# 81           4
# 113          5
# 137          6
#      index dataset algorithm  ensemble_size  cores batch_size  rate  \
# 14      14    GMSC  OBRUNPER             25      2          1     1
# 42      34    GMSC  OBRUNPER             25      4          1     1
# 62      14    GMSC  OBRUNPER             25      2          1     1
# 90      34    GMSC  OBRUNPER             25      4          1     1
# 101     41    GMSC      OBMB             25      4         50     1
# 125      5    GMSC      OBMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 14  150,000.00 169.29 93.50 76.86   53.96    0.00   VFH2               600
# 42  150,000.00 149.46 93.50 76.86   53.96    0.00   VFH4               600
# 62  150,000.00  91.80 93.50 76.86   53.96    0.00    CL2              1200
# 90  150,000.00  81.15 93.50 76.86   53.96    0.00    CL4              1200
# 101 150,000.00  38.35 93.46 78.33   52.40    0.00     MB               NaN
# 125 150,000.00  21.77 93.39 74.83   52.57    0.00  MB-LF               NaN
#
#      label_num
# 14           1
# 42           2
# 62           3
# 90           4
# 101          5
# 125          6
#      index      dataset  algorithm  ensemble_size  cores batch_size  rate  \
# 8        8  elecNormNew  ARFRUNPER             25      2          1     1
# 27       6  elecNormNew  ARFRUNPER             25      4          1     1
# 56       8  elecNormNew  ARFRUNPER             25      2          1     1
# 75       6  elecNormNew  ARFRUNPER             25      4          1     1
# 106     64  elecNormNew      ARFMB             25      4         50     1
# 130     10  elecNormNew      ARFMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 8    45,312.00 216.68 88.82 88.79   88.26    0.00   VFH2               600
# 27   45,312.00 173.90 88.82 88.79   88.26    0.00   VFH4               600
# 56   45,312.00 116.13 88.82 88.79   88.26    0.00    CL2              1200
# 75   45,312.00 103.11 88.82 88.79   88.26    0.00    CL4              1200
# 106  45,312.00  58.68 80.19 79.98   79.20    0.00     MB               NaN
# 130  45,312.00  49.64 88.87 88.87   88.28    0.00  MB-LF               NaN
#
#      label_num
# 8            1
# 27           2
# 56           3
# 75           4
# 106          5
# 130          6
#      index      dataset   algorithm  ensemble_size  cores batch_size  rate  \
# 13      13  elecNormNew  LBagRUNPER             25      2          1     1
# 37      26  elecNormNew  LBagRUNPER             25      4          1     1
# 61      13  elecNormNew  LBagRUNPER             25      2          1     1
# 85      26  elecNormNew  LBagRUNPER             25      4          1     1
# 114    115  elecNormNew      LBagMB             25      4         50     1
# 138     18  elecNormNew      LBagMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 13   45,312.00 147.91 89.93 89.94   89.39  290.00   VFH2               600
# 37   45,312.00 123.36 89.93 89.94   89.39  290.00   VFH4               600
# 61   45,312.00  78.27 89.93 89.94   89.39  290.00    CL2              1200
# 85   45,312.00  65.77 89.93 89.94   89.39  290.00    CL4              1200
# 114  45,312.00  40.07 81.36 81.25   80.34  902.00     MB               NaN
# 138  45,312.00  35.79 90.63 90.65   90.11  902.00  MB-LF               NaN
#
#      label_num
# 13           1
# 37           2
# 61           3
# 85           4
# 114          5
# 138          6
#      index      dataset  algorithm  ensemble_size  cores batch_size  rate  \
# 3        3  elecNormNew  SRPRUNPER             25      2          1     1
# 31      12  elecNormNew  SRPRUNPER             25      4          1     1
# 51       3  elecNormNew  SRPRUNPER             25      2          1     1
# 79      12  elecNormNew  SRPRUNPER             25      4          1     1
# 112     95  elecNormNew      SRPMB             25      4         50     1
# 136     16  elecNormNew      SRPMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 3    45,312.00 409.81 89.76 89.78   89.20    0.00   VFH2               600
# 31   45,312.00 333.22 89.48 89.49   88.92    0.00   VFH4               600
# 51   45,312.00 219.36 89.76 89.78   89.20    0.00    CL2              1200
# 79   45,312.00 177.40 89.40 89.40   88.83    0.00    CL4              1200
# 112  45,312.00 116.15 81.20 81.17   80.09    0.00     MB               NaN
# 136  45,312.00 116.60 89.82 89.84   89.28    0.00  MB-LF               NaN
#
#      label_num
# 3            1
# 31           2
# 51           3
# 79           4
# 112          5
# 136          6
#      index      dataset      algorithm  ensemble_size  cores batch_size  rate  \
# 10      10  elecNormNew  OBAdwinRUNPER             25      2          1     1
# 34      20  elecNormNew  OBAdwinRUNPER             25      4          1     1
# 58      10  elecNormNew  OBAdwinRUNPER             25      2          1     1
# 82      20  elecNormNew  OBAdwinRUNPER             25      4          1     1
# 102     47  elecNormNew      OBAdwinMB             25      4         50     1
# 126      6  elecNormNew      OBAdwinMB             25      4      MB-LF     1
#
#      instances  time   acc  prec  recall  change  label frequency_maximum  \
# 10   45,312.00 90.50 86.19 86.28   85.34    0.00   VFH2               600
# 34   45,312.00 73.19 86.19 86.28   85.34    0.00   VFH4               600
# 58   45,312.00 49.19 86.19 86.28   85.34    0.00    CL2              1200
# 82   45,312.00 39.25 86.19 86.28   85.34    0.00    CL4              1200
# 102  45,312.00 21.12 80.02 80.04   78.75    0.00     MB               NaN
# 126  45,312.00 19.52 85.96 86.33   84.87    0.00  MB-LF               NaN
#
#      label_num
# 10           1
# 34           2
# 58           3
# 82           4
# 102          5
# 126          6
#      index      dataset     algorithm  ensemble_size  cores batch_size  rate  \
# 5        5  elecNormNew  OBASHTRUNPER             25      2          1     1
# 24       0  elecNormNew  OBASHTRUNPER             25      4          1     1
# 53       5  elecNormNew  OBASHTRUNPER             25      2          1     1
# 72       0  elecNormNew  OBASHTRUNPER             25      4          1     1
# 100     34  elecNormNew      OBASHTMB             25      4         50     1
# 124      4  elecNormNew      OBASHTMB             25      4      MB-LF     1
#
#      instances  time   acc  prec  recall  change  label frequency_maximum  \
# 5    45,312.00 70.94 83.36 83.12   82.67    0.00   VFH2               600
# 24   45,312.00 63.13 83.36 83.12   82.67    0.00   VFH4               600
# 53   45,312.00 40.19 83.36 83.12   82.67    0.00    CL2              1200
# 72   45,312.00 33.65 83.36 83.12   82.67    0.00    CL4              1200
# 100  45,312.00 16.71 79.59 79.32   78.63    0.00     MB               NaN
# 124  45,312.00 10.85 76.35 78.97   73.42    0.00  MB-LF               NaN
#
#      label_num
# 5            1
# 24           2
# 53           3
# 72           4
# 100          5
# 124          6
#      index      dataset algorithm  ensemble_size  cores batch_size  rate  \
# 18      18  elecNormNew  OBRUNPER             25      2          1     1
# 39      28  elecNormNew  OBRUNPER             25      4          1     1
# 66      18  elecNormNew  OBRUNPER             25      2          1     1
# 87      28  elecNormNew  OBRUNPER             25      4          1     1
# 96       3  elecNormNew      OBMB             25      4         50     1
# 120      0  elecNormNew      OBMB             25      4      MB-LF     1
#
#      instances  time   acc  prec  recall  change  label frequency_maximum  \
# 18   45,312.00 69.31 82.30 81.93   81.79    0.00   VFH2               600
# 39   45,312.00 60.58 82.30 81.93   81.79    0.00   VFH4               600
# 66   45,312.00 37.65 82.30 81.93   81.79    0.00    CL2              1200
# 87   45,312.00 32.62 82.30 81.93   81.79    0.00    CL4              1200
# 96   45,312.00 17.59 78.77 78.41   77.88    0.00     MB               NaN
# 120  45,312.00 10.74 78.41 79.05   76.55    0.00  MB-LF               NaN
#
#      label_num
# 18           1
# 39           2
# 66           3
# 87           4
# 96           5
# 120          6
#      index      dataset  algorithm  ensemble_size  cores batch_size  rate  \
# 7        7  covtypeNorm  ARFRUNPER             25      2          1     1
# 26       5  covtypeNorm  ARFRUNPER             25      4          1     1
# 55       7  covtypeNorm  ARFRUNPER             25      2          1     1
# 74       5  covtypeNorm  ARFRUNPER             25      4          1     1
# 108     72  covtypeNorm      ARFMB             25      4         50     1
# 132     12  covtypeNorm      ARFMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 7    77,040.00 433.24 90.10 82.28   81.51    0.00   VFH2               600
# 26   72,950.00 369.47 90.04 82.27   81.59    0.00   VFH4               600
# 55  138,660.00 407.86 91.36 82.39   79.84    0.00    CL2              1200
# 74  152,860.00 380.52 91.49 82.46   79.54    0.00    CL4              1200
# 108  70,800.00 120.17 87.84 78.55   76.33    0.00     MB               NaN
# 132 581,012.00 735.90 92.42 89.42   81.56    0.00  MB-LF               NaN
#
#      label_num
# 7            1
# 26           2
# 55           3
# 74           4
# 108          5
# 132          6
#      index      dataset   algorithm  ensemble_size  cores batch_size  rate  \
# 12      12  covtypeNorm  LBagRUNPER             25      2          1     1
# 36      24  covtypeNorm  LBagRUNPER             25      4          1     1
# 60      12  covtypeNorm  LBagRUNPER             25      2          1     1
# 84      24  covtypeNorm  LBagRUNPER             25      4          1     1
# 118    139  covtypeNorm      LBagMB             25      4         50     1
# 142     22  covtypeNorm      LBagMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall    change  label frequency_maximum  \
# 12   62,720.00 478.47 90.77 82.60   82.34    393.00   VFH2               600
# 36   63,300.00 420.76 90.76 82.59   82.32    402.00   VFH4               600
# 60  134,090.00 515.73 93.17 82.81   82.15    659.00    CL2              1200
# 84  136,800.00 465.33 93.24 82.86   82.09    664.00    CL4              1200
# 118  53,650.00 120.00 88.06 79.93   78.01  1,056.00     MB               NaN
# 142 581,012.00 965.29 91.86 85.29   85.33 11,604.00  MB-LF               NaN
#
#      label_num
# 12           1
# 36           2
# 60           3
# 84           4
# 118          5
# 142          6
#      index      dataset  algorithm  ensemble_size  cores batch_size  rate  \
# 6        6  covtypeNorm  SRPRUNPER             25      2          1     1
# 25       1  covtypeNorm  SRPRUNPER             25      4          1     1
# 54       6  covtypeNorm  SRPRUNPER             25      2          1     1
# 73       1  covtypeNorm  SRPRUNPER             25      4          1     1
# 110     89  covtypeNorm      SRPMB             25      4         50     1
# 134     14  covtypeNorm      SRPMB             25      4      MB-LF     1
#
#      instances     time   acc  prec  recall  change  label frequency_maximum  \
# 6    29,640.00   578.15 88.36 85.72   85.76    0.00   VFH2               600
# 25   30,010.00   509.26 88.41 85.79   85.65    0.00   VFH4               600
# 54   62,340.00   584.13 93.19 87.49   87.34    0.00    CL2              1200
# 73   62,730.00   521.48 93.08 87.61   87.40    0.00    CL4              1200
# 110  16,850.00   120.20 76.94 77.91   77.16    0.00     MB               NaN
# 134 581,012.00 2,687.39 95.55 93.08   90.41    0.00  MB-LF               NaN
#
#      label_num
# 6            1
# 25           2
# 54           3
# 73           4
# 110          5
# 134          6
#      index      dataset      algorithm  ensemble_size  cores batch_size  rate  \
# 0        0  covtypeNorm  OBAdwinRUNPER             25      2          1     1
# 28       7  covtypeNorm  OBAdwinRUNPER             25      4          1     1
# 48       0  covtypeNorm  OBAdwinRUNPER             25      2          1     1
# 76       7  covtypeNorm  OBAdwinRUNPER             25      4          1     1
# 119    142  covtypeNorm      OBAdwinMB             25      4         50     1
# 143     23  covtypeNorm      OBAdwinMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 0    59,740.00 344.72 87.21 80.66   80.34    0.00   VFH2               600
# 28   54,990.00 271.00 86.78 80.42   80.25    0.00   VFH4               600
# 48  119,180.00 332.59 89.10 80.73   79.82    0.00    CL2              1200
# 76  115,970.00 275.25 89.21 80.78   79.97    0.00    CL4              1200
# 119  74,250.00 120.01 84.42 76.28   74.15    0.00     MB               NaN
# 143 581,012.00 594.36 86.62 80.49   85.85    0.00  MB-LF               NaN
#
#      label_num
# 0            1
# 28           2
# 48           3
# 76           4
# 119          5
# 143          6
#      index      dataset     algorithm  ensemble_size  cores batch_size  rate  \
# 4        4  covtypeNorm  OBASHTRUNPER             25      2          1     1
# 32      13  covtypeNorm  OBASHTRUNPER             25      4          1     1
# 52       4  covtypeNorm  OBASHTRUNPER             25      2          1     1
# 80      13  covtypeNorm  OBASHTRUNPER             25      4          1     1
# 107     65  covtypeNorm      OBASHTMB             25      4         50     1
# 131     11  covtypeNorm      OBASHTMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 4    37,580.00 235.19 75.73 68.55   71.45    0.00   VFH2               600
# 32   32,820.00 188.01 74.23 68.11   71.28    0.00   VFH4               600
# 52  103,930.00 275.06 86.94 72.21   74.67    0.00    CL2              1200
# 80   97,330.00 225.65 86.46 72.01   74.62    0.00    CL4              1200
# 107  83,500.00 120.00 82.35 69.14   71.11    0.00     MB               NaN
# 131 581,012.00 198.36 77.29 74.79   59.67    0.00  MB-LF               NaN
#
#      label_num
# 4            1
# 32           2
# 52           3
# 80           4
# 107          5
# 131          6
#      index      dataset algorithm  ensemble_size  cores batch_size  rate  \
# 17      17  covtypeNorm  OBRUNPER             25      2          1     1
# 45      40  covtypeNorm  OBRUNPER             25      4          1     1
# 65      17  covtypeNorm  OBRUNPER             25      2          1     1
# 93      40  covtypeNorm  OBRUNPER             25      4          1     1
# 115    126  covtypeNorm      OBMB             25      4         50     1
# 139     19  covtypeNorm      OBMB             25      4      MB-LF     1
#
#      instances   time   acc  prec  recall  change  label frequency_maximum  \
# 17   35,750.00 231.35 74.84 68.15   71.19    0.00   VFH2               600
# 45   31,410.00 187.31 73.51 67.88   71.19    0.00   VFH4               600
# 65  104,410.00 274.50 86.78 72.11   74.37    0.00    CL2              1200
# 93   95,800.00 220.53 86.11 71.86   74.39    0.00    CL4              1200
# 115  86,950.00 120.02 82.70 69.29   70.95    0.00     MB               NaN
# 139 581,012.00 195.05 75.76 74.90   53.19    0.00  MB-LF               NaN
#
#      label_num
# 17           1
# 45           2
# 65           3
# 93           4
# 115          5
# 139          6
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# pega execução sequencial e bota em um novo dataframe
df_sequential = dvf4.loc[(dvf4.cores == 1) & (dvf4.batch_size == 1)]

dvh2 = dvh2.drop(dvh2[(dvh2.cores == 1) & (dvh2.batch_size == 1)].index) # rodado
dvh2['frequency_maximum'] = "600"
dvh4 = dvh4.drop(dvh4[(dvh4.cores == 1) & (dvh4.batch_size == 1)].index) # rodado
dvh4['frequency_maximum'] = "600"

dvf2 = dvf2.drop(dvf2[(dvf2.cores == 1) & (dvf2.batch_size == 1)].index) # a rodar
dvf2['frequency_maximum'] = "1200"
dvf4 = dvf4.drop(dvf4[(dvf4.cores == 1) & (dvf4.batch_size == 1)].index) # rodado
dvf4['frequency_maximum'] = "1200"

# remove mb nao utilizados
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 1].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 25].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 75].index)
df_mb = df_mb.drop(df_mb[df_mb.batch_size == 100].index)

df = pd.concat([df_sequential, dvh2, dvh4, dvf2, dvf4, df_mb])
df = build_label(df.reset_index())

df_mapping = pd.DataFrame({
    'label': ['S', 'VFH2', 'VFH4', 'CL2', 'CL4', 'MB'],
})
sort_mapping = df_mapping.reset_index().set_index('label')
df['label_num'] = df['label'].map(sort_mapping['index'])

df = df.drop_duplicates().sort_values('label_num')

# %%
#false makes the chart without markers
gen_chart(df, False)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
