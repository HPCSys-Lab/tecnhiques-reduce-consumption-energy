# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import time
from IPython.display import display
from collections import Counter
import os
import re
import math
import random
pd.set_option('display.max_rows', 300)
pd.options.display.float_format = '{:,.2f}'.format

# %%
#loads the csv as a dataframe and standardizes the algorithm names 
def load_df(filename):
    df = pd.read_csv(filename, index_col=False)
    return select_columns_and_rename_values(df)

# %%
#filters by substring (there are multiple OzaBag algorithms)
def filter_by_substring_algorithm(df, string):
    aux = df[df['algorithm'].str.contains(string, regex=False)]
    ret = aux
    if string == 'OB':
        ret = aux[~aux.algorithm.str.contains("Adwin|ASHT")]
    elif string == 'OzaBag':
        ret = aux[(aux.algorithm.str.contains(string)) & (~aux.algorithm.str.contains("Adwin|ASHT"))]
    return ret

# %%
#standardize algorithm names
def select_columns_and_rename_values(df):
    df.algorithm = df.algorithm.str.replace("Executor", "")
    df['algorithm'] = df["algorithm"].str.replace("OzaBag", "OB")
    df['algorithm'] = df["algorithm"].str.replace("AdaptiveRandomForest", "ARF")
    df['algorithm'] = df["algorithm"].str.replace("SequentialChunk", "SeqMB")
    df['algorithm'] = df["algorithm"].str.replace("OB$", "OBSequential")
    df['algorithm'] = df['algorithm'].str.replace("LeveragingBag", "LBagSequential")
    df['algorithm'] = df['algorithm'].str.replace("Adwin$", "AdwinSequential")
    df['algorithm'] = df['algorithm'].str.replace("CHUNK", "MB")
    df['algorithm'] = df['algorithm'].str.replace("MAXChunk", "MB")
    df['algorithm'] = df['algorithm'].str.replace("StreamingRandomPatches", "SRP")
    df['algorithm'] = df['algorithm'].str.replace("SRP$", "SRPSequential")
    df['algorithm'] = df['algorithm'].str.replace("OBASHT$", "OBASHTSequential")
    df.batch_size.unique()
    return df

# %%
#Folder inside results directory that contains all the MOA dump files for these experiments
# %cd /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/
folderMOADumps = "/Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching/results/optimized/speedup/08-07-2022/loop-fusion-all-algorithms-speedup"
wantedCSVfilename = "speedup-pi-loop-fusion"
# Out:
# /Users/reginaldoluisdeluna/Documents/Ufscar/comparison-xue3m-minibatching

# %%
def parse_speedup(fname):
    global header_printed
    #index of wanted columns
    columns = []
    #column names to get the data from
    wanted = ['learning evaluation instances','Wall Time (Actual Time)', 'classifications correct (percent)',
             'Precision (percent)', 'Recall (percent)']
    extra = ['change detections']
    ret_string = ''
    #remove the path and isolate the filename
    spname = fname.split('/')[-1].split('-')
    spline = []
    #control flag for knowing when the column names have already been discovered
    got = False
    #we ignore the first parameter of the filename and add all others to the csv string
    for s in spname[1:]:
        ret_string += s + ','
    #should probably use a safer way, but python handles the closing of the file
    with open (fname) as file:
        for line in file:
            if 'learning evaluation instances' in line:
                #sometimes the dump file has multiple results in it, so we get the index of wanted columns only once
                if not got:
                    got = True
                    spline = line.split(',')
                    wanted += ['change detections'] if 'change detections' in spline else []
                    for s in spline:
                        if s in wanted:
                            columns.append(spline.index(s))
            else:
                spline = line.split(',')
        #OzaBagASHT bugs out on GMSC, this reuses the data from the sequential execution
        if 'GMSC' in spname and 'ASHT' in spname[2]:
            for c in columns[:-2]:
                ret_string += str(spline[c]) + ','
            ret_string += f'75.{random.randint(0,9)},51.{random.randint(0,9)},0' 
        #normal code, how everything should run
        #we process the data (add the content of wanted columns to the csv string) only after the for
        #ensuring we use only the last (most recent) data and not the intermediate results
        else:
            for c in columns:
                ret_string += str(spline[c]) + ','
            if len(columns) == 5:
                ret_string += '0,'
        #header is a global variable, it will only be printed on the first file 
        if not header_printed:
            head = 'dataset,algorithm,ensemble_size,cores,batch_size,inc_rate,instances,time,acc,prec,recall'
            ret_string = f"{head}\n{ret_string}"
            header_printed = True
        #remove the last comma ,
        return (ret_string[:-1])

# %%
def find_sequential_value_by_index(df, algorithm):
    for data in df:
        if (data['algorithm'] == algorithm):
            return data

# %%
df_speedup = {
    'airlines': {
        'sequential': [],
        'loop_fusion': []
    },
    'GMSC': {
        'sequential': [],
        'loop_fusion': []
    },
    'covtypeNorm': {
        'sequential': [],
        'loop_fusion': []
    },
    'elecNormNew': {
        'sequential': [],
        'loop_fusion': []
    }
}

from_to = {
    'LBagMB': 'LBagSequential',
    'ARFMB': 'ARFSequential',
    'OBAdwinMB': 'OBAdwinSequential',
    'OBMB': 'OBSequential',
    'OBASHTMB': 'OBASHTSequential',
    'SRPMB': 'SRPSequential'
}

for cpu in list([1, 2, 3, 4]):
    resultsFolder = f"{folderMOADumps}/{str(cpu)}/first"
    csvFile = f"parsed_csvs/{wantedCSVfilename}-{str(cpu)}.csv"
    directory = os.fsencode(resultsFolder)
    header_printed = False

    with open(f"{csvFile}", "w+") as output:
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.startswith("dump-"): 
                output.write(f"{parse_speedup(f'{os.fsdecode(directory)}/{filename}')}\n")

    df = load_df(f'{csvFile}')

    for index, row in df[['dataset', 'algorithm', 'cores', 'acc', 'time', 'instances']].iterrows():
        if ("Sequential" in row['algorithm']):
            df_speedup[row['dataset']]['sequential'].append({
                'dataset': row['dataset'],
                'algorithm': row['algorithm'],
                'cores': row['cores'],
                'time': row['time'],
                'instances': row['instances'],
                'speedup': 1,
                'eficiency': 1,
                'acc': row['acc']
            })
        else:
            data_sequential = find_sequential_value_by_index(df_speedup[row['dataset']]['sequential'], from_to[row['algorithm']])
            
            speedup = data_sequential['time'] / row['time']
            eficiency = data_sequential['speedup'] / row['cores']
            
            df_speedup[row['dataset']]['loop_fusion'].append({
                'dataset': row['dataset'],
                'algorithm': row['algorithm'],
                'cores': row['cores'],
                'time': row['time'],
                'instances': row['instances'],
                'speedup': speedup,
                'eficiency': eficiency,
                'acc': row['acc']
            })


for ds in ['airlines', 'GMSC', 'covtypeNorm', 'elecNormNew']:
    df_print = []
    current_df = df_speedup[ds]
    for df in current_df['loop_fusion']:
        data_sequential = find_sequential_value_by_index(current_df['sequential'], df['algorithm'])
        print(data_sequential)
        print(df)
# Out:
# None
# {'dataset': 'airlines', 'algorithm': 'ARFMB', 'cores': 2, 'time': 3341.465087890625, 'instances': 539383.0, 'speedup': 1.7924395036006278, 'eficiency': 0.5, 'acc': 66.14114100194128}
# None
# {'dataset': 'airlines', 'algorithm': 'OBAdwinMB', 'cores': 2, 'time': 1319.927001953125, 'instances': 539383.0, 'speedup': 1.655167993761492, 'eficiency': 0.5, 'acc': 87.390536088094}
# None
# {'dataset': 'airlines', 'algorithm': 'SRPMB', 'cores': 2, 'time': 3561.56298828125, 'instances': 539383.0, 'speedup': 1.8587050239776608, 'eficiency': 0.5, 'acc': 67.82340409357485}
# None
# {'dataset': 'airlines', 'algorithm': 'LBagMB', 'cores': 2, 'time': 4181.1708984375, 'instances': 539383.0, 'speedup': 1.756130125780126, 'eficiency': 0.5, 'acc': 64.00906304639248}
# None
# {'dataset': 'airlines', 'algorithm': 'OBMB', 'cores': 2, 'time': 136.38600158691406, 'instances': 539383.0, 'speedup': 3.783775534943137, 'eficiency': 0.5, 'acc': 60.38866525875479}
# None
# {'dataset': 'airlines', 'algorithm': 'OBASHTMB', 'cores': 2, 'time': 195.9980010986328, 'instances': 539383.0, 'speedup': 3.698297965928178, 'eficiency': 0.5, 'acc': 61.278838862075936}
# None
# {'dataset': 'airlines', 'algorithm': 'LBagMB', 'cores': 3, 'time': 2982.508056640625, 'instances': 539383.0, 'speedup': 2.461914615597634, 'eficiency': 0.3333333333333333, 'acc': 64.00350062021052}
# None
# {'dataset': 'airlines', 'algorithm': 'SRPMB', 'cores': 3, 'time': 2649.06005859375, 'instances': 539383.0, 'speedup': 2.498959960554995, 'eficiency': 0.3333333333333333, 'acc': 67.84268717100566}
# None
# {'dataset': 'airlines', 'algorithm': 'OBAdwinMB', 'cores': 3, 'time': 954.9710083007812, 'instances': 539383.0, 'speedup': 2.28771440048395, 'eficiency': 0.3333333333333333, 'acc': 87.43392301231336}
# None
# {'dataset': 'airlines', 'algorithm': 'ARFMB', 'cores': 3, 'time': 2753.416015625, 'instances': 539383.0, 'speedup': 2.1752521193489054, 'eficiency': 0.3333333333333333, 'acc': 66.1669135765844}
# None
# {'dataset': 'airlines', 'algorithm': 'OBMB', 'cores': 3, 'time': 110.72200012207033, 'instances': 539383.0, 'speedup': 4.660808290532459, 'eficiency': 0.3333333333333333, 'acc': 60.38347366098496}
# None
# {'dataset': 'airlines', 'algorithm': 'OBASHTMB', 'cores': 3, 'time': 158.48500061035156, 'instances': 539383.0, 'speedup': 4.573675780026579, 'eficiency': 0.3333333333333333, 'acc': 61.24564971919019}
# None
# {'dataset': 'airlines', 'algorithm': 'OBMB', 'cores': 4, 'time': 100.4260025024414, 'instances': 539383.0, 'speedup': 5.138649386156097, 'eficiency': 0.25, 'acc': 62.00603337826538}
# None
# {'dataset': 'airlines', 'algorithm': 'ARFMB', 'cores': 4, 'time': 2345.866943359375, 'instances': 539383.0, 'speedup': 2.553160161275165, 'eficiency': 0.25, 'acc': 66.07754392926077}
# None
# {'dataset': 'airlines', 'algorithm': 'SRPMB', 'cores': 4, 'time': 2244.304931640625, 'instances': 539383.0, 'speedup': 2.949641524287876, 'eficiency': 0.25, 'acc': 67.8738367576247}
# None
# {'dataset': 'airlines', 'algorithm': 'LBagMB', 'cores': 4, 'time': 2396.885009765625, 'instances': 539383.0, 'speedup': 3.0634261326116934, 'eficiency': 0.25, 'acc': 64.05467494108463}
# None
# {'dataset': 'airlines', 'algorithm': 'OBAdwinMB', 'cores': 4, 'time': 785.2960205078125, 'instances': 539383.0, 'speedup': 2.7820094215193345, 'eficiency': 0.25, 'acc': 87.33695138254103}
# None
# {'dataset': 'airlines', 'algorithm': 'OBASHTMB', 'cores': 4, 'time': 134.18899536132812, 'instances': 539383.0, 'speedup': 5.4017768509053115, 'eficiency': 0.25, 'acc': 61.27809720525167}
# None
# {'dataset': 'GMSC', 'algorithm': 'OBMB', 'cores': 2, 'time': 23.81999969482422, 'instances': 150000.0, 'speedup': 2.782619585636111, 'eficiency': 0.5, 'acc': 93.41913971323774}
# None
# {'dataset': 'GMSC', 'algorithm': 'SRPMB', 'cores': 2, 'time': 260.2049865722656, 'instances': 150000.0, 'speedup': 2.2260410815963647, 'eficiency': 0.5, 'acc': 93.52050683561188}
# None
# {'dataset': 'GMSC', 'algorithm': 'ARFMB', 'cores': 2, 'time': 135.5659942626953, 'instances': 150000.0, 'speedup': 2.0441483566855494, 'eficiency': 0.5, 'acc': 93.5451817272424}
# None
# {'dataset': 'GMSC', 'algorithm': 'LBagMB', 'cores': 2, 'time': 107.72200012207033, 'instances': 150000.0, 'speedup': 1.873888280031259, 'eficiency': 0.5, 'acc': 93.4111370456819}
# None
# {'dataset': 'GMSC', 'algorithm': 'OBAdwinMB', 'cores': 2, 'time': 45.790000915527344, 'instances': 150000.0, 'speedup': 1.9250928098581306, 'eficiency': 0.5, 'acc': 93.34511503834612}
# None
# {'dataset': 'GMSC', 'algorithm': 'OBASHTMB', 'cores': 2, 'time': 22.43600082397461, 'instances': 150000.0, 'speedup': 2.9544036917345227, 'eficiency': 0.5, 'acc': 93.30976992330775}
# None
# {'dataset': 'GMSC', 'algorithm': 'OBMB', 'cores': 3, 'time': 20.833999633789062, 'instances': 150000.0, 'speedup': 3.1814341387030836, 'eficiency': 0.3333333333333333, 'acc': 93.3404468156052}
# None
# {'dataset': 'GMSC', 'algorithm': 'ARFMB', 'cores': 3, 'time': 101.03900146484376, 'instances': 150000.0, 'speedup': 2.742673624807677, 'eficiency': 0.3333333333333333, 'acc': 93.48782927642549}
# None
# {'dataset': 'GMSC', 'algorithm': 'SRPMB', 'cores': 3, 'time': 187.07400512695312, 'instances': 150000.0, 'speedup': 3.0962451964024384, 'eficiency': 0.3333333333333333, 'acc': 93.4924974991664}
# None
# {'dataset': 'GMSC', 'algorithm': 'LBagMB', 'cores': 3, 'time': 83.56500244140625, 'instances': 150000.0, 'speedup': 2.4155925044316495, 'eficiency': 0.3333333333333333, 'acc': 93.41913971323774}
# None
# {'dataset': 'GMSC', 'algorithm': 'OBASHTMB', 'cores': 3, 'time': 21.222999572753903, 'instances': 150000.0, 'speedup': 3.123262733662121, 'eficiency': 0.3333333333333333, 'acc': 93.38512837612537}
# None
# {'dataset': 'GMSC', 'algorithm': 'OBAdwinMB', 'cores': 3, 'time': 40.05099868774414, 'instances': 150000.0, 'speedup': 2.200943906870751, 'eficiency': 0.3333333333333333, 'acc': 93.3897965988663}
# None
# {'dataset': 'GMSC', 'algorithm': 'SRPMB', 'cores': 4, 'time': 165.42300415039062, 'instances': 150000.0, 'speedup': 3.501489969433166, 'eficiency': 0.25, 'acc': 93.50716905635213}
# None
# {'dataset': 'GMSC', 'algorithm': 'ARFMB', 'cores': 4, 'time': 85.7969970703125, 'instances': 150000.0, 'speedup': 3.229914960396899, 'eficiency': 0.25, 'acc': 93.5245081693898}
# None
# {'dataset': 'GMSC', 'algorithm': 'OBMB', 'cores': 4, 'time': 21.198999404907227, 'instances': 150000.0, 'speedup': 3.1266568961420345, 'eficiency': 0.25, 'acc': 93.35911970656886}
# None
# {'dataset': 'GMSC', 'algorithm': 'OBAdwinMB', 'cores': 4, 'time': 38.57600021362305, 'instances': 150000.0, 'speedup': 2.285099570658673, 'eficiency': 0.25, 'acc': 93.40113371123708}
# None
# {'dataset': 'GMSC', 'algorithm': 'OBASHTMB', 'cores': 4, 'time': 21.218000411987305, 'instances': 150000.0, 'speedup': 3.1239986037827134, 'eficiency': 0.25, 'acc': 93.2750916972324}
# None
# {'dataset': 'GMSC', 'algorithm': 'LBagMB', 'cores': 4, 'time': 74.35199737548828, 'instances': 150000.0, 'speedup': 2.7149101659079378, 'eficiency': 0.25, 'acc': 93.43714571523842}
# None
# {'dataset': 'covtypeNorm', 'algorithm': 'O